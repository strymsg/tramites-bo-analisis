# %% [markdown]
# # Trámites del estado Boliviano (gob.bo) - Desglosando o expandiendo el dataset
#
# El dataset original tramites.json está muy anidado y la idea de este notebook es desglosarlo o expandirlo para facilitar el análisis. Para esto se ha visto que cada trámite puede tener varios:
#
# - Públicos objetivo
# - Procedimientos divididas por modalidades
# - Duración de trámites
# - Costos

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

df = pd.read_csv('../tramites.csv')
df
# Out:
#         id     estado fechaActualización  \
# 0     1005  PUBLICADO         09/07/2025
# 1     1006  PUBLICADO         09/09/2025
# 2     1008  PUBLICADO         04/08/2025
# 3     1009  PUBLICADO         04/08/2025
# 4     1010  PUBLICADO         09/07/2025
# ...    ...        ...                ...
# 1343  2793  PUBLICADO         02/10/2025
# 1344  2819  PUBLICADO         03/10/2025
# 1345  2825  PUBLICADO         03/10/2025
# 1346  2827  PUBLICADO         03/10/2025
# 1347  2843  PUBLICADO         08/10/2025
#
#                                                  nombre  \
# 0                      Registro de Ciudadanos Digitales
# 1                        Registro en Ciudadanía Digital
# 2                       RESOLUCIÓN DE RECURSO DE ALZADA
# 3                      RESOLUCIÓN DE RECURSO JERÁRQUICO
# 4                                  REGISTRO PROVISIONAL
# ...                                                 ...
# 1343  Servicio de denuncia de vulneración de derecho...
# 1344  DETECCION Y CUANTIFICACION DE ORGANISMOS GENÉT...
# 1345  Desinfección ambiental por termoniebla empresa...
# 1346                        VENTA DE PALMITO 800 GRAMOS
# 1347                         Transporte Aereo  de Carga
#
#                                                    slug    sigla  \
# 0                      registro-de-ciudadanos-digitales      NaN
# 1                        registro-en-ciudadania-digital       CD
# 2                       resolucion-de-recurso-de-alzada      NaN
# 3                      resolucion-de-recurso-jerarquico      NaN
# 4                                  registro-provisional      NaN
# ...                                                 ...      ...
# 1343  servicio-de-denuncia-de-vulneracion-de-derecho...      SSP
# 1344  deteccion-y-cuantificacion-de-organismos-genet...      OGM
# 1345  desinfeccion-ambiental-por-termoniebla-empresa...  PBS-007
# 1346                        venta-de-palmito-800-gramos    INBOL
# 1347                          transporte-aereo-de-carga      NaN
#
#                                             descripcion  \
# 0     Se brinda la colaboración personalizada a la c...
# 1     Ciudadanía Digital es la identidad digital de ...
# 2     Es el recurso que tiene el contribuyente o suj...
# 3     Es la impugnación que se presenta en contra de...
# 4     Modalidad de inscripción que tiene por objeto ...
# ...                                                 ...
# 1343  Servicio de denuncia de vulneración de derecho...
# 1344  DETECCION Y CUANTIFICACION DE ORGANISMOS GENÉT...
# 1345  Desinfección de ambientes utilizando un produc...
# 1346            Venta de palmito en lata de 800 gramos.
# 1347  Realizar servicios de Transporte Aereo de carg...
#
#                                              marcoLegal  like  dislike  \
# 0     1. Ley N° 1173 - Ley de abreviación procesal p...     0        0
# 1                      Ley N° 1080 - Ciudadanía Digital     0        0
# 2     La Autoridad de Impugnación Tributaria (AIT), ...     0        0
# 3     La Autoridad de Impugnación Tributaria (AIT), ...     0        0
# 4                                           D.S. 26256      0        0
# ...                                                 ...   ...      ...
# 1343  Reglamento del Sistema de Servicio al Pueblo R...     0        0
# 1344                        Resolución Ministerial 0533     0        0
# 1345    Resolución Administrativa INLASA/UJ/N° 25/2022      0        0
# 1346                           Decreto Supremo N° 29727     0        0
# 1347  Decreto Supremo No. 15091 del 7 de noviembre d...     0        0
#
#       esPresencial  esVirtual resultado  \
# 0                1          0       NaN
# 1                1          1  Registro
# 2                1          0       NaN
# 3                1          0       NaN
# 4                1          0       NaN
# ...            ...        ...       ...
# 1343             1          0       NaN
# 1344             1          0       NaN
# 1345             1          0       NaN
# 1346             1          0       NaN
# 1347             1          0       NaN
#
#                                                 enlaces  \
# 0                                                    []
# 1     [{'nombre': 'Ciudadania Digital', 'url': 'http...
# 2     [{'nombre': 'Doctrina Tributaria', 'url': 'htt...
# 3     [{'nombre': 'Registro Público', 'url': 'https:...
# 4     [{'nombre': 'información', 'url': 'https://www...
# ...                                                 ...
# 1343                                                 []
# 1344                                                 []
# 1345                                                 []
# 1346                                                 []
# 1347                                                 []
#
#                                             modalidades  \
# 0     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 2     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 3     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 4     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# ...                                                 ...
# 1343  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1344  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1345  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1346  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1347  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
#
#                                             ubicaciones  \
# 0     [{'nombre': 'Tribunal Supremo de Justicia', 't...
# 1     [{'nombre': 'AGETIC', 'tipo': 'Oficina central...
# 2     [{'nombre': 'Autoridad Regional de Impugnación...
# 3     [{'nombre': 'AUTORIDAD GENERAL DE IMPUGNACIÓN ...
# 4     [{'nombre': 'REGISTRO INTERNACIONAL BOLIVIANO ...
# ...                                                 ...
# 1343  [{'nombre': 'Oficina Nacional', 'tipo': 'Ofici...
# 1344  [{'nombre': 'INLASA', 'tipo': 'Oficina central...
# 1345  [{'nombre': 'INLASA', 'tipo': 'Oficina central...
# 1346  [{'nombre': 'OFICINA CENTRAL', 'tipo': 'Oficin...
# 1347  [{'nombre': 'TRANSPORTES AÉREOS BOLIVIANOS GER...
#
#                                          entidad.nombre entidad.sigla  \
# 0                          Tribunal Supremo de Justicia           TSJ
# 1     Agencia de Gobierno Electrónico y Tecnologías ...        AGETIC
# 2                   Autoridad de Impugnación Tributaria           AIT
# 3                   Autoridad de Impugnación Tributaria           AIT
# 4            Registro Internacional Boliviano De Buques          RIBB
# ...                                                 ...           ...
# 1343                              Defensoria del Pueblo            DP
# 1344         Instituto Nacional De Laboratorio De Salud        INLASA
# 1345         Instituto Nacional De Laboratorio De Salud        INLASA
# 1346                                    Insumos Bolivia      IN - BOL
# 1347                      Transportes Aéreos Bolivianos           TAB
#
#                                            entidad.slug  \
# 0                          tribunal-supremo-de-justicia
# 1     agencia-de-gobierno-electronico-y-tecnologias-...
# 2                   autoridad-de-impugnacion-tributaria
# 3                   autoridad-de-impugnacion-tributaria
# 4            registro-internacional-boliviano-de-buques
# ...                                                 ...
# 1343                              defensoria-del-pueblo
# 1344         instituto-nacional-de-laboratorio-de-salud
# 1345         instituto-nacional-de-laboratorio-de-salud
# 1346                                    insumos-bolivia
# 1347                      transportes-aereos-bolivianos
#
#                                            entidad.logo  \
# 0     https://www.gob.bo/ws/api/archivos/9989169e-b9...
# 1     https://www.gob.bo/ws/api/archivos/b48eee08-24...
# 2     https://www.gob.bo/ws/api/archivos/71c7476f-3c...
# 3     https://www.gob.bo/ws/api/archivos/71c7476f-3c...
# 4     https://www.gob.bo/ws/api/archivos/8baef1e9-22...
# ...                                                 ...
# 1343  https://www.gob.bo/ws/api/archivos/ae641fb1-53...
# 1344  https://www.gob.bo/ws/api/archivos/f610506f-61...
# 1345  https://www.gob.bo/ws/api/archivos/f610506f-61...
# 1346  https://www.gob.bo/ws/api/archivos/bf78cfea-24...
# 1347  https://www.gob.bo/ws/api/archivos/b097f8a8-86...
#
#                                     entidad.descripcion  \
# 0     El Tribunal Supremo de Justicia (TSJ) es la má...
# 1     La AGETIC está acá para desarrollar tecnología...
# 2     La AIT tiene como objeto conocer y resolver lo...
# 3     La AIT tiene como objeto conocer y resolver lo...
# 4     El Registro Internacional Boliviano de Buques ...
# ...                                                 ...
# 1343  La Defensoría del Pueblo es una institución qu...
# 1344  El  Instituto  Nacional  de  Laboratorios  de ...
# 1345  El  Instituto  Nacional  de  Laboratorios  de ...
# 1346  Insumos Bolivia (INBOL) es una Entidad Pública...
# 1347  Transportes Aéreos Bolivianos (TAB) es la aero...
#
#                      entidad.urlSitioWeb entidad.telefonoContacto  \
# 0                         https://tsj.bo                 46453200
# 1              https://www.agetic.gob.bo            (591) 2184026
# 2                https://www.ait.gob.bo/        2412789 – 2412048
# 3                https://www.ait.gob.bo/        2412789 – 2412048
# 4                https://www.ribb.gob.bo                  2434415
# ...                                  ...                      ...
# 1343           https://defensoria.gob.bo                  2113600
# 1344           https://www.inlasa.gob.bo        2226048 - 2226670
# 1345           https://www.inlasa.gob.bo        2226048 - 2226670
# 1346  https://www.insumosbolivia.gob.bo/                  2408191
# 1347             https://tab-bolivia.com            0-800-100-110
#
#       entidad.correoElectronicoContacto  \
# 0      soporteogp@organojudicial.gob.bo
# 1                 soporte@agetic.gob.bo
# 2                    infoait@ait.gob.bo
# 3                    infoait@ait.gob.bo
# 4              ribb_bolivia@ribb.gob.bo
# ...                                 ...
# 1343             f.olivares.c@gmail.com
# 1344       inlasalapazbolivia@gmail.com
# 1345       inlasalapazbolivia@gmail.com
# 1346         info@insumosbolivia.gob.bo
# 1347  atencionalcliente@tab-bolivia.com
#
#                                           palabrasClave  \
# 0                                                   NaN
# 1     digital,ciudadania,registro,pre registro,const...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1343                                denuncia,defensoria
# 1344                                                NaN
# 1345                                                NaN
# 1346                                      venta,palmito
# 1347  Transporte de carga,transporte,aerea,logistica...
#
#                     categorias       eventosVida documentos  herramientas
# 0                     Justicia               NaN        NaN           NaN
# 1     Seguridad,Identificación            Empleo   Registro           NaN
# 2           Justicia,Impuestos               NaN        NaN           NaN
# 3           Justicia,Impuestos               NaN        NaN           NaN
# 4                     Empresas               NaN        NaN           NaN
# ...                        ...               ...        ...           ...
# 1343                  Justicia               NaN        NaN           NaN
# 1344      Medio ambiente,Salud  Cuidado de salud        NaN           NaN
# 1345                     Salud               NaN        NaN           NaN
# 1346                  Empresas               NaN        NaN           NaN
# 1347                Transporte               NaN        NaN           NaN
#
# [1348 rows x 29 columns]

# %% [markdown]
# ## Dicionarios, listas, tuplas -- guradar como JSON
#
# En este dataset muchas columnas como listas u objetos json, al ser leídas se guardan como diccionarios python representados en cadenas. Para estandarizar el dataset para que sea usable en otros lenguages más fácilmente todas las columnas con listas, tuplas o diccionarios se guardarán como cadenas JSON.

# %%
import json
import ast

df['enlaces'] = df['enlaces'].map(lambda x: json.dumps(ast.literal_eval(x), ensure_ascii=False))
df['ubicaciones'] = df['ubicaciones'].map(lambda x: json.dumps(ast.literal_eval(x), ensure_ascii=False))
df.sample(2)
# Out:
#        id     estado fechaActualización  \
# 742  1909  PUBLICADO         10/07/2025
# 645  1739  PUBLICADO         10/07/2025
#
#                                                 nombre  \
# 742       Apertura de Módulos Tecnológicos Productivos
# 645  Impresión de Historial Académico de Educación ...
#
#                                                   slug      sigla  \
# 742       apertura-de-modulos-tecnologicos-productivos    Regular
# 645  impresion-de-historial-academico-de-educacion-...  UAA - SIE
#
#                                            descripcion  \
# 742       Apertura de Módulos Tecnológicos Productivos
# 645  Impresión de Historial Académico de Educación ...
#
#                                             marcoLegal  like  dislike  \
# 742  Resolución Administrativa Departamental DDE-BE...     0        0
# 645  Resolución Administrativa Departamental DDE-BE...     0        0
#
#      esPresencial  esVirtual              resultado enlaces  \
# 742             1          0  Registro y constancia      []
# 645             1          0             Constancia      []
#
#                                            modalidades  \
# 742  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 645  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
#
#                                            ubicaciones  \
# 742  [{"nombre": "DIRECCION DEPARTAMENTAL DEL BENI"...
# 645  [{"nombre": "DIRECCION DEPARTAMENTAL DEL BENI"...
#
#                       entidad.nombre entidad.sigla  \
# 742  Direc. Dptal. de Educación Beni       DDE-BEN
# 645  Direc. Dptal. de Educación Beni       DDE-BEN
#
#                       entidad.slug  \
# 742  direc-dptal-de-educacion-beni
# 645  direc-dptal-de-educacion-beni
#
#                                           entidad.logo  \
# 742  https://www.gob.bo/ws/api/archivos/7197f9e0-96...
# 645  https://www.gob.bo/ws/api/archivos/7197f9e0-96...
#
#                                    entidad.descripcion  \
# 742  La Dirección Departamental de Educación del Be...
# 645  La Dirección Departamental de Educación del Be...
#
#              entidad.urlSitioWeb entidad.telefonoContacto  \
# 742  https://www.ddebeni.edu.bo/                346-22226
# 645  https://www.ddebeni.edu.bo/                346-22226
#
#     entidad.correoElectronicoContacto                  palabrasClave  \
# 742             ddebeni20221@gmai.com  apertura,modulos,tecnologicos
# 645             ddebeni20221@gmai.com  historial,academico,impresion
#
#     categorias   eventosVida  \
# 742  Educación  Mi educación
# 645  Educación  Mi educación
#
#                                             documentos  herramientas
# 742  Resolución Administrativa - Apertura de Módulo...           NaN
# 645                                Historial Academico           NaN

# %% [markdown]
# ## Desglosando modalidades

# %%
import json
import ast

ast.literal_eval(df.iloc[0]['modalidades'])
# Out:
# [{'tipo': 'PRESENCIAL',
#   'url': None,
#   'urlSeguimiento': None,
#   'publico': [{'tieneCosto': False,
#     'duracion': '5',
#     'unidadMedidaDuracion': 'Minuto(s)',
#     'procedimiento': '<ol><li><p>Realizar el pre registro</p></li><li><p>Acudir a cualquier Oficina Gestora de Procesos a nivel nacional para confirmar el registro.</p></li></ol>',
#     'requisitoNoParametrizado': None,
#     'nombrePublicoObjetivo': 'Persona Natural',
#     'estadoPublicoObjetivo': 'ACTIVO',
#     'emisionFactura': '',
#     'formaCobro': [],
#     'horario': [{'dia': 'Lunes',
#       'continuo': True,
#       'inicioManiana': '08:00',
#       'finManiana': '16:30',
#       'inicioTarde': None,
#       'finTarde': None},
#      {'dia': 'Martes',
#       'continuo': True,
#       'inicioManiana': '08:00',
#       'finManiana': '16:30',
#       'inicioTarde': None,
#       'finTarde': None},
#      {'dia': 'Miércoles',
#       'continuo': True,
#       'inicioManiana': '08:00',
#       'finManiana': '16:30',
#       'inicioTarde': None,
#       'finTarde': None},
#      {'dia': 'Jueves',
#       'continuo': True,
#       'inicioManiana': '08:00',
#       'finManiana': '16:30',
#       'inicioTarde': None,
#       'finTarde': None},
#      {'dia': 'Viernes',
#       'continuo': True,
#       'inicioManiana': '08:00',
#       'finManiana': '16:30',
#       'inicioTarde': None,
#       'finTarde': None}],
#     'depositoBancario': [],
#     'costos': [],
#     'requisitos': [{'comentario': None,
#       'nombre': 'Correo electrónico',
#       'entidad': None,
#       'entidadActiva': True},
#      {'comentario': None,
#       'nombre': 'Número de teléfono',
#       'entidad': None,
#       'entidadActiva': True},
#      {'comentario': 'Vigente',
#       'nombre': 'Cédula de Identidad',
#       'entidad': None,
#       'entidadActiva': True}]}]}]

# %%
def desglosar_segun_tipo_modalidad(df):
    new_df = pd.DataFrame(columns=df.columns.to_list() + ['modalidad.tipo', 'modalidad'])
    print(new_df.columns)
    _df = df.copy()
    for i in _df.index.to_list():
        data = _df.iloc[i].to_dict()
        #print(data)
        modalidades = ast.literal_eval(data['modalidades'])
        for modalidad in modalidades:
            data['modalidad.tipo'] = modalidad['tipo']
            data['modalidad'] = modalidad
            print(f"Agregando id: {data['id']} -> tipo: {data['modalidad.tipo']}")
            new_df.loc[len(new_df)] = data
    del new_df['modalidades']
    return new_df

new_df = desglosar_segun_tipo_modalidad(df)
print(new_df.shape)
new_df.sample(3)

# %% [markdown]
# ## Dividiendo en procedimientos (una fila para cada público objetivo)
#
# Al parecer hay también diferentes públicos objetivo por cada trámite. Para facilitar el análisis conviene dividir cada trámite también por público objetivo, donde cada uno de estos tiene su propio **procedimiento**. Entonces un trámite puede tener varias modalidades y cada modalidad varios procedimientos.

# %%
def desglosar_por_procedimientos(df):
    new_df = pd.DataFrame(
        columns=df.columns.to_list() + 
        [
         'tramite.url', 'tramite.urlSeguimiento',
         'tramite.tieneCosto', 'tramite.duracion', 'tramite.unidadMedidaDuracion', 'tramite.procedimiento',
         'tramite.publicoObjetivo', 'tramite.requisitoNoParametrizado', 'tramite.estado',
         'tramite.emisionFactura','tramite.formaCobro','tramite.horarios','tramite.depositoBancario',
         'tramite.costos', 'tramite.requisitos'
         ])
    print(new_df.columns)
    _df = df.copy()
    for i in _df.index.to_list():
        data = _df.iloc[i]['modalidad']
        for procedimiento in data['publico']:
            proc = _df.iloc[i].copy()
            proc['tramite.url'] = data['url']
            proc['tramite.urlSeguimiento'] = data['urlSeguimiento']
            proc['tramite.tieneCosto'] = 1 if procedimiento['tieneCosto'] == True else 0
            proc['tramite.duracion'] = procedimiento['duracion']
            proc['tramite.unidadMedidaDuracion'] = procedimiento['unidadMedidaDuracion']
            proc['tramite.procedimiento'] = procedimiento['procedimiento']
            proc['tramite.publicoObjetivo'] = procedimiento['nombrePublicoObjetivo']
            proc['tramite.requisitoNoParametrizado'] = procedimiento['requisitoNoParametrizado']
            proc['tramite.estado'] = procedimiento['estadoPublicoObjetivo']
            proc['tramite.emisionFactura'] = procedimiento['emisionFactura']
            proc['tramite.formaCobro'] = procedimiento['formaCobro']
            proc['tramite.horarios'] = procedimiento['horario']
            proc['tramite.depositoBancario'] = procedimiento['depositoBancario']
            proc['tramite.costos'] = procedimiento['costos']
            proc['tramite.requisitos'] = procedimiento['requisitos']
            del proc['modalidad']
            print(f"Agregando id: {_df.iloc[i]['id']} --> {proc['tramite.publicoObjetivo']}")
            new_df.loc[len(new_df)] = proc
    del new_df['modalidad']
    return new_df

new_df = desglosar_por_procedimientos(new_df)
print(new_df.shape)
new_df.sample(3)

# %%
def obtener_duracion(num_duracion, unidad_medida, unidad_destino='min'):
    minutos = 0
    try:
        num_duracion = int(num_duracion)
    except Exception as E:
        return np.nan
    
    if unidad_medida == 'Día(s)':
        minutos = num_duracion*1440
    elif unidad_medida == 'Horas(s)':
        minutos = num_duracion*60
    elif unidad_medida == 'Mes(es)':
        minutos = num_duracion*43200
    elif unidad_medida == 'Año(s)':
        minutos = num_duracion*15768000
    elif unidad_medida == 'Semana(s)':
        minutos = num_duracion*10080

    if unidad_destino == 'min':
        return int(minutos)
    elif unidad_destino == 'hora':
        return int(minutos/60)
    elif unidad_destino == 'dia':
        return int(minutos/1440)

new_df['tramite.duracionMin'] = new_df.apply(
    lambda x: obtener_duracion(x['tramite.duracion'], x['tramite.unidadMedidaDuracion'], 'min'), axis=1)
new_df['tramite.duracionHora'] = new_df.apply(
    lambda x: obtener_duracion(x['tramite.duracion'], x['tramite.unidadMedidaDuracion'], 'hora'), axis=1)
new_df['tramite.duracionDia'] = new_df.apply(
    lambda x: obtener_duracion(x['tramite.duracion'], x['tramite.unidadMedidaDuracion'], 'dia'), axis=1)

new_df.sample(5)[['tramite.duracion', 'tramite.duracionMin', 'tramite.duracionHora', 'tramite.duracionDia',
                       'tramite.unidadMedidaDuracion', 'tramite.unidadMedidaDuracion',
                      'modalidad.tipo', 'estado']]

# %% [markdown]
# ## Desglosando costos de tramites

# %%
s = new_df.groupby('tramite.tieneCosto').count()['id']
s.index = ['Sin costo', 'Tiene costo']
s
# Out:
# Sin costo       518
# Tiene costo    1026
# Name: id, dtype: int64

# %%
def desglosar_segun_costos(df):
    _new_df = pd.DataFrame(columns=df.columns.to_list() + [
        'costo.conceptoPago', 'costo.monto', 'costo.moneda'])
    print(_new_df.columns)
    _df = df.copy()
    for i in _df.index.to_list():
        data = _df.iloc[i].to_dict()
        #print(data)
        costos = data['tramite.costos']
        for costo in costos:
            data['costo.conceptoPago'] = costo['conceptoPago']
            data['costo.monto'] = float(costo['costo'])
            data['costo.moneda'] = costo['moneda']
            #print('>>>>', data)
            print(f"Agregando id: {data['id']} -> {data['costo.monto']}: {data['costo.moneda']}")
            _new_df.loc[len(_new_df)] = data
    del _new_df['tramite.costos']
    return _new_df

new_df = desglosar_segun_costos(new_df)
print(new_df.shape)
new_df.sample(3)

# %% [markdown]
# ## Requisitos y procedimientos
#
# Reto: Averiguar cúantos trámites y procedimientos requieren el Carnet de Identidad (C.I) como requisito.

# %%
def desglosar_segun_costos(df):
    _new_df = pd.DataFrame(columns=df.columns.to_list() + [
        'requisito.comentario', 'requisito.nombre', 'requisito.entidad', 'requisito.entidadActiva'])
    print(_new_df.columns)
    _df = df.copy()
    for i in _df.index.to_list():
        data = _df.iloc[i].to_dict()
        #print(data)
        requisitos = data['tramite.requisitos']
        for requisito in requisitos:
            data['requisito.comentario'] = requisito['comentario']
            data['requisito.nombre'] = requisito['nombre']
            data['requisito.entidad'] = requisito['entidad']
            data['requisito.entidadActiva'] = 1 if requisito['entidadActiva'] == True else 0
            #print('>>>>', data)
            print(f"Agregando id: {data['id']} -> {data['requisito.nombre']}")
            _new_df.loc[len(_new_df)] = data
    del _new_df['tramite.requisitos']
    return _new_df

new_df = desglosar_segun_costos(new_df)
print(new_df.shape)
new_df.sample(3)

# %% [markdown]
# ## Guardando como csv
#
# Solo quedaría pendiente guardar los campos que son diccionarios como cadenas JSON.

# %%
df_desglosado = pd.DataFrame(columns=new_df.columns.to_list())

for column in new_df.columns:
    print(column, new_df[column].dtype)
    if new_df[column].dtype != 'object':
        df_desglosado[column] = new_df[column]
    else:
        # comprobando si la columna tiene objetos que pueden representarse como json
        contains_dict = new_df[column].map(lambda x: isinstance(x, dict) | isinstance(x, list) | isinstance(x, tuple))
        #print(f'{column}:\n {True in contains_dict.unique()}')
        if True in contains_dict.unique(): # existe al menos un valor que es diccionario
            print(f'Existe dict o array: {contains_dict.unique()}')
            try:
                df_desglosado[column] = new_df[column].map(lambda x: json.dumps(x, ensure_ascii=False))
            except:
                print(f'No se pudo convertir diccionario a json: {new_df[column]}')
                df_desglosado[column] = new_df[column]
        else:
            #print(f'No existe dict: {contains_dict.unique()}')
            df_desglosado[column] = new_df[column]

print(df_desglosado.shape, df_desglosado.columns)
df_desglosado.sample(3)
# Out:
# id int64
# estado object
# fechaActualización object
# nombre object
# slug object
# sigla object
# descripcion object
# marcoLegal object
# like int64
# dislike int64
# esPresencial int64
# esVirtual int64
# resultado object
# enlaces object
# ubicaciones object
# entidad.nombre object
# entidad.sigla object
# entidad.slug object
# entidad.logo object
# entidad.descripcion object
# entidad.urlSitioWeb object
# entidad.telefonoContacto object
# entidad.correoElectronicoContacto object
# palabrasClave object
# categorias object
# eventosVida object
# documentos object
# herramientas float64
# modalidad.tipo object
# tramite.url object
# tramite.urlSeguimiento object
# tramite.tieneCosto int64
# tramite.duracion object
# tramite.unidadMedidaDuracion object
# tramite.procedimiento object
# tramite.publicoObjetivo object
# tramite.requisitoNoParametrizado object
# tramite.estado object
# tramite.emisionFactura object
# tramite.formaCobro object
# Existe dict o array: [ True]
# tramite.horarios object
# Existe dict o array: [ True]
# tramite.depositoBancario object
# Existe dict o array: [ True]
# tramite.duracionMin float64
# tramite.duracionHora float64
# tramite.duracionDia float64
# costo.conceptoPago object
# costo.monto float64
# costo.moneda object
# requisito.comentario object
# requisito.nombre object
# requisito.entidad object
# Existe dict o array: [False  True]
# requisito.entidadActiva int64
# (5991, 52) Index(['id', 'estado', 'fechaActualización', 'nombre', 'slug', 'sigla',
#        'descripcion', 'marcoLegal', 'like', 'dislike', 'esPresencial',
#        'esVirtual', 'resultado', 'enlaces', 'ubicaciones', 'entidad.nombre',
#        'entidad.sigla', 'entidad.slug', 'entidad.logo', 'entidad.descripcion',
#        'entidad.urlSitioWeb', 'entidad.telefonoContacto',
#        'entidad.correoElectronicoContacto', 'palabrasClave', 'categorias',
#        'eventosVida', 'documentos', 'herramientas', 'modalidad.tipo',
#        'tramite.url', 'tramite.urlSeguimiento', 'tramite.tieneCosto',
#        'tramite.duracion', 'tramite.unidadMedidaDuracion',
#        'tramite.procedimiento', 'tramite.publicoObjetivo',
#        'tramite.requisitoNoParametrizado', 'tramite.estado',
#        'tramite.emisionFactura', 'tramite.formaCobro', 'tramite.horarios',
#        'tramite.depositoBancario', 'tramite.duracionMin',
#        'tramite.duracionHora', 'tramite.duracionDia', 'costo.conceptoPago',
#        'costo.monto', 'costo.moneda', 'requisito.comentario',
#        'requisito.nombre', 'requisito.entidad', 'requisito.entidadActiva'],
#       dtype='object')
#         id     estado fechaActualización  \
# 1538  1535  PUBLICADO         10/07/2025
# 2694  1761  PUBLICADO         10/07/2025
# 3435  1979  PUBLICADO         09/07/2025
#
#                                                  nombre  \
# 1538  LEGALIZACIÓN DE FOTOCOPIA DE DIPLOMA DE BACHILLER
# 2694  Actualización de Número de Identificación de A...
# 3435  Autorización de Publicación Oficial de Textos ...
#
#                                                    slug sigla  \
# 1538  legalizacion-de-fotocopia-de-diploma-de-bachiller   NaN
# 2694  actualizacion-de-numero-de-identificacion-de-a...   NaN
# 3435  autorizacion-de-publicacion-oficial-de-textos-...   NaN
#
#                                             descripcion  \
# 1538  Trámite dirigido a Estudiantes, para postulant...
# 2694  Proceso de Actualización de Número de Identifi...
# 3435  La Gaceta Oficial de Bolivia autoriza la publi...
#
#                                              marcoLegal  like  dislike  \
# 1538                       Verificación de Originalidad     0        0
# 2694  Ley 535 (Ministerio de Mineria y Metalurgia), ...     0        0
# 3435  Resolución Ministerial N° 039/11 de 11 de marz...     0        0
#
#       esPresencial  esVirtual   resultado  \
# 1538             1          0  Constancia
# 2694             1          0    Registro
# 3435             1          0         NaN
#
#                                                 enlaces  \
# 1538  [{"nombre": "Archivos", "url": "https://www.ar...
# 2694  [{"nombre": "Actualización NIAR", "url": "http...
# 3435                                                 []
#
#                                             ubicaciones  \
# 1538  [{"nombre": "Archivos", "tipo": "Oficina centr...
# 2694  [{"nombre": "OFICINA CENTRAL DEL SENARECOM", "...
# 3435  [{"nombre": "Gaceta Oficial de Bolivia", "tipo...
#
#                                          entidad.nombre entidad.sigla  \
# 1538                     Universidad Mayor de San Simón          UMSS
# 2694  Serv. Nal. de Reg. y Control de la Comer. de M...     SENARECOM
# 3435                             Gaceta Oficial Bolivia        GACETA
#
#                                            entidad.slug  \
# 1538                     universidad-mayor-de-san-simon
# 2694  serv-nal-de-reg-y-control-de-la-comer-de-miner...
# 3435                             gaceta-oficial-bolivia
#
#                                            entidad.logo  \
# 1538  https://www.gob.bo/ws/api/archivos/64632538-41...
# 2694  https://www.gob.bo/ws/api/archivos/7bcbc6ca-09...
# 3435  https://www.gob.bo/ws/api/archivos/bff8413e-a1...
#
#                                     entidad.descripcion  \
# 1538  La Universidad Mayor de San Simón (UMSS), fund...
# 2694  Entidad encargada de realizar el registro y co...
# 3435  Unidad Desconcentrada del Ministerio de la Pre...
#
#                             entidad.urlSitioWeb entidad.telefonoContacto  \
# 1538                   https://www.umss.edu.bo/                      NaN
# 2694              https://www.senarecom.gob.bo/          (591-2) 2154523
# 3435  https://www.gacetaoficialdebolivia.gob.bo                  2147937
#
#            entidad.correoElectronicoContacto palabrasClave  \
# 1538                        soporte@umss.edu           NaN
# 2694               contacto@senarecom.gob.bo           NaN
# 3435  info_gob@gacetaoficialdebolivia.gob.bo           NaN
#
#                                              categorias eventosVida  \
# 1538                                          Educación         NaN
# 2694                                           Empresas         NaN
# 3435  Educación,Justicia,Medio ambiente,Seguridad,Mi...         NaN
#
#                                              documentos  herramientas  \
# 1538                Sello de Originalidad del Documento           NaN
# 2694  Certificado del Número de Identificación de Ag...           NaN
# 3435                                                NaN           NaN
#
#      modalidad.tipo tramite.url tramite.urlSeguimiento  tramite.tieneCosto  \
# 1538     PRESENCIAL        None                   None                   1
# 2694     PRESENCIAL        None                   None                   1
# 3435     PRESENCIAL        None                   None                   1
#
#      tramite.duracion tramite.unidadMedidaDuracion  \
# 1538               24                     Horas(s)
# 2694             None
# 3435             None
#
#                                   tramite.procedimiento  \
# 1538  <p><strong>¿Qué necesito?</strong></p><ul><li>...
# 2694  <ul><li><p>El interesado con los documentos co...
# 3435  <p><strong>Resolución Ministerial N° 039/11</s...
#
#        tramite.publicoObjetivo tramite.requisitoNoParametrizado  \
# 1538  Personas Aseguradas SSUE                             None
# 2694   Actor Productivo Minero                             None
# 3435        Entidades Públicas                             None
#
#      tramite.estado         tramite.emisionFactura  \
# 1538         ACTIVO               No emite factura
# 2694         ACTIVO  Sistema propio de facturación
# 3435         ACTIVO               No emite factura
#
#                                      tramite.formaCobro  \
# 1538                 ["Pago en efectivo en ventanilla"]
# 2694  ["Pago en banco(presenta boleta de depósito)",...
# 3435     ["Pago en banco(presenta boleta de depósito)"]
#
#                                        tramite.horarios  \
# 1538  [{"dia": "Lunes", "continuo": false, "inicioMa...
# 2694  [{"dia": "Lunes", "continuo": true, "inicioMan...
# 3435  [{"dia": "Lunes", "continuo": true, "inicioMan...
#
#                                tramite.depositoBancario  tramite.duracionMin  \
# 1538                                                 []               1440.0
# 2694  [{"nombre": "Banco Unión S.A.", "nroCuenta": "...                  NaN
# 3435                                                 []                  NaN
#
#       tramite.duracionHora  tramite.duracionDia  \
# 1538                  24.0                  1.0
# 2694                   NaN                  NaN
# 3435                   NaN                  NaN
#
#                                      costo.conceptoPago  costo.monto  \
# 1538  Valorado para Fotocopia Legalizada de Diploma ...        100.0
# 2694                       Actualización y/o Renovación        300.0
# 3435                               De 201 a 300 Páginas        800.0
#
#      costo.moneda                               requisito.comentario  \
# 1538           Bs                                               None
# 2694           Bs  Comprobante de depósito bancario\noriginal y f...
# 3435           Bs  Dirigida al Director de la Gaceta Oficial - Ab...
#
#                  requisito.nombre requisito.entidad  requisito.entidadActiva
# 1538         Diploma de Bachiller              null                        1
# 2694  Boleta de Depósito Bancario              null                        1
# 3435      Carta/Nota de Solicitud              null                        1

# %%
df_desglosado.to_csv('../tramites_desglosados.csv', index=False)
