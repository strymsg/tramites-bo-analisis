# %% [markdown]
# # Trámites del estado Boliviano (gob.bo) - Desglosando o expandiendo el dataset
#
# El dataset original tramites.json está muy anidado y la idea de este notebook es desglosarlo o expandirlo para facilitar el análisis. Para esto se ha visto que cada trámite puede tener varios:
#
# - Públicos objetivo
# - Procedimientos divididas por modalidades
# - Duración de trámites
# - Costos

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

df = pd.read_csv('../tramites.csv')
df
# Out:
#         id     estado fechaActualización  \
# 0     1005  PUBLICADO         09/07/2025
# 1     1006  PUBLICADO         09/09/2025
# 2     1008  PUBLICADO         04/08/2025
# 3     1009  PUBLICADO         04/08/2025
# 4     1010  PUBLICADO         09/07/2025
# ...    ...        ...                ...
# 1343  2793  PUBLICADO         02/10/2025
# 1344  2819  PUBLICADO         03/10/2025
# 1345  2825  PUBLICADO         03/10/2025
# 1346  2827  PUBLICADO         03/10/2025
# 1347  2843  PUBLICADO         08/10/2025
#
#                                                  nombre  \
# 0                      Registro de Ciudadanos Digitales
# 1                        Registro en Ciudadanía Digital
# 2                       RESOLUCIÓN DE RECURSO DE ALZADA
# 3                      RESOLUCIÓN DE RECURSO JERÁRQUICO
# 4                                  REGISTRO PROVISIONAL
# ...                                                 ...
# 1343  Servicio de denuncia de vulneración de derecho...
# 1344  DETECCION Y CUANTIFICACION DE ORGANISMOS GENÉT...
# 1345  Desinfección ambiental por termoniebla empresa...
# 1346                        VENTA DE PALMITO 800 GRAMOS
# 1347                         Transporte Aereo  de Carga
#
#                                                    slug    sigla  \
# 0                      registro-de-ciudadanos-digitales      NaN
# 1                        registro-en-ciudadania-digital       CD
# 2                       resolucion-de-recurso-de-alzada      NaN
# 3                      resolucion-de-recurso-jerarquico      NaN
# 4                                  registro-provisional      NaN
# ...                                                 ...      ...
# 1343  servicio-de-denuncia-de-vulneracion-de-derecho...      SSP
# 1344  deteccion-y-cuantificacion-de-organismos-genet...      OGM
# 1345  desinfeccion-ambiental-por-termoniebla-empresa...  PBS-007
# 1346                        venta-de-palmito-800-gramos    INBOL
# 1347                          transporte-aereo-de-carga      NaN
#
#                                             descripcion  \
# 0     Se brinda la colaboración personalizada a la c...
# 1     Ciudadanía Digital es la identidad digital de ...
# 2     Es el recurso que tiene el contribuyente o suj...
# 3     Es la impugnación que se presenta en contra de...
# 4     Modalidad de inscripción que tiene por objeto ...
# ...                                                 ...
# 1343  Servicio de denuncia de vulneración de derecho...
# 1344  DETECCION Y CUANTIFICACION DE ORGANISMOS GENÉT...
# 1345  Desinfección de ambientes utilizando un produc...
# 1346            Venta de palmito en lata de 800 gramos.
# 1347  Realizar servicios de Transporte Aereo de carg...
#
#                                              marcoLegal  like  dislike  \
# 0     1. Ley N° 1173 - Ley de abreviación procesal p...     0        0
# 1                      Ley N° 1080 - Ciudadanía Digital     0        0
# 2     La Autoridad de Impugnación Tributaria (AIT), ...     0        0
# 3     La Autoridad de Impugnación Tributaria (AIT), ...     0        0
# 4                                           D.S. 26256      0        0
# ...                                                 ...   ...      ...
# 1343  Reglamento del Sistema de Servicio al Pueblo R...     0        0
# 1344                        Resolución Ministerial 0533     0        0
# 1345    Resolución Administrativa INLASA/UJ/N° 25/2022      0        0
# 1346                           Decreto Supremo N° 29727     0        0
# 1347  Decreto Supremo No. 15091 del 7 de noviembre d...     0        0
#
#       esPresencial  esVirtual resultado  \
# 0                1          0       NaN
# 1                1          1  Registro
# 2                1          0       NaN
# 3                1          0       NaN
# 4                1          0       NaN
# ...            ...        ...       ...
# 1343             1          0       NaN
# 1344             1          0       NaN
# 1345             1          0       NaN
# 1346             1          0       NaN
# 1347             1          0       NaN
#
#                                                 enlaces  \
# 0                                                    []
# 1     [{'nombre': 'Ciudadania Digital', 'url': 'http...
# 2     [{'nombre': 'Doctrina Tributaria', 'url': 'htt...
# 3     [{'nombre': 'Registro Público', 'url': 'https:...
# 4     [{'nombre': 'información', 'url': 'https://www...
# ...                                                 ...
# 1343                                                 []
# 1344                                                 []
# 1345                                                 []
# 1346                                                 []
# 1347                                                 []
#
#                                             modalidades  \
# 0     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 2     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 3     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 4     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# ...                                                 ...
# 1343  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1344  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1345  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1346  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1347  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
#
#                                             ubicaciones  \
# 0     [{'nombre': 'Tribunal Supremo de Justicia', 't...
# 1     [{'nombre': 'AGETIC', 'tipo': 'Oficina central...
# 2     [{'nombre': 'Autoridad Regional de Impugnación...
# 3     [{'nombre': 'AUTORIDAD GENERAL DE IMPUGNACIÓN ...
# 4     [{'nombre': 'REGISTRO INTERNACIONAL BOLIVIANO ...
# ...                                                 ...
# 1343  [{'nombre': 'Oficina Nacional', 'tipo': 'Ofici...
# 1344  [{'nombre': 'INLASA', 'tipo': 'Oficina central...
# 1345  [{'nombre': 'INLASA', 'tipo': 'Oficina central...
# 1346  [{'nombre': 'OFICINA CENTRAL', 'tipo': 'Oficin...
# 1347  [{'nombre': 'TRANSPORTES AÉREOS BOLIVIANOS GER...
#
#                                          entidad.nombre entidad.sigla  \
# 0                          Tribunal Supremo de Justicia           TSJ
# 1     Agencia de Gobierno Electrónico y Tecnologías ...        AGETIC
# 2                   Autoridad de Impugnación Tributaria           AIT
# 3                   Autoridad de Impugnación Tributaria           AIT
# 4            Registro Internacional Boliviano De Buques          RIBB
# ...                                                 ...           ...
# 1343                              Defensoria del Pueblo            DP
# 1344         Instituto Nacional De Laboratorio De Salud        INLASA
# 1345         Instituto Nacional De Laboratorio De Salud        INLASA
# 1346                                    Insumos Bolivia      IN - BOL
# 1347                      Transportes Aéreos Bolivianos           TAB
#
#                                            entidad.slug  \
# 0                          tribunal-supremo-de-justicia
# 1     agencia-de-gobierno-electronico-y-tecnologias-...
# 2                   autoridad-de-impugnacion-tributaria
# 3                   autoridad-de-impugnacion-tributaria
# 4            registro-internacional-boliviano-de-buques
# ...                                                 ...
# 1343                              defensoria-del-pueblo
# 1344         instituto-nacional-de-laboratorio-de-salud
# 1345         instituto-nacional-de-laboratorio-de-salud
# 1346                                    insumos-bolivia
# 1347                      transportes-aereos-bolivianos
#
#                                            entidad.logo  \
# 0     https://www.gob.bo/ws/api/archivos/9989169e-b9...
# 1     https://www.gob.bo/ws/api/archivos/b48eee08-24...
# 2     https://www.gob.bo/ws/api/archivos/71c7476f-3c...
# 3     https://www.gob.bo/ws/api/archivos/71c7476f-3c...
# 4     https://www.gob.bo/ws/api/archivos/8baef1e9-22...
# ...                                                 ...
# 1343  https://www.gob.bo/ws/api/archivos/ae641fb1-53...
# 1344  https://www.gob.bo/ws/api/archivos/f610506f-61...
# 1345  https://www.gob.bo/ws/api/archivos/f610506f-61...
# 1346  https://www.gob.bo/ws/api/archivos/bf78cfea-24...
# 1347  https://www.gob.bo/ws/api/archivos/b097f8a8-86...
#
#                                     entidad.descripcion  \
# 0     El Tribunal Supremo de Justicia (TSJ) es la má...
# 1     La AGETIC está acá para desarrollar tecnología...
# 2     La AIT tiene como objeto conocer y resolver lo...
# 3     La AIT tiene como objeto conocer y resolver lo...
# 4     El Registro Internacional Boliviano de Buques ...
# ...                                                 ...
# 1343  La Defensoría del Pueblo es una institución qu...
# 1344  El  Instituto  Nacional  de  Laboratorios  de ...
# 1345  El  Instituto  Nacional  de  Laboratorios  de ...
# 1346  Insumos Bolivia (INBOL) es una Entidad Pública...
# 1347  Transportes Aéreos Bolivianos (TAB) es la aero...
#
#                      entidad.urlSitioWeb entidad.telefonoContacto  \
# 0                         https://tsj.bo                 46453200
# 1              https://www.agetic.gob.bo            (591) 2184026
# 2                https://www.ait.gob.bo/        2412789 – 2412048
# 3                https://www.ait.gob.bo/        2412789 – 2412048
# 4                https://www.ribb.gob.bo                  2434415
# ...                                  ...                      ...
# 1343           https://defensoria.gob.bo                  2113600
# 1344           https://www.inlasa.gob.bo        2226048 - 2226670
# 1345           https://www.inlasa.gob.bo        2226048 - 2226670
# 1346  https://www.insumosbolivia.gob.bo/                  2408191
# 1347             https://tab-bolivia.com            0-800-100-110
#
#       entidad.correoElectronicoContacto  \
# 0      soporteogp@organojudicial.gob.bo
# 1                 soporte@agetic.gob.bo
# 2                    infoait@ait.gob.bo
# 3                    infoait@ait.gob.bo
# 4              ribb_bolivia@ribb.gob.bo
# ...                                 ...
# 1343             f.olivares.c@gmail.com
# 1344       inlasalapazbolivia@gmail.com
# 1345       inlasalapazbolivia@gmail.com
# 1346         info@insumosbolivia.gob.bo
# 1347  atencionalcliente@tab-bolivia.com
#
#                                           palabrasClave  \
# 0                                                   NaN
# 1     digital,ciudadania,registro,pre registro,const...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1343                                denuncia,defensoria
# 1344                                                NaN
# 1345                                                NaN
# 1346                                      venta,palmito
# 1347  Transporte de carga,transporte,aerea,logistica...
#
#                     categorias       eventosVida documentos  herramientas
# 0                     Justicia               NaN        NaN           NaN
# 1     Seguridad,Identificación            Empleo   Registro           NaN
# 2           Justicia,Impuestos               NaN        NaN           NaN
# 3           Justicia,Impuestos               NaN        NaN           NaN
# 4                     Empresas               NaN        NaN           NaN
# ...                        ...               ...        ...           ...
# 1343                  Justicia               NaN        NaN           NaN
# 1344      Medio ambiente,Salud  Cuidado de salud        NaN           NaN
# 1345                     Salud               NaN        NaN           NaN
# 1346                  Empresas               NaN        NaN           NaN
# 1347                Transporte               NaN        NaN           NaN
#
# [1348 rows x 29 columns]

# %% [markdown]
# ## Dicionarios, listas, tuplas -- guradar como JSON
#
# En este dataset muchas columnas como listas u objetos json, al ser leídas se guardan como diccionarios python representados en cadenas. Para estandarizar el dataset para que sea usable en otros lenguages más fácilmente todas las columnas con listas, tuplas o diccionarios se guardarán como cadenas JSON.

# %%
import json
import ast

df['enlaces'] = df['enlaces'].map(lambda x: json.dumps(ast.literal_eval(x), ensure_ascii=False))
df['ubicaciones'] = df['ubicaciones'].map(lambda x: json.dumps(ast.literal_eval(x), ensure_ascii=False))
df.sample(2)
# Out:
#        id     estado fechaActualización  \
# 742  1909  PUBLICADO         10/07/2025
# 645  1739  PUBLICADO         10/07/2025
#
#                                                 nombre  \
# 742       Apertura de Módulos Tecnológicos Productivos
# 645  Impresión de Historial Académico de Educación ...
#
#                                                   slug      sigla  \
# 742       apertura-de-modulos-tecnologicos-productivos    Regular
# 645  impresion-de-historial-academico-de-educacion-...  UAA - SIE
#
#                                            descripcion  \
# 742       Apertura de Módulos Tecnológicos Productivos
# 645  Impresión de Historial Académico de Educación ...
#
#                                             marcoLegal  like  dislike  \
# 742  Resolución Administrativa Departamental DDE-BE...     0        0
# 645  Resolución Administrativa Departamental DDE-BE...     0        0
#
#      esPresencial  esVirtual              resultado enlaces  \
# 742             1          0  Registro y constancia      []
# 645             1          0             Constancia      []
#
#                                            modalidades  \
# 742  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 645  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
#
#                                            ubicaciones  \
# 742  [{"nombre": "DIRECCION DEPARTAMENTAL DEL BENI"...
# 645  [{"nombre": "DIRECCION DEPARTAMENTAL DEL BENI"...
#
#                       entidad.nombre entidad.sigla  \
# 742  Direc. Dptal. de Educación Beni       DDE-BEN
# 645  Direc. Dptal. de Educación Beni       DDE-BEN
#
#                       entidad.slug  \
# 742  direc-dptal-de-educacion-beni
# 645  direc-dptal-de-educacion-beni
#
#                                           entidad.logo  \
# 742  https://www.gob.bo/ws/api/archivos/7197f9e0-96...
# 645  https://www.gob.bo/ws/api/archivos/7197f9e0-96...
#
#                                    entidad.descripcion  \
# 742  La Dirección Departamental de Educación del Be...
# 645  La Dirección Departamental de Educación del Be...
#
#              entidad.urlSitioWeb entidad.telefonoContacto  \
# 742  https://www.ddebeni.edu.bo/                346-22226
# 645  https://www.ddebeni.edu.bo/                346-22226
#
#     entidad.correoElectronicoContacto                  palabrasClave  \
# 742             ddebeni20221@gmai.com  apertura,modulos,tecnologicos
# 645             ddebeni20221@gmai.com  historial,academico,impresion
#
#     categorias   eventosVida  \
# 742  Educación  Mi educación
# 645  Educación  Mi educación
#
#                                             documentos  herramientas
# 742  Resolución Administrativa - Apertura de Módulo...           NaN
# 645                                Historial Academico           NaN

# %% [markdown]
# ## Desglosando modalidades

# %%
import json
import ast

ast.literal_eval(df.iloc[0]['modalidades'])
# Out:
# [{'tipo': 'PRESENCIAL',
#   'url': None,
#   'urlSeguimiento': None,
#   'publico': [{'tieneCosto': False,
#     'duracion': '5',
#     'unidadMedidaDuracion': 'Minuto(s)',
#     'procedimiento': '<ol><li><p>Realizar el pre registro</p></li><li><p>Acudir a cualquier Oficina Gestora de Procesos a nivel nacional para confirmar el registro.</p></li></ol>',
#     'requisitoNoParametrizado': None,
#     'nombrePublicoObjetivo': 'Persona Natural',
#     'estadoPublicoObjetivo': 'ACTIVO',
#     'emisionFactura': '',
#     'formaCobro': [],
#     'horario': [{'dia': 'Lunes',
#       'continuo': True,
#       'inicioManiana': '08:00',
#       'finManiana': '16:30',
#       'inicioTarde': None,
#       'finTarde': None},
#      {'dia': 'Martes',
#       'continuo': True,
#       'inicioManiana': '08:00',
#       'finManiana': '16:30',
#       'inicioTarde': None,
#       'finTarde': None},
#      {'dia': 'Miércoles',
#       'continuo': True,
#       'inicioManiana': '08:00',
#       'finManiana': '16:30',
#       'inicioTarde': None,
#       'finTarde': None},
#      {'dia': 'Jueves',
#       'continuo': True,
#       'inicioManiana': '08:00',
#       'finManiana': '16:30',
#       'inicioTarde': None,
#       'finTarde': None},
#      {'dia': 'Viernes',
#       'continuo': True,
#       'inicioManiana': '08:00',
#       'finManiana': '16:30',
#       'inicioTarde': None,
#       'finTarde': None}],
#     'depositoBancario': [],
#     'costos': [],
#     'requisitos': [{'comentario': None,
#       'nombre': 'Correo electrónico',
#       'entidad': None,
#       'entidadActiva': True},
#      {'comentario': None,
#       'nombre': 'Número de teléfono',
#       'entidad': None,
#       'entidadActiva': True},
#      {'comentario': 'Vigente',
#       'nombre': 'Cédula de Identidad',
#       'entidad': None,
#       'entidadActiva': True}]}]}]

# %%
def desglosar_segun_tipo_modalidad(df):
    new_df = pd.DataFrame(columns=df.columns.to_list() + ['modalidad.tipo', 'modalidad'])
    print(new_df.columns)
    _df = df.copy()
    for i in _df.index.to_list():
        data = _df.iloc[i].to_dict()
        #print(data)
        modalidades = ast.literal_eval(data['modalidades'])
        for modalidad in modalidades:
            data['modalidad.tipo'] = modalidad['tipo']
            data['modalidad'] = modalidad
            print(f"Agregando id: {data['id']} -> tipo: {data['modalidad.tipo']}")
            new_df.loc[len(new_df)] = data
    del new_df['modalidades']
    return new_df

new_df = desglosar_segun_tipo_modalidad(df)
print(new_df.shape)
new_df.sample(3)
# Out:
# Index(['id', 'estado', 'fechaActualización', 'nombre', 'slug', 'sigla',
#        'descripcion', 'marcoLegal', 'like', 'dislike', 'esPresencial',
#        'esVirtual', 'resultado', 'enlaces', 'modalidades', 'ubicaciones',
#        'entidad.nombre', 'entidad.sigla', 'entidad.slug', 'entidad.logo',
#        'entidad.descripcion', 'entidad.urlSitioWeb',
#        'entidad.telefonoContacto', 'entidad.correoElectronicoContacto',
#        'palabrasClave', 'categorias', 'eventosVida', 'documentos',
#        'herramientas', 'modalidad.tipo', 'modalidad'],
#       dtype='object')
# Agregando id: 1005 -> tipo: PRESENCIAL
# Agregando id: 1006 -> tipo: PRESENCIAL
# Agregando id: 1006 -> tipo: VIRTUAL
# Agregando id: 1008 -> tipo: PRESENCIAL
# Agregando id: 1009 -> tipo: PRESENCIAL
# Agregando id: 1010 -> tipo: PRESENCIAL
# Agregando id: 1011 -> tipo: PRESENCIAL
# Agregando id: 1012 -> tipo: PRESENCIAL
# Agregando id: 1013 -> tipo: PRESENCIAL
# Agregando id: 1014 -> tipo: PRESENCIAL
# Agregando id: 1015 -> tipo: PRESENCIAL
# Agregando id: 1017 -> tipo: PRESENCIAL
# Agregando id: 1018 -> tipo: PRESENCIAL
# Agregando id: 1019 -> tipo: PRESENCIAL
# Agregando id: 1020 -> tipo: PRESENCIAL
# Agregando id: 1021 -> tipo: PRESENCIAL
# Agregando id: 1022 -> tipo: PRESENCIAL
# Agregando id: 1023 -> tipo: PRESENCIAL
# Agregando id: 1024 -> tipo: PRESENCIAL
# Agregando id: 1025 -> tipo: PRESENCIAL
# Agregando id: 1026 -> tipo: PRESENCIAL
# Agregando id: 1027 -> tipo: PRESENCIAL
# Agregando id: 1028 -> tipo: PRESENCIAL
# Agregando id: 1029 -> tipo: PRESENCIAL
# Agregando id: 1030 -> tipo: PRESENCIAL
# Agregando id: 1031 -> tipo: PRESENCIAL
# Agregando id: 1032 -> tipo: PRESENCIAL
# Agregando id: 1033 -> tipo: PRESENCIAL
# Agregando id: 1034 -> tipo: PRESENCIAL
# Agregando id: 1035 -> tipo: PRESENCIAL
# Agregando id: 1037 -> tipo: PRESENCIAL
# Agregando id: 1038 -> tipo: PRESENCIAL
# Agregando id: 1039 -> tipo: PRESENCIAL
# Agregando id: 1041 -> tipo: PRESENCIAL
# Agregando id: 1042 -> tipo: PRESENCIAL
# Agregando id: 1043 -> tipo: PRESENCIAL
# Agregando id: 1044 -> tipo: PRESENCIAL
# Agregando id: 1045 -> tipo: PRESENCIAL
# Agregando id: 1046 -> tipo: PRESENCIAL
# Agregando id: 1047 -> tipo: PRESENCIAL
# Agregando id: 1048 -> tipo: PRESENCIAL
# Agregando id: 1049 -> tipo: PRESENCIAL
# Agregando id: 1050 -> tipo: PRESENCIAL
# Agregando id: 1051 -> tipo: PRESENCIAL
# Agregando id: 1052 -> tipo: PRESENCIAL
# Agregando id: 1052 -> tipo: VIRTUAL
# Agregando id: 1053 -> tipo: PRESENCIAL
# Agregando id: 1054 -> tipo: VIRTUAL
# Agregando id: 1055 -> tipo: VIRTUAL
# Agregando id: 1056 -> tipo: PRESENCIAL
# Agregando id: 1057 -> tipo: PRESENCIAL
# Agregando id: 1058 -> tipo: PRESENCIAL
# Agregando id: 1059 -> tipo: PRESENCIAL
# Agregando id: 1060 -> tipo: PRESENCIAL
# Agregando id: 1061 -> tipo: PRESENCIAL
# Agregando id: 1062 -> tipo: PRESENCIAL
# Agregando id: 1063 -> tipo: PRESENCIAL
# Agregando id: 1063 -> tipo: VIRTUAL
# Agregando id: 1064 -> tipo: PRESENCIAL
# Agregando id: 1064 -> tipo: VIRTUAL
# Agregando id: 1065 -> tipo: PRESENCIAL
# Agregando id: 1066 -> tipo: PRESENCIAL
# Agregando id: 1066 -> tipo: VIRTUAL
# Agregando id: 1067 -> tipo: PRESENCIAL
# Agregando id: 1067 -> tipo: VIRTUAL
# Agregando id: 1069 -> tipo: PRESENCIAL
# Agregando id: 1069 -> tipo: VIRTUAL
# Agregando id: 1070 -> tipo: PRESENCIAL
# Agregando id: 1070 -> tipo: VIRTUAL
# Agregando id: 1071 -> tipo: PRESENCIAL
# Agregando id: 1073 -> tipo: PRESENCIAL
# Agregando id: 1073 -> tipo: VIRTUAL
# Agregando id: 1074 -> tipo: PRESENCIAL
# Agregando id: 1074 -> tipo: VIRTUAL
# Agregando id: 1076 -> tipo: PRESENCIAL
# Agregando id: 1078 -> tipo: PRESENCIAL
# Agregando id: 1079 -> tipo: PRESENCIAL
# Agregando id: 1079 -> tipo: VIRTUAL
# Agregando id: 1080 -> tipo: PRESENCIAL
# Agregando id: 1082 -> tipo: PRESENCIAL
# Agregando id: 1082 -> tipo: VIRTUAL
# Agregando id: 1084 -> tipo: PRESENCIAL
# Agregando id: 1084 -> tipo: VIRTUAL
# Agregando id: 1087 -> tipo: PRESENCIAL
# Agregando id: 1087 -> tipo: VIRTUAL
# Agregando id: 1089 -> tipo: PRESENCIAL
# Agregando id: 1089 -> tipo: VIRTUAL
# Agregando id: 1091 -> tipo: PRESENCIAL
# Agregando id: 1091 -> tipo: VIRTUAL
# Agregando id: 1094 -> tipo: PRESENCIAL
# Agregando id: 1096 -> tipo: PRESENCIAL
# Agregando id: 1100 -> tipo: PRESENCIAL
# Agregando id: 1101 -> tipo: PRESENCIAL
# Agregando id: 1102 -> tipo: PRESENCIAL
# Agregando id: 1103 -> tipo: PRESENCIAL
# Agregando id: 1104 -> tipo: PRESENCIAL
# Agregando id: 1104 -> tipo: VIRTUAL
# Agregando id: 1105 -> tipo: PRESENCIAL
# Agregando id: 1105 -> tipo: VIRTUAL
# Agregando id: 1106 -> tipo: PRESENCIAL
# Agregando id: 1106 -> tipo: VIRTUAL
# Agregando id: 1107 -> tipo: PRESENCIAL
# Agregando id: 1107 -> tipo: VIRTUAL
# Agregando id: 1108 -> tipo: PRESENCIAL
# Agregando id: 1108 -> tipo: VIRTUAL
# Agregando id: 1109 -> tipo: PRESENCIAL
# Agregando id: 1109 -> tipo: VIRTUAL
# Agregando id: 1110 -> tipo: PRESENCIAL
# Agregando id: 1110 -> tipo: VIRTUAL
# Agregando id: 1111 -> tipo: PRESENCIAL
# Agregando id: 1111 -> tipo: VIRTUAL
# Agregando id: 1113 -> tipo: PRESENCIAL
# Agregando id: 1114 -> tipo: PRESENCIAL
# Agregando id: 1114 -> tipo: VIRTUAL
# Agregando id: 1115 -> tipo: PRESENCIAL
# Agregando id: 1116 -> tipo: PRESENCIAL
# Agregando id: 1118 -> tipo: PRESENCIAL
# Agregando id: 1118 -> tipo: VIRTUAL
# Agregando id: 1119 -> tipo: PRESENCIAL
# Agregando id: 1120 -> tipo: PRESENCIAL
# Agregando id: 1120 -> tipo: VIRTUAL
# Agregando id: 1121 -> tipo: PRESENCIAL
# Agregando id: 1121 -> tipo: VIRTUAL
# Agregando id: 1122 -> tipo: PRESENCIAL
# Agregando id: 1122 -> tipo: VIRTUAL
# Agregando id: 1123 -> tipo: PRESENCIAL
# Agregando id: 1123 -> tipo: VIRTUAL
# Agregando id: 1124 -> tipo: PRESENCIAL
# Agregando id: 1124 -> tipo: VIRTUAL
# Agregando id: 1125 -> tipo: PRESENCIAL
# Agregando id: 1125 -> tipo: VIRTUAL
# Agregando id: 1126 -> tipo: PRESENCIAL
# Agregando id: 1126 -> tipo: VIRTUAL
# Agregando id: 1127 -> tipo: PRESENCIAL
# Agregando id: 1127 -> tipo: VIRTUAL
# Agregando id: 1128 -> tipo: PRESENCIAL
# Agregando id: 1128 -> tipo: VIRTUAL
# Agregando id: 1129 -> tipo: PRESENCIAL
# Agregando id: 1130 -> tipo: PRESENCIAL
# Agregando id: 1131 -> tipo: PRESENCIAL
# Agregando id: 1131 -> tipo: VIRTUAL
# Agregando id: 1132 -> tipo: PRESENCIAL
# Agregando id: 1132 -> tipo: VIRTUAL
# Agregando id: 1133 -> tipo: PRESENCIAL
# Agregando id: 1134 -> tipo: VIRTUAL
# Agregando id: 1135 -> tipo: VIRTUAL
# Agregando id: 1136 -> tipo: PRESENCIAL
# Agregando id: 1136 -> tipo: VIRTUAL
# Agregando id: 1137 -> tipo: PRESENCIAL
# Agregando id: 1137 -> tipo: VIRTUAL
# Agregando id: 1138 -> tipo: PRESENCIAL
# Agregando id: 1138 -> tipo: VIRTUAL
# Agregando id: 1139 -> tipo: VIRTUAL
# Agregando id: 1140 -> tipo: PRESENCIAL
# Agregando id: 1140 -> tipo: VIRTUAL
# Agregando id: 1141 -> tipo: PRESENCIAL
# Agregando id: 1141 -> tipo: VIRTUAL
# Agregando id: 1142 -> tipo: PRESENCIAL
# Agregando id: 1142 -> tipo: VIRTUAL
# Agregando id: 1143 -> tipo: PRESENCIAL
# Agregando id: 1143 -> tipo: VIRTUAL
# Agregando id: 1146 -> tipo: PRESENCIAL
# Agregando id: 1146 -> tipo: VIRTUAL
# Agregando id: 1148 -> tipo: PRESENCIAL
# Agregando id: 1148 -> tipo: VIRTUAL
# Agregando id: 1150 -> tipo: PRESENCIAL
# Agregando id: 1150 -> tipo: VIRTUAL
# Agregando id: 1151 -> tipo: PRESENCIAL
# Agregando id: 1152 -> tipo: PRESENCIAL
# Agregando id: 1152 -> tipo: VIRTUAL
# Agregando id: 1153 -> tipo: PRESENCIAL
# Agregando id: 1153 -> tipo: VIRTUAL
# Agregando id: 1154 -> tipo: PRESENCIAL
# Agregando id: 1154 -> tipo: VIRTUAL
# Agregando id: 1155 -> tipo: PRESENCIAL
# Agregando id: 1155 -> tipo: VIRTUAL
# Agregando id: 1156 -> tipo: PRESENCIAL
# Agregando id: 1156 -> tipo: VIRTUAL
# Agregando id: 1157 -> tipo: PRESENCIAL
# Agregando id: 1157 -> tipo: VIRTUAL
# Agregando id: 1158 -> tipo: PRESENCIAL
# Agregando id: 1158 -> tipo: VIRTUAL
# Agregando id: 1159 -> tipo: PRESENCIAL
# Agregando id: 1159 -> tipo: VIRTUAL
# Agregando id: 1160 -> tipo: PRESENCIAL
# Agregando id: 1160 -> tipo: VIRTUAL
# Agregando id: 1161 -> tipo: PRESENCIAL
# Agregando id: 1161 -> tipo: VIRTUAL
# Agregando id: 1162 -> tipo: PRESENCIAL
# Agregando id: 1162 -> tipo: VIRTUAL
# Agregando id: 1163 -> tipo: PRESENCIAL
# Agregando id: 1163 -> tipo: VIRTUAL
# Agregando id: 1164 -> tipo: PRESENCIAL
# Agregando id: 1164 -> tipo: VIRTUAL
# Agregando id: 1166 -> tipo: PRESENCIAL
# Agregando id: 1166 -> tipo: VIRTUAL
# Agregando id: 1167 -> tipo: PRESENCIAL
# Agregando id: 1167 -> tipo: VIRTUAL
# Agregando id: 1168 -> tipo: PRESENCIAL
# Agregando id: 1168 -> tipo: VIRTUAL
# Agregando id: 1169 -> tipo: PRESENCIAL
# Agregando id: 1169 -> tipo: VIRTUAL
# Agregando id: 1170 -> tipo: PRESENCIAL
# Agregando id: 1170 -> tipo: VIRTUAL
# Agregando id: 1171 -> tipo: PRESENCIAL
# Agregando id: 1171 -> tipo: VIRTUAL
# Agregando id: 1172 -> tipo: PRESENCIAL
# Agregando id: 1172 -> tipo: VIRTUAL
# Agregando id: 1173 -> tipo: PRESENCIAL
# Agregando id: 1173 -> tipo: VIRTUAL
# Agregando id: 1174 -> tipo: PRESENCIAL
# Agregando id: 1174 -> tipo: VIRTUAL
# Agregando id: 1176 -> tipo: PRESENCIAL
# Agregando id: 1176 -> tipo: VIRTUAL
# Agregando id: 1177 -> tipo: PRESENCIAL
# Agregando id: 1177 -> tipo: VIRTUAL
# Agregando id: 1178 -> tipo: PRESENCIAL
# Agregando id: 1178 -> tipo: VIRTUAL
# Agregando id: 1179 -> tipo: PRESENCIAL
# Agregando id: 1179 -> tipo: VIRTUAL
# Agregando id: 1180 -> tipo: PRESENCIAL
# Agregando id: 1180 -> tipo: VIRTUAL
# Agregando id: 1181 -> tipo: PRESENCIAL
# Agregando id: 1181 -> tipo: VIRTUAL
# Agregando id: 1182 -> tipo: PRESENCIAL
# Agregando id: 1182 -> tipo: VIRTUAL
# Agregando id: 1183 -> tipo: PRESENCIAL
# Agregando id: 1183 -> tipo: VIRTUAL
# Agregando id: 1184 -> tipo: PRESENCIAL
# Agregando id: 1184 -> tipo: VIRTUAL
# Agregando id: 1185 -> tipo: PRESENCIAL
# Agregando id: 1185 -> tipo: VIRTUAL
# Agregando id: 1186 -> tipo: PRESENCIAL
# Agregando id: 1186 -> tipo: VIRTUAL
# Agregando id: 1187 -> tipo: PRESENCIAL
# Agregando id: 1188 -> tipo: PRESENCIAL
# Agregando id: 1189 -> tipo: PRESENCIAL
# Agregando id: 1190 -> tipo: PRESENCIAL
# Agregando id: 1190 -> tipo: VIRTUAL
# Agregando id: 1191 -> tipo: PRESENCIAL
# Agregando id: 1192 -> tipo: PRESENCIAL
# Agregando id: 1193 -> tipo: PRESENCIAL
# Agregando id: 1194 -> tipo: PRESENCIAL
# Agregando id: 1195 -> tipo: PRESENCIAL
# Agregando id: 1195 -> tipo: VIRTUAL
# Agregando id: 1196 -> tipo: PRESENCIAL
# Agregando id: 1197 -> tipo: PRESENCIAL
# Agregando id: 1198 -> tipo: PRESENCIAL
# Agregando id: 1199 -> tipo: PRESENCIAL
# Agregando id: 1199 -> tipo: VIRTUAL
# Agregando id: 1200 -> tipo: PRESENCIAL
# Agregando id: 1201 -> tipo: PRESENCIAL
# Agregando id: 1201 -> tipo: VIRTUAL
# Agregando id: 1202 -> tipo: PRESENCIAL
# Agregando id: 1202 -> tipo: VIRTUAL
# Agregando id: 1203 -> tipo: VIRTUAL
# Agregando id: 1204 -> tipo: PRESENCIAL
# Agregando id: 1204 -> tipo: VIRTUAL
# Agregando id: 1205 -> tipo: PRESENCIAL
# Agregando id: 1205 -> tipo: VIRTUAL
# Agregando id: 1206 -> tipo: PRESENCIAL
# Agregando id: 1206 -> tipo: VIRTUAL
# Agregando id: 1207 -> tipo: PRESENCIAL
# Agregando id: 1207 -> tipo: VIRTUAL
# Agregando id: 1209 -> tipo: PRESENCIAL
# Agregando id: 1209 -> tipo: VIRTUAL
# Agregando id: 1210 -> tipo: PRESENCIAL
# Agregando id: 1210 -> tipo: VIRTUAL
# Agregando id: 1211 -> tipo: VIRTUAL
# Agregando id: 1212 -> tipo: PRESENCIAL
# Agregando id: 1212 -> tipo: VIRTUAL
# Agregando id: 1213 -> tipo: VIRTUAL
# Agregando id: 1214 -> tipo: PRESENCIAL
# Agregando id: 1215 -> tipo: PRESENCIAL
# Agregando id: 1216 -> tipo: PRESENCIAL
# Agregando id: 1216 -> tipo: VIRTUAL
# Agregando id: 1217 -> tipo: VIRTUAL
# Agregando id: 1218 -> tipo: VIRTUAL
# Agregando id: 1219 -> tipo: VIRTUAL
# Agregando id: 1220 -> tipo: PRESENCIAL
# Agregando id: 1220 -> tipo: VIRTUAL
# Agregando id: 1221 -> tipo: VIRTUAL
# Agregando id: 1222 -> tipo: VIRTUAL
# Agregando id: 1223 -> tipo: PRESENCIAL
# Agregando id: 1223 -> tipo: VIRTUAL
# Agregando id: 1224 -> tipo: VIRTUAL
# Agregando id: 1225 -> tipo: VIRTUAL
# Agregando id: 1226 -> tipo: VIRTUAL
# Agregando id: 1227 -> tipo: VIRTUAL
# Agregando id: 1228 -> tipo: PRESENCIAL
# Agregando id: 1228 -> tipo: VIRTUAL
# Agregando id: 1229 -> tipo: VIRTUAL
# Agregando id: 1230 -> tipo: VIRTUAL
# Agregando id: 1231 -> tipo: PRESENCIAL
# Agregando id: 1231 -> tipo: VIRTUAL
# Agregando id: 1232 -> tipo: PRESENCIAL
# Agregando id: 1232 -> tipo: VIRTUAL
# Agregando id: 1233 -> tipo: PRESENCIAL
# Agregando id: 1233 -> tipo: VIRTUAL
# Agregando id: 1234 -> tipo: PRESENCIAL
# Agregando id: 1234 -> tipo: VIRTUAL
# Agregando id: 1235 -> tipo: PRESENCIAL
# Agregando id: 1235 -> tipo: VIRTUAL
# Agregando id: 1236 -> tipo: PRESENCIAL
# Agregando id: 1236 -> tipo: VIRTUAL
# Agregando id: 1237 -> tipo: PRESENCIAL
# Agregando id: 1237 -> tipo: VIRTUAL
# Agregando id: 1238 -> tipo: PRESENCIAL
# Agregando id: 1239 -> tipo: PRESENCIAL
# Agregando id: 1239 -> tipo: VIRTUAL
# Agregando id: 1240 -> tipo: PRESENCIAL
# Agregando id: 1241 -> tipo: PRESENCIAL
# Agregando id: 1241 -> tipo: VIRTUAL
# Agregando id: 1242 -> tipo: PRESENCIAL
# Agregando id: 1242 -> tipo: VIRTUAL
# Agregando id: 1243 -> tipo: PRESENCIAL
# Agregando id: 1244 -> tipo: PRESENCIAL
# Agregando id: 1244 -> tipo: VIRTUAL
# Agregando id: 1245 -> tipo: PRESENCIAL
# Agregando id: 1245 -> tipo: VIRTUAL
# Agregando id: 1246 -> tipo: PRESENCIAL
# Agregando id: 1246 -> tipo: VIRTUAL
# Agregando id: 1247 -> tipo: PRESENCIAL
# Agregando id: 1250 -> tipo: PRESENCIAL
# Agregando id: 1250 -> tipo: VIRTUAL
# Agregando id: 1251 -> tipo: PRESENCIAL
# Agregando id: 1252 -> tipo: PRESENCIAL
# Agregando id: 1253 -> tipo: PRESENCIAL
# Agregando id: 1253 -> tipo: VIRTUAL
# Agregando id: 1254 -> tipo: PRESENCIAL
# Agregando id: 1255 -> tipo: PRESENCIAL
# Agregando id: 1256 -> tipo: PRESENCIAL
# Agregando id: 1256 -> tipo: VIRTUAL
# Agregando id: 1257 -> tipo: PRESENCIAL
# Agregando id: 1257 -> tipo: VIRTUAL
# Agregando id: 1258 -> tipo: PRESENCIAL
# Agregando id: 1259 -> tipo: PRESENCIAL
# Agregando id: 1260 -> tipo: PRESENCIAL
# Agregando id: 1262 -> tipo: PRESENCIAL
# Agregando id: 1263 -> tipo: PRESENCIAL
# Agregando id: 1264 -> tipo: PRESENCIAL
# Agregando id: 1265 -> tipo: PRESENCIAL
# Agregando id: 1266 -> tipo: PRESENCIAL
# Agregando id: 1266 -> tipo: VIRTUAL
# Agregando id: 1267 -> tipo: PRESENCIAL
# Agregando id: 1267 -> tipo: VIRTUAL
# Agregando id: 1268 -> tipo: PRESENCIAL
# Agregando id: 1268 -> tipo: VIRTUAL
# Agregando id: 1269 -> tipo: PRESENCIAL
# Agregando id: 1269 -> tipo: VIRTUAL
# Agregando id: 1270 -> tipo: PRESENCIAL
# Agregando id: 1270 -> tipo: VIRTUAL
# Agregando id: 1271 -> tipo: PRESENCIAL
# Agregando id: 1271 -> tipo: VIRTUAL
# Agregando id: 1272 -> tipo: PRESENCIAL
# Agregando id: 1272 -> tipo: VIRTUAL
# Agregando id: 1273 -> tipo: PRESENCIAL
# Agregando id: 1273 -> tipo: VIRTUAL
# Agregando id: 1274 -> tipo: PRESENCIAL
# Agregando id: 1275 -> tipo: PRESENCIAL
# Agregando id: 1275 -> tipo: VIRTUAL
# Agregando id: 1276 -> tipo: PRESENCIAL
# Agregando id: 1277 -> tipo: VIRTUAL
# Agregando id: 1278 -> tipo: PRESENCIAL
# Agregando id: 1278 -> tipo: VIRTUAL
# Agregando id: 1279 -> tipo: PRESENCIAL
# Agregando id: 1279 -> tipo: VIRTUAL
# Agregando id: 1280 -> tipo: PRESENCIAL
# Agregando id: 1280 -> tipo: VIRTUAL
# Agregando id: 1281 -> tipo: PRESENCIAL
# Agregando id: 1281 -> tipo: VIRTUAL
# Agregando id: 1282 -> tipo: PRESENCIAL
# Agregando id: 1282 -> tipo: VIRTUAL
# Agregando id: 1283 -> tipo: PRESENCIAL
# Agregando id: 1283 -> tipo: VIRTUAL
# Agregando id: 1284 -> tipo: PRESENCIAL
# Agregando id: 1284 -> tipo: VIRTUAL
# Agregando id: 1285 -> tipo: PRESENCIAL
# Agregando id: 1286 -> tipo: PRESENCIAL
# Agregando id: 1286 -> tipo: VIRTUAL
# Agregando id: 1288 -> tipo: PRESENCIAL
# Agregando id: 1288 -> tipo: VIRTUAL
# Agregando id: 1289 -> tipo: PRESENCIAL
# Agregando id: 1290 -> tipo: PRESENCIAL
# Agregando id: 1291 -> tipo: PRESENCIAL
# Agregando id: 1291 -> tipo: VIRTUAL
# Agregando id: 1292 -> tipo: PRESENCIAL
# Agregando id: 1293 -> tipo: PRESENCIAL
# Agregando id: 1293 -> tipo: VIRTUAL
# Agregando id: 1294 -> tipo: PRESENCIAL
# Agregando id: 1295 -> tipo: PRESENCIAL
# Agregando id: 1296 -> tipo: PRESENCIAL
# Agregando id: 1297 -> tipo: PRESENCIAL
# Agregando id: 1297 -> tipo: VIRTUAL
# Agregando id: 1298 -> tipo: PRESENCIAL
# Agregando id: 1299 -> tipo: PRESENCIAL
# Agregando id: 1299 -> tipo: VIRTUAL
# Agregando id: 1300 -> tipo: PRESENCIAL
# Agregando id: 1301 -> tipo: PRESENCIAL
# Agregando id: 1303 -> tipo: PRESENCIAL
# Agregando id: 1303 -> tipo: VIRTUAL
# Agregando id: 1304 -> tipo: PRESENCIAL
# Agregando id: 1305 -> tipo: VIRTUAL
# Agregando id: 1306 -> tipo: PRESENCIAL
# Agregando id: 1307 -> tipo: PRESENCIAL
# Agregando id: 1307 -> tipo: VIRTUAL
# Agregando id: 1308 -> tipo: PRESENCIAL
# Agregando id: 1309 -> tipo: PRESENCIAL
# Agregando id: 1310 -> tipo: VIRTUAL
# Agregando id: 1311 -> tipo: PRESENCIAL
# Agregando id: 1311 -> tipo: VIRTUAL
# Agregando id: 1312 -> tipo: VIRTUAL
# Agregando id: 1313 -> tipo: PRESENCIAL
# Agregando id: 1314 -> tipo: PRESENCIAL
# Agregando id: 1314 -> tipo: VIRTUAL
# Agregando id: 1315 -> tipo: PRESENCIAL
# Agregando id: 1316 -> tipo: PRESENCIAL
# Agregando id: 1316 -> tipo: VIRTUAL
# Agregando id: 1317 -> tipo: PRESENCIAL
# Agregando id: 1317 -> tipo: VIRTUAL
# Agregando id: 1318 -> tipo: PRESENCIAL
# Agregando id: 1318 -> tipo: VIRTUAL
# Agregando id: 1319 -> tipo: PRESENCIAL
# Agregando id: 1320 -> tipo: PRESENCIAL
# Agregando id: 1320 -> tipo: VIRTUAL
# Agregando id: 1321 -> tipo: PRESENCIAL
# Agregando id: 1321 -> tipo: VIRTUAL
# Agregando id: 1323 -> tipo: PRESENCIAL
# Agregando id: 1324 -> tipo: PRESENCIAL
# Agregando id: 1324 -> tipo: VIRTUAL
# Agregando id: 1325 -> tipo: PRESENCIAL
# Agregando id: 1326 -> tipo: PRESENCIAL
# Agregando id: 1326 -> tipo: VIRTUAL
# Agregando id: 1327 -> tipo: PRESENCIAL
# Agregando id: 1327 -> tipo: VIRTUAL
# Agregando id: 1328 -> tipo: PRESENCIAL
# Agregando id: 1328 -> tipo: VIRTUAL
# Agregando id: 1329 -> tipo: PRESENCIAL
# Agregando id: 1329 -> tipo: VIRTUAL
# Agregando id: 1330 -> tipo: PRESENCIAL
# Agregando id: 1330 -> tipo: VIRTUAL
# Agregando id: 1331 -> tipo: PRESENCIAL
# Agregando id: 1331 -> tipo: VIRTUAL
# Agregando id: 1332 -> tipo: PRESENCIAL
# Agregando id: 1332 -> tipo: VIRTUAL
# Agregando id: 1333 -> tipo: PRESENCIAL
# Agregando id: 1333 -> tipo: VIRTUAL
# Agregando id: 1334 -> tipo: PRESENCIAL
# Agregando id: 1335 -> tipo: PRESENCIAL
# Agregando id: 1335 -> tipo: VIRTUAL
# Agregando id: 1336 -> tipo: PRESENCIAL
# Agregando id: 1336 -> tipo: VIRTUAL
# Agregando id: 1337 -> tipo: PRESENCIAL
# Agregando id: 1337 -> tipo: VIRTUAL
# Agregando id: 1339 -> tipo: PRESENCIAL
# Agregando id: 1339 -> tipo: VIRTUAL
# Agregando id: 1340 -> tipo: PRESENCIAL
# Agregando id: 1340 -> tipo: VIRTUAL
# Agregando id: 1341 -> tipo: PRESENCIAL
# Agregando id: 1341 -> tipo: VIRTUAL
# Agregando id: 1342 -> tipo: PRESENCIAL
# Agregando id: 1343 -> tipo: PRESENCIAL
# Agregando id: 1344 -> tipo: PRESENCIAL
# Agregando id: 1345 -> tipo: PRESENCIAL
# Agregando id: 1346 -> tipo: PRESENCIAL
# Agregando id: 1347 -> tipo: PRESENCIAL
# Agregando id: 1348 -> tipo: PRESENCIAL
# Agregando id: 1351 -> tipo: PRESENCIAL
# Agregando id: 1351 -> tipo: VIRTUAL
# Agregando id: 1352 -> tipo: PRESENCIAL
# Agregando id: 1352 -> tipo: VIRTUAL
# Agregando id: 1353 -> tipo: VIRTUAL
# Agregando id: 1354 -> tipo: PRESENCIAL
# Agregando id: 1355 -> tipo: PRESENCIAL
# Agregando id: 1356 -> tipo: PRESENCIAL
# Agregando id: 1357 -> tipo: PRESENCIAL
# Agregando id: 1358 -> tipo: PRESENCIAL
# Agregando id: 1359 -> tipo: PRESENCIAL
# Agregando id: 1360 -> tipo: PRESENCIAL
# Agregando id: 1361 -> tipo: PRESENCIAL
# Agregando id: 1362 -> tipo: PRESENCIAL
# Agregando id: 1363 -> tipo: PRESENCIAL
# Agregando id: 1364 -> tipo: PRESENCIAL
# Agregando id: 1365 -> tipo: PRESENCIAL
# Agregando id: 1366 -> tipo: PRESENCIAL
# Agregando id: 1367 -> tipo: PRESENCIAL
# Agregando id: 1368 -> tipo: PRESENCIAL
# Agregando id: 1369 -> tipo: PRESENCIAL
# Agregando id: 1370 -> tipo: PRESENCIAL
# Agregando id: 1371 -> tipo: PRESENCIAL
# Agregando id: 1372 -> tipo: PRESENCIAL
# Agregando id: 1373 -> tipo: PRESENCIAL
# Agregando id: 1374 -> tipo: PRESENCIAL
# Agregando id: 1374 -> tipo: VIRTUAL
# Agregando id: 1375 -> tipo: PRESENCIAL
# Agregando id: 1376 -> tipo: PRESENCIAL
# Agregando id: 1377 -> tipo: PRESENCIAL
# Agregando id: 1378 -> tipo: PRESENCIAL
# Agregando id: 1379 -> tipo: PRESENCIAL
# Agregando id: 1380 -> tipo: VIRTUAL
# Agregando id: 1381 -> tipo: PRESENCIAL
# Agregando id: 1382 -> tipo: PRESENCIAL
# Agregando id: 1383 -> tipo: PRESENCIAL
# Agregando id: 1384 -> tipo: PRESENCIAL
# Agregando id: 1385 -> tipo: PRESENCIAL
# Agregando id: 1386 -> tipo: PRESENCIAL
# Agregando id: 1387 -> tipo: PRESENCIAL
# Agregando id: 1388 -> tipo: PRESENCIAL
# Agregando id: 1389 -> tipo: PRESENCIAL
# Agregando id: 1390 -> tipo: PRESENCIAL
# Agregando id: 1391 -> tipo: PRESENCIAL
# Agregando id: 1392 -> tipo: PRESENCIAL
# Agregando id: 1393 -> tipo: PRESENCIAL
# Agregando id: 1394 -> tipo: PRESENCIAL
# Agregando id: 1395 -> tipo: PRESENCIAL
# Agregando id: 1396 -> tipo: PRESENCIAL
# Agregando id: 1397 -> tipo: PRESENCIAL
# Agregando id: 1398 -> tipo: PRESENCIAL
# Agregando id: 1399 -> tipo: PRESENCIAL
# Agregando id: 1400 -> tipo: PRESENCIAL
# Agregando id: 1401 -> tipo: PRESENCIAL
# Agregando id: 1402 -> tipo: PRESENCIAL
# Agregando id: 1403 -> tipo: PRESENCIAL
# Agregando id: 1404 -> tipo: PRESENCIAL
# Agregando id: 1405 -> tipo: PRESENCIAL
# Agregando id: 1406 -> tipo: PRESENCIAL
# Agregando id: 1407 -> tipo: PRESENCIAL
# Agregando id: 1408 -> tipo: PRESENCIAL
# Agregando id: 1409 -> tipo: PRESENCIAL
# Agregando id: 1416 -> tipo: PRESENCIAL
# Agregando id: 1417 -> tipo: PRESENCIAL
# Agregando id: 1418 -> tipo: PRESENCIAL
# Agregando id: 1419 -> tipo: PRESENCIAL
# Agregando id: 1420 -> tipo: PRESENCIAL
# Agregando id: 1421 -> tipo: PRESENCIAL
# Agregando id: 1422 -> tipo: PRESENCIAL
# Agregando id: 1423 -> tipo: PRESENCIAL
# Agregando id: 1424 -> tipo: PRESENCIAL
# Agregando id: 1425 -> tipo: PRESENCIAL
# Agregando id: 1426 -> tipo: PRESENCIAL
# Agregando id: 1427 -> tipo: PRESENCIAL
# Agregando id: 1428 -> tipo: PRESENCIAL
# Agregando id: 1429 -> tipo: PRESENCIAL
# Agregando id: 1430 -> tipo: PRESENCIAL
# Agregando id: 1431 -> tipo: VIRTUAL
# Agregando id: 1432 -> tipo: VIRTUAL
# Agregando id: 1434 -> tipo: PRESENCIAL
# Agregando id: 1435 -> tipo: PRESENCIAL
# Agregando id: 1436 -> tipo: PRESENCIAL
# Agregando id: 1437 -> tipo: PRESENCIAL
# Agregando id: 1438 -> tipo: PRESENCIAL
# Agregando id: 1439 -> tipo: PRESENCIAL
# Agregando id: 1440 -> tipo: PRESENCIAL
# Agregando id: 1441 -> tipo: PRESENCIAL
# Agregando id: 1442 -> tipo: PRESENCIAL
# Agregando id: 1443 -> tipo: PRESENCIAL
# Agregando id: 1444 -> tipo: PRESENCIAL
# Agregando id: 1445 -> tipo: PRESENCIAL
# Agregando id: 1446 -> tipo: PRESENCIAL
# Agregando id: 1447 -> tipo: PRESENCIAL
# Agregando id: 1448 -> tipo: PRESENCIAL
# Agregando id: 1449 -> tipo: PRESENCIAL
# Agregando id: 1450 -> tipo: PRESENCIAL
# Agregando id: 1451 -> tipo: PRESENCIAL
# Agregando id: 1452 -> tipo: VIRTUAL
# Agregando id: 1454 -> tipo: PRESENCIAL
# Agregando id: 1455 -> tipo: PRESENCIAL
# Agregando id: 1456 -> tipo: PRESENCIAL
# Agregando id: 1457 -> tipo: PRESENCIAL
# Agregando id: 1458 -> tipo: PRESENCIAL
# Agregando id: 1459 -> tipo: PRESENCIAL
# Agregando id: 1460 -> tipo: PRESENCIAL
# Agregando id: 1461 -> tipo: PRESENCIAL
# Agregando id: 1462 -> tipo: PRESENCIAL
# Agregando id: 1463 -> tipo: VIRTUAL
# Agregando id: 1464 -> tipo: PRESENCIAL
# Agregando id: 1465 -> tipo: PRESENCIAL
# Agregando id: 1465 -> tipo: VIRTUAL
# Agregando id: 1466 -> tipo: PRESENCIAL
# Agregando id: 1467 -> tipo: PRESENCIAL
# Agregando id: 1500 -> tipo: PRESENCIAL
# Agregando id: 1501 -> tipo: PRESENCIAL
# Agregando id: 1502 -> tipo: PRESENCIAL
# Agregando id: 1503 -> tipo: PRESENCIAL
# Agregando id: 1504 -> tipo: PRESENCIAL
# Agregando id: 1505 -> tipo: PRESENCIAL
# Agregando id: 1506 -> tipo: PRESENCIAL
# Agregando id: 1507 -> tipo: PRESENCIAL
# Agregando id: 1508 -> tipo: PRESENCIAL
# Agregando id: 1509 -> tipo: PRESENCIAL
# Agregando id: 1510 -> tipo: PRESENCIAL
# Agregando id: 1511 -> tipo: PRESENCIAL
# Agregando id: 1512 -> tipo: PRESENCIAL
# Agregando id: 1513 -> tipo: PRESENCIAL
# Agregando id: 1514 -> tipo: PRESENCIAL
# Agregando id: 1515 -> tipo: PRESENCIAL
# Agregando id: 1516 -> tipo: PRESENCIAL
# Agregando id: 1517 -> tipo: PRESENCIAL
# Agregando id: 1518 -> tipo: PRESENCIAL
# Agregando id: 1519 -> tipo: PRESENCIAL
# Agregando id: 1520 -> tipo: PRESENCIAL
# Agregando id: 1521 -> tipo: PRESENCIAL
# Agregando id: 1522 -> tipo: PRESENCIAL
# Agregando id: 1523 -> tipo: PRESENCIAL
# Agregando id: 1524 -> tipo: PRESENCIAL
# Agregando id: 1525 -> tipo: PRESENCIAL
# Agregando id: 1526 -> tipo: PRESENCIAL
# Agregando id: 1527 -> tipo: PRESENCIAL
# Agregando id: 1528 -> tipo: PRESENCIAL
# Agregando id: 1529 -> tipo: VIRTUAL
# Agregando id: 1531 -> tipo: VIRTUAL
# Agregando id: 1532 -> tipo: PRESENCIAL
# Agregando id: 1533 -> tipo: PRESENCIAL
# Agregando id: 1534 -> tipo: VIRTUAL
# Agregando id: 1535 -> tipo: PRESENCIAL
# Agregando id: 1536 -> tipo: PRESENCIAL
# Agregando id: 1537 -> tipo: VIRTUAL
# Agregando id: 1538 -> tipo: PRESENCIAL
# Agregando id: 1540 -> tipo: PRESENCIAL
# Agregando id: 1541 -> tipo: VIRTUAL
# Agregando id: 1542 -> tipo: VIRTUAL
# Agregando id: 1543 -> tipo: PRESENCIAL
# Agregando id: 1544 -> tipo: PRESENCIAL
# Agregando id: 1545 -> tipo: PRESENCIAL
# Agregando id: 1546 -> tipo: PRESENCIAL
# Agregando id: 1547 -> tipo: PRESENCIAL
# Agregando id: 1548 -> tipo: PRESENCIAL
# Agregando id: 1549 -> tipo: PRESENCIAL
# Agregando id: 1550 -> tipo: PRESENCIAL
# Agregando id: 1551 -> tipo: PRESENCIAL
# Agregando id: 1552 -> tipo: PRESENCIAL
# Agregando id: 1553 -> tipo: PRESENCIAL
# Agregando id: 1554 -> tipo: VIRTUAL
# Agregando id: 1555 -> tipo: PRESENCIAL
# Agregando id: 1556 -> tipo: PRESENCIAL
# Agregando id: 1557 -> tipo: PRESENCIAL
# Agregando id: 1558 -> tipo: PRESENCIAL
# Agregando id: 1559 -> tipo: PRESENCIAL
# Agregando id: 1560 -> tipo: PRESENCIAL
# Agregando id: 1561 -> tipo: PRESENCIAL
# Agregando id: 1562 -> tipo: PRESENCIAL
# Agregando id: 1563 -> tipo: PRESENCIAL
# Agregando id: 1564 -> tipo: PRESENCIAL
# Agregando id: 1565 -> tipo: PRESENCIAL
# Agregando id: 1566 -> tipo: PRESENCIAL
# Agregando id: 1567 -> tipo: PRESENCIAL
# Agregando id: 1568 -> tipo: PRESENCIAL
# Agregando id: 1569 -> tipo: PRESENCIAL
# Agregando id: 1570 -> tipo: VIRTUAL
# Agregando id: 1571 -> tipo: PRESENCIAL
# Agregando id: 1572 -> tipo: PRESENCIAL
# Agregando id: 1573 -> tipo: PRESENCIAL
# Agregando id: 1574 -> tipo: PRESENCIAL
# Agregando id: 1575 -> tipo: PRESENCIAL
# Agregando id: 1576 -> tipo: PRESENCIAL
# Agregando id: 1577 -> tipo: PRESENCIAL
# Agregando id: 1578 -> tipo: PRESENCIAL
# Agregando id: 1579 -> tipo: PRESENCIAL
# Agregando id: 1580 -> tipo: PRESENCIAL
# Agregando id: 1581 -> tipo: PRESENCIAL
# Agregando id: 1582 -> tipo: PRESENCIAL
# Agregando id: 1583 -> tipo: PRESENCIAL
# Agregando id: 1584 -> tipo: PRESENCIAL
# Agregando id: 1585 -> tipo: PRESENCIAL
# Agregando id: 1586 -> tipo: PRESENCIAL
# Agregando id: 1587 -> tipo: PRESENCIAL
# Agregando id: 1588 -> tipo: PRESENCIAL
# Agregando id: 1589 -> tipo: PRESENCIAL
# Agregando id: 1590 -> tipo: PRESENCIAL
# Agregando id: 1591 -> tipo: PRESENCIAL
# Agregando id: 1592 -> tipo: PRESENCIAL
# Agregando id: 1593 -> tipo: PRESENCIAL
# Agregando id: 1594 -> tipo: PRESENCIAL
# Agregando id: 1595 -> tipo: PRESENCIAL
# Agregando id: 1596 -> tipo: PRESENCIAL
# Agregando id: 1597 -> tipo: PRESENCIAL
# Agregando id: 1598 -> tipo: PRESENCIAL
# Agregando id: 1599 -> tipo: PRESENCIAL
# Agregando id: 1600 -> tipo: PRESENCIAL
# Agregando id: 1601 -> tipo: PRESENCIAL
# Agregando id: 1603 -> tipo: PRESENCIAL
# Agregando id: 1604 -> tipo: PRESENCIAL
# Agregando id: 1605 -> tipo: PRESENCIAL
# Agregando id: 1606 -> tipo: PRESENCIAL
# Agregando id: 1607 -> tipo: PRESENCIAL
# Agregando id: 1608 -> tipo: PRESENCIAL
# Agregando id: 1609 -> tipo: PRESENCIAL
# Agregando id: 1610 -> tipo: PRESENCIAL
# Agregando id: 1611 -> tipo: PRESENCIAL
# Agregando id: 1611 -> tipo: VIRTUAL
# Agregando id: 1612 -> tipo: PRESENCIAL
# Agregando id: 1614 -> tipo: PRESENCIAL
# Agregando id: 1615 -> tipo: VIRTUAL
# Agregando id: 1616 -> tipo: PRESENCIAL
# Agregando id: 1617 -> tipo: PRESENCIAL
# Agregando id: 1618 -> tipo: PRESENCIAL
# Agregando id: 1619 -> tipo: PRESENCIAL
# Agregando id: 1620 -> tipo: PRESENCIAL
# Agregando id: 1621 -> tipo: PRESENCIAL
# Agregando id: 1622 -> tipo: PRESENCIAL
# Agregando id: 1623 -> tipo: PRESENCIAL
# Agregando id: 1624 -> tipo: PRESENCIAL
# Agregando id: 1625 -> tipo: PRESENCIAL
# Agregando id: 1626 -> tipo: VIRTUAL
# Agregando id: 1627 -> tipo: VIRTUAL
# Agregando id: 1628 -> tipo: PRESENCIAL
# Agregando id: 1630 -> tipo: PRESENCIAL
# Agregando id: 1631 -> tipo: PRESENCIAL
# Agregando id: 1632 -> tipo: PRESENCIAL
# Agregando id: 1633 -> tipo: PRESENCIAL
# Agregando id: 1634 -> tipo: PRESENCIAL
# Agregando id: 1635 -> tipo: PRESENCIAL
# Agregando id: 1636 -> tipo: PRESENCIAL
# Agregando id: 1637 -> tipo: PRESENCIAL
# Agregando id: 1638 -> tipo: PRESENCIAL
# Agregando id: 1639 -> tipo: PRESENCIAL
# Agregando id: 1642 -> tipo: PRESENCIAL
# Agregando id: 1643 -> tipo: PRESENCIAL
# Agregando id: 1644 -> tipo: PRESENCIAL
# Agregando id: 1645 -> tipo: PRESENCIAL
# Agregando id: 1646 -> tipo: PRESENCIAL
# Agregando id: 1647 -> tipo: PRESENCIAL
# Agregando id: 1648 -> tipo: PRESENCIAL
# Agregando id: 1649 -> tipo: PRESENCIAL
# Agregando id: 1650 -> tipo: PRESENCIAL
# Agregando id: 1651 -> tipo: PRESENCIAL
# Agregando id: 1652 -> tipo: PRESENCIAL
# Agregando id: 1653 -> tipo: PRESENCIAL
# Agregando id: 1654 -> tipo: PRESENCIAL
# Agregando id: 1655 -> tipo: PRESENCIAL
# Agregando id: 1656 -> tipo: PRESENCIAL
# Agregando id: 1657 -> tipo: PRESENCIAL
# Agregando id: 1658 -> tipo: PRESENCIAL
# Agregando id: 1659 -> tipo: PRESENCIAL
# Agregando id: 1660 -> tipo: PRESENCIAL
# Agregando id: 1661 -> tipo: PRESENCIAL
# Agregando id: 1662 -> tipo: PRESENCIAL
# Agregando id: 1663 -> tipo: PRESENCIAL
# Agregando id: 1664 -> tipo: PRESENCIAL
# Agregando id: 1665 -> tipo: VIRTUAL
# Agregando id: 1666 -> tipo: PRESENCIAL
# Agregando id: 1668 -> tipo: PRESENCIAL
# Agregando id: 1669 -> tipo: PRESENCIAL
# Agregando id: 1670 -> tipo: PRESENCIAL
# Agregando id: 1671 -> tipo: PRESENCIAL
# Agregando id: 1672 -> tipo: PRESENCIAL
# Agregando id: 1673 -> tipo: PRESENCIAL
# Agregando id: 1674 -> tipo: PRESENCIAL
# Agregando id: 1675 -> tipo: PRESENCIAL
# Agregando id: 1676 -> tipo: PRESENCIAL
# Agregando id: 1677 -> tipo: PRESENCIAL
# Agregando id: 1678 -> tipo: PRESENCIAL
# Agregando id: 1679 -> tipo: PRESENCIAL
# Agregando id: 1680 -> tipo: PRESENCIAL
# Agregando id: 1681 -> tipo: PRESENCIAL
# Agregando id: 1682 -> tipo: VIRTUAL
# Agregando id: 1683 -> tipo: VIRTUAL
# Agregando id: 1684 -> tipo: PRESENCIAL
# Agregando id: 1685 -> tipo: PRESENCIAL
# Agregando id: 1685 -> tipo: VIRTUAL
# Agregando id: 1686 -> tipo: PRESENCIAL
# Agregando id: 1687 -> tipo: PRESENCIAL
# Agregando id: 1688 -> tipo: PRESENCIAL
# Agregando id: 1689 -> tipo: PRESENCIAL
# Agregando id: 1690 -> tipo: PRESENCIAL
# Agregando id: 1691 -> tipo: PRESENCIAL
# Agregando id: 1692 -> tipo: PRESENCIAL
# Agregando id: 1693 -> tipo: PRESENCIAL
# Agregando id: 1694 -> tipo: PRESENCIAL
# Agregando id: 1695 -> tipo: PRESENCIAL
# Agregando id: 1696 -> tipo: PRESENCIAL
# Agregando id: 1697 -> tipo: PRESENCIAL
# Agregando id: 1698 -> tipo: PRESENCIAL
# Agregando id: 1699 -> tipo: PRESENCIAL
# Agregando id: 1700 -> tipo: PRESENCIAL
# Agregando id: 1701 -> tipo: PRESENCIAL
# Agregando id: 1702 -> tipo: PRESENCIAL
# Agregando id: 1703 -> tipo: PRESENCIAL
# Agregando id: 1704 -> tipo: PRESENCIAL
# Agregando id: 1705 -> tipo: PRESENCIAL
# Agregando id: 1706 -> tipo: PRESENCIAL
# Agregando id: 1707 -> tipo: PRESENCIAL
# Agregando id: 1708 -> tipo: PRESENCIAL
# Agregando id: 1709 -> tipo: PRESENCIAL
# Agregando id: 1710 -> tipo: VIRTUAL
# Agregando id: 1711 -> tipo: VIRTUAL
# Agregando id: 1712 -> tipo: VIRTUAL
# Agregando id: 1713 -> tipo: PRESENCIAL
# Agregando id: 1714 -> tipo: VIRTUAL
# Agregando id: 1715 -> tipo: PRESENCIAL
# Agregando id: 1716 -> tipo: PRESENCIAL
# Agregando id: 1718 -> tipo: PRESENCIAL
# Agregando id: 1719 -> tipo: PRESENCIAL
# Agregando id: 1720 -> tipo: PRESENCIAL
# Agregando id: 1721 -> tipo: PRESENCIAL
# Agregando id: 1722 -> tipo: PRESENCIAL
# Agregando id: 1724 -> tipo: PRESENCIAL
# Agregando id: 1725 -> tipo: PRESENCIAL
# Agregando id: 1726 -> tipo: PRESENCIAL
# Agregando id: 1727 -> tipo: PRESENCIAL
# Agregando id: 1728 -> tipo: PRESENCIAL
# Agregando id: 1729 -> tipo: PRESENCIAL
# Agregando id: 1730 -> tipo: PRESENCIAL
# Agregando id: 1731 -> tipo: PRESENCIAL
# Agregando id: 1732 -> tipo: PRESENCIAL
# Agregando id: 1733 -> tipo: PRESENCIAL
# Agregando id: 1734 -> tipo: PRESENCIAL
# Agregando id: 1735 -> tipo: PRESENCIAL
# Agregando id: 1736 -> tipo: PRESENCIAL
# Agregando id: 1737 -> tipo: PRESENCIAL
# Agregando id: 1739 -> tipo: PRESENCIAL
# Agregando id: 1740 -> tipo: PRESENCIAL
# Agregando id: 1741 -> tipo: PRESENCIAL
# Agregando id: 1743 -> tipo: PRESENCIAL
# Agregando id: 1744 -> tipo: PRESENCIAL
# Agregando id: 1745 -> tipo: PRESENCIAL
# Agregando id: 1746 -> tipo: PRESENCIAL
# Agregando id: 1747 -> tipo: PRESENCIAL
# Agregando id: 1748 -> tipo: PRESENCIAL
# Agregando id: 1749 -> tipo: PRESENCIAL
# Agregando id: 1750 -> tipo: PRESENCIAL
# Agregando id: 1751 -> tipo: PRESENCIAL
# Agregando id: 1753 -> tipo: PRESENCIAL
# Agregando id: 1754 -> tipo: PRESENCIAL
# Agregando id: 1755 -> tipo: PRESENCIAL
# Agregando id: 1756 -> tipo: PRESENCIAL
# Agregando id: 1757 -> tipo: PRESENCIAL
# Agregando id: 1758 -> tipo: PRESENCIAL
# Agregando id: 1759 -> tipo: PRESENCIAL
# Agregando id: 1760 -> tipo: PRESENCIAL
# Agregando id: 1761 -> tipo: PRESENCIAL
# Agregando id: 1762 -> tipo: PRESENCIAL
# Agregando id: 1763 -> tipo: VIRTUAL
# Agregando id: 1764 -> tipo: PRESENCIAL
# Agregando id: 1765 -> tipo: PRESENCIAL
# Agregando id: 1766 -> tipo: PRESENCIAL
# Agregando id: 1767 -> tipo: PRESENCIAL
# Agregando id: 1769 -> tipo: PRESENCIAL
# Agregando id: 1770 -> tipo: PRESENCIAL
# Agregando id: 1771 -> tipo: PRESENCIAL
# Agregando id: 1772 -> tipo: PRESENCIAL
# Agregando id: 1773 -> tipo: PRESENCIAL
# Agregando id: 1774 -> tipo: PRESENCIAL
# Agregando id: 1775 -> tipo: PRESENCIAL
# Agregando id: 1776 -> tipo: PRESENCIAL
# Agregando id: 1777 -> tipo: PRESENCIAL
# Agregando id: 1778 -> tipo: PRESENCIAL
# Agregando id: 1779 -> tipo: PRESENCIAL
# Agregando id: 1812 -> tipo: PRESENCIAL
# Agregando id: 1813 -> tipo: PRESENCIAL
# Agregando id: 1814 -> tipo: PRESENCIAL
# Agregando id: 1815 -> tipo: PRESENCIAL
# Agregando id: 1816 -> tipo: PRESENCIAL
# Agregando id: 1817 -> tipo: PRESENCIAL
# Agregando id: 1818 -> tipo: PRESENCIAL
# Agregando id: 1819 -> tipo: PRESENCIAL
# Agregando id: 1820 -> tipo: PRESENCIAL
# Agregando id: 1821 -> tipo: PRESENCIAL
# Agregando id: 1822 -> tipo: PRESENCIAL
# Agregando id: 1823 -> tipo: PRESENCIAL
# Agregando id: 1824 -> tipo: PRESENCIAL
# Agregando id: 1825 -> tipo: PRESENCIAL
# Agregando id: 1826 -> tipo: PRESENCIAL
# Agregando id: 1827 -> tipo: PRESENCIAL
# Agregando id: 1828 -> tipo: PRESENCIAL
# Agregando id: 1829 -> tipo: PRESENCIAL
# Agregando id: 1830 -> tipo: PRESENCIAL
# Agregando id: 1831 -> tipo: PRESENCIAL
# Agregando id: 1832 -> tipo: PRESENCIAL
# Agregando id: 1865 -> tipo: PRESENCIAL
# Agregando id: 1866 -> tipo: PRESENCIAL
# Agregando id: 1867 -> tipo: PRESENCIAL
# Agregando id: 1868 -> tipo: PRESENCIAL
# Agregando id: 1869 -> tipo: PRESENCIAL
# Agregando id: 1870 -> tipo: PRESENCIAL
# Agregando id: 1871 -> tipo: PRESENCIAL
# Agregando id: 1872 -> tipo: PRESENCIAL
# Agregando id: 1873 -> tipo: VIRTUAL
# Agregando id: 1874 -> tipo: VIRTUAL
# Agregando id: 1875 -> tipo: PRESENCIAL
# Agregando id: 1876 -> tipo: PRESENCIAL
# Agregando id: 1877 -> tipo: PRESENCIAL
# Agregando id: 1878 -> tipo: PRESENCIAL
# Agregando id: 1879 -> tipo: PRESENCIAL
# Agregando id: 1880 -> tipo: PRESENCIAL
# Agregando id: 1881 -> tipo: PRESENCIAL
# Agregando id: 1882 -> tipo: PRESENCIAL
# Agregando id: 1883 -> tipo: PRESENCIAL
# Agregando id: 1885 -> tipo: PRESENCIAL
# Agregando id: 1888 -> tipo: PRESENCIAL
# Agregando id: 1891 -> tipo: PRESENCIAL
# Agregando id: 1892 -> tipo: PRESENCIAL
# Agregando id: 1894 -> tipo: PRESENCIAL
# Agregando id: 1895 -> tipo: PRESENCIAL
# Agregando id: 1896 -> tipo: PRESENCIAL
# Agregando id: 1897 -> tipo: PRESENCIAL
# Agregando id: 1898 -> tipo: PRESENCIAL
# Agregando id: 1899 -> tipo: PRESENCIAL
# Agregando id: 1900 -> tipo: PRESENCIAL
# Agregando id: 1901 -> tipo: PRESENCIAL
# Agregando id: 1902 -> tipo: PRESENCIAL
# Agregando id: 1903 -> tipo: VIRTUAL
# Agregando id: 1904 -> tipo: PRESENCIAL
# Agregando id: 1905 -> tipo: VIRTUAL
# Agregando id: 1906 -> tipo: PRESENCIAL
# Agregando id: 1907 -> tipo: PRESENCIAL
# Agregando id: 1908 -> tipo: PRESENCIAL
# Agregando id: 1909 -> tipo: PRESENCIAL
# Agregando id: 1910 -> tipo: PRESENCIAL
# Agregando id: 1912 -> tipo: PRESENCIAL
# Agregando id: 1913 -> tipo: PRESENCIAL
# Agregando id: 1914 -> tipo: PRESENCIAL
# Agregando id: 1915 -> tipo: PRESENCIAL
# Agregando id: 1916 -> tipo: PRESENCIAL
# Agregando id: 1917 -> tipo: PRESENCIAL
# Agregando id: 1918 -> tipo: PRESENCIAL
# Agregando id: 1919 -> tipo: PRESENCIAL
# Agregando id: 1920 -> tipo: PRESENCIAL
# Agregando id: 1922 -> tipo: PRESENCIAL
# Agregando id: 1923 -> tipo: PRESENCIAL
# Agregando id: 1924 -> tipo: PRESENCIAL
# Agregando id: 1925 -> tipo: PRESENCIAL
# Agregando id: 1958 -> tipo: PRESENCIAL
# Agregando id: 1959 -> tipo: PRESENCIAL
# Agregando id: 1960 -> tipo: PRESENCIAL
# Agregando id: 1964 -> tipo: PRESENCIAL
# Agregando id: 1966 -> tipo: PRESENCIAL
# Agregando id: 1967 -> tipo: PRESENCIAL
# Agregando id: 1968 -> tipo: PRESENCIAL
# Agregando id: 1969 -> tipo: PRESENCIAL
# Agregando id: 1970 -> tipo: PRESENCIAL
# Agregando id: 1971 -> tipo: PRESENCIAL
# Agregando id: 1973 -> tipo: PRESENCIAL
# Agregando id: 1974 -> tipo: PRESENCIAL
# Agregando id: 1975 -> tipo: PRESENCIAL
# Agregando id: 1976 -> tipo: PRESENCIAL
# Agregando id: 1978 -> tipo: PRESENCIAL
# Agregando id: 1979 -> tipo: PRESENCIAL
# Agregando id: 1980 -> tipo: PRESENCIAL
# Agregando id: 1982 -> tipo: PRESENCIAL
# Agregando id: 1983 -> tipo: PRESENCIAL
# Agregando id: 1984 -> tipo: PRESENCIAL
# Agregando id: 1985 -> tipo: PRESENCIAL
# Agregando id: 1986 -> tipo: PRESENCIAL
# Agregando id: 1987 -> tipo: PRESENCIAL
# Agregando id: 1988 -> tipo: PRESENCIAL
# Agregando id: 1989 -> tipo: PRESENCIAL
# Agregando id: 1990 -> tipo: PRESENCIAL
# Agregando id: 1991 -> tipo: PRESENCIAL
# Agregando id: 1992 -> tipo: PRESENCIAL
# Agregando id: 1993 -> tipo: VIRTUAL
# Agregando id: 1995 -> tipo: PRESENCIAL
# Agregando id: 1996 -> tipo: PRESENCIAL
# Agregando id: 1997 -> tipo: PRESENCIAL
# Agregando id: 2003 -> tipo: PRESENCIAL
# Agregando id: 2006 -> tipo: PRESENCIAL
# Agregando id: 2007 -> tipo: PRESENCIAL
# Agregando id: 2008 -> tipo: PRESENCIAL
# Agregando id: 2009 -> tipo: VIRTUAL
# Agregando id: 2010 -> tipo: PRESENCIAL
# Agregando id: 2011 -> tipo: PRESENCIAL
# Agregando id: 2012 -> tipo: PRESENCIAL
# Agregando id: 2014 -> tipo: PRESENCIAL
# Agregando id: 2015 -> tipo: PRESENCIAL
# Agregando id: 2016 -> tipo: PRESENCIAL
# Agregando id: 2017 -> tipo: PRESENCIAL
# Agregando id: 2018 -> tipo: PRESENCIAL
# Agregando id: 2019 -> tipo: PRESENCIAL
# Agregando id: 2020 -> tipo: VIRTUAL
# Agregando id: 2022 -> tipo: PRESENCIAL
# Agregando id: 2023 -> tipo: PRESENCIAL
# Agregando id: 2024 -> tipo: PRESENCIAL
# Agregando id: 2025 -> tipo: PRESENCIAL
# Agregando id: 2038 -> tipo: VIRTUAL
# Agregando id: 2039 -> tipo: VIRTUAL
# Agregando id: 2040 -> tipo: VIRTUAL
# Agregando id: 2041 -> tipo: VIRTUAL
# Agregando id: 2042 -> tipo: PRESENCIAL
# Agregando id: 2043 -> tipo: PRESENCIAL
# Agregando id: 2044 -> tipo: PRESENCIAL
# Agregando id: 2045 -> tipo: PRESENCIAL
# Agregando id: 2046 -> tipo: PRESENCIAL
# Agregando id: 2047 -> tipo: PRESENCIAL
# Agregando id: 2048 -> tipo: PRESENCIAL
# Agregando id: 2049 -> tipo: PRESENCIAL
# Agregando id: 2050 -> tipo: PRESENCIAL
# Agregando id: 2051 -> tipo: PRESENCIAL
# Agregando id: 2052 -> tipo: PRESENCIAL
# Agregando id: 2053 -> tipo: PRESENCIAL
# Agregando id: 2054 -> tipo: PRESENCIAL
# Agregando id: 2055 -> tipo: PRESENCIAL
# Agregando id: 2056 -> tipo: PRESENCIAL
# Agregando id: 2057 -> tipo: PRESENCIAL
# Agregando id: 2058 -> tipo: PRESENCIAL
# Agregando id: 2059 -> tipo: PRESENCIAL
# Agregando id: 2060 -> tipo: PRESENCIAL
# Agregando id: 2061 -> tipo: PRESENCIAL
# Agregando id: 2062 -> tipo: PRESENCIAL
# Agregando id: 2063 -> tipo: PRESENCIAL
# Agregando id: 2064 -> tipo: PRESENCIAL
# Agregando id: 2065 -> tipo: PRESENCIAL
# Agregando id: 2066 -> tipo: PRESENCIAL
# Agregando id: 2067 -> tipo: PRESENCIAL
# Agregando id: 2068 -> tipo: PRESENCIAL
# Agregando id: 2069 -> tipo: PRESENCIAL
# Agregando id: 2070 -> tipo: PRESENCIAL
# Agregando id: 2071 -> tipo: PRESENCIAL
# Agregando id: 2072 -> tipo: PRESENCIAL
# Agregando id: 2073 -> tipo: PRESENCIAL
# Agregando id: 2074 -> tipo: PRESENCIAL
# Agregando id: 2075 -> tipo: PRESENCIAL
# Agregando id: 2076 -> tipo: PRESENCIAL
# Agregando id: 2077 -> tipo: PRESENCIAL
# Agregando id: 2078 -> tipo: PRESENCIAL
# Agregando id: 2079 -> tipo: PRESENCIAL
# Agregando id: 2080 -> tipo: PRESENCIAL
# Agregando id: 2081 -> tipo: PRESENCIAL
# Agregando id: 2082 -> tipo: PRESENCIAL
# Agregando id: 2083 -> tipo: PRESENCIAL
# Agregando id: 2084 -> tipo: PRESENCIAL
# Agregando id: 2085 -> tipo: PRESENCIAL
# Agregando id: 2086 -> tipo: PRESENCIAL
# Agregando id: 2087 -> tipo: PRESENCIAL
# Agregando id: 2088 -> tipo: PRESENCIAL
# Agregando id: 2089 -> tipo: PRESENCIAL
# Agregando id: 2090 -> tipo: PRESENCIAL
# Agregando id: 2091 -> tipo: PRESENCIAL
# Agregando id: 2092 -> tipo: PRESENCIAL
# Agregando id: 2093 -> tipo: PRESENCIAL
# Agregando id: 2094 -> tipo: PRESENCIAL
# Agregando id: 2095 -> tipo: PRESENCIAL
# Agregando id: 2096 -> tipo: PRESENCIAL
# Agregando id: 2097 -> tipo: PRESENCIAL
# Agregando id: 2098 -> tipo: PRESENCIAL
# Agregando id: 2099 -> tipo: PRESENCIAL
# Agregando id: 2100 -> tipo: PRESENCIAL
# Agregando id: 2101 -> tipo: PRESENCIAL
# Agregando id: 2102 -> tipo: PRESENCIAL
# Agregando id: 2103 -> tipo: PRESENCIAL
# Agregando id: 2104 -> tipo: PRESENCIAL
# Agregando id: 2105 -> tipo: PRESENCIAL
# Agregando id: 2106 -> tipo: PRESENCIAL
# Agregando id: 2107 -> tipo: PRESENCIAL
# Agregando id: 2108 -> tipo: PRESENCIAL
# Agregando id: 2109 -> tipo: PRESENCIAL
# Agregando id: 2110 -> tipo: PRESENCIAL
# Agregando id: 2111 -> tipo: PRESENCIAL
# Agregando id: 2113 -> tipo: PRESENCIAL
# Agregando id: 2114 -> tipo: PRESENCIAL
# Agregando id: 2115 -> tipo: PRESENCIAL
# Agregando id: 2116 -> tipo: PRESENCIAL
# Agregando id: 2117 -> tipo: PRESENCIAL
# Agregando id: 2118 -> tipo: PRESENCIAL
# Agregando id: 2119 -> tipo: PRESENCIAL
# Agregando id: 2120 -> tipo: PRESENCIAL
# Agregando id: 2121 -> tipo: PRESENCIAL
# Agregando id: 2122 -> tipo: PRESENCIAL
# Agregando id: 2123 -> tipo: PRESENCIAL
# Agregando id: 2124 -> tipo: PRESENCIAL
# Agregando id: 2125 -> tipo: PRESENCIAL
# Agregando id: 2126 -> tipo: PRESENCIAL
# Agregando id: 2127 -> tipo: PRESENCIAL
# Agregando id: 2128 -> tipo: PRESENCIAL
# Agregando id: 2129 -> tipo: PRESENCIAL
# Agregando id: 2130 -> tipo: PRESENCIAL
# Agregando id: 2131 -> tipo: PRESENCIAL
# Agregando id: 2134 -> tipo: PRESENCIAL
# Agregando id: 2135 -> tipo: PRESENCIAL
# Agregando id: 2136 -> tipo: PRESENCIAL
# Agregando id: 2137 -> tipo: VIRTUAL
# Agregando id: 2138 -> tipo: PRESENCIAL
# Agregando id: 2139 -> tipo: PRESENCIAL
# Agregando id: 2140 -> tipo: VIRTUAL
# Agregando id: 2141 -> tipo: VIRTUAL
# Agregando id: 2142 -> tipo: VIRTUAL
# Agregando id: 2143 -> tipo: VIRTUAL
# Agregando id: 2144 -> tipo: VIRTUAL
# Agregando id: 2145 -> tipo: VIRTUAL
# Agregando id: 2146 -> tipo: PRESENCIAL
# Agregando id: 2146 -> tipo: VIRTUAL
# Agregando id: 2148 -> tipo: PRESENCIAL
# Agregando id: 2150 -> tipo: PRESENCIAL
# Agregando id: 2151 -> tipo: PRESENCIAL
# Agregando id: 2152 -> tipo: PRESENCIAL
# Agregando id: 2155 -> tipo: PRESENCIAL
# Agregando id: 2157 -> tipo: PRESENCIAL
# Agregando id: 2159 -> tipo: PRESENCIAL
# Agregando id: 2160 -> tipo: PRESENCIAL
# Agregando id: 2161 -> tipo: PRESENCIAL
# Agregando id: 2162 -> tipo: PRESENCIAL
# Agregando id: 2163 -> tipo: PRESENCIAL
# Agregando id: 2164 -> tipo: PRESENCIAL
# Agregando id: 2165 -> tipo: PRESENCIAL
# Agregando id: 2166 -> tipo: PRESENCIAL
# Agregando id: 2167 -> tipo: PRESENCIAL
# Agregando id: 2168 -> tipo: PRESENCIAL
# Agregando id: 2169 -> tipo: PRESENCIAL
# Agregando id: 2170 -> tipo: PRESENCIAL
# Agregando id: 2171 -> tipo: PRESENCIAL
# Agregando id: 2172 -> tipo: PRESENCIAL
# Agregando id: 2173 -> tipo: PRESENCIAL
# Agregando id: 2208 -> tipo: PRESENCIAL
# Agregando id: 2209 -> tipo: PRESENCIAL
# Agregando id: 2210 -> tipo: PRESENCIAL
# Agregando id: 2211 -> tipo: PRESENCIAL
# Agregando id: 2212 -> tipo: PRESENCIAL
# Agregando id: 2213 -> tipo: PRESENCIAL
# Agregando id: 2214 -> tipo: PRESENCIAL
# Agregando id: 2215 -> tipo: PRESENCIAL
# Agregando id: 2216 -> tipo: PRESENCIAL
# Agregando id: 2217 -> tipo: PRESENCIAL
# Agregando id: 2218 -> tipo: PRESENCIAL
# Agregando id: 2219 -> tipo: PRESENCIAL
# Agregando id: 2220 -> tipo: PRESENCIAL
# Agregando id: 2221 -> tipo: PRESENCIAL
# Agregando id: 2222 -> tipo: PRESENCIAL
# Agregando id: 2223 -> tipo: PRESENCIAL
# Agregando id: 2224 -> tipo: PRESENCIAL
# Agregando id: 2225 -> tipo: PRESENCIAL
# Agregando id: 2226 -> tipo: PRESENCIAL
# Agregando id: 2227 -> tipo: PRESENCIAL
# Agregando id: 2228 -> tipo: PRESENCIAL
# Agregando id: 2229 -> tipo: PRESENCIAL
# Agregando id: 2230 -> tipo: PRESENCIAL
# Agregando id: 2231 -> tipo: PRESENCIAL
# Agregando id: 2232 -> tipo: PRESENCIAL
# Agregando id: 2233 -> tipo: PRESENCIAL
# Agregando id: 2234 -> tipo: PRESENCIAL
# Agregando id: 2235 -> tipo: PRESENCIAL
# Agregando id: 2236 -> tipo: PRESENCIAL
# Agregando id: 2237 -> tipo: PRESENCIAL
# Agregando id: 2238 -> tipo: PRESENCIAL
# Agregando id: 2239 -> tipo: PRESENCIAL
# Agregando id: 2240 -> tipo: PRESENCIAL
# Agregando id: 2241 -> tipo: PRESENCIAL
# Agregando id: 2242 -> tipo: PRESENCIAL
# Agregando id: 2243 -> tipo: PRESENCIAL
# Agregando id: 2244 -> tipo: PRESENCIAL
# Agregando id: 2246 -> tipo: PRESENCIAL
# Agregando id: 2247 -> tipo: PRESENCIAL
# Agregando id: 2249 -> tipo: PRESENCIAL
# Agregando id: 2250 -> tipo: PRESENCIAL
# Agregando id: 2252 -> tipo: VIRTUAL
# Agregando id: 2253 -> tipo: PRESENCIAL
# Agregando id: 2254 -> tipo: PRESENCIAL
# Agregando id: 2255 -> tipo: PRESENCIAL
# Agregando id: 2256 -> tipo: PRESENCIAL
# Agregando id: 2257 -> tipo: PRESENCIAL
# Agregando id: 2258 -> tipo: PRESENCIAL
# Agregando id: 2259 -> tipo: PRESENCIAL
# Agregando id: 2260 -> tipo: PRESENCIAL
# Agregando id: 2261 -> tipo: PRESENCIAL
# Agregando id: 2262 -> tipo: PRESENCIAL
# Agregando id: 2263 -> tipo: PRESENCIAL
# Agregando id: 2264 -> tipo: PRESENCIAL
# Agregando id: 2265 -> tipo: PRESENCIAL
# Agregando id: 2267 -> tipo: VIRTUAL
# Agregando id: 2268 -> tipo: VIRTUAL
# Agregando id: 2269 -> tipo: PRESENCIAL
# Agregando id: 2269 -> tipo: VIRTUAL
# Agregando id: 2270 -> tipo: VIRTUAL
# Agregando id: 2272 -> tipo: PRESENCIAL
# Agregando id: 2273 -> tipo: PRESENCIAL
# Agregando id: 2275 -> tipo: PRESENCIAL
# Agregando id: 2279 -> tipo: PRESENCIAL
# Agregando id: 2281 -> tipo: PRESENCIAL
# Agregando id: 2282 -> tipo: PRESENCIAL
# Agregando id: 2284 -> tipo: PRESENCIAL
# Agregando id: 2285 -> tipo: PRESENCIAL
# Agregando id: 2286 -> tipo: PRESENCIAL
# Agregando id: 2287 -> tipo: PRESENCIAL
# Agregando id: 2288 -> tipo: PRESENCIAL
# Agregando id: 2289 -> tipo: PRESENCIAL
# Agregando id: 2290 -> tipo: PRESENCIAL
# Agregando id: 2291 -> tipo: PRESENCIAL
# Agregando id: 2292 -> tipo: PRESENCIAL
# Agregando id: 2293 -> tipo: PRESENCIAL
# Agregando id: 2294 -> tipo: PRESENCIAL
# Agregando id: 2295 -> tipo: PRESENCIAL
# Agregando id: 2296 -> tipo: PRESENCIAL
# Agregando id: 2297 -> tipo: PRESENCIAL
# Agregando id: 2298 -> tipo: PRESENCIAL
# Agregando id: 2301 -> tipo: PRESENCIAL
# Agregando id: 2303 -> tipo: PRESENCIAL
# Agregando id: 2304 -> tipo: PRESENCIAL
# Agregando id: 2305 -> tipo: PRESENCIAL
# Agregando id: 2306 -> tipo: PRESENCIAL
# Agregando id: 2307 -> tipo: PRESENCIAL
# Agregando id: 2308 -> tipo: PRESENCIAL
# Agregando id: 2309 -> tipo: PRESENCIAL
# Agregando id: 2310 -> tipo: PRESENCIAL
# Agregando id: 2311 -> tipo: PRESENCIAL
# Agregando id: 2313 -> tipo: PRESENCIAL
# Agregando id: 2314 -> tipo: PRESENCIAL
# Agregando id: 2315 -> tipo: PRESENCIAL
# Agregando id: 2316 -> tipo: PRESENCIAL
# Agregando id: 2317 -> tipo: PRESENCIAL
# Agregando id: 2318 -> tipo: PRESENCIAL
# Agregando id: 2319 -> tipo: PRESENCIAL
# Agregando id: 2321 -> tipo: PRESENCIAL
# Agregando id: 2322 -> tipo: PRESENCIAL
# Agregando id: 2323 -> tipo: PRESENCIAL
# Agregando id: 2324 -> tipo: PRESENCIAL
# Agregando id: 2325 -> tipo: PRESENCIAL
# Agregando id: 2326 -> tipo: PRESENCIAL
# Agregando id: 2327 -> tipo: PRESENCIAL
# Agregando id: 2328 -> tipo: PRESENCIAL
# Agregando id: 2329 -> tipo: PRESENCIAL
# Agregando id: 2330 -> tipo: PRESENCIAL
# Agregando id: 2331 -> tipo: PRESENCIAL
# Agregando id: 2332 -> tipo: PRESENCIAL
# Agregando id: 2333 -> tipo: PRESENCIAL
# Agregando id: 2334 -> tipo: PRESENCIAL
# Agregando id: 2335 -> tipo: PRESENCIAL
# Agregando id: 2336 -> tipo: PRESENCIAL
# Agregando id: 2338 -> tipo: PRESENCIAL
# Agregando id: 2339 -> tipo: PRESENCIAL
# Agregando id: 2340 -> tipo: PRESENCIAL
# Agregando id: 2341 -> tipo: PRESENCIAL
# Agregando id: 2342 -> tipo: PRESENCIAL
# Agregando id: 2343 -> tipo: PRESENCIAL
# Agregando id: 2344 -> tipo: PRESENCIAL
# Agregando id: 2346 -> tipo: PRESENCIAL
# Agregando id: 2347 -> tipo: PRESENCIAL
# Agregando id: 2348 -> tipo: PRESENCIAL
# Agregando id: 2349 -> tipo: PRESENCIAL
# Agregando id: 2350 -> tipo: PRESENCIAL
# Agregando id: 2351 -> tipo: PRESENCIAL
# Agregando id: 2352 -> tipo: PRESENCIAL
# Agregando id: 2353 -> tipo: PRESENCIAL
# Agregando id: 2354 -> tipo: PRESENCIAL
# Agregando id: 2355 -> tipo: PRESENCIAL
# Agregando id: 2356 -> tipo: PRESENCIAL
# Agregando id: 2357 -> tipo: PRESENCIAL
# Agregando id: 2358 -> tipo: PRESENCIAL
# Agregando id: 2359 -> tipo: PRESENCIAL
# Agregando id: 2360 -> tipo: PRESENCIAL
# Agregando id: 2361 -> tipo: PRESENCIAL
# Agregando id: 2362 -> tipo: PRESENCIAL
# Agregando id: 2363 -> tipo: PRESENCIAL
# Agregando id: 2364 -> tipo: PRESENCIAL
# Agregando id: 2365 -> tipo: PRESENCIAL
# Agregando id: 2366 -> tipo: PRESENCIAL
# Agregando id: 2367 -> tipo: PRESENCIAL
# Agregando id: 2368 -> tipo: PRESENCIAL
# Agregando id: 2369 -> tipo: PRESENCIAL
# Agregando id: 2370 -> tipo: PRESENCIAL
# Agregando id: 2371 -> tipo: PRESENCIAL
# Agregando id: 2372 -> tipo: PRESENCIAL
# Agregando id: 2373 -> tipo: PRESENCIAL
# Agregando id: 2374 -> tipo: PRESENCIAL
# Agregando id: 2375 -> tipo: PRESENCIAL
# Agregando id: 2376 -> tipo: PRESENCIAL
# Agregando id: 2377 -> tipo: PRESENCIAL
# Agregando id: 2378 -> tipo: PRESENCIAL
# Agregando id: 2379 -> tipo: PRESENCIAL
# Agregando id: 2380 -> tipo: PRESENCIAL
# Agregando id: 2381 -> tipo: PRESENCIAL
# Agregando id: 2382 -> tipo: PRESENCIAL
# Agregando id: 2383 -> tipo: PRESENCIAL
# Agregando id: 2384 -> tipo: PRESENCIAL
# Agregando id: 2385 -> tipo: PRESENCIAL
# Agregando id: 2386 -> tipo: PRESENCIAL
# Agregando id: 2387 -> tipo: PRESENCIAL
# Agregando id: 2388 -> tipo: PRESENCIAL
# Agregando id: 2389 -> tipo: PRESENCIAL
# Agregando id: 2390 -> tipo: PRESENCIAL
# Agregando id: 2391 -> tipo: PRESENCIAL
# Agregando id: 2392 -> tipo: PRESENCIAL
# Agregando id: 2393 -> tipo: PRESENCIAL
# Agregando id: 2394 -> tipo: PRESENCIAL
# Agregando id: 2395 -> tipo: PRESENCIAL
# Agregando id: 2396 -> tipo: PRESENCIAL
# Agregando id: 2397 -> tipo: PRESENCIAL
# Agregando id: 2398 -> tipo: VIRTUAL
# Agregando id: 2399 -> tipo: PRESENCIAL
# Agregando id: 2400 -> tipo: PRESENCIAL
# Agregando id: 2401 -> tipo: PRESENCIAL
# Agregando id: 2405 -> tipo: PRESENCIAL
# Agregando id: 2408 -> tipo: VIRTUAL
# Agregando id: 2409 -> tipo: PRESENCIAL
# Agregando id: 2409 -> tipo: VIRTUAL
# Agregando id: 2410 -> tipo: PRESENCIAL
# Agregando id: 2412 -> tipo: PRESENCIAL
# Agregando id: 2413 -> tipo: VIRTUAL
# Agregando id: 2415 -> tipo: PRESENCIAL
# Agregando id: 2416 -> tipo: VIRTUAL
# Agregando id: 2417 -> tipo: PRESENCIAL
# Agregando id: 2418 -> tipo: PRESENCIAL
# Agregando id: 2419 -> tipo: VIRTUAL
# Agregando id: 2420 -> tipo: PRESENCIAL
# Agregando id: 2421 -> tipo: PRESENCIAL
# Agregando id: 2422 -> tipo: PRESENCIAL
# Agregando id: 2423 -> tipo: VIRTUAL
# Agregando id: 2424 -> tipo: PRESENCIAL
# Agregando id: 2425 -> tipo: PRESENCIAL
# Agregando id: 2426 -> tipo: PRESENCIAL
# Agregando id: 2427 -> tipo: PRESENCIAL
# Agregando id: 2428 -> tipo: PRESENCIAL
# Agregando id: 2429 -> tipo: PRESENCIAL
# Agregando id: 2430 -> tipo: PRESENCIAL
# Agregando id: 2431 -> tipo: PRESENCIAL
# Agregando id: 2432 -> tipo: PRESENCIAL
# Agregando id: 2433 -> tipo: PRESENCIAL
# Agregando id: 2434 -> tipo: PRESENCIAL
# Agregando id: 2435 -> tipo: PRESENCIAL
# Agregando id: 2436 -> tipo: PRESENCIAL
# Agregando id: 2437 -> tipo: PRESENCIAL
# Agregando id: 2438 -> tipo: PRESENCIAL
# Agregando id: 2439 -> tipo: PRESENCIAL
# Agregando id: 2441 -> tipo: PRESENCIAL
# Agregando id: 2442 -> tipo: PRESENCIAL
# Agregando id: 2443 -> tipo: PRESENCIAL
# Agregando id: 2444 -> tipo: PRESENCIAL
# Agregando id: 2445 -> tipo: PRESENCIAL
# Agregando id: 2446 -> tipo: PRESENCIAL
# Agregando id: 2447 -> tipo: PRESENCIAL
# Agregando id: 2448 -> tipo: PRESENCIAL
# Agregando id: 2449 -> tipo: PRESENCIAL
# Agregando id: 2450 -> tipo: PRESENCIAL
# Agregando id: 2451 -> tipo: PRESENCIAL
# Agregando id: 2452 -> tipo: PRESENCIAL
# Agregando id: 2453 -> tipo: PRESENCIAL
# Agregando id: 2454 -> tipo: PRESENCIAL
# Agregando id: 2455 -> tipo: PRESENCIAL
# Agregando id: 2456 -> tipo: PRESENCIAL
# Agregando id: 2457 -> tipo: PRESENCIAL
# Agregando id: 2458 -> tipo: PRESENCIAL
# Agregando id: 2459 -> tipo: PRESENCIAL
# Agregando id: 2460 -> tipo: PRESENCIAL
# Agregando id: 2461 -> tipo: PRESENCIAL
# Agregando id: 2462 -> tipo: VIRTUAL
# Agregando id: 2463 -> tipo: PRESENCIAL
# Agregando id: 2464 -> tipo: PRESENCIAL
# Agregando id: 2465 -> tipo: VIRTUAL
# Agregando id: 2466 -> tipo: VIRTUAL
# Agregando id: 2467 -> tipo: VIRTUAL
# Agregando id: 2468 -> tipo: VIRTUAL
# Agregando id: 2469 -> tipo: PRESENCIAL
# Agregando id: 2470 -> tipo: PRESENCIAL
# Agregando id: 2471 -> tipo: PRESENCIAL
# Agregando id: 2472 -> tipo: PRESENCIAL
# Agregando id: 2473 -> tipo: PRESENCIAL
# Agregando id: 2474 -> tipo: PRESENCIAL
# Agregando id: 2475 -> tipo: PRESENCIAL
# Agregando id: 2476 -> tipo: PRESENCIAL
# Agregando id: 2477 -> tipo: PRESENCIAL
# Agregando id: 2478 -> tipo: PRESENCIAL
# Agregando id: 2479 -> tipo: PRESENCIAL
# Agregando id: 2480 -> tipo: PRESENCIAL
# Agregando id: 2483 -> tipo: PRESENCIAL
# Agregando id: 2484 -> tipo: PRESENCIAL
# Agregando id: 2485 -> tipo: PRESENCIAL
# Agregando id: 2486 -> tipo: PRESENCIAL
# Agregando id: 2487 -> tipo: PRESENCIAL
# Agregando id: 2488 -> tipo: PRESENCIAL
# Agregando id: 2489 -> tipo: PRESENCIAL
# Agregando id: 2490 -> tipo: PRESENCIAL
# Agregando id: 2491 -> tipo: PRESENCIAL
# Agregando id: 2492 -> tipo: PRESENCIAL
# Agregando id: 2493 -> tipo: PRESENCIAL
# Agregando id: 2494 -> tipo: PRESENCIAL
# Agregando id: 2495 -> tipo: VIRTUAL
# Agregando id: 2496 -> tipo: VIRTUAL
# Agregando id: 2497 -> tipo: PRESENCIAL
# Agregando id: 2498 -> tipo: PRESENCIAL
# Agregando id: 2499 -> tipo: PRESENCIAL
# Agregando id: 2500 -> tipo: PRESENCIAL
# Agregando id: 2501 -> tipo: PRESENCIAL
# Agregando id: 2502 -> tipo: PRESENCIAL
# Agregando id: 2503 -> tipo: PRESENCIAL
# Agregando id: 2504 -> tipo: PRESENCIAL
# Agregando id: 2505 -> tipo: PRESENCIAL
# Agregando id: 2506 -> tipo: PRESENCIAL
# Agregando id: 2507 -> tipo: PRESENCIAL
# Agregando id: 2508 -> tipo: PRESENCIAL
# Agregando id: 2509 -> tipo: PRESENCIAL
# Agregando id: 2510 -> tipo: PRESENCIAL
# Agregando id: 2512 -> tipo: PRESENCIAL
# Agregando id: 2513 -> tipo: PRESENCIAL
# Agregando id: 2514 -> tipo: PRESENCIAL
# Agregando id: 2515 -> tipo: PRESENCIAL
# Agregando id: 2516 -> tipo: PRESENCIAL
# Agregando id: 2517 -> tipo: PRESENCIAL
# Agregando id: 2518 -> tipo: PRESENCIAL
# Agregando id: 2520 -> tipo: PRESENCIAL
# Agregando id: 2521 -> tipo: PRESENCIAL
# Agregando id: 2522 -> tipo: PRESENCIAL
# Agregando id: 2523 -> tipo: PRESENCIAL
# Agregando id: 2524 -> tipo: PRESENCIAL
# Agregando id: 2525 -> tipo: PRESENCIAL
# Agregando id: 2526 -> tipo: PRESENCIAL
# Agregando id: 2527 -> tipo: PRESENCIAL
# Agregando id: 2528 -> tipo: VIRTUAL
# Agregando id: 2529 -> tipo: PRESENCIAL
# Agregando id: 2531 -> tipo: PRESENCIAL
# Agregando id: 2531 -> tipo: VIRTUAL
# Agregando id: 2532 -> tipo: VIRTUAL
# Agregando id: 2533 -> tipo: PRESENCIAL
# Agregando id: 2534 -> tipo: PRESENCIAL
# Agregando id: 2535 -> tipo: PRESENCIAL
# Agregando id: 2536 -> tipo: PRESENCIAL
# Agregando id: 2537 -> tipo: PRESENCIAL
# Agregando id: 2538 -> tipo: PRESENCIAL
# Agregando id: 2539 -> tipo: PRESENCIAL
# Agregando id: 2540 -> tipo: PRESENCIAL
# Agregando id: 2541 -> tipo: PRESENCIAL
# Agregando id: 2542 -> tipo: PRESENCIAL
# Agregando id: 2543 -> tipo: VIRTUAL
# Agregando id: 2576 -> tipo: PRESENCIAL
# Agregando id: 2577 -> tipo: PRESENCIAL
# Agregando id: 2578 -> tipo: PRESENCIAL
# Agregando id: 2579 -> tipo: PRESENCIAL
# Agregando id: 2580 -> tipo: PRESENCIAL
# Agregando id: 2581 -> tipo: PRESENCIAL
# Agregando id: 2583 -> tipo: PRESENCIAL
# Agregando id: 2584 -> tipo: PRESENCIAL
# Agregando id: 2585 -> tipo: PRESENCIAL
# Agregando id: 2587 -> tipo: PRESENCIAL
# Agregando id: 2588 -> tipo: PRESENCIAL
# Agregando id: 2589 -> tipo: PRESENCIAL
# Agregando id: 2590 -> tipo: PRESENCIAL
# Agregando id: 2591 -> tipo: PRESENCIAL
# Agregando id: 2592 -> tipo: PRESENCIAL
# Agregando id: 2593 -> tipo: VIRTUAL
# Agregando id: 2594 -> tipo: PRESENCIAL
# Agregando id: 2595 -> tipo: PRESENCIAL
# Agregando id: 2597 -> tipo: PRESENCIAL
# Agregando id: 2598 -> tipo: PRESENCIAL
# Agregando id: 2599 -> tipo: PRESENCIAL
# Agregando id: 2600 -> tipo: PRESENCIAL
# Agregando id: 2601 -> tipo: VIRTUAL
# Agregando id: 2603 -> tipo: PRESENCIAL
# Agregando id: 2604 -> tipo: PRESENCIAL
# Agregando id: 2605 -> tipo: PRESENCIAL
# Agregando id: 2605 -> tipo: VIRTUAL
# Agregando id: 2607 -> tipo: PRESENCIAL
# Agregando id: 2608 -> tipo: PRESENCIAL
# Agregando id: 2609 -> tipo: VIRTUAL
# Agregando id: 2610 -> tipo: PRESENCIAL
# Agregando id: 2611 -> tipo: VIRTUAL
# Agregando id: 2612 -> tipo: VIRTUAL
# Agregando id: 2613 -> tipo: VIRTUAL
# Agregando id: 2614 -> tipo: VIRTUAL
# Agregando id: 2615 -> tipo: VIRTUAL
# Agregando id: 2616 -> tipo: VIRTUAL
# Agregando id: 2617 -> tipo: VIRTUAL
# Agregando id: 2618 -> tipo: VIRTUAL
# Agregando id: 2619 -> tipo: VIRTUAL
# Agregando id: 2620 -> tipo: VIRTUAL
# Agregando id: 2621 -> tipo: VIRTUAL
# Agregando id: 2622 -> tipo: VIRTUAL
# Agregando id: 2623 -> tipo: VIRTUAL
# Agregando id: 2624 -> tipo: VIRTUAL
# Agregando id: 2625 -> tipo: VIRTUAL
# Agregando id: 2626 -> tipo: VIRTUAL
# Agregando id: 2627 -> tipo: VIRTUAL
# Agregando id: 2628 -> tipo: VIRTUAL
# Agregando id: 2629 -> tipo: PRESENCIAL
# Agregando id: 2630 -> tipo: VIRTUAL
# Agregando id: 2631 -> tipo: VIRTUAL
# Agregando id: 2632 -> tipo: VIRTUAL
# Agregando id: 2633 -> tipo: VIRTUAL
# Agregando id: 2634 -> tipo: VIRTUAL
# Agregando id: 2635 -> tipo: VIRTUAL
# Agregando id: 2636 -> tipo: VIRTUAL
# Agregando id: 2637 -> tipo: VIRTUAL
# Agregando id: 2638 -> tipo: VIRTUAL
# Agregando id: 2639 -> tipo: VIRTUAL
# Agregando id: 2640 -> tipo: VIRTUAL
# Agregando id: 2641 -> tipo: VIRTUAL
# Agregando id: 2643 -> tipo: VIRTUAL
# Agregando id: 2644 -> tipo: VIRTUAL
# Agregando id: 2645 -> tipo: VIRTUAL
# Agregando id: 2646 -> tipo: VIRTUAL
# Agregando id: 2647 -> tipo: VIRTUAL
# Agregando id: 2648 -> tipo: VIRTUAL
# Agregando id: 2649 -> tipo: VIRTUAL
# Agregando id: 2650 -> tipo: PRESENCIAL
# Agregando id: 2651 -> tipo: PRESENCIAL
# Agregando id: 2655 -> tipo: PRESENCIAL
# Agregando id: 2656 -> tipo: PRESENCIAL
# Agregando id: 2657 -> tipo: PRESENCIAL
# Agregando id: 2658 -> tipo: PRESENCIAL
# Agregando id: 2659 -> tipo: PRESENCIAL
# Agregando id: 2660 -> tipo: PRESENCIAL
# Agregando id: 2661 -> tipo: VIRTUAL
# Agregando id: 2662 -> tipo: PRESENCIAL
# Agregando id: 2663 -> tipo: PRESENCIAL
# Agregando id: 2664 -> tipo: PRESENCIAL
# Agregando id: 2665 -> tipo: PRESENCIAL
# Agregando id: 2666 -> tipo: PRESENCIAL
# Agregando id: 2667 -> tipo: PRESENCIAL
# Agregando id: 2668 -> tipo: PRESENCIAL
# Agregando id: 2677 -> tipo: PRESENCIAL
# Agregando id: 2728 -> tipo: PRESENCIAL
# Agregando id: 2757 -> tipo: PRESENCIAL
# Agregando id: 2759 -> tipo: VIRTUAL
# Agregando id: 2763 -> tipo: PRESENCIAL
# Agregando id: 2764 -> tipo: PRESENCIAL
# Agregando id: 2765 -> tipo: PRESENCIAL
# Agregando id: 2766 -> tipo: PRESENCIAL
# Agregando id: 2767 -> tipo: PRESENCIAL
# Agregando id: 2768 -> tipo: PRESENCIAL
# Agregando id: 2769 -> tipo: PRESENCIAL
# Agregando id: 2771 -> tipo: PRESENCIAL
# Agregando id: 2772 -> tipo: PRESENCIAL
# Agregando id: 2773 -> tipo: PRESENCIAL
# Agregando id: 2774 -> tipo: PRESENCIAL
# Agregando id: 2776 -> tipo: VIRTUAL
# Agregando id: 2777 -> tipo: PRESENCIAL
# Agregando id: 2778 -> tipo: PRESENCIAL
# Agregando id: 2779 -> tipo: PRESENCIAL
# Agregando id: 2793 -> tipo: PRESENCIAL
# Agregando id: 2819 -> tipo: PRESENCIAL
# Agregando id: 2825 -> tipo: PRESENCIAL
# Agregando id: 2827 -> tipo: PRESENCIAL
# Agregando id: 2843 -> tipo: PRESENCIAL
# (1518, 30)
#        id     estado fechaActualización  \
# 365  1279  PUBLICADO         09/07/2025
# 78   1080  PUBLICADO         08/07/2025
# 704  1627  PUBLICADO         08/07/2025
#
#                                                 nombre  \
# 365  Legalización de Resoluciones Administrativas d...
# 78                         Urbanización Papa Francisco
# 704                         Registro de Empresa - SIGA
#
#                                                   slug   sigla  \
# 365  legalizacion-de-resoluciones-administrativas-d...     NaN
# 78                         urbanizacion-papa-francisco  U.P.F.
# 704                           registro-de-empresa-siga    SIGA
#
#                                            descripcion  \
# 365  Establecer Procedimiento para procesar la Lega...
# 78   * A precios de carácter social de:\n- 197.633 ...
# 704  Es un módulo paralelo desarrollado con el obje...
#
#                                             marcoLegal  like  dislike  \
# 365  "R.M. N° 928/2015 R.M. N° 710/2016 R.M. N° 082...     0        0
# 78   CONSTITUCIÓN POLÍTICA DEL ESTADO\nArtículo 19....     0        0
# 704  Decreto Supremo Nº3525\nEstablece la Política ...     0        0
#
#      esPresencial  esVirtual              resultado  \
# 365             1          1  Registro y constancia
# 78              1          0                    NaN
# 704             0          1               Registro
#
#                                                enlaces  \
# 365  [{"nombre": "ÁREA DE LEGALIZACIONES - UNIDAD D...
# 78   [{"nombre": "Agencia Estatal de Vivienda", "ur...
# 704  [{"nombre": "Registro de Empresas", "url": "ht...
#
#                                            ubicaciones  \
# 365  [{"nombre": "Ministerio de Educación", "tipo":...
# 78   [{"nombre": "Agencia Estatal de Vivienda", "ti...
# 704  [{"nombre": "UPRE - Unidad de Proyectos Especi...
#
#                      entidad.nombre entidad.sigla  \
# 365         Ministerio de Educación       MIN-EDU
# 78      Agencia Estatal de Vivienda    AEVIVIENDA
# 704  Unidad De Proyectos Especiales          UPRE
#
#                        entidad.slug  \
# 365         ministerio-de-educacion
# 78      agencia-estatal-de-vivienda
# 704  unidad-de-proyectos-especiales
#
#                                           entidad.logo  \
# 365  https://www.gob.bo/ws/api/archivos/78598177-59...
# 78   https://www.gob.bo/ws/api/archivos/cf207c64-0a...
# 704  https://www.gob.bo/ws/api/archivos/a6c8f095-c9...
#
#                                    entidad.descripcion  \
# 365                            MINISTERIO DE EDUCACIÓN
# 78   Agencia Estatal de Vivienda\r\nConstruyendo Vi...
# 704  La Unidad de Proyectos Especiales\r\nCreado me...
#
#                entidad.urlSitioWeb entidad.telefonoContacto  \
# 365     https://www.minedu.gob.bo/        (591-2)  2442144
# 78   https://www.aevivienda.gob.bo          (591) 2-2149962
# 704        https://www.upre.gob.bo          (591-2) 2146146
#
#     entidad.correoElectronicoContacto  \
# 365         informacion@minedu.gob.bo
# 78        icontacto@aevivienda.gob.bo
# 704                  info@upre.gob.bo
#
#                                palabrasClave categorias         eventosVida  \
# 365  Institutos,Administrativas,Resoluciones  Educación        Mi educación
# 78                                       NaN   Vivienda  Compra de vivienda
# 704                                      NaN   Empresas                 NaN
#
#                                             documentos  herramientas  \
# 365  Legalización de Resoluciones Administrativas d...           NaN
# 78                                                 NaN           NaN
# 704                        Registro de Empresas - SIGA           NaN
#
#     modalidad.tipo                                          modalidad
# 365     PRESENCIAL  {'tipo': 'PRESENCIAL', 'url': None, 'urlSeguim...
# 78      PRESENCIAL  {'tipo': 'PRESENCIAL', 'url': None, 'urlSeguim...
# 704        VIRTUAL  {'tipo': 'VIRTUAL', 'url': 'https://www.siga.u...

# %% [markdown]
# ## Dividiendo en procedimientos (una fila para cada público objetivo)
#
# Al parecer hay también diferentes públicos objetivo por cada trámite. Para facilitar el análisis conviene dividir cada trámite también por público objetivo, donde cada uno de estos tiene su propio **procedimiento**. Entonces un trámite puede tener varias modalidades y cada modalidad varios procedimientos.

# %%
def desglosar_por_procedimientos(df):
    new_df = pd.DataFrame(
        columns=df.columns.to_list() + 
        [
         'tramite.url', 'tramite.urlSeguimiento',
         'tramite.tieneCosto', 'tramite.duracion', 'tramite.unidadMedidaDuracion', 'tramite.procedimiento',
         'tramite.publicoObjetivo', 'tramite.requisitoNoParametrizado', 'tramite.estado',
         'tramite.emisionFactura','tramite.formaCobro','tramite.horarios','tramite.depositoBancario',
         'tramite.costos', 'tramite.requisitos'
         ])
    print(new_df.columns)
    _df = df.copy()
    for i in _df.index.to_list():
        data = _df.iloc[i]['modalidad']
        for procedimiento in data['publico']:
            proc = _df.iloc[i].copy()
            proc['tramite.url'] = data['url']
            proc['tramite.urlSeguimiento'] = data['urlSeguimiento']
            proc['tramite.tieneCosto'] = 1 if procedimiento['tieneCosto'] == True else 0
            proc['tramite.duracion'] = procedimiento['duracion']
            proc['tramite.unidadMedidaDuracion'] = procedimiento['unidadMedidaDuracion']
            proc['tramite.procedimiento'] = procedimiento['procedimiento']
            proc['tramite.publicoObjetivo'] = procedimiento['nombrePublicoObjetivo']
            proc['tramite.requisitoNoParametrizado'] = procedimiento['requisitoNoParametrizado']
            proc['tramite.estado'] = procedimiento['estadoPublicoObjetivo']
            proc['tramite.emisionFactura'] = procedimiento['emisionFactura']
            proc['tramite.formaCobro'] = procedimiento['formaCobro']
            proc['tramite.horarios'] = procedimiento['horario']
            proc['tramite.depositoBancario'] = procedimiento['depositoBancario']
            proc['tramite.costos'] = procedimiento['costos']
            proc['tramite.requisitos'] = procedimiento['requisitos']
            del proc['modalidad']
            print(f"Agregando id: {_df.iloc[i]['id']} --> {proc['tramite.publicoObjetivo']}")
            new_df.loc[len(new_df)] = proc
    del new_df['modalidad']
    return new_df

new_df = desglosar_por_procedimientos(new_df)
print(new_df.shape)
new_df.sample(3)
# Out:
# Index(['id', 'estado', 'fechaActualización', 'nombre', 'slug', 'sigla',
#        'descripcion', 'marcoLegal', 'like', 'dislike', 'esPresencial',
#        'esVirtual', 'resultado', 'enlaces', 'ubicaciones', 'entidad.nombre',
#        'entidad.sigla', 'entidad.slug', 'entidad.logo', 'entidad.descripcion',
#        'entidad.urlSitioWeb', 'entidad.telefonoContacto',
#        'entidad.correoElectronicoContacto', 'palabrasClave', 'categorias',
#        'eventosVida', 'documentos', 'herramientas', 'modalidad.tipo',
#        'modalidad', 'tramite.url', 'tramite.urlSeguimiento',
#        'tramite.tieneCosto', 'tramite.duracion',
#        'tramite.unidadMedidaDuracion', 'tramite.procedimiento',
#        'tramite.publicoObjetivo', 'tramite.requisitoNoParametrizado',
#        'tramite.estado', 'tramite.emisionFactura', 'tramite.formaCobro',
#        'tramite.horarios', 'tramite.depositoBancario', 'tramite.costos',
#        'tramite.requisitos'],
#       dtype='object')
# Agregando id: 1005 --> Persona Natural
# Agregando id: 1006 --> Todos (Cualquier persona solicitante)
# Agregando id: 1006 --> Todos (Cualquier persona solicitante)
# Agregando id: 1008 --> Todos (Cualquier persona solicitante)
# Agregando id: 1009 --> Todos (Cualquier persona solicitante)
# Agregando id: 1010 --> Todos (Cualquier persona solicitante)
# Agregando id: 1011 --> Todos (Cualquier persona solicitante)
# Agregando id: 1012 --> Todos (Cualquier persona solicitante)
# Agregando id: 1013 --> Todos (Cualquier persona solicitante)
# Agregando id: 1014 --> Todos (Cualquier persona solicitante)
# Agregando id: 1015 --> Todos (Cualquier persona solicitante)
# Agregando id: 1017 --> Comunidades Educativas
# Agregando id: 1018 --> Comunidades Educativas
# Agregando id: 1019 --> Todos (Cualquier persona solicitante)
# Agregando id: 1020 --> Comunidades Educativas
# Agregando id: 1021 --> Comunidades Educativas
# Agregando id: 1022 --> Comunidades Educativas
# Agregando id: 1023 --> Comunidades Educativas
# Agregando id: 1024 --> Todos (Cualquier persona solicitante)
# Agregando id: 1025 --> Comunidades Educativas
# Agregando id: 1026 --> Todos (Cualquier persona solicitante)
# Agregando id: 1027 --> Comunidades Educativas
# Agregando id: 1028 --> Todos (Cualquier persona solicitante)
# Agregando id: 1029 --> Empresas Públicas
# Agregando id: 1030 --> Todos (Cualquier persona solicitante)
# Agregando id: 1031 --> Comunidades Educativas
# Agregando id: 1032 --> Comunidades Educativas
# Agregando id: 1033 --> Comunidades Educativas
# Agregando id: 1034 --> Comunidades Educativas
# Agregando id: 1035 --> Comunidades Educativas
# Agregando id: 1037 --> Comunidades Educativas
# Agregando id: 1038 --> Comunidades Educativas
# Agregando id: 1039 --> Comunidades Educativas
# Agregando id: 1041 --> Comunidades Educativas
# Agregando id: 1042 --> Comunidades Educativas
# Agregando id: 1043 --> Comunidades Educativas
# Agregando id: 1044 --> Comunidades Educativas
# Agregando id: 1045 --> Comunidades Educativas
# Agregando id: 1046 --> Comunidades Educativas
# Agregando id: 1047 --> Comunidades Educativas
# Agregando id: 1048 --> Todos (Cualquier persona solicitante)
# Agregando id: 1049 --> Cooperativa
# Agregando id: 1050 --> Cooperativa
# Agregando id: 1051 --> Empresas Públicas o Privadas
# Agregando id: 1052 --> Todos (Cualquier persona solicitante)
# Agregando id: 1052 --> consumidor financiero
# Agregando id: 1053 --> Todos (Cualquier persona solicitante)
# Agregando id: 1054 --> Todos (Cualquier persona solicitante)
# Agregando id: 1055 --> Cooperativas
# Agregando id: 1056 --> Todos (Cualquier persona solicitante)
# Agregando id: 1057 --> Todos (Cualquier persona solicitante)
# Agregando id: 1058 --> Todos (Cualquier persona solicitante)
# Agregando id: 1059 --> Todos (Cualquier persona solicitante)
# Agregando id: 1060 --> Todos (Cualquier persona solicitante)
# Agregando id: 1061 --> Todos (Cualquier persona solicitante)
# Agregando id: 1062 --> Todos (Cualquier persona solicitante)
# Agregando id: 1063 --> Todos (Cualquier persona solicitante)
# Agregando id: 1063 --> Todos (Cualquier persona solicitante)
# Agregando id: 1064 --> Todos (Cualquier persona solicitante)
# Agregando id: 1064 --> Todos (Cualquier persona solicitante)
# Agregando id: 1065 --> Todos (Cualquier persona solicitante)
# Agregando id: 1066 --> Todos (Cualquier persona solicitante)
# Agregando id: 1066 --> Todos (Cualquier persona solicitante)
# Agregando id: 1067 --> Todos (Cualquier persona solicitante)
# Agregando id: 1067 --> Todos (Cualquier persona solicitante)
# Agregando id: 1069 --> Todos (Cualquier persona solicitante)
# Agregando id: 1069 --> Todos (Cualquier persona solicitante)
# Agregando id: 1070 --> Todos (Cualquier persona solicitante)
# Agregando id: 1070 --> Todos (Cualquier persona solicitante)
# Agregando id: 1071 --> Empresas Públicas o Privadas
# Agregando id: 1073 --> Todos (Cualquier persona solicitante)
# Agregando id: 1073 --> Todos (Cualquier persona solicitante)
# Agregando id: 1074 --> Todos (Cualquier persona solicitante)
# Agregando id: 1074 --> Todos (Cualquier persona solicitante)
# Agregando id: 1076 --> Persona Natural
# Agregando id: 1078 --> Persona Natural
# Agregando id: 1079 --> Todos (Cualquier persona solicitante)
# Agregando id: 1079 --> Todos (Cualquier persona solicitante)
# Agregando id: 1080 --> Persona Natural
# Agregando id: 1082 --> Todos (Cualquier persona solicitante)
# Agregando id: 1082 --> Todos (Cualquier persona solicitante)
# Agregando id: 1084 --> Todos (Cualquier persona solicitante)
# Agregando id: 1084 --> Todos (Cualquier persona solicitante)
# Agregando id: 1087 --> Todos (Cualquier persona solicitante)
# Agregando id: 1087 --> Todos (Cualquier persona solicitante)
# Agregando id: 1089 --> Todos (Cualquier persona solicitante)
# Agregando id: 1089 --> Todos (Cualquier persona solicitante)
# Agregando id: 1091 --> Todos (Cualquier persona solicitante)
# Agregando id: 1091 --> Todos (Cualquier persona solicitante)
# Agregando id: 1094 --> Todos (Cualquier persona solicitante)
# Agregando id: 1096 --> Todos (Cualquier persona solicitante)
# Agregando id: 1100 --> Persona Natural
# Agregando id: 1101 --> Todos (Cualquier persona solicitante)
# Agregando id: 1102 --> Persona Natural
# Agregando id: 1103 --> Todos (Cualquier persona solicitante)
# Agregando id: 1104 --> Todos (Cualquier persona solicitante)
# Agregando id: 1104 --> Todos (Cualquier persona solicitante)
# Agregando id: 1105 --> Todos (Cualquier persona solicitante)
# Agregando id: 1105 --> Todos (Cualquier persona solicitante)
# Agregando id: 1106 --> Todos (Cualquier persona solicitante)
# Agregando id: 1106 --> Todos (Cualquier persona solicitante)
# Agregando id: 1107 --> Todos (Cualquier persona solicitante)
# Agregando id: 1107 --> Todos (Cualquier persona solicitante)
# Agregando id: 1108 --> Todos (Cualquier persona solicitante)
# Agregando id: 1108 --> Todos (Cualquier persona solicitante)
# Agregando id: 1109 --> Todos (Cualquier persona solicitante)
# Agregando id: 1109 --> Todos (Cualquier persona solicitante)
# Agregando id: 1110 --> Todos (Cualquier persona solicitante)
# Agregando id: 1110 --> Todos (Cualquier persona solicitante)
# Agregando id: 1111 --> Todos (Cualquier persona solicitante)
# Agregando id: 1111 --> Todos (Cualquier persona solicitante)
# Agregando id: 1113 --> Todos (Cualquier persona solicitante)
# Agregando id: 1114 --> Todos (Cualquier persona solicitante)
# Agregando id: 1114 --> Todos (Cualquier persona solicitante)
# Agregando id: 1115 --> Todos (Cualquier persona solicitante)
# Agregando id: 1116 --> Todos (Cualquier persona solicitante)
# Agregando id: 1118 --> Todos (Cualquier persona solicitante)
# Agregando id: 1118 --> Todos (Cualquier persona solicitante)
# Agregando id: 1119 --> Todos (Cualquier persona solicitante)
# Agregando id: 1120 --> Todos (Cualquier persona solicitante)
# Agregando id: 1120 --> Todos (Cualquier persona solicitante)
# Agregando id: 1121 --> Todos (Cualquier persona solicitante)
# Agregando id: 1121 --> Todos (Cualquier persona solicitante)
# Agregando id: 1122 --> Todos (Cualquier persona solicitante)
# Agregando id: 1122 --> Todos (Cualquier persona solicitante)
# Agregando id: 1123 --> Todos (Cualquier persona solicitante)
# Agregando id: 1123 --> Todos (Cualquier persona solicitante)
# Agregando id: 1124 --> Todos (Cualquier persona solicitante)
# Agregando id: 1124 --> Todos (Cualquier persona solicitante)
# Agregando id: 1125 --> Todos (Cualquier persona solicitante)
# Agregando id: 1125 --> Todos (Cualquier persona solicitante)
# Agregando id: 1126 --> Todos (Cualquier persona solicitante)
# Agregando id: 1126 --> Todos (Cualquier persona solicitante)
# Agregando id: 1127 --> Todos (Cualquier persona solicitante)
# Agregando id: 1127 --> Todos (Cualquier persona solicitante)
# Agregando id: 1128 --> Todos (Cualquier persona solicitante)
# Agregando id: 1128 --> Todos (Cualquier persona solicitante)
# Agregando id: 1129 --> Actor Productivo Minero
# Agregando id: 1129 --> Industria Minera Privada
# Agregando id: 1129 --> Cooperativas Mineras
# Agregando id: 1130 --> Todos (Cualquier persona solicitante)
# Agregando id: 1131 --> Todos (Cualquier persona solicitante)
# Agregando id: 1131 --> Todos (Cualquier persona solicitante)
# Agregando id: 1132 --> Todos (Cualquier persona solicitante)
# Agregando id: 1132 --> Todos (Cualquier persona solicitante)
# Agregando id: 1133 --> Personas Aseguradas
# Agregando id: 1134 --> Todos (Cualquier persona solicitante)
# Agregando id: 1135 --> Todos (Cualquier persona solicitante)
# Agregando id: 1136 --> Todos (Cualquier persona solicitante)
# Agregando id: 1136 --> Todos (Cualquier persona solicitante)
# Agregando id: 1137 --> Todos (Cualquier persona solicitante)
# Agregando id: 1137 --> Todos (Cualquier persona solicitante)
# Agregando id: 1138 --> Todos (Cualquier persona solicitante)
# Agregando id: 1138 --> Todos (Cualquier persona solicitante)
# Agregando id: 1139 --> Todos (Cualquier persona solicitante)
# Agregando id: 1140 --> Todos (Cualquier persona solicitante)
# Agregando id: 1140 --> Todos (Cualquier persona solicitante)
# Agregando id: 1141 --> Todos (Cualquier persona solicitante)
# Agregando id: 1141 --> Todos (Cualquier persona solicitante)
# Agregando id: 1142 --> Todos (Cualquier persona solicitante)
# Agregando id: 1142 --> Todos (Cualquier persona solicitante)
# Agregando id: 1143 --> Todos (Cualquier persona solicitante)
# Agregando id: 1143 --> Todos (Cualquier persona solicitante)
# Agregando id: 1146 --> Todos (Cualquier persona solicitante)
# Agregando id: 1146 --> Todos (Cualquier persona solicitante)
# Agregando id: 1148 --> Todos (Cualquier persona solicitante)
# Agregando id: 1148 --> Todos (Cualquier persona solicitante)
# Agregando id: 1150 --> Todos (Cualquier persona solicitante)
# Agregando id: 1150 --> Todos (Cualquier persona solicitante)
# Agregando id: 1151 --> Entidades Públicas
# Agregando id: 1152 --> Todos (Cualquier persona solicitante)
# Agregando id: 1152 --> Todos (Cualquier persona solicitante)
# Agregando id: 1153 --> Todos (Cualquier persona solicitante)
# Agregando id: 1153 --> Todos (Cualquier persona solicitante)
# Agregando id: 1154 --> Todos (Cualquier persona solicitante)
# Agregando id: 1154 --> Todos (Cualquier persona solicitante)
# Agregando id: 1155 --> Todos (Cualquier persona solicitante)
# Agregando id: 1155 --> Todos (Cualquier persona solicitante)
# Agregando id: 1156 --> Todos (Cualquier persona solicitante)
# Agregando id: 1156 --> Todos (Cualquier persona solicitante)
# Agregando id: 1157 --> Todos (Cualquier persona solicitante)
# Agregando id: 1157 --> Todos (Cualquier persona solicitante)
# Agregando id: 1158 --> Todos (Cualquier persona solicitante)
# Agregando id: 1158 --> Todos (Cualquier persona solicitante)
# Agregando id: 1159 --> Todos (Cualquier persona solicitante)
# Agregando id: 1159 --> Todos (Cualquier persona solicitante)
# Agregando id: 1160 --> Todos (Cualquier persona solicitante)
# Agregando id: 1160 --> Todos (Cualquier persona solicitante)
# Agregando id: 1161 --> Todos (Cualquier persona solicitante)
# Agregando id: 1161 --> Todos (Cualquier persona solicitante)
# Agregando id: 1162 --> Todos (Cualquier persona solicitante)
# Agregando id: 1162 --> Todos (Cualquier persona solicitante)
# Agregando id: 1163 --> Todos (Cualquier persona solicitante)
# Agregando id: 1163 --> Todos (Cualquier persona solicitante)
# Agregando id: 1164 --> Todos (Cualquier persona solicitante)
# Agregando id: 1164 --> Todos (Cualquier persona solicitante)
# Agregando id: 1166 --> Todos (Cualquier persona solicitante)
# Agregando id: 1166 --> Todos (Cualquier persona solicitante)
# Agregando id: 1167 --> Todos (Cualquier persona solicitante)
# Agregando id: 1167 --> Todos (Cualquier persona solicitante)
# Agregando id: 1168 --> Todos (Cualquier persona solicitante)
# Agregando id: 1168 --> Todos (Cualquier persona solicitante)
# Agregando id: 1169 --> Todos (Cualquier persona solicitante)
# Agregando id: 1169 --> Todos (Cualquier persona solicitante)
# Agregando id: 1170 --> Todos (Cualquier persona solicitante)
# Agregando id: 1170 --> Todos (Cualquier persona solicitante)
# Agregando id: 1171 --> Todos (Cualquier persona solicitante)
# Agregando id: 1171 --> Todos (Cualquier persona solicitante)
# Agregando id: 1172 --> Todos (Cualquier persona solicitante)
# Agregando id: 1172 --> Todos (Cualquier persona solicitante)
# Agregando id: 1173 --> Todos (Cualquier persona solicitante)
# Agregando id: 1173 --> Todos (Cualquier persona solicitante)
# Agregando id: 1174 --> Todos (Cualquier persona solicitante)
# Agregando id: 1174 --> Todos (Cualquier persona solicitante)
# Agregando id: 1176 --> Todos (Cualquier persona solicitante)
# Agregando id: 1176 --> Todos (Cualquier persona solicitante)
# Agregando id: 1177 --> Todos (Cualquier persona solicitante)
# Agregando id: 1177 --> Todos (Cualquier persona solicitante)
# Agregando id: 1178 --> Todos (Cualquier persona solicitante)
# Agregando id: 1178 --> Todos (Cualquier persona solicitante)
# Agregando id: 1179 --> Todos (Cualquier persona solicitante)
# Agregando id: 1179 --> Todos (Cualquier persona solicitante)
# Agregando id: 1180 --> Todos (Cualquier persona solicitante)
# Agregando id: 1180 --> Todos (Cualquier persona solicitante)
# Agregando id: 1181 --> Todos (Cualquier persona solicitante)
# Agregando id: 1181 --> Todos (Cualquier persona solicitante)
# Agregando id: 1182 --> Todos (Cualquier persona solicitante)
# Agregando id: 1182 --> Todos (Cualquier persona solicitante)
# Agregando id: 1183 --> Todos (Cualquier persona solicitante)
# Agregando id: 1183 --> Todos (Cualquier persona solicitante)
# Agregando id: 1184 --> Todos (Cualquier persona solicitante)
# Agregando id: 1184 --> Todos (Cualquier persona solicitante)
# Agregando id: 1185 --> Todos (Cualquier persona solicitante)
# Agregando id: 1185 --> Todos (Cualquier persona solicitante)
# Agregando id: 1186 --> Todos (Cualquier persona solicitante)
# Agregando id: 1186 --> Todos (Cualquier persona solicitante)
# Agregando id: 1187 --> Todos (Cualquier persona solicitante)
# Agregando id: 1188 --> Todos (Cualquier persona solicitante)
# Agregando id: 1189 --> Todos (Cualquier persona solicitante)
# Agregando id: 1190 --> Todos (Cualquier persona solicitante)
# Agregando id: 1190 --> Todos (Cualquier persona solicitante)
# Agregando id: 1191 --> Todos (Cualquier persona solicitante)
# Agregando id: 1192 --> Todos (Cualquier persona solicitante)
# Agregando id: 1193 --> Todos (Cualquier persona solicitante)
# Agregando id: 1194 --> Todos (Cualquier persona solicitante)
# Agregando id: 1195 --> Todos (Cualquier persona solicitante)
# Agregando id: 1195 --> Todos (Cualquier persona solicitante)
# Agregando id: 1196 --> Todos (Cualquier persona solicitante)
# Agregando id: 1197 --> Todos (Cualquier persona solicitante)
# Agregando id: 1198 --> Todos (Cualquier persona solicitante)
# Agregando id: 1199 --> Todos (Cualquier persona solicitante)
# Agregando id: 1199 --> Todos (Cualquier persona solicitante)
# Agregando id: 1200 --> Todos (Cualquier persona solicitante)
# Agregando id: 1201 --> Todos (Cualquier persona solicitante)
# Agregando id: 1201 --> Todos (Cualquier persona solicitante)
# Agregando id: 1202 --> Todos (Cualquier persona solicitante)
# Agregando id: 1202 --> Todos (Cualquier persona solicitante)
# Agregando id: 1203 --> Todos (Cualquier persona solicitante)
# Agregando id: 1204 --> Todos (Cualquier persona solicitante)
# Agregando id: 1204 --> Todos (Cualquier persona solicitante)
# Agregando id: 1205 --> Todos (Cualquier persona solicitante)
# Agregando id: 1205 --> Todos (Cualquier persona solicitante)
# Agregando id: 1206 --> Todos (Cualquier persona solicitante)
# Agregando id: 1206 --> Todos (Cualquier persona solicitante)
# Agregando id: 1207 --> Todos (Cualquier persona solicitante)
# Agregando id: 1207 --> Todos (Cualquier persona solicitante)
# Agregando id: 1209 --> Todos (Cualquier persona solicitante)
# Agregando id: 1209 --> Todos (Cualquier persona solicitante)
# Agregando id: 1210 --> Todos (Cualquier persona solicitante)
# Agregando id: 1210 --> Todos (Cualquier persona solicitante)
# Agregando id: 1211 --> Todos (Cualquier persona solicitante)
# Agregando id: 1212 --> Todos (Cualquier persona solicitante)
# Agregando id: 1212 --> Todos (Cualquier persona solicitante)
# Agregando id: 1213 --> Todos (Cualquier persona solicitante)
# Agregando id: 1214 --> Todos (Cualquier persona solicitante)
# Agregando id: 1215 --> Todos (Cualquier persona solicitante)
# Agregando id: 1216 --> Todos (Cualquier persona solicitante)
# Agregando id: 1216 --> Todos (Cualquier persona solicitante)
# Agregando id: 1217 --> Todos (Cualquier persona solicitante)
# Agregando id: 1218 --> Todos (Cualquier persona solicitante)
# Agregando id: 1219 --> Todos (Cualquier persona solicitante)
# Agregando id: 1220 --> Todos (Cualquier persona solicitante)
# Agregando id: 1220 --> Todos (Cualquier persona solicitante)
# Agregando id: 1221 --> Todos (Cualquier persona solicitante)
# Agregando id: 1222 --> Todos (Cualquier persona solicitante)
# Agregando id: 1223 --> Todos (Cualquier persona solicitante)
# Agregando id: 1223 --> Todos (Cualquier persona solicitante)
# Agregando id: 1224 --> Todos (Cualquier persona solicitante)
# Agregando id: 1225 --> Todos (Cualquier persona solicitante)
# Agregando id: 1226 --> Todos (Cualquier persona solicitante)
# Agregando id: 1227 --> Todos (Cualquier persona solicitante)
# Agregando id: 1228 --> Todos (Cualquier persona solicitante)
# Agregando id: 1228 --> Todos (Cualquier persona solicitante)
# Agregando id: 1229 --> Todos (Cualquier persona solicitante)
# Agregando id: 1230 --> Todos (Cualquier persona solicitante)
# Agregando id: 1231 --> Todos (Cualquier persona solicitante)
# Agregando id: 1231 --> Todos (Cualquier persona solicitante)
# Agregando id: 1232 --> Todos (Cualquier persona solicitante)
# Agregando id: 1232 --> Todos (Cualquier persona solicitante)
# Agregando id: 1233 --> Todos (Cualquier persona solicitante)
# Agregando id: 1233 --> Todos (Cualquier persona solicitante)
# Agregando id: 1234 --> Todos (Cualquier persona solicitante)
# Agregando id: 1234 --> Todos (Cualquier persona solicitante)
# Agregando id: 1235 --> Todos (Cualquier persona solicitante)
# Agregando id: 1235 --> Todos (Cualquier persona solicitante)
# Agregando id: 1236 --> Todos (Cualquier persona solicitante)
# Agregando id: 1236 --> Todos (Cualquier persona solicitante)
# Agregando id: 1237 --> Todos (Cualquier persona solicitante)
# Agregando id: 1237 --> Todos (Cualquier persona solicitante)
# Agregando id: 1238 --> Personas Aseguradas
# Agregando id: 1239 --> Todos (Cualquier persona solicitante)
# Agregando id: 1239 --> Todos (Cualquier persona solicitante)
# Agregando id: 1240 --> Personas Aseguradas
# Agregando id: 1241 --> Todos (Cualquier persona solicitante)
# Agregando id: 1241 --> Todos (Cualquier persona solicitante)
# Agregando id: 1242 --> Todos (Cualquier persona solicitante)
# Agregando id: 1242 --> Todos (Cualquier persona solicitante)
# Agregando id: 1243 --> Personas Aseguradas
# Agregando id: 1244 --> Todos (Cualquier persona solicitante)
# Agregando id: 1244 --> Todos (Cualquier persona solicitante)
# Agregando id: 1245 --> Todos (Cualquier persona solicitante)
# Agregando id: 1245 --> Todos (Cualquier persona solicitante)
# Agregando id: 1246 --> Todos (Cualquier persona solicitante)
# Agregando id: 1246 --> Todos (Cualquier persona solicitante)
# Agregando id: 1247 --> Entidades Públicas
# Agregando id: 1250 --> Todos (Cualquier persona solicitante)
# Agregando id: 1250 --> Todos (Cualquier persona solicitante)
# Agregando id: 1251 --> Entidades Públicas
# Agregando id: 1252 --> Comunidades Educativas
# Agregando id: 1253 --> Todos (Cualquier persona solicitante)
# Agregando id: 1253 --> Todos (Cualquier persona solicitante)
# Agregando id: 1254 --> Adulto Mayor
# Agregando id: 1255 --> Personas Aseguradas
# Agregando id: 1256 --> Todos (Cualquier persona solicitante)
# Agregando id: 1256 --> Todos (Cualquier persona solicitante)
# Agregando id: 1257 --> Todos (Cualquier persona solicitante)
# Agregando id: 1257 --> Todos (Cualquier persona solicitante)
# Agregando id: 1258 --> Personas Aseguradas
# Agregando id: 1259 --> Todos (Cualquier persona solicitante)
# Agregando id: 1260 --> Todos (Cualquier persona solicitante)
# Agregando id: 1262 --> Comunidades Educativas
# Agregando id: 1263 --> Todos (Cualquier persona solicitante)
# Agregando id: 1264 --> Personas Aseguradas
# Agregando id: 1265 --> Todos (Cualquier persona solicitante)
# Agregando id: 1266 --> Todos (Cualquier persona solicitante)
# Agregando id: 1266 --> Todos (Cualquier persona solicitante)
# Agregando id: 1267 --> Todos (Cualquier persona solicitante)
# Agregando id: 1267 --> Todos (Cualquier persona solicitante)
# Agregando id: 1268 --> Todos (Cualquier persona solicitante)
# Agregando id: 1268 --> Todos (Cualquier persona solicitante)
# Agregando id: 1269 --> Todos (Cualquier persona solicitante)
# Agregando id: 1269 --> Todos (Cualquier persona solicitante)
# Agregando id: 1270 --> Todos (Cualquier persona solicitante)
# Agregando id: 1270 --> Todos (Cualquier persona solicitante)
# Agregando id: 1271 --> Todos (Cualquier persona solicitante)
# Agregando id: 1271 --> Todos (Cualquier persona solicitante)
# Agregando id: 1272 --> Todos (Cualquier persona solicitante)
# Agregando id: 1272 --> Todos (Cualquier persona solicitante)
# Agregando id: 1273 --> Todos (Cualquier persona solicitante)
# Agregando id: 1273 --> Todos (Cualquier persona solicitante)
# Agregando id: 1274 --> Actor Productivo Minero
# Agregando id: 1274 --> INDUSTRIA MINERA ESTATAL
# Agregando id: 1274 --> Industria Minera Privada
# Agregando id: 1275 --> Todos (Cualquier persona solicitante)
# Agregando id: 1275 --> Todos (Cualquier persona solicitante)
# Agregando id: 1276 --> Actor Productivo Minero
# Agregando id: 1277 --> Persona Natural
# Agregando id: 1277 --> Persona Jurídica (Empresa)
# Agregando id: 1278 --> Todos (Cualquier persona solicitante)
# Agregando id: 1278 --> Todos (Cualquier persona solicitante)
# Agregando id: 1279 --> Todos (Cualquier persona solicitante)
# Agregando id: 1279 --> Todos (Cualquier persona solicitante)
# Agregando id: 1280 --> Todos (Cualquier persona solicitante)
# Agregando id: 1280 --> Todos (Cualquier persona solicitante)
# Agregando id: 1281 --> Todos (Cualquier persona solicitante)
# Agregando id: 1281 --> Todos (Cualquier persona solicitante)
# Agregando id: 1282 --> Todos (Cualquier persona solicitante)
# Agregando id: 1282 --> Todos (Cualquier persona solicitante)
# Agregando id: 1283 --> Todos (Cualquier persona solicitante)
# Agregando id: 1283 --> Todos (Cualquier persona solicitante)
# Agregando id: 1284 --> Todos (Cualquier persona solicitante)
# Agregando id: 1284 --> Todos (Cualquier persona solicitante)
# Agregando id: 1285 --> Todos (Cualquier persona solicitante)
# Agregando id: 1286 --> Todos (Cualquier persona solicitante)
# Agregando id: 1286 --> Todos (Cualquier persona solicitante)
# Agregando id: 1288 --> Todos (Cualquier persona solicitante)
# Agregando id: 1288 --> Todos (Cualquier persona solicitante)
# Agregando id: 1289 --> Personas Aseguradas
# Agregando id: 1290 --> Comunidades Educativas
# Agregando id: 1291 --> Todos (Cualquier persona solicitante)
# Agregando id: 1291 --> Todos (Cualquier persona solicitante)
# Agregando id: 1292 --> Estudiantes Universitarios
# Agregando id: 1293 --> Todos (Cualquier persona solicitante)
# Agregando id: 1293 --> Todos (Cualquier persona solicitante)
# Agregando id: 1294 --> Estudiantes Universitarios
# Agregando id: 1295 --> Personas Aseguradas
# Agregando id: 1296 --> Comunidades Educativas
# Agregando id: 1297 --> Todos (Cualquier persona solicitante)
# Agregando id: 1297 --> Todos (Cualquier persona solicitante)
# Agregando id: 1298 --> Todos (Cualquier persona solicitante)
# Agregando id: 1299 --> Todos (Cualquier persona solicitante)
# Agregando id: 1299 --> Todos (Cualquier persona solicitante)
# Agregando id: 1300 --> establecimientos de salud
# Agregando id: 1301 --> Personas Aseguradas
# Agregando id: 1303 --> Todos (Cualquier persona solicitante)
# Agregando id: 1303 --> Todos (Cualquier persona solicitante)
# Agregando id: 1304 --> Personas Aseguradas
# Agregando id: 1305 --> Persona Natural
# Agregando id: 1306 --> Comunidades Educativas
# Agregando id: 1307 --> Todos (Cualquier persona solicitante)
# Agregando id: 1307 --> Todos (Cualquier persona solicitante)
# Agregando id: 1308 --> Todos (Cualquier persona solicitante)
# Agregando id: 1309 --> Todos (Cualquier persona solicitante)
# Agregando id: 1310 --> Todos (Cualquier persona solicitante)
# Agregando id: 1311 --> Todos (Cualquier persona solicitante)
# Agregando id: 1311 --> Todos (Cualquier persona solicitante)
# Agregando id: 1312 --> Todos (Cualquier persona solicitante)
# Agregando id: 1313 --> Todos (Cualquier persona solicitante)
# Agregando id: 1314 --> Todos (Cualquier persona solicitante)
# Agregando id: 1314 --> Todos (Cualquier persona solicitante)
# Agregando id: 1315 --> Todos (Cualquier persona solicitante)
# Agregando id: 1316 --> Todos (Cualquier persona solicitante)
# Agregando id: 1316 --> Todos (Cualquier persona solicitante)
# Agregando id: 1317 --> Todos (Cualquier persona solicitante)
# Agregando id: 1317 --> Todos (Cualquier persona solicitante)
# Agregando id: 1318 --> Todos (Cualquier persona solicitante)
# Agregando id: 1318 --> Todos (Cualquier persona solicitante)
# Agregando id: 1319 --> Comunidades Educativas
# Agregando id: 1320 --> Todos (Cualquier persona solicitante)
# Agregando id: 1320 --> Todos (Cualquier persona solicitante)
# Agregando id: 1321 --> Todos (Cualquier persona solicitante)
# Agregando id: 1321 --> Todos (Cualquier persona solicitante)
# Agregando id: 1323 --> Comunidades Educativas
# Agregando id: 1324 --> Todos (Cualquier persona solicitante)
# Agregando id: 1324 --> Todos (Cualquier persona solicitante)
# Agregando id: 1325 --> Comunidades Educativas
# Agregando id: 1326 --> Todos (Cualquier persona solicitante)
# Agregando id: 1326 --> Todos (Cualquier persona solicitante)
# Agregando id: 1327 --> Todos (Cualquier persona solicitante)
# Agregando id: 1327 --> Todos (Cualquier persona solicitante)
# Agregando id: 1328 --> Todos (Cualquier persona solicitante)
# Agregando id: 1328 --> Todos (Cualquier persona solicitante)
# Agregando id: 1329 --> Todos (Cualquier persona solicitante)
# Agregando id: 1329 --> Todos (Cualquier persona solicitante)
# Agregando id: 1330 --> Todos (Cualquier persona solicitante)
# Agregando id: 1330 --> Todos (Cualquier persona solicitante)
# Agregando id: 1331 --> Todos (Cualquier persona solicitante)
# Agregando id: 1331 --> Todos (Cualquier persona solicitante)
# Agregando id: 1332 --> Todos (Cualquier persona solicitante)
# Agregando id: 1332 --> Todos (Cualquier persona solicitante)
# Agregando id: 1333 --> Todos (Cualquier persona solicitante)
# Agregando id: 1333 --> Todos (Cualquier persona solicitante)
# Agregando id: 1334 --> Todos (Cualquier persona solicitante)
# Agregando id: 1335 --> Todos (Cualquier persona solicitante)
# Agregando id: 1335 --> Todos (Cualquier persona solicitante)
# Agregando id: 1336 --> Todos (Cualquier persona solicitante)
# Agregando id: 1336 --> Todos (Cualquier persona solicitante)
# Agregando id: 1337 --> Todos (Cualquier persona solicitante)
# Agregando id: 1337 --> Todos (Cualquier persona solicitante)
# Agregando id: 1339 --> Todos (Cualquier persona solicitante)
# Agregando id: 1339 --> Todos (Cualquier persona solicitante)
# Agregando id: 1340 --> Todos (Cualquier persona solicitante)
# Agregando id: 1340 --> Todos (Cualquier persona solicitante)
# Agregando id: 1341 --> Todos (Cualquier persona solicitante)
# Agregando id: 1341 --> Todos (Cualquier persona solicitante)
# Agregando id: 1342 --> Todos (Cualquier persona solicitante)
# Agregando id: 1343 --> Todos (Cualquier persona solicitante)
# Agregando id: 1344 --> Todos (Cualquier persona solicitante)
# Agregando id: 1345 --> Todos (Cualquier persona solicitante)
# Agregando id: 1346 --> Todos (Cualquier persona solicitante)
# Agregando id: 1347 --> Todos (Cualquier persona solicitante)
# Agregando id: 1348 --> Todos (Cualquier persona solicitante)
# Agregando id: 1351 --> Empresas Públicas o Privadas
# Agregando id: 1351 --> Empresas Públicas o Privadas
# Agregando id: 1352 --> Empresas Públicas o Privadas
# Agregando id: 1352 --> Empresas Públicas y Privadas
# Agregando id: 1353 --> Empresas Públicas o Privadas
# Agregando id: 1354 --> Todos (Cualquier persona solicitante)
# Agregando id: 1355 --> Todos (Cualquier persona solicitante)
# Agregando id: 1356 --> Comunidades Educativas
# Agregando id: 1357 --> Todos (Cualquier persona solicitante)
# Agregando id: 1358 --> Comunidades Educativas
# Agregando id: 1359 --> Todos (Cualquier persona solicitante)
# Agregando id: 1360 --> Todos (Cualquier persona solicitante)
# Agregando id: 1361 --> Comunidades Educativas
# Agregando id: 1362 --> Todos (Cualquier persona solicitante)
# Agregando id: 1363 --> Comunidades Educativas
# Agregando id: 1364 --> Todos (Cualquier persona solicitante)
# Agregando id: 1365 --> Todos (Cualquier persona solicitante)
# Agregando id: 1366 --> Comunidades Educativas
# Agregando id: 1367 --> Todos (Cualquier persona solicitante)
# Agregando id: 1368 --> Todos (Cualquier persona solicitante)
# Agregando id: 1369 --> Comunidades Educativas
# Agregando id: 1370 --> Todos (Cualquier persona solicitante)
# Agregando id: 1371 --> Todos (Cualquier persona solicitante)
# Agregando id: 1372 --> Empresas Públicas o Privadas
# Agregando id: 1373 --> Todos (Cualquier persona solicitante)
# Agregando id: 1374 --> Todos (Cualquier persona solicitante)
# Agregando id: 1374 --> Toda persona natural y/o jurídica
# Agregando id: 1375 --> Todos (Cualquier persona solicitante)
# Agregando id: 1376 --> Todos (Cualquier persona solicitante)
# Agregando id: 1377 --> Todos (Cualquier persona solicitante)
# Agregando id: 1378 --> Todos (Cualquier persona solicitante)
# Agregando id: 1379 --> Todos (Cualquier persona solicitante)
# Agregando id: 1380 --> Todos (Cualquier persona solicitante)
# Agregando id: 1381 --> Todos (Cualquier persona solicitante)
# Agregando id: 1382 --> Todos (Cualquier persona solicitante)
# Agregando id: 1383 --> Todos (Cualquier persona solicitante)
# Agregando id: 1384 --> Todos (Cualquier persona solicitante)
# Agregando id: 1385 --> Entidades Públicas
# Agregando id: 1386 --> Todos (Cualquier persona solicitante)
# Agregando id: 1387 --> Todos (Cualquier persona solicitante)
# Agregando id: 1388 --> Todos (Cualquier persona solicitante)
# Agregando id: 1389 --> Todos (Cualquier persona solicitante)
# Agregando id: 1390 --> Todos (Cualquier persona solicitante)
# Agregando id: 1391 --> Todos (Cualquier persona solicitante)
# Agregando id: 1392 --> Todos (Cualquier persona solicitante)
# Agregando id: 1393 --> Todos (Cualquier persona solicitante)
# Agregando id: 1394 --> Todos (Cualquier persona solicitante)
# Agregando id: 1395 --> Todos (Cualquier persona solicitante)
# Agregando id: 1396 --> Todos (Cualquier persona solicitante)
# Agregando id: 1397 --> Todos (Cualquier persona solicitante)
# Agregando id: 1398 --> Todos (Cualquier persona solicitante)
# Agregando id: 1399 --> Todos (Cualquier persona solicitante)
# Agregando id: 1400 --> Persona Natural
# Agregando id: 1401 --> Todos (Cualquier persona solicitante)
# Agregando id: 1402 --> Todos (Cualquier persona solicitante)
# Agregando id: 1403 --> Persona Natural
# Agregando id: 1404 --> Persona Jurídica (Empresa)
# Agregando id: 1404 --> Persona Jurídica (Empresa Internacional)
# Agregando id: 1405 --> Cooperativa
# Agregando id: 1406 --> Cooperativa
# Agregando id: 1407 --> Comunidades Educativas
# Agregando id: 1408 --> Comunidades Educativas
# Agregando id: 1409 --> Comunidades Educativas
# Agregando id: 1416 --> Policía
# Agregando id: 1417 --> Cooperativa
# Agregando id: 1418 --> Cooperativa
# Agregando id: 1419 --> Cooperativa
# Agregando id: 1420 --> Cooperativa
# Agregando id: 1421 --> Cooperativa
# Agregando id: 1422 --> Cooperativa
# Agregando id: 1423 --> Cooperativa
# Agregando id: 1424 --> Cooperativa
# Agregando id: 1425 --> Cooperativa
# Agregando id: 1426 --> Cooperativa
# Agregando id: 1427 --> Cooperativa
# Agregando id: 1428 --> Cooperativa
# Agregando id: 1429 --> Cooperativa
# Agregando id: 1430 --> Cooperativa
# Agregando id: 1431 --> Cooperativa
# Agregando id: 1432 --> Cooperativa
# Agregando id: 1434 --> Cooperativa
# Agregando id: 1435 --> Persona Jurídica (Empresa)
# Agregando id: 1435 --> Persona Jurídica (Empresa Internacional)
# Agregando id: 1436 --> Cooperativa
# Agregando id: 1437 --> Cooperativa
# Agregando id: 1438 --> Todos (Cualquier persona solicitante)
# Agregando id: 1439 --> Cooperativa
# Agregando id: 1440 --> Todos (Cualquier persona solicitante)
# Agregando id: 1441 --> Todos (Cualquier persona solicitante)
# Agregando id: 1442 --> Todos (Cualquier persona solicitante)
# Agregando id: 1443 --> Todos (Cualquier persona solicitante)
# Agregando id: 1444 --> Todos (Cualquier persona solicitante)
# Agregando id: 1445 --> Todos (Cualquier persona solicitante)
# Agregando id: 1446 --> Todos (Cualquier persona solicitante)
# Agregando id: 1447 --> Comunidades Educativas
# Agregando id: 1448 --> Cooperativa
# Agregando id: 1449 --> Comunidades Educativas
# Agregando id: 1450 --> Comunidades Educativas
# Agregando id: 1451 --> Comunidades Educativas
# Agregando id: 1452 --> Empresas Públicas y Privadas
# Agregando id: 1454 --> Comunidades Educativas
# Agregando id: 1455 --> Comunidades Educativas
# Agregando id: 1456 --> Comunidades Educativas
# Agregando id: 1457 --> Comunidades Educativas
# Agregando id: 1458 --> Comunidades Educativas
# Agregando id: 1459 --> Comunidades Educativas
# Agregando id: 1460 --> Todos (Cualquier persona solicitante)
# Agregando id: 1461 --> Todos (Cualquier persona solicitante)
# Agregando id: 1462 --> Todos (Cualquier persona solicitante)
# Agregando id: 1463 --> Todos (Cualquier persona solicitante)
# Agregando id: 1464 --> Personas Jubiladas
# Agregando id: 1465 --> Todos (Cualquier persona solicitante)
# Agregando id: 1465 --> Todos (Cualquier persona solicitante)
# Agregando id: 1466 --> Todos (Cualquier persona solicitante)
# Agregando id: 1467 --> Todos (Cualquier persona solicitante)
# Agregando id: 1500 --> Comunidades Educativas
# Agregando id: 1501 --> Comunidades Educativas
# Agregando id: 1502 --> Personas Jubiladas
# Agregando id: 1503 --> Personas Jubiladas
# Agregando id: 1504 --> Todos (Cualquier persona solicitante)
# Agregando id: 1505 --> Todos (Cualquier persona solicitante)
# Agregando id: 1506 --> Todos (Cualquier persona solicitante)
# Agregando id: 1507 --> Todos (Cualquier persona solicitante)
# Agregando id: 1508 --> Todos (Cualquier persona solicitante)
# Agregando id: 1509 --> Todos (Cualquier persona solicitante)
# Agregando id: 1510 --> Todos (Cualquier persona solicitante)
# Agregando id: 1511 --> Comunidades Educativas
# Agregando id: 1512 --> Comunidades Educativas
# Agregando id: 1513 --> Comunidades Educativas
# Agregando id: 1514 --> Comunidades Educativas
# Agregando id: 1515 --> Personas Jubiladas
# Agregando id: 1516 --> Comunidades Educativas
# Agregando id: 1517 --> Comunidades Educativas
# Agregando id: 1518 --> Comunidades Educativas
# Agregando id: 1519 --> Personas Jubiladas
# Agregando id: 1520 --> Personas Jubiladas
# Agregando id: 1521 --> Personas Jubiladas
# Agregando id: 1522 --> Personas Jubiladas
# Agregando id: 1523 --> Personas Jubiladas
# Agregando id: 1524 --> Todos (Cualquier persona solicitante)
# Agregando id: 1525 --> Comunidades Educativas
# Agregando id: 1526 --> Comunidades Educativas
# Agregando id: 1527 --> Comunidades Educativas
# Agregando id: 1528 --> Todos (Cualquier persona solicitante)
# Agregando id: 1529 --> Todos (Cualquier persona solicitante)
# Agregando id: 1531 --> Importadores
# Agregando id: 1532 --> Todos (Cualquier persona solicitante)
# Agregando id: 1533 --> Personas Aseguradas
# Agregando id: 1534 --> Importadores
# Agregando id: 1535 --> Personas Aseguradas SSUE
# Agregando id: 1536 --> Personas Aseguradas SSUE
# Agregando id: 1537 --> Todos (Cualquier persona solicitante)
# Agregando id: 1538 --> Todos (Cualquier persona solicitante)
# Agregando id: 1540 --> Policía
# Agregando id: 1541 --> Todos (Cualquier persona solicitante)
# Agregando id: 1542 --> Todos (Cualquier persona solicitante)
# Agregando id: 1543 --> Todos (Cualquier persona solicitante)
# Agregando id: 1544 --> Todos (Cualquier persona solicitante)
# Agregando id: 1545 --> Policía
# Agregando id: 1546 --> Policía
# Agregando id: 1547 --> Policía
# Agregando id: 1548 --> Policía
# Agregando id: 1549 --> Policía
# Agregando id: 1550 --> Policía
# Agregando id: 1551 --> Policía
# Agregando id: 1552 --> Todos (Cualquier persona solicitante)
# Agregando id: 1553 --> Personas Aseguradas SSUE
# Agregando id: 1554 --> Todos (Cualquier persona solicitante)
# Agregando id: 1555 --> Todos (Cualquier persona solicitante)
# Agregando id: 1556 --> Todos (Cualquier persona solicitante)
# Agregando id: 1557 --> Todos (Cualquier persona solicitante)
# Agregando id: 1558 --> Todos (Cualquier persona solicitante)
# Agregando id: 1559 --> Todos (Cualquier persona solicitante)
# Agregando id: 1560 --> Personas Aseguradas SSUE
# Agregando id: 1561 --> Personas con discapacidad
# Agregando id: 1562 --> Personas Aseguradas SSUE
# Agregando id: 1563 --> Personas Aseguradas SSUE
# Agregando id: 1564 --> Personas Aseguradas SSUE
# Agregando id: 1565 --> Personas Aseguradas SSUE
# Agregando id: 1566 --> Personas Aseguradas SSUE
# Agregando id: 1567 --> Personas Aseguradas SSUE
# Agregando id: 1568 --> Personas Aseguradas SSUE
# Agregando id: 1569 --> Personas Aseguradas SSUE
# Agregando id: 1570 --> Todos (Cualquier persona solicitante)
# Agregando id: 1571 --> Policía
# Agregando id: 1572 --> Policía
# Agregando id: 1573 --> Policía
# Agregando id: 1574 --> Policía
# Agregando id: 1575 --> Personas Aseguradas SSUE
# Agregando id: 1576 --> Personas Aseguradas SSUE
# Agregando id: 1577 --> Personas Aseguradas SSUE
# Agregando id: 1578 --> Personas Aseguradas SSUE
# Agregando id: 1579 --> Personas Aseguradas SSUE
# Agregando id: 1580 --> Personas Aseguradas SSUE
# Agregando id: 1581 --> Personas Aseguradas SSUE
# Agregando id: 1582 --> Personas Aseguradas SSUE
# Agregando id: 1583 --> Personas Aseguradas SSUE
# Agregando id: 1584 --> Personas Aseguradas SSUE
# Agregando id: 1585 --> Policía
# Agregando id: 1586 --> Personas Aseguradas SSUE
# Agregando id: 1587 --> Personas Aseguradas SSUE
# Agregando id: 1588 --> Personas Aseguradas SSUE
# Agregando id: 1589 --> Personas Aseguradas SSUE
# Agregando id: 1590 --> Personas Aseguradas SSUE
# Agregando id: 1591 --> Personas Aseguradas SSUE
# Agregando id: 1592 --> Policía
# Agregando id: 1593 --> Personas Aseguradas SSUE
# Agregando id: 1594 --> Personas Aseguradas SSUE
# Agregando id: 1595 --> Personas Aseguradas SSUE
# Agregando id: 1596 --> Personas Aseguradas SSUE
# Agregando id: 1597 --> Personas Aseguradas SSUE
# Agregando id: 1598 --> Personas Aseguradas SSUE
# Agregando id: 1599 --> Todos (Cualquier persona solicitante)
# Agregando id: 1600 --> Personas Aseguradas SSUE
# Agregando id: 1601 --> Representante de fábricante de juegos
# Agregando id: 1601 --> Empresas Públicas o Privadas
# Agregando id: 1603 --> Fabricante Autorizado (Software de juego)
# Agregando id: 1603 --> Fabricante Autorizado (maquina o medio de juego)
# Agregando id: 1604 --> Policía
# Agregando id: 1605 --> Policía
# Agregando id: 1606 --> Policía
# Agregando id: 1607 --> Policía
# Agregando id: 1608 --> Todos (Cualquier persona solicitante)
# Agregando id: 1609 --> Todos (Cualquier persona solicitante)
# Agregando id: 1610 --> Todos (Cualquier persona solicitante)
# Agregando id: 1611 --> Servidor Público Personal Eventual Consultor Línea
# Agregando id: 1611 --> Servidor Público Personal Eventual Consultor Línea
# Agregando id: 1612 --> Todos (Cualquier persona solicitante)
# Agregando id: 1614 --> Personas con Discapacidad
# Agregando id: 1615 --> Empresas Públicas y Privadas
# Agregando id: 1616 --> Personas con Discapacidad
# Agregando id: 1617 --> Personas Aseguradas
# Agregando id: 1618 --> Empleador
# Agregando id: 1619 --> Empleador
# Agregando id: 1620 --> Empleador
# Agregando id: 1621 --> Empleador
# Agregando id: 1622 --> Personas Aseguradas
# Agregando id: 1623 --> Todos (Cualquier persona solicitante)
# Agregando id: 1624 --> Personas Aseguradas
# Agregando id: 1625 --> Personas Aseguradas
# Agregando id: 1626 --> Todos (Cualquier persona solicitante)
# Agregando id: 1627 --> Persona Jurídica (Empresa)
# Agregando id: 1628 --> Empleador
# Agregando id: 1630 --> Personas con Discapacidad
# Agregando id: 1631 --> Empleador
# Agregando id: 1632 --> Empleador
# Agregando id: 1633 --> Personas Aseguradas
# Agregando id: 1634 --> Personas Aseguradas
# Agregando id: 1635 --> Personas Aseguradas
# Agregando id: 1636 --> Personas Aseguradas
# Agregando id: 1637 --> Empleador
# Agregando id: 1638 --> Personas Aseguradas
# Agregando id: 1639 --> Personas Aseguradas
# Agregando id: 1642 --> Policía
# Agregando id: 1643 --> Policía
# Agregando id: 1644 --> Policía
# Agregando id: 1645 --> Policía
# Agregando id: 1646 --> Policía
# Agregando id: 1647 --> Policía
# Agregando id: 1648 --> Policía
# Agregando id: 1649 --> Policía
# Agregando id: 1650 --> Policía
# Agregando id: 1651 --> Policía
# Agregando id: 1652 --> Policía
# Agregando id: 1653 --> Policía
# Agregando id: 1654 --> Policía
# Agregando id: 1655 --> Policía
# Agregando id: 1656 --> Policía
# Agregando id: 1657 --> Policía
# Agregando id: 1658 --> Policía
# Agregando id: 1659 --> Policía
# Agregando id: 1660 --> Policía
# Agregando id: 1661 --> Policía
# Agregando id: 1662 --> Policía
# Agregando id: 1663 --> Todos (Cualquier persona solicitante)
# Agregando id: 1664 --> Personas Aseguradas y Derechohabientes
# Agregando id: 1665 --> Todos (Cualquier persona solicitante)
# Agregando id: 1666 --> Todos (Cualquier persona solicitante)
# Agregando id: 1668 --> Persona Natural
# Agregando id: 1669 --> Persona Natural
# Agregando id: 1670 --> Persona Jurídica (Empresa)
# Agregando id: 1671 --> Persona Natural
# Agregando id: 1672 --> SERVIDORES PÚBLICOS
# Agregando id: 1673 --> SERVIDORES PÚBLICOS
# Agregando id: 1674 --> Persona Natural
# Agregando id: 1675 --> Todos (Cualquier persona solicitante)
# Agregando id: 1676 --> Todos (Cualquier persona solicitante)
# Agregando id: 1677 --> Todos (Cualquier persona solicitante)
# Agregando id: 1678 --> Personas con Discapacidad
# Agregando id: 1679 --> Todos (Cualquier persona solicitante)
# Agregando id: 1680 --> Personas Aseguradas
# Agregando id: 1681 --> Empleador
# Agregando id: 1682 --> Empleador
# Agregando id: 1683 --> Personas Aseguradas
# Agregando id: 1684 --> Todos (Cualquier persona solicitante)
# Agregando id: 1685 --> Minero Metalúrgico
# Agregando id: 1685 --> ASEGURADOS
# Agregando id: 1686 --> Todos (Cualquier persona solicitante)
# Agregando id: 1687 --> Personas Aseguradas
# Agregando id: 1688 --> Personas Aseguradas
# Agregando id: 1689 --> Personas Aseguradas
# Agregando id: 1690 --> Personas Aseguradas
# Agregando id: 1691 --> Empleador
# Agregando id: 1692 --> Todos (Cualquier persona solicitante)
# Agregando id: 1693 --> Empleador
# Agregando id: 1694 --> Personas mayores de 60 años
# Agregando id: 1695 --> Personas Aseguradas
# Agregando id: 1696 --> Todos (Cualquier persona solicitante)
# Agregando id: 1697 --> Personas Aseguradas
# Agregando id: 1698 --> Herederos
# Agregando id: 1699 --> Todos (Cualquier persona solicitante)
# Agregando id: 1700 --> Todos (Cualquier persona solicitante)
# Agregando id: 1701 --> Todos (Cualquier persona solicitante)
# Agregando id: 1702 --> Personas Aseguradas
# Agregando id: 1703 --> Personas Aseguradas
# Agregando id: 1704 --> Derechohabientes
# Agregando id: 1705 --> Personas Aseguradas
# Agregando id: 1706 --> Personas Aseguradas
# Agregando id: 1707 --> Personas mayores de 60 años
# Agregando id: 1708 --> Servidores Públicos
# Agregando id: 1709 --> Servidores Públicos
# Agregando id: 1710 --> Servidores Públicos
# Agregando id: 1711 --> Todos (Cualquier persona solicitante)
# Agregando id: 1712 --> Todos (Cualquier persona solicitante)
# Agregando id: 1713 --> Policía
# Agregando id: 1714 --> Guías de Turismo
# Agregando id: 1715 --> Actor Productivo Minero
# Agregando id: 1715 --> Industria Minera Privada - Empresa Unipersonal
# Agregando id: 1715 --> INDUSTRIA MINERA ESTATAL
# Agregando id: 1715 --> Industria Minera Privada-Empresa Colectiva SRL SA
# Agregando id: 1716 --> Actor Productivo Minero
# Agregando id: 1716 --> Cooperativas Mineras
# Agregando id: 1716 --> Industria Minera Privada
# Agregando id: 1718 --> Comunidades Educativas
# Agregando id: 1719 --> Persona Jurídica (Empresa)
# Agregando id: 1720 --> Persona Jurídica (Empresa)
# Agregando id: 1721 --> Comunidades Educativas
# Agregando id: 1722 --> Comunidades Educativas
# Agregando id: 1724 --> Usuario - Sistema Educativo Beni
# Agregando id: 1725 --> Comunidades Educativas
# Agregando id: 1726 --> Comunidades Educativas
# Agregando id: 1727 --> Comunidades Educativas
# Agregando id: 1728 --> Comunidades Educativas
# Agregando id: 1729 --> Comunidades Educativas
# Agregando id: 1730 --> Comunidades Educativas
# Agregando id: 1731 --> Comunidades Educativas
# Agregando id: 1732 --> Comunidades Educativas
# Agregando id: 1733 --> Comunidades Educativas
# Agregando id: 1734 --> Todos (Cualquier persona solicitante)
# Agregando id: 1735 --> Comunidades Educativas
# Agregando id: 1736 --> Comunidades Educativas
# Agregando id: 1737 --> Comunidades Educativas
# Agregando id: 1739 --> Comunidades Educativas
# Agregando id: 1740 --> Comunidades Educativas
# Agregando id: 1741 --> Comunidades Educativas
# Agregando id: 1743 --> Comunidades Educativas
# Agregando id: 1744 --> Usuario - Sistema Educativo Beni
# Agregando id: 1745 --> Usuario - Sistema Educativo Beni
# Agregando id: 1746 --> Personas Extranjeras
# Agregando id: 1747 --> Todos (Cualquier persona solicitante)
# Agregando id: 1748 --> Todos (Cualquier persona solicitante)
# Agregando id: 1749 --> Todos (Cualquier persona solicitante)
# Agregando id: 1750 --> Todos (Cualquier persona solicitante)
# Agregando id: 1751 --> Personas Aseguradas
# Agregando id: 1753 --> Persona Natural
# Agregando id: 1754 --> Todos (Cualquier persona solicitante)
# Agregando id: 1755 --> Todos (Cualquier persona solicitante)
# Agregando id: 1756 --> Todos (Cualquier persona solicitante)
# Agregando id: 1757 --> Todos (Cualquier persona solicitante)
# Agregando id: 1758 --> Actor Productivo Minero
# Agregando id: 1759 --> Joyerias y Orfebrerias
# Agregando id: 1759 --> Empresas Industriales y Manufactura
# Agregando id: 1760 --> Actor Productivo Minero
# Agregando id: 1761 --> Actor Productivo Minero
# Agregando id: 1762 --> Actor Productivo Minero
# Agregando id: 1763 --> Actor Productivo Minero
# Agregando id: 1764 --> Persona Natural
# Agregando id: 1765 --> Todos (Cualquier persona solicitante)
# Agregando id: 1766 --> Todos (Cualquier persona solicitante)
# Agregando id: 1767 --> Todos (Cualquier persona solicitante)
# Agregando id: 1769 --> Todos (Cualquier persona solicitante)
# Agregando id: 1770 --> Todos (Cualquier persona solicitante)
# Agregando id: 1771 --> Todos (Cualquier persona solicitante)
# Agregando id: 1772 --> Todos (Cualquier persona solicitante)
# Agregando id: 1773 --> Todos (Cualquier persona solicitante)
# Agregando id: 1774 --> Todos (Cualquier persona solicitante)
# Agregando id: 1775 --> Todos (Cualquier persona solicitante)
# Agregando id: 1776 --> Todos (Cualquier persona solicitante)
# Agregando id: 1777 --> Todos (Cualquier persona solicitante)
# Agregando id: 1778 --> Todos (Cualquier persona solicitante)
# Agregando id: 1779 --> Todos (Cualquier persona solicitante)
# Agregando id: 1812 --> Todos (Cualquier persona solicitante)
# Agregando id: 1813 --> Todos (Cualquier persona solicitante)
# Agregando id: 1814 --> Todos (Cualquier persona solicitante)
# Agregando id: 1815 --> Todos (Cualquier persona solicitante)
# Agregando id: 1816 --> Todos (Cualquier persona solicitante)
# Agregando id: 1817 --> Todos (Cualquier persona solicitante)
# ...
# Agregando id: 2450 --> Todos (Cualquier persona solicitante)
# Agregando id: 2451 --> Personas de todas las edades con discapacidad
# Agregando id: 2452 --> Todos (Cualquier persona solicitante)
# Agregando id: 2453 --> Personas con discapacidad.
# Agregando id: 2454 --> Niños, niñas y adolescentes menores de 18 años
# Agregando id: 2455 --> Niños, niñas y adolescentes menores de 18 años
# Agregando id: 2456 --> Todos (Cualquier persona solicitante)
# Agregando id: 2457 --> Niños, niñas y adolescentes menores de 18 años
# Agregando id: 2458 --> Niños, niñas y adolescentes menores de 18 años
# Agregando id: 2459 --> Todos (Cualquier persona solicitante)
# Agregando id: 2460 --> Todos (Cualquier persona solicitante)
# Agregando id: 2461 --> Todos (Cualquier persona solicitante)
# Agregando id: 2462 --> Empresas
# Agregando id: 2463 --> Todos (Cualquier persona solicitante)
# Agregando id: 2464 --> Todos (Cualquier persona solicitante)
# Agregando id: 2465 --> Organizaciones No Gubernamentales (ONG´s)
# Agregando id: 2466 --> Embajadas
# Agregando id: 2467 --> Organismo Internacional
# Agregando id: 2468 --> Cooperativas
# Agregando id: 2469 --> Todos (Cualquier persona solicitante)
# Agregando id: 2470 --> Todos (Cualquier persona solicitante)
# Agregando id: 2471 --> Todos (Cualquier persona solicitante)
# Agregando id: 2472 --> REQUISITOS PARA AFILIACIÓN DE TRABAJADOR ACTIVO
# Agregando id: 2472 --> Todos (cualquier persona solicitante - Tarija)
# Agregando id: 2473 --> BENEFICIARIO DEPENDIENTE
# Agregando id: 2474 --> JUBILADO-RENTISTA
# Agregando id: 2475 --> AFILIADO ACTIVO SSUT
# Agregando id: 2475 --> Personas Aseguradas
# Agregando id: 2476 --> Personas Aseguradas
# Agregando id: 2477 --> Persona Natural
# Agregando id: 2478 --> Personas Naturales o Jurídicas
# Agregando id: 2479 --> Todos (cualquier persona solicitante - Cochabamba)
# Agregando id: 2480 --> Todos (cualquier persona solicitante - Cochabamba)
# Agregando id: 2483 --> Todos (Cualquier persona solicitante)
# Agregando id: 2484 --> Todos (Cualquier persona solicitante)
# Agregando id: 2485 --> Todos (Cualquier persona solicitante)
# Agregando id: 2486 --> Población en  General
# Agregando id: 2487 --> Persona Natural
# Agregando id: 2488 --> Persona Natural
# Agregando id: 2489 --> Persona Natural
# Agregando id: 2490 --> Todos (Cualquier persona solicitante)
# Agregando id: 2491 --> Todos (Cualquier persona solicitante)
# Agregando id: 2492 --> Todos (Cualquier persona solicitante)
# Agregando id: 2493 --> público en general
# Agregando id: 2494 --> Población en general
# Agregando id: 2495 --> Comunidad
# Agregando id: 2496 --> Comunidad
# Agregando id: 2497 --> Comunidades Educativas
# Agregando id: 2498 --> Comunidad
# Agregando id: 2499 --> Comunidades Educativas
# Agregando id: 2500 --> Comunidad
# Agregando id: 2501 --> Comunidad
# Agregando id: 2502 --> Personas Naturales o Jurídicas
# Agregando id: 2503 --> Persona Natural
# Agregando id: 2504 --> Persona Natural
# Agregando id: 2505 --> Persona Natural
# Agregando id: 2506 --> Todos (Cualquier persona solicitante)
# Agregando id: 2507 --> Persona Natural
# Agregando id: 2508 --> Persona Natural
# Agregando id: 2509 --> Todos (Cualquier persona solicitante)
# Agregando id: 2510 --> Todos (Cualquier persona solicitante)
# Agregando id: 2512 --> Todos (Cualquier persona solicitante)
# Agregando id: 2513 --> Entidad Pública
# Agregando id: 2514 --> Personas natuales o jurídicas
# Agregando id: 2515 --> REQUISITOS PARA AFILIACIÓN DE TRABAJADOR ACTIVO
# Agregando id: 2516 --> TRABAJADOR ACTIVO
# Agregando id: 2517 --> Personas Naturales o Jurídicas
# Agregando id: 2518 --> Personas Naturales o Jurídicas
# Agregando id: 2520 --> Personas Naturales o Jurídicas
# Agregando id: 2521 --> Egresados
# Agregando id: 2522 --> Egresados
# Agregando id: 2523 --> Egresados
# Agregando id: 2524 --> Egresados
# Agregando id: 2525 --> Egresados
# Agregando id: 2526 --> público en general
# Agregando id: 2527 --> Egresados
# Agregando id: 2528 --> Importadores
# Agregando id: 2529 --> Empresas constructoras e inmobiliarias
# Agregando id: 2531 --> Toda Persona que lo requiera
# Agregando id: 2531 --> Toda Persona que lo requiera
# Agregando id: 2532 --> Persona Jurídica (Empresa)
# Agregando id: 2533 --> Toda Persona que lo requiera
# Agregando id: 2534 --> SERVIDORES PÚBLICOS
# Agregando id: 2535 --> Cooperativa
# Agregando id: 2536 --> Cooperativa
# Agregando id: 2537 --> Cooperativa
# Agregando id: 2538 --> Cooperativas Mineras
# Agregando id: 2539 --> Cooperativas Mineras
# Agregando id: 2540 --> Estudiantes
# Agregando id: 2541 --> Todos (Cualquier persona solicitante)
# Agregando id: 2542 --> Importadores
# Agregando id: 2543 --> Empresas
# Agregando id: 2576 --> Estudiantes de unidades educativas
# Agregando id: 2577 --> Estudiantes de unidades educativas
# Agregando id: 2578 --> Estudiantes de unidades educativas
# Agregando id: 2579 --> Estudiantes de unidades educativas
# Agregando id: 2580 --> Estudiantes de unidades educativas
# Agregando id: 2581 --> todos
# Agregando id: 2583 --> todos
# Agregando id: 2584 --> todos
# Agregando id: 2585 --> Estudiantes de unidades educativas
# Agregando id: 2587 --> Estudiantes de unidades educativas
# Agregando id: 2588 --> Estudiantes de unidades educativas
# Agregando id: 2589 --> Estudiantes de unidades educativas
# Agregando id: 2590 --> Personas Naturales o Jurídicas
# Agregando id: 2591 --> Empleadores (públicos y privados)
# Agregando id: 2592 --> Estudiantes de unidades educativas
# Agregando id: 2593 --> Empresas
# Agregando id: 2594 --> Trabajadores con más de un empleador
# Agregando id: 2595 --> Estudiantes de unidades educativas
# Agregando id: 2597 --> Trabajadores con más de un empleador
# Agregando id: 2598 --> Trabajadores que cambian de empleador
# Agregando id: 2599 --> Estudiantes de unidades educativas
# Agregando id: 2600 --> Estudiantes de unidades educativas
# Agregando id: 2601 --> Empresas
# Agregando id: 2603 --> Estudiantes de unidades educativas
# Agregando id: 2604 --> Estudiantes de unidades educativas
# Agregando id: 2605 --> Empresas
# Agregando id: 2605 --> Empresas
# Agregando id: 2607 --> Personas Naturales o Jurídicas
# Agregando id: 2608 --> Importadores/Exportadores
# Agregando id: 2609 --> Empresas
# Agregando id: 2610 --> Personas Naturales
# Agregando id: 2611 --> Empresas
# Agregando id: 2612 --> Empresas
# Agregando id: 2613 --> Empresas
# Agregando id: 2614 --> Empresas
# Agregando id: 2615 --> Todos (Cualquier persona solicitante)
# Agregando id: 2616 --> Todos (Cualquier persona solicitante)
# Agregando id: 2617 --> Empresas
# Agregando id: 2618 --> Empresas
# Agregando id: 2619 --> Empresas
# Agregando id: 2620 --> Empresas
# Agregando id: 2621 --> Empresas
# Agregando id: 2622 --> Empresas
# Agregando id: 2623 --> Empresas
# Agregando id: 2624 --> Empresas
# Agregando id: 2625 --> Empresas
# Agregando id: 2626 --> Empresas
# Agregando id: 2627 --> Empresas
# Agregando id: 2628 --> Empresas
# Agregando id: 2629 --> Empresas
# Agregando id: 2630 --> Empresas
# Agregando id: 2631 --> Empresas
# Agregando id: 2632 --> Empresas
# Agregando id: 2633 --> Empresas
# Agregando id: 2634 --> Empresas
# Agregando id: 2635 --> Empresas
# Agregando id: 2636 --> Empresas
# Agregando id: 2637 --> Empresas
# Agregando id: 2638 --> Empresas
# Agregando id: 2639 --> Empresas
# Agregando id: 2640 --> Empresas
# Agregando id: 2641 --> Empresas
# Agregando id: 2643 --> Empresas
# Agregando id: 2644 --> Empresas
# Agregando id: 2645 --> Empresas
# Agregando id: 2646 --> Empresas
# Agregando id: 2647 --> Empresas
# Agregando id: 2648 --> Empresas
# Agregando id: 2649 --> Empresas
# Agregando id: 2650 --> Todos (Cualquier persona solicitante)
# Agregando id: 2651 --> Todos (Cualquier persona solicitante)
# Agregando id: 2655 --> Todos (Cualquier persona solicitante)
# Agregando id: 2656 --> Todos (Cualquier persona solicitante)
# Agregando id: 2657 --> Todos (Cualquier persona solicitante)
# Agregando id: 2658 --> Todos (Cualquier persona solicitante)
# Agregando id: 2659 --> Todos (Cualquier persona solicitante)
# Agregando id: 2660 --> Todos (Cualquier persona solicitante)
# Agregando id: 2661 --> Todos (Cualquier persona solicitante)
# Agregando id: 2662 --> Todos (Cualquier persona solicitante)
# Agregando id: 2663 --> Todos (Cualquier persona solicitante)
# Agregando id: 2664 --> Todos (Cualquier persona solicitante)
# Agregando id: 2665 --> Todos (Cualquier persona solicitante)
# Agregando id: 2666 --> Todos (Cualquier persona solicitante)
# Agregando id: 2667 --> Todos (Cualquier persona solicitante)
# Agregando id: 2668 --> Todos (Cualquier persona solicitante)
# Agregando id: 2677 --> público en general
# Agregando id: 2728 --> Empresas Públicas o Privadas
# Agregando id: 2757 --> Comunidad
# Agregando id: 2759 --> Establecimientos de Salud
# Agregando id: 2763 --> Egresados
# Agregando id: 2764 --> Todos (Cualquier persona solicitante)
# Agregando id: 2765 --> Todos (Cualquier persona solicitante)
# Agregando id: 2766 --> Todos (Cualquier persona solicitante)
# Agregando id: 2767 --> Todos (Cualquier persona solicitante)
# Agregando id: 2768 --> Todos (Cualquier persona solicitante)
# Agregando id: 2769 --> Todos (Cualquier persona solicitante)
# Agregando id: 2771 --> Empresas Públicas o Privadas
# Agregando id: 2772 --> Empresas Públicas o Privadas
# Agregando id: 2773 --> establecimientos de salud
# Agregando id: 2774 --> Empresas Públicas o Privadas
# Agregando id: 2776 --> Todos (Cualquier persona solicitante)
# Agregando id: 2777 --> Población en  General
# Agregando id: 2778 --> Población en general
# Agregando id: 2779 --> Establecimientos de Salud
# Agregando id: 2793 --> Todos (Cualquier persona solicitante)
# Agregando id: 2819 --> público en general
# Agregando id: 2825 --> Toda persona natural y/o jurídica
# Agregando id: 2827 --> Todos (Cualquier persona solicitante)
# Agregando id: 2843 --> Agentes de Carga
# (1544, 44)
#         id     estado fechaActualización  \
# 215   1176  PUBLICADO         10/07/2025
# 1025  2074  PUBLICADO         07/07/2025
# 624   1538  PUBLICADO         10/07/2025
#
#                                                  nombre  \
# 215   Trámite 20 - Registro de Otorgamiento de Poder...
# 1025  PROGRAMA MUNICIPAL DE PROTECCION SOCIAL PARA N...
# 624   Certificado de Información sobre Solvencia con...
#
#                                                    slug       sigla  \
# 215   tramite-20-registro-de-otorgamiento-de-poder-y...  Trámite 20
# 1025  programa-municipal-de-proteccion-social-para-n...       NNATs
# 624   certificado-de-informacion-sobre-solvencia-con...         NaN
#
#                                             descripcion  \
# 215   Acto mediante el cual un Comerciante Individua...
# 1025  SE TIENE EL OBJETIVO DE REDUCIR EL TRABAJO INF...
# 624   Documento emitido por la Contraloría General d...
#
#                                              marcoLegal like dislike  \
# 215   D.L. No. 14379 de 25 de febrero de 1977, Códig...    0       0
# 1025  LEY AUTONOMICA MUNICIPAL N° 120/18 "LEY MUNICI...    0       0
# 624   •\tDecreto Supremo N° 24278 de 18 de abril de ...    0       0
#
#      esPresencial esVirtual   resultado  \
# 215             1         1    Registro
# 1025            1         0         NaN
# 624             1         0  Constancia
#
#                                                 enlaces  \
# 215   [{"nombre": "Guía de Trámites", "url": "https:...
# 1025                                                 []
# 624   [{"nombre": "SISTEMA DE REGISTRO DE PROCESOS J...
#
#                                             ubicaciones  \
# 215   [{"nombre": "Oficina Nacional", "tipo": "Ofici...
# 1025  [{"nombre": "OFICINAS DEL ADULTO MAYOR D3, D6,...
# 624   [{"nombre": "CONTRALORIA GENERAL DEL ESTADO", ...
#
#                                       entidad.nombre entidad.sigla  \
# 215   Servicio Plurinacional de Registro de Comercio        SEPREC
# 1025            Gobierno Autónomo Municipal de Sucre           SUC
# 624                   Contraloria General del Estado           CGE
#
#                                         entidad.slug  \
# 215   servicio-plurinacional-de-registro-de-comercio
# 1025            gobierno-autonomo-municipal-de-sucre
# 624                   contraloria-general-del-estado
#
#                                            entidad.logo  \
# 215   https://www.gob.bo/ws/api/archivos/dec5dd8d-a6...
# 1025  https://www.gob.bo/ws/api/archivos/34c1052a-76...
# 624   https://www.gob.bo/ws/api/archivos/79609d48-71...
#
#                                     entidad.descripcion  \
# 215   El Servicio Plurinacional de Registro de Comer...
# 1025  El Gobierno Autónomo Municipal de Sucre desemp...
# 624   La Contraloría General del Estado es la instit...
#
#                   entidad.urlSitioWeb entidad.telefonoContacto  \
# 215         https://www.seprec.gob.bo                800102992
# 1025                 https://sucre.bo                      NaN
# 624   https://www.contraloria.gob.bo/                  2177400
#
#      entidad.correoElectronicoContacto palabrasClave  \
# 215                                NaN           NaN
# 1025                     info@sucre.bo           NaN
# 624      cge_prensa@contraloria.gob.bo           NaN
#
#                       categorias eventosVida  \
# 215                     Empresas         NaN
# 1025  Educación,Seguridad social         NaN
# 624                     Justicia         NaN
#
#                                              documentos herramientas  \
# 215    Certificado de Registro de Poder y/o Revocatoria          NaN
# 1025                                                NaN          NaN
# 624   Certificado de Información sobre Solvencia con...          NaN
#
#      modalidad.tipo                             tramite.url  \
# 215         VIRTUAL  https://tramites.seprec.gob.bo/#/login
# 1025     PRESENCIAL                                    None
# 624      PRESENCIAL                                    None
#
#      tramite.urlSeguimiento tramite.tieneCosto tramite.duracion  \
# 215                    None                  1             None
# 1025                   None                  0                3
# 624                    None                  1               24
#
#      tramite.unidadMedidaDuracion  \
# 215
# 1025                       Año(s)
# 624                      Horas(s)
#
#                                   tramite.procedimiento  \
# 215   <p><strong>PROCEDIMIENTO TRÁMITE VIRTUAL</stro...
# 1025  <ul><li><p><em>El procedimiento para el ingres...
# 624   <p>Las personas naturales y jurídicas que requ...
#
#                     tramite.publicoObjetivo tramite.requisitoNoParametrizado  \
# 215   Todos (Cualquier persona solicitante)                             None
# 1025                        Persona Natural                             None
# 624   Todos (Cualquier persona solicitante)                             None
#
#      tramite.estado                        tramite.emisionFactura  \
# 215          ACTIVO  Servicio de Emisión de Facturas Electrónicas
# 1025         ACTIVO
# 624          ACTIVO  Servicio de Emisión de Facturas Electrónicas
#
#                     tramite.formaCobro  \
# 215     [Pasarela de pagos del estado]
# 1025                                []
# 624   [Pago en efectivo en ventanilla]
#
#                                        tramite.horarios  \
# 215   [{'dia': 'Lunes', 'continuo': True, 'inicioMan...
# 1025  [{'dia': 'Lunes', 'continuo': True, 'inicioMan...
# 624   [{'dia': 'Lunes', 'continuo': True, 'inicioMan...
#
#      tramite.depositoBancario  \
# 215                        []
# 1025                       []
# 624                        []
#
#                                          tramite.costos  \
# 215   [{'conceptoPago': 'Empresa Unipersonal', 'cost...
# 1025                                                 []
# 624   [{'conceptoPago': 'De Bs1 a Bs20.000', 'costo'...
#
#                                      tramite.requisitos
# 215   [{'comentario': 'Formulario Virtual de Registr...
# 1025  [{'comentario': 'Fotocopia del menor, de los p...
# 624   [{'comentario': ' Formulario de Solicitud de I...

# %%
def obtener_duracion(num_duracion, unidad_medida, unidad_destino='min'):
    minutos = 0
    try:
        num_duracion = int(num_duracion)
    except Exception as E:
        return np.nan
    
    if unidad_medida == 'Día(s)':
        minutos = num_duracion*1440
    elif unidad_medida == 'Horas(s)':
        minutos = num_duracion*60
    elif unidad_medida == 'Mes(es)':
        minutos = num_duracion*43200
    elif unidad_medida == 'Año(s)':
        minutos = num_duracion*15768000
    elif unidad_medida == 'Semana(s)':
        minutos = num_duracion*10080

    if unidad_destino == 'min':
        return int(minutos)
    elif unidad_destino == 'hora':
        return int(minutos/60)
    elif unidad_destino == 'dia':
        return int(minutos/1440)

new_df['tramite.duracionMin'] = new_df.apply(
    lambda x: obtener_duracion(x['tramite.duracion'], x['tramite.unidadMedidaDuracion'], 'min'), axis=1)
new_df['tramite.duracionHora'] = new_df.apply(
    lambda x: obtener_duracion(x['tramite.duracion'], x['tramite.unidadMedidaDuracion'], 'hora'), axis=1)
new_df['tramite.duracionDia'] = new_df.apply(
    lambda x: obtener_duracion(x['tramite.duracion'], x['tramite.unidadMedidaDuracion'], 'dia'), axis=1)

new_df.sample(5)[['tramite.duracion', 'tramite.duracionMin', 'tramite.duracionHora', 'tramite.duracionDia',
                       'tramite.unidadMedidaDuracion', 'tramite.unidadMedidaDuracion',
                      'modalidad.tipo', 'estado']]

# %% [markdown]
# ## Desglosando costos de tramites

# %%
s = new_df.groupby('tramite.tieneCosto').count()['id']
s.index = ['Sin costo', 'Tiene costo']
s
# Out:
# Sin costo       518
# Tiene costo    1026
# Name: id, dtype: int64

# %%
def desglosar_segun_costos(df):
    _new_df = pd.DataFrame(columns=df.columns.to_list() + [
        'costo.conceptoPago', 'costo.monto', 'costo.moneda'])
    print(_new_df.columns)
    _df = df.copy()
    for i in _df.index.to_list():
        data = _df.iloc[i].to_dict()
        #print(data)
        costos = data['tramite.costos']
        for costo in costos:
            data['costo.conceptoPago'] = costo['conceptoPago']
            data['costo.monto'] = float(costo['costo'])
            data['costo.moneda'] = costo['moneda']
            #print('>>>>', data)
            print(f"Agregando id: {data['id']} -> {data['costo.monto']}: {data['costo.moneda']}")
            _new_df.loc[len(_new_df)] = data
    del _new_df['tramite.costos']
    return _new_df

new_df = desglosar_segun_costos(new_df)
print(new_df.shape)
new_df.sample(3)

# %% [markdown]
# ## Requisitos y procedimientos
#
# Reto: Averiguar cúantos trámites y procedimientos requieren el Carnet de Identidad (C.I) como requisito.

# %%
def desglosar_segun_costos(df):
    _new_df = pd.DataFrame(columns=df.columns.to_list() + [
        'requisito.comentario', 'requisito.nombre', 'requisito.entidad', 'requisito.entidadActiva'])
    print(_new_df.columns)
    _df = df.copy()
    for i in _df.index.to_list():
        data = _df.iloc[i].to_dict()
        #print(data)
        requisitos = data['tramite.requisitos']
        for requisito in requisitos:
            data['requisito.comentario'] = requisito['comentario']
            data['requisito.nombre'] = requisito['nombre']
            data['requisito.entidad'] = requisito['entidad']
            data['requisito.entidadActiva'] = 1 if requisito['entidadActiva'] == True else 0
            #print('>>>>', data)
            print(f"Agregando id: {data['id']} -> {data['requisito.nombre']}")
            _new_df.loc[len(_new_df)] = data
    del _new_df['tramite.requisitos']
    return _new_df

new_df = desglosar_segun_costos(new_df)
print(new_df.shape)
new_df.sample(3)

# %% [markdown]
# ## Guardando como csv
#
# Solo quedaría pendiente guardar los campos que son diccionarios como cadenas JSON.

# %%
df_desglosado = pd.DataFrame(columns=new_df.columns.to_list())

for column in new_df.columns:
    print(column, new_df[column].dtype)
    if new_df[column].dtype != 'object':
        df_desglosado[column] = new_df[column]
    else:
        # comprobando si la columna tiene objetos que pueden representarse como json
        contains_dict = new_df[column].map(lambda x: isinstance(x, dict) | isinstance(x, list) | isinstance(x, tuple))
        #print(f'{column}:\n {True in contains_dict.unique()}')
        if True in contains_dict.unique(): # existe al menos un valor que es diccionario
            print(f'Existe dict o array: {contains_dict.unique()}')
            try:
                df_desglosado[column] = new_df[column].map(lambda x: json.dumps(x, ensure_ascii=False))
            except:
                print(f'No se pudo convertir diccionario a json: {new_df[column]}')
                df_desglosado[column] = new_df[column]
        else:
            #print(f'No existe dict: {contains_dict.unique()}')
            df_desglosado[column] = new_df[column]

print(df_desglosado.shape, df_desglosado.columns)
df_desglosado.sample(3)
# Out:
# id int64
# estado object
# fechaActualización object
# nombre object
# slug object
# sigla object
# descripcion object
# marcoLegal object
# like int64
# dislike int64
# esPresencial int64
# esVirtual int64
# resultado object
# enlaces object
# ubicaciones object
# entidad.nombre object
# entidad.sigla object
# entidad.slug object
# entidad.logo object
# entidad.descripcion object
# entidad.urlSitioWeb object
# entidad.telefonoContacto object
# entidad.correoElectronicoContacto object
# palabrasClave object
# categorias object
# eventosVida object
# documentos object
# herramientas float64
# modalidad.tipo object
# tramite.url object
# tramite.urlSeguimiento object
# tramite.tieneCosto int64
# tramite.duracion object
# tramite.unidadMedidaDuracion object
# tramite.procedimiento object
# tramite.publicoObjetivo object
# tramite.requisitoNoParametrizado object
# tramite.estado object
# tramite.emisionFactura object
# tramite.formaCobro object
# Existe dict o array: [ True]
# tramite.horarios object
# Existe dict o array: [ True]
# tramite.depositoBancario object
# Existe dict o array: [ True]
# tramite.duracionMin float64
# tramite.duracionHora float64
# tramite.duracionDia float64
# costo.conceptoPago object
# costo.monto float64
# costo.moneda object
# requisito.comentario object
# requisito.nombre object
# requisito.entidad object
# Existe dict o array: [False  True]
# requisito.entidadActiva int64
# (5991, 52) Index(['id', 'estado', 'fechaActualización', 'nombre', 'slug', 'sigla',
#        'descripcion', 'marcoLegal', 'like', 'dislike', 'esPresencial',
#        'esVirtual', 'resultado', 'enlaces', 'ubicaciones', 'entidad.nombre',
#        'entidad.sigla', 'entidad.slug', 'entidad.logo', 'entidad.descripcion',
#        'entidad.urlSitioWeb', 'entidad.telefonoContacto',
#        'entidad.correoElectronicoContacto', 'palabrasClave', 'categorias',
#        'eventosVida', 'documentos', 'herramientas', 'modalidad.tipo',
#        'tramite.url', 'tramite.urlSeguimiento', 'tramite.tieneCosto',
#        'tramite.duracion', 'tramite.unidadMedidaDuracion',
#        'tramite.procedimiento', 'tramite.publicoObjetivo',
#        'tramite.requisitoNoParametrizado', 'tramite.estado',
#        'tramite.emisionFactura', 'tramite.formaCobro', 'tramite.horarios',
#        'tramite.depositoBancario', 'tramite.duracionMin',
#        'tramite.duracionHora', 'tramite.duracionDia', 'costo.conceptoPago',
#        'costo.monto', 'costo.moneda', 'requisito.comentario',
#        'requisito.nombre', 'requisito.entidad', 'requisito.entidadActiva'],
#       dtype='object')
#         id     estado fechaActualización  \
# 1538  1535  PUBLICADO         10/07/2025
# 2694  1761  PUBLICADO         10/07/2025
# 3435  1979  PUBLICADO         09/07/2025
#
#                                                  nombre  \
# 1538  LEGALIZACIÓN DE FOTOCOPIA DE DIPLOMA DE BACHILLER
# 2694  Actualización de Número de Identificación de A...
# 3435  Autorización de Publicación Oficial de Textos ...
#
#                                                    slug sigla  \
# 1538  legalizacion-de-fotocopia-de-diploma-de-bachiller   NaN
# 2694  actualizacion-de-numero-de-identificacion-de-a...   NaN
# 3435  autorizacion-de-publicacion-oficial-de-textos-...   NaN
#
#                                             descripcion  \
# 1538  Trámite dirigido a Estudiantes, para postulant...
# 2694  Proceso de Actualización de Número de Identifi...
# 3435  La Gaceta Oficial de Bolivia autoriza la publi...
#
#                                              marcoLegal  like  dislike  \
# 1538                       Verificación de Originalidad     0        0
# 2694  Ley 535 (Ministerio de Mineria y Metalurgia), ...     0        0
# 3435  Resolución Ministerial N° 039/11 de 11 de marz...     0        0
#
#       esPresencial  esVirtual   resultado  \
# 1538             1          0  Constancia
# 2694             1          0    Registro
# 3435             1          0         NaN
#
#                                                 enlaces  \
# 1538  [{"nombre": "Archivos", "url": "https://www.ar...
# 2694  [{"nombre": "Actualización NIAR", "url": "http...
# 3435                                                 []
#
#                                             ubicaciones  \
# 1538  [{"nombre": "Archivos", "tipo": "Oficina centr...
# 2694  [{"nombre": "OFICINA CENTRAL DEL SENARECOM", "...
# 3435  [{"nombre": "Gaceta Oficial de Bolivia", "tipo...
#
#                                          entidad.nombre entidad.sigla  \
# 1538                     Universidad Mayor de San Simón          UMSS
# 2694  Serv. Nal. de Reg. y Control de la Comer. de M...     SENARECOM
# 3435                             Gaceta Oficial Bolivia        GACETA
#
#                                            entidad.slug  \
# 1538                     universidad-mayor-de-san-simon
# 2694  serv-nal-de-reg-y-control-de-la-comer-de-miner...
# 3435                             gaceta-oficial-bolivia
#
#                                            entidad.logo  \
# 1538  https://www.gob.bo/ws/api/archivos/64632538-41...
# 2694  https://www.gob.bo/ws/api/archivos/7bcbc6ca-09...
# 3435  https://www.gob.bo/ws/api/archivos/bff8413e-a1...
#
#                                     entidad.descripcion  \
# 1538  La Universidad Mayor de San Simón (UMSS), fund...
# 2694  Entidad encargada de realizar el registro y co...
# 3435  Unidad Desconcentrada del Ministerio de la Pre...
#
#                             entidad.urlSitioWeb entidad.telefonoContacto  \
# 1538                   https://www.umss.edu.bo/                      NaN
# 2694              https://www.senarecom.gob.bo/          (591-2) 2154523
# 3435  https://www.gacetaoficialdebolivia.gob.bo                  2147937
#
#            entidad.correoElectronicoContacto palabrasClave  \
# 1538                        soporte@umss.edu           NaN
# 2694               contacto@senarecom.gob.bo           NaN
# 3435  info_gob@gacetaoficialdebolivia.gob.bo           NaN
#
#                                              categorias eventosVida  \
# 1538                                          Educación         NaN
# 2694                                           Empresas         NaN
# 3435  Educación,Justicia,Medio ambiente,Seguridad,Mi...         NaN
#
#                                              documentos  herramientas  \
# 1538                Sello de Originalidad del Documento           NaN
# 2694  Certificado del Número de Identificación de Ag...           NaN
# 3435                                                NaN           NaN
#
#      modalidad.tipo tramite.url tramite.urlSeguimiento  tramite.tieneCosto  \
# 1538     PRESENCIAL        None                   None                   1
# 2694     PRESENCIAL        None                   None                   1
# 3435     PRESENCIAL        None                   None                   1
#
#      tramite.duracion tramite.unidadMedidaDuracion  \
# 1538               24                     Horas(s)
# 2694             None
# 3435             None
#
#                                   tramite.procedimiento  \
# 1538  <p><strong>¿Qué necesito?</strong></p><ul><li>...
# 2694  <ul><li><p>El interesado con los documentos co...
# 3435  <p><strong>Resolución Ministerial N° 039/11</s...
#
#        tramite.publicoObjetivo tramite.requisitoNoParametrizado  \
# 1538  Personas Aseguradas SSUE                             None
# 2694   Actor Productivo Minero                             None
# 3435        Entidades Públicas                             None
#
#      tramite.estado         tramite.emisionFactura  \
# 1538         ACTIVO               No emite factura
# 2694         ACTIVO  Sistema propio de facturación
# 3435         ACTIVO               No emite factura
#
#                                      tramite.formaCobro  \
# 1538                 ["Pago en efectivo en ventanilla"]
# 2694  ["Pago en banco(presenta boleta de depósito)",...
# 3435     ["Pago en banco(presenta boleta de depósito)"]
#
#                                        tramite.horarios  \
# 1538  [{"dia": "Lunes", "continuo": false, "inicioMa...
# 2694  [{"dia": "Lunes", "continuo": true, "inicioMan...
# 3435  [{"dia": "Lunes", "continuo": true, "inicioMan...
#
#                                tramite.depositoBancario  tramite.duracionMin  \
# 1538                                                 []               1440.0
# 2694  [{"nombre": "Banco Unión S.A.", "nroCuenta": "...                  NaN
# 3435                                                 []                  NaN
#
#       tramite.duracionHora  tramite.duracionDia  \
# 1538                  24.0                  1.0
# 2694                   NaN                  NaN
# 3435                   NaN                  NaN
#
#                                      costo.conceptoPago  costo.monto  \
# 1538  Valorado para Fotocopia Legalizada de Diploma ...        100.0
# 2694                       Actualización y/o Renovación        300.0
# 3435                               De 201 a 300 Páginas        800.0
#
#      costo.moneda                               requisito.comentario  \
# 1538           Bs                                               None
# 2694           Bs  Comprobante de depósito bancario\noriginal y f...
# 3435           Bs  Dirigida al Director de la Gaceta Oficial - Ab...
#
#                  requisito.nombre requisito.entidad  requisito.entidadActiva
# 1538         Diploma de Bachiller              null                        1
# 2694  Boleta de Depósito Bancario              null                        1
# 3435      Carta/Nota de Solicitud              null                        1

# %%
df_desglosado.to_csv('../tramites_desglosados.csv', index=False)
