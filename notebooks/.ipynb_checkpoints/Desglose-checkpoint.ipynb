# %% [markdown]
# # Trámites del estado Boliviano (gob.bo) - Desglosando o expandiendo el dataset
#
# El dataset original tramites.json está muy anidado y la idea de este notebook es desglosarlo o expandirlo para facilitar el análisis. Para esto se ha visto que cada trámite puede tener varios:
#
# - Públicos objetivo
# - Procedimientos divididas por modalidades
# - Duración de trámites
# - Costos

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

df = pd.read_csv('../tramites.csv')
df
# Out:
#         id     estado fechaActualización  \
# 0     1005  PUBLICADO         09/07/2025
# 1     1006  PUBLICADO         09/09/2025
# 2     1008  PUBLICADO         04/08/2025
# 3     1009  PUBLICADO         04/08/2025
# 4     1010  PUBLICADO         09/07/2025
# ...    ...        ...                ...
# 1343  2793  PUBLICADO         02/10/2025
# 1344  2819  PUBLICADO         03/10/2025
# 1345  2825  PUBLICADO         03/10/2025
# 1346  2827  PUBLICADO         03/10/2025
# 1347  2843  PUBLICADO         08/10/2025
#
#                                                  nombre  \
# 0                      Registro de Ciudadanos Digitales
# 1                        Registro en Ciudadanía Digital
# 2                       RESOLUCIÓN DE RECURSO DE ALZADA
# 3                      RESOLUCIÓN DE RECURSO JERÁRQUICO
# 4                                  REGISTRO PROVISIONAL
# ...                                                 ...
# 1343  Servicio de denuncia de vulneración de derecho...
# 1344  DETECCION Y CUANTIFICACION DE ORGANISMOS GENÉT...
# 1345  Desinfección ambiental por termoniebla empresa...
# 1346                        VENTA DE PALMITO 800 GRAMOS
# 1347                         Transporte Aereo  de Carga
#
#                                                    slug    sigla  \
# 0                      registro-de-ciudadanos-digitales      NaN
# 1                        registro-en-ciudadania-digital       CD
# 2                       resolucion-de-recurso-de-alzada      NaN
# 3                      resolucion-de-recurso-jerarquico      NaN
# 4                                  registro-provisional      NaN
# ...                                                 ...      ...
# 1343  servicio-de-denuncia-de-vulneracion-de-derecho...      SSP
# 1344  deteccion-y-cuantificacion-de-organismos-genet...      OGM
# 1345  desinfeccion-ambiental-por-termoniebla-empresa...  PBS-007
# 1346                        venta-de-palmito-800-gramos    INBOL
# 1347                          transporte-aereo-de-carga      NaN
#
#                                             descripcion  \
# 0     Se brinda la colaboración personalizada a la c...
# 1     Ciudadanía Digital es la identidad digital de ...
# 2     Es el recurso que tiene el contribuyente o suj...
# 3     Es la impugnación que se presenta en contra de...
# 4     Modalidad de inscripción que tiene por objeto ...
# ...                                                 ...
# 1343  Servicio de denuncia de vulneración de derecho...
# 1344  DETECCION Y CUANTIFICACION DE ORGANISMOS GENÉT...
# 1345  Desinfección de ambientes utilizando un produc...
# 1346            Venta de palmito en lata de 800 gramos.
# 1347  Realizar servicios de Transporte Aereo de carg...
#
#                                              marcoLegal  like  dislike  \
# 0     1. Ley N° 1173 - Ley de abreviación procesal p...     0        0
# 1                      Ley N° 1080 - Ciudadanía Digital     0        0
# 2     La Autoridad de Impugnación Tributaria (AIT), ...     0        0
# 3     La Autoridad de Impugnación Tributaria (AIT), ...     0        0
# 4                                           D.S. 26256      0        0
# ...                                                 ...   ...      ...
# 1343  Reglamento del Sistema de Servicio al Pueblo R...     0        0
# 1344                        Resolución Ministerial 0533     0        0
# 1345    Resolución Administrativa INLASA/UJ/N° 25/2022      0        0
# 1346                           Decreto Supremo N° 29727     0        0
# 1347  Decreto Supremo No. 15091 del 7 de noviembre d...     0        0
#
#       esPresencial  esVirtual resultado  \
# 0                1          0       NaN
# 1                1          1  Registro
# 2                1          0       NaN
# 3                1          0       NaN
# 4                1          0       NaN
# ...            ...        ...       ...
# 1343             1          0       NaN
# 1344             1          0       NaN
# 1345             1          0       NaN
# 1346             1          0       NaN
# 1347             1          0       NaN
#
#                                                 enlaces  \
# 0                                                    []
# 1     [{'nombre': 'Ciudadania Digital', 'url': 'http...
# 2     [{'nombre': 'Doctrina Tributaria', 'url': 'htt...
# 3     [{'nombre': 'Registro Público', 'url': 'https:...
# 4     [{'nombre': 'información', 'url': 'https://www...
# ...                                                 ...
# 1343                                                 []
# 1344                                                 []
# 1345                                                 []
# 1346                                                 []
# 1347                                                 []
#
#                                             modalidades  \
# 0     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 2     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 3     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 4     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# ...                                                 ...
# 1343  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1344  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1345  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1346  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1347  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
#
#                                             ubicaciones  \
# 0     [{'nombre': 'Tribunal Supremo de Justicia', 't...
# 1     [{'nombre': 'AGETIC', 'tipo': 'Oficina central...
# 2     [{'nombre': 'Autoridad Regional de Impugnación...
# 3     [{'nombre': 'AUTORIDAD GENERAL DE IMPUGNACIÓN ...
# 4     [{'nombre': 'REGISTRO INTERNACIONAL BOLIVIANO ...
# ...                                                 ...
# 1343  [{'nombre': 'Oficina Nacional', 'tipo': 'Ofici...
# 1344  [{'nombre': 'INLASA', 'tipo': 'Oficina central...
# 1345  [{'nombre': 'INLASA', 'tipo': 'Oficina central...
# 1346  [{'nombre': 'OFICINA CENTRAL', 'tipo': 'Oficin...
# 1347  [{'nombre': 'TRANSPORTES AÉREOS BOLIVIANOS GER...
#
#                                          entidad.nombre entidad.sigla  \
# 0                          Tribunal Supremo de Justicia           TSJ
# 1     Agencia de Gobierno Electrónico y Tecnologías ...        AGETIC
# 2                   Autoridad de Impugnación Tributaria           AIT
# 3                   Autoridad de Impugnación Tributaria           AIT
# 4            Registro Internacional Boliviano De Buques          RIBB
# ...                                                 ...           ...
# 1343                              Defensoria del Pueblo            DP
# 1344         Instituto Nacional De Laboratorio De Salud        INLASA
# 1345         Instituto Nacional De Laboratorio De Salud        INLASA
# 1346                                    Insumos Bolivia      IN - BOL
# 1347                      Transportes Aéreos Bolivianos           TAB
#
#                                            entidad.slug  \
# 0                          tribunal-supremo-de-justicia
# 1     agencia-de-gobierno-electronico-y-tecnologias-...
# 2                   autoridad-de-impugnacion-tributaria
# 3                   autoridad-de-impugnacion-tributaria
# 4            registro-internacional-boliviano-de-buques
# ...                                                 ...
# 1343                              defensoria-del-pueblo
# 1344         instituto-nacional-de-laboratorio-de-salud
# 1345         instituto-nacional-de-laboratorio-de-salud
# 1346                                    insumos-bolivia
# 1347                      transportes-aereos-bolivianos
#
#                                            entidad.logo  \
# 0     https://www.gob.bo/ws/api/archivos/9989169e-b9...
# 1     https://www.gob.bo/ws/api/archivos/b48eee08-24...
# 2     https://www.gob.bo/ws/api/archivos/71c7476f-3c...
# 3     https://www.gob.bo/ws/api/archivos/71c7476f-3c...
# 4     https://www.gob.bo/ws/api/archivos/8baef1e9-22...
# ...                                                 ...
# 1343  https://www.gob.bo/ws/api/archivos/ae641fb1-53...
# 1344  https://www.gob.bo/ws/api/archivos/f610506f-61...
# 1345  https://www.gob.bo/ws/api/archivos/f610506f-61...
# 1346  https://www.gob.bo/ws/api/archivos/bf78cfea-24...
# 1347  https://www.gob.bo/ws/api/archivos/b097f8a8-86...
#
#                                     entidad.descripcion  \
# 0     El Tribunal Supremo de Justicia (TSJ) es la má...
# 1     La AGETIC está acá para desarrollar tecnología...
# 2     La AIT tiene como objeto conocer y resolver lo...
# 3     La AIT tiene como objeto conocer y resolver lo...
# 4     El Registro Internacional Boliviano de Buques ...
# ...                                                 ...
# 1343  La Defensoría del Pueblo es una institución qu...
# 1344  El  Instituto  Nacional  de  Laboratorios  de ...
# 1345  El  Instituto  Nacional  de  Laboratorios  de ...
# 1346  Insumos Bolivia (INBOL) es una Entidad Pública...
# 1347  Transportes Aéreos Bolivianos (TAB) es la aero...
#
#                      entidad.urlSitioWeb entidad.telefonoContacto  \
# 0                         https://tsj.bo                 46453200
# 1              https://www.agetic.gob.bo            (591) 2184026
# 2                https://www.ait.gob.bo/        2412789 – 2412048
# 3                https://www.ait.gob.bo/        2412789 – 2412048
# 4                https://www.ribb.gob.bo                  2434415
# ...                                  ...                      ...
# 1343           https://defensoria.gob.bo                  2113600
# 1344           https://www.inlasa.gob.bo        2226048 - 2226670
# 1345           https://www.inlasa.gob.bo        2226048 - 2226670
# 1346  https://www.insumosbolivia.gob.bo/                  2408191
# 1347             https://tab-bolivia.com            0-800-100-110
#
#       entidad.correoElectronicoContacto  \
# 0      soporteogp@organojudicial.gob.bo
# 1                 soporte@agetic.gob.bo
# 2                    infoait@ait.gob.bo
# 3                    infoait@ait.gob.bo
# 4              ribb_bolivia@ribb.gob.bo
# ...                                 ...
# 1343             f.olivares.c@gmail.com
# 1344       inlasalapazbolivia@gmail.com
# 1345       inlasalapazbolivia@gmail.com
# 1346         info@insumosbolivia.gob.bo
# 1347  atencionalcliente@tab-bolivia.com
#
#                                           palabrasClave  \
# 0                                                   NaN
# 1     digital,ciudadania,registro,pre registro,const...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1343                                denuncia,defensoria
# 1344                                                NaN
# 1345                                                NaN
# 1346                                      venta,palmito
# 1347  Transporte de carga,transporte,aerea,logistica...
#
#                     categorias       eventosVida documentos  herramientas
# 0                     Justicia               NaN        NaN           NaN
# 1     Seguridad,Identificación            Empleo   Registro           NaN
# 2           Justicia,Impuestos               NaN        NaN           NaN
# 3           Justicia,Impuestos               NaN        NaN           NaN
# 4                     Empresas               NaN        NaN           NaN
# ...                        ...               ...        ...           ...
# 1343                  Justicia               NaN        NaN           NaN
# 1344      Medio ambiente,Salud  Cuidado de salud        NaN           NaN
# 1345                     Salud               NaN        NaN           NaN
# 1346                  Empresas               NaN        NaN           NaN
# 1347                Transporte               NaN        NaN           NaN
#
# [1348 rows x 29 columns]

# %% [markdown]
# ## Dicionarios, listas, tuplas -- guradar como JSON
#
# En este dataset muchas columnas como listas u objetos json, al ser leídas se guardan como diccionarios python representados en cadenas. Para estandarizar el dataset para que sea usable en otros lenguages más fácilmente todas las columnas con listas, tuplas o diccionarios se guardarán como cadenas JSON.

# %%
import json
import ast

df['enlaces'] = df['enlaces'].map(lambda x: json.dumps(ast.literal_eval(x), ensure_ascii=False))
df['ubicaciones'] = df['ubicaciones'].map(lambda x: json.dumps(ast.literal_eval(x), ensure_ascii=False))
df.sample(2)
# Out:
#         id     estado fechaActualización  \
# 1072  2363  PUBLICADO         04/08/2025
# 862   2092  PUBLICADO         10/07/2025
#
#                                                  nombre  \
# 1072  INSCRIPCIÓN DEL VEHÍCULO AUTOMOTOR TERRESTRE\n...
# 862   Cambio de Infraestructura de Unidades Educativ...
#
#                                                    slug sigla  \
# 1072  inscripcion-del-vehiculo-automotor-terrestre-p...   NaN
# 862   cambio-de-infraestructura-de-unidades-educativ...   SER
#
#                                             descripcion  \
# 1072  Es el  proceso  mediante  el  cual  se inscrib...
# 862   Cambio de Infraestructura de Unidades Educativ...
#
#                                              marcoLegal  like  dislike  \
# 1072  Código Tributario, Ley Nacional Nº 2492.\nLey ...     0        0
# 862   Resolución Administrativa Departamental DDE-BE...     0        0
#
#       esPresencial  esVirtual              resultado  \
# 1072             1          0  Registro y constancia
# 862              1          0             Constancia
#
#                                                 enlaces  \
# 1072  [{"nombre": "GAMLP", "url": "https://lapaz.bo/...
# 862                                                  []
#
#                                             modalidades  \
# 1072  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 862   [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
#
#                                             ubicaciones  \
# 1072  [{"nombre": "Plataforma de Vehículos", "tipo":...
# 862   [{"nombre": "DIRECCION DEPARTAMENTAL DEL BENI"...
#
#                              entidad.nombre entidad.sigla  \
# 1072  Gobierno Autónomo Municipal de La Paz           LPZ
# 862         Direc. Dptal. de Educación Beni       DDE-BEN
#
#                                entidad.slug  \
# 1072  gobierno-autonomo-municipal-de-la-paz
# 862           direc-dptal-de-educacion-beni
#
#                                            entidad.logo  \
# 1072  https://www.gob.bo/ws/api/archivos/a9f8ee34-74...
# 862   https://www.gob.bo/ws/api/archivos/7197f9e0-96...
#
#                                     entidad.descripcion  \
# 1072  Somos una institución pública municipal renova...
# 862   La Dirección Departamental de Educación del Be...
#
#               entidad.urlSitioWeb entidad.telefonoContacto  \
# 1072             https://lapaz.bo            591-2-2650000
# 862   https://www.ddebeni.edu.bo/                346-22226
#
#      entidad.correoElectronicoContacto  \
# 1072               info.gamlp@lapaz.bo
# 862              ddebeni20221@gmai.com
#
#                                           palabrasClave  \
# 1072  inscripcion vehículo,automotores terrestres,im...
# 862   Cambio de Infraestructura,Unidades Educativas ...
#
#                          categorias   eventosVida  \
# 1072  Impuestos,Transporte,Empresas           NaN
# 862                       Educación  Mi educación
#
#                                              documentos  herramientas
# 1072                         Emisión de certificaciones           NaN
# 862   RESOLUCIÓN ADMINISTRATIVA DE UNIDAD EDUCATIVA ...           NaN

# %% [markdown]
# ## Desglosando modalidades

# %%
import json
import ast

ast.literal_eval(df.iloc[0]['modalidades'])

# %%
def desglosar_segun_tipo_modalidad(df):
    new_df = pd.DataFrame(columns=df.columns.to_list() + ['modalidad.tipo', 'modalidad'])
    print(new_df.columns)
    _df = df.copy()
    for i in _df.index.to_list():
        data = _df.iloc[i].to_dict()
        #print(data)
        modalidades = ast.literal_eval(data['modalidades'])
        for modalidad in modalidades:
            data['modalidad.tipo'] = modalidad['tipo']
            data['modalidad'] = modalidad
            print(f"Agregando id: {data['id']} -> tipo: {data['modalidad.tipo']}")
            new_df.loc[len(new_df)] = data
    del new_df['modalidades']
    return new_df

new_df = desglosar_segun_tipo_modalidad(df)
print(new_df.shape)
new_df.sample(3)

# %% [markdown]
# ## Dividiendo en procedimientos (una fila para cada público objetivo)
#
# Al parecer hay también diferentes públicos objetivo por cada trámite. Para facilitar el análisis conviene dividir cada trámite también por público objetivo, donde cada uno de estos tiene su propio **procedimiento**. Entonces un trámite puede tener varias modalidades y cada modalidad varios procedimientos.

# %%
def desglosar_por_procedimientos(df):
    new_df = pd.DataFrame(
        columns=df.columns.to_list() + 
        [
         'tramite.url', 'tramite.urlSeguimiento',
         'tramite.tieneCosto', 'tramite.duracion', 'tramite.unidadMedidaDuracion', 'tramite.procedimiento',
         'tramite.publicoObjetivo', 'tramite.requisitoNoParametrizado', 'tramite.estado',
         'tramite.emisionFactura','tramite.formaCobro','tramite.horarios','tramite.depositoBancario',
         'tramite.costos', 'tramite.requisitos'
         ])
    print(new_df.columns)
    _df = df.copy()
    for i in _df.index.to_list():
        data = _df.iloc[i]['modalidad']
        for procedimiento in data['publico']:
            proc = _df.iloc[i].copy()
            proc['tramite.url'] = data['url']
            proc['tramite.urlSeguimiento'] = data['urlSeguimiento']
            proc['tramite.tieneCosto'] = 1 if procedimiento['tieneCosto'] == True else 0
            proc['tramite.duracion'] = procedimiento['duracion']
            proc['tramite.unidadMedidaDuracion'] = procedimiento['unidadMedidaDuracion']
            proc['tramite.procedimiento'] = procedimiento['procedimiento']
            proc['tramite.publicoObjetivo'] = procedimiento['nombrePublicoObjetivo']
            proc['tramite.requisitoNoParametrizado'] = procedimiento['requisitoNoParametrizado']
            proc['tramite.estado'] = procedimiento['estadoPublicoObjetivo']
            proc['tramite.emisionFactura'] = procedimiento['emisionFactura']
            proc['tramite.formaCobro'] = procedimiento['formaCobro']
            proc['tramite.horarios'] = procedimiento['horario']
            proc['tramite.depositoBancario'] = procedimiento['depositoBancario']
            proc['tramite.costos'] = procedimiento['costos']
            proc['tramite.requisitos'] = procedimiento['requisitos']
            del proc['modalidad']
            print(f"Agregando id: {_df.iloc[i]['id']} --> {proc['tramite.publicoObjetivo']}")
            new_df.loc[len(new_df)] = proc
    del new_df['modalidad']
    return new_df

new_df = desglosar_por_procedimientos(new_df)
print(new_df.shape)
new_df.sample(3)

# %%
def obtener_duracion(num_duracion, unidad_medida, unidad_destino='min'):
    minutos = 0
    try:
        num_duracion = int(num_duracion)
    except Exception as E:
        return np.nan
    
    if unidad_medida == 'Día(s)':
        minutos = num_duracion*1440
    elif unidad_medida == 'Horas(s)':
        minutos = num_duracion*60
    elif unidad_medida == 'Mes(es)':
        minutos = num_duracion*43200
    elif unidad_medida == 'Año(s)':
        minutos = num_duracion*15768000
    elif unidad_medida == 'Semana(s)':
        minutos = num_duracion*10080

    if unidad_destino == 'min':
        return int(minutos)
    elif unidad_destino == 'hora':
        return int(minutos/60)
    elif unidad_destino == 'dia':
        return int(minutos/1440)

new_df['tramite.duracionMin'] = new_df.apply(
    lambda x: obtener_duracion(x['tramite.duracion'], x['tramite.unidadMedidaDuracion'], 'min'), axis=1)
new_df['tramite.duracionHora'] = new_df.apply(
    lambda x: obtener_duracion(x['tramite.duracion'], x['tramite.unidadMedidaDuracion'], 'hora'), axis=1)
new_df['tramite.duracionDia'] = new_df.apply(
    lambda x: obtener_duracion(x['tramite.duracion'], x['tramite.unidadMedidaDuracion'], 'dia'), axis=1)

new_df.sample(5)[['tramite.duracion', 'tramite.duracionMin', 'tramite.duracionHora', 'tramite.duracionDia',
                       'tramite.unidadMedidaDuracion', 'tramite.unidadMedidaDuracion',
                      'modalidad.tipo', 'estado']]
# Out:
#     tramite.duracion  tramite.duracionMin  tramite.duracionHora  \
# 834             None                  NaN                   NaN
# 783             None                  NaN                   NaN
# 464             None                  NaN                   NaN
# 275             None                  NaN                   NaN
# 231             None                  NaN                   NaN
#
#      tramite.duracionDia tramite.unidadMedidaDuracion  \
# 834                  NaN
# 783                  NaN
# 464                  NaN
# 275                  NaN
# 231                  NaN
#
#     tramite.unidadMedidaDuracion modalidad.tipo     estado
# 834                                  PRESENCIAL  PUBLICADO
# 783                                  PRESENCIAL  PUBLICADO
# 464                                     VIRTUAL  PUBLICADO
# 275                                  PRESENCIAL  PUBLICADO
# 231                                     VIRTUAL  PUBLICADO

# %% [markdown]
# ## Desglosando costos de tramites

# %%
s = new_df.groupby('tramite.tieneCosto').count()['id']
s.index = ['Sin costo', 'Tiene costo']
s
# Out:
# Sin costo       518
# Tiene costo    1026
# Name: id, dtype: int64

# %%
def desglosar_segun_costos(df):
    _new_df = pd.DataFrame(columns=df.columns.to_list() + [
        'costo.conceptoPago', 'costo.monto', 'costo.moneda'])
    print(_new_df.columns)
    _df = df.copy()
    for i in _df.index.to_list():
        data = _df.iloc[i].to_dict()
        #print(data)
        costos = data['tramite.costos']
        for costo in costos:
            data['costo.conceptoPago'] = costo['conceptoPago']
            data['costo.monto'] = float(costo['costo'])
            data['costo.moneda'] = costo['moneda']
            #print('>>>>', data)
            print(f"Agregando id: {data['id']} -> {data['costo.monto']}: {data['costo.moneda']}")
            _new_df.loc[len(_new_df)] = data
    del _new_df['tramite.costos']
    return _new_df

new_df = desglosar_segun_costos(new_df)
print(new_df.shape)
new_df.sample(3)
# Out:
# Index(['id', 'estado', 'fechaActualización', 'nombre', 'slug', 'sigla',
#        'descripcion', 'marcoLegal', 'like', 'dislike', 'esPresencial',
#        'esVirtual', 'resultado', 'enlaces', 'ubicaciones', 'entidad.nombre',
#        'entidad.sigla', 'entidad.slug', 'entidad.logo', 'entidad.descripcion',
#        'entidad.urlSitioWeb', 'entidad.telefonoContacto',
#        'entidad.correoElectronicoContacto', 'palabrasClave', 'categorias',
#        'eventosVida', 'documentos', 'herramientas', 'modalidad.tipo',
#        'tramite.url', 'tramite.urlSeguimiento', 'tramite.tieneCosto',
#        'tramite.duracion', 'tramite.unidadMedidaDuracion',
#        'tramite.procedimiento', 'tramite.publicoObjetivo',
#        'tramite.requisitoNoParametrizado', 'tramite.estado',
#        'tramite.emisionFactura', 'tramite.formaCobro', 'tramite.horarios',
#        'tramite.depositoBancario', 'tramite.costos', 'tramite.requisitos',
#        'tramite.duracionMin', 'tramite.duracionHora', 'tramite.duracionDia',
#        'costo.conceptoPago', 'costo.monto', 'costo.moneda'],
#       dtype='object')
# Agregando id: 1010 -> 0.0: USD
# Agregando id: 1011 -> 0.0: USD
# Agregando id: 1014 -> 0.0: USD
# Agregando id: 1017 -> 521.0: Bs
# Agregando id: 1018 -> 521.0: Bs
# Agregando id: 1019 -> 0.0: USD
# Agregando id: 1020 -> 47.0: Bs
# Agregando id: 1021 -> 71.0: Bs
# Agregando id: 1022 -> 71.0: Bs
# Agregando id: 1023 -> 71.0: Bs
# Agregando id: 1024 -> 0.0: USD
# Agregando id: 1025 -> 71.0: Bs
# Agregando id: 1026 -> 0.0: USD
# Agregando id: 1027 -> 71.0: Bs
# Agregando id: 1028 -> 0.0: USD
# Agregando id: 1029 -> 130.0: Bs
# Agregando id: 1030 -> 150.0: Bs
# Agregando id: 1030 -> 400.0: Bs
# Agregando id: 1032 -> 6.0: Bs
# Agregando id: 1033 -> 50.0: Bs
# Agregando id: 1034 -> 100.0: Bs
# Agregando id: 1035 -> 100.0: Bs
# Agregando id: 1037 -> 124.0: Bs
# Agregando id: 1038 -> 50.0: Bs
# Agregando id: 1038 -> 10.0: Bs
# Agregando id: 1039 -> 50.0: Bs
# Agregando id: 1039 -> 10.0: Bs
# Agregando id: 1041 -> 3.0: Bs
# Agregando id: 1042 -> 3.0: Bs
# Agregando id: 1045 -> 20.0: Bs
# Agregando id: 1051 -> 360.0: Bs
# Agregando id: 1051 -> 413.0: Bs
# Agregando id: 1051 -> 479.0: Bs
# Agregando id: 1051 -> 1010.0: Bs
# Agregando id: 1051 -> 1673.0: Bs
# Agregando id: 1051 -> 2337.0: Bs
# Agregando id: 1051 -> 3000.0: Bs
# Agregando id: 1051 -> 3000.0: Bs
# Agregando id: 1051 -> 7000.0: Bs
# Agregando id: 1051 -> 7000.0: Bs
# Agregando id: 1056 -> 100.0: Bs
# Agregando id: 1059 -> 100.0: Bs
# Agregando id: 1060 -> 200.0: Bs
# Agregando id: 1061 -> 0.0: Bs
# Agregando id: 1062 -> 0.0: Bs
# Agregando id: 1063 -> 213.0: Bs
# Agregando id: 1063 -> 213.0: Bs
# Agregando id: 1064 -> 107.0: Bs
# Agregando id: 1064 -> 107.0: Bs
# Agregando id: 1065 -> 0.0: Bs
# Agregando id: 1066 -> 107.0: Bs
# Agregando id: 1066 -> 107.0: Bs
# Agregando id: 1067 -> 38.0: Bs
# Agregando id: 1067 -> 38.0: Bs
# Agregando id: 1069 -> 38.0: Bs
# Agregando id: 1069 -> 38.0: Bs
# Agregando id: 1070 -> 38.0: Bs
# Agregando id: 1070 -> 38.0: Bs
# Agregando id: 1071 -> 580.0: Bs
# Agregando id: 1073 -> 38.0: Bs
# Agregando id: 1073 -> 38.0: Bs
# Agregando id: 1074 -> 213.0: Bs
# Agregando id: 1074 -> 213.0: Bs
# Agregando id: 1079 -> 213.0: Bs
# Agregando id: 1079 -> 213.0: Bs
# Agregando id: 1082 -> 38.0: Bs
# Agregando id: 1082 -> 38.0: Bs
# Agregando id: 1084 -> 38.0: Bs
# Agregando id: 1084 -> 38.0: Bs
# Agregando id: 1087 -> 38.0: Bs
# Agregando id: 1087 -> 38.0: Bs
# Agregando id: 1089 -> 38.0: Bs
# Agregando id: 1089 -> 38.0: Bs
# Agregando id: 1091 -> 213.0: Bs
# Agregando id: 1091 -> 213.0: Bs
# Agregando id: 1104 -> 213.0: Bs
# Agregando id: 1104 -> 213.0: Bs
# Agregando id: 1105 -> 38.0: Bs
# Agregando id: 1105 -> 38.0: Bs
# Agregando id: 1106 -> 38.0: Bs
# Agregando id: 1106 -> 38.0: Bs
# Agregando id: 1107 -> 38.0: Bs
# Agregando id: 1107 -> 38.0: Bs
# Agregando id: 1108 -> 38.0: Bs
# Agregando id: 1108 -> 38.0: Bs
# Agregando id: 1109 -> 213.0: Bs
# Agregando id: 1109 -> 213.0: Bs
# Agregando id: 1110 -> 213.0: Bs
# Agregando id: 1110 -> 213.0: Bs
# Agregando id: 1111 -> 213.0: Bs
# Agregando id: 1111 -> 213.0: Bs
# Agregando id: 1114 -> 213.0: Bs
# Agregando id: 1114 -> 213.0: Bs
# Agregando id: 1118 -> 213.0: Bs
# Agregando id: 1118 -> 213.0: Bs
# Agregando id: 1120 -> 107.0: Bs
# Agregando id: 1120 -> 107.0: Bs
# Agregando id: 1121 -> 213.0: Bs
# Agregando id: 1121 -> 213.0: Bs
# Agregando id: 1122 -> 107.0: Bs
# Agregando id: 1122 -> 107.0: Bs
# Agregando id: 1123 -> 93.0: Bs
# Agregando id: 1123 -> 93.0: Bs
# Agregando id: 1124 -> 455.0: Bs
# Agregando id: 1124 -> 192.0: Bs
# Agregando id: 1124 -> 455.0: Bs
# Agregando id: 1124 -> 192.0: Bs
# Agregando id: 1125 -> 22.0: Bs
# Agregando id: 1125 -> 22.0: Bs
# Agregando id: 1126 -> 584.5: Bs
# Agregando id: 1126 -> 192.0: Bs
# Agregando id: 1126 -> 584.5: Bs
# Agregando id: 1126 -> 192.0: Bs
# Agregando id: 1127 -> 584.5: Bs
# Agregando id: 1127 -> 192.0: Bs
# Agregando id: 1127 -> 584.5: Bs
# Agregando id: 1127 -> 192.0: Bs
# Agregando id: 1128 -> 213.0: Bs
# Agregando id: 1128 -> 213.0: Bs
# Agregando id: 1129 -> 100.0: Bs
# Agregando id: 1129 -> 70.0: Bs
# Agregando id: 1129 -> 65.0: Bs
# Agregando id: 1129 -> 60.0: Bs
# Agregando id: 1129 -> 55.0: Bs
# Agregando id: 1129 -> 50.0: Bs
# Agregando id: 1129 -> 45.0: Bs
# Agregando id: 1129 -> 100.0: Bs
# Agregando id: 1129 -> 70.0: Bs
# Agregando id: 1129 -> 65.0: Bs
# Agregando id: 1129 -> 60.0: Bs
# Agregando id: 1129 -> 55.0: Bs
# Agregando id: 1129 -> 50.0: Bs
# Agregando id: 1129 -> 45.0: Bs
# Agregando id: 1129 -> 100.0: Bs
# Agregando id: 1129 -> 70.0: Bs
# Agregando id: 1129 -> 65.0: Bs
# Agregando id: 1129 -> 60.0: Bs
# Agregando id: 1129 -> 55.0: Bs
# Agregando id: 1129 -> 50.0: Bs
# Agregando id: 1129 -> 45.0: Bs
# Agregando id: 1130 -> 584.5: Bs
# Agregando id: 1130 -> 192.0: Bs
# Agregando id: 1131 -> 584.5: Bs
# Agregando id: 1131 -> 192.0: Bs
# Agregando id: 1131 -> 584.5: Bs
# Agregando id: 1131 -> 192.0: Bs
# Agregando id: 1132 -> 213.0: Bs
# Agregando id: 1132 -> 213.0: Bs
# Agregando id: 1134 -> 584.5: Bs
# Agregando id: 1134 -> 192.0: Bs
# Agregando id: 1135 -> 584.5: Bs
# Agregando id: 1135 -> 192.0: Bs
# Agregando id: 1136 -> 584.5: Bs
# Agregando id: 1136 -> 192.0: Bs
# Agregando id: 1136 -> 584.5: Bs
# Agregando id: 1136 -> 192.0: Bs
# Agregando id: 1137 -> 213.0: Bs
# Agregando id: 1137 -> 213.0: Bs
# Agregando id: 1138 -> 107.0: Bs
# Agregando id: 1138 -> 107.0: Bs
# Agregando id: 1139 -> 192.0: Bs
# Agregando id: 1139 -> 260.0: Bs
# Agregando id: 1139 -> 455.0: Bs
# Agregando id: 1139 -> 584.5: Bs
# Agregando id: 1139 -> 78.0: Bs
# Agregando id: 1139 -> 136.5: Bs
# Agregando id: 1139 -> 175.0: Bs
# Agregando id: 1140 -> 260.0: Bs
# Agregando id: 1140 -> 455.0: Bs
# Agregando id: 1140 -> 584.5: Bs
# Agregando id: 1140 -> 192.0: Bs
# Agregando id: 1140 -> 260.0: Bs
# Agregando id: 1140 -> 455.0: Bs
# Agregando id: 1140 -> 584.5: Bs
# Agregando id: 1140 -> 192.0: Bs
# Agregando id: 1141 -> 107.0: Bs
# Agregando id: 1141 -> 107.0: Bs
# Agregando id: 1142 -> 455.0: Bs
# Agregando id: 1142 -> 584.5: Bs
# Agregando id: 1142 -> 192.0: Bs
# Agregando id: 1142 -> 455.0: Bs
# Agregando id: 1142 -> 584.5: Bs
# Agregando id: 1142 -> 192.0: Bs
# Agregando id: 1143 -> 123.0: Bs
# Agregando id: 1143 -> 123.0: Bs
# Agregando id: 1146 -> 318.0: Bs
# Agregando id: 1146 -> 318.0: Bs
# Agregando id: 1148 -> 13.0: Bs
# Agregando id: 1148 -> 13.0: Bs
# Agregando id: 1150 -> 107.0: Bs
# Agregando id: 1150 -> 107.0: Bs
# Agregando id: 1152 -> 160.0: Bs
# Agregando id: 1152 -> 160.0: Bs
# Agregando id: 1153 -> 318.0: Bs
# Agregando id: 1153 -> 318.0: Bs
# Agregando id: 1154 -> 54.0: Bs
# Agregando id: 1154 -> 54.0: Bs
# Agregando id: 1155 -> 54.0: Bs
# Agregando id: 1155 -> 54.0: Bs
# Agregando id: 1156 -> 62.0: Bs
# Agregando id: 1156 -> 62.0: Bs
# Agregando id: 1157 -> 107.0: Bs
# Agregando id: 1157 -> 107.0: Bs
# Agregando id: 1158 -> 213.0: Bs
# Agregando id: 1158 -> 213.0: Bs
# Agregando id: 1159 -> 54.0: Bs
# Agregando id: 1159 -> 54.0: Bs
# Agregando id: 1160 -> 213.0: Bs
# Agregando id: 1160 -> 213.0: Bs
# Agregando id: 1161 -> 54.0: Bs
# Agregando id: 1161 -> 54.0: Bs
# Agregando id: 1162 -> 455.0: Bs
# Agregando id: 1162 -> 584.5: Bs
# Agregando id: 1162 -> 192.0: Bs
# Agregando id: 1162 -> 455.0: Bs
# Agregando id: 1162 -> 584.5: Bs
# Agregando id: 1162 -> 192.0: Bs
# Agregando id: 1163 -> 140.0: Bs
# Agregando id: 1163 -> 245.0: Bs
# Agregando id: 1163 -> 315.0: Bs
# Agregando id: 1163 -> 192.0: Bs
# Agregando id: 1163 -> 140.0: Bs
# Agregando id: 1163 -> 245.0: Bs
# Agregando id: 1163 -> 315.0: Bs
# Agregando id: 1163 -> 192.0: Bs
# Agregando id: 1164 -> 318.0: Bs
# Agregando id: 1164 -> 318.0: Bs
# Agregando id: 1166 -> 107.0: Bs
# Agregando id: 1166 -> 107.0: Bs
# Agregando id: 1167 -> 54.0: Bs
# Agregando id: 1167 -> 54.0: Bs
# Agregando id: 1168 -> 140.0: Bs
# Agregando id: 1168 -> 245.0: Bs
# Agregando id: 1168 -> 315.0: Bs
# Agregando id: 1168 -> 192.0: Bs
# Agregando id: 1168 -> 140.0: Bs
# Agregando id: 1168 -> 245.0: Bs
# Agregando id: 1168 -> 315.0: Bs
# Agregando id: 1168 -> 192.0: Bs
# Agregando id: 1169 -> 140.0: Bs
# Agregando id: 1169 -> 245.0: Bs
# Agregando id: 1169 -> 315.0: Bs
# Agregando id: 1169 -> 192.0: Bs
# Agregando id: 1169 -> 140.0: Bs
# Agregando id: 1169 -> 245.0: Bs
# Agregando id: 1169 -> 315.0: Bs
# Agregando id: 1169 -> 192.0: Bs
# Agregando id: 1170 -> 245.0: Bs
# Agregando id: 1170 -> 192.0: Bs
# Agregando id: 1170 -> 245.0: Bs
# Agregando id: 1170 -> 192.0: Bs
# Agregando id: 1171 -> 54.0: Bs
# Agregando id: 1171 -> 54.0: Bs
# Agregando id: 1172 -> 140.0: Bs
# Agregando id: 1172 -> 20.0: Bs
# Agregando id: 1172 -> 140.0: Bs
# Agregando id: 1172 -> 20.0: Bs
# Agregando id: 1173 -> 54.0: Bs
# Agregando id: 1173 -> 54.0: Bs
# Agregando id: 1174 -> 130.0: Bs
# Agregando id: 1174 -> 455.0: Bs
# Agregando id: 1174 -> 584.5: Bs
# Agregando id: 1174 -> 130.0: Bs
# Agregando id: 1174 -> 455.0: Bs
# Agregando id: 1174 -> 584.5: Bs
# Agregando id: 1176 -> 78.0: Bs
# Agregando id: 1176 -> 136.5: Bs
# Agregando id: 1176 -> 175.0: Bs
# Agregando id: 1176 -> 78.0: Bs
# Agregando id: 1176 -> 136.5: Bs
# Agregando id: 1176 -> 175.0: Bs
# Agregando id: 1177 -> 160.0: Bs
# Agregando id: 1177 -> 160.0: Bs
# Agregando id: 1178 -> 136.5: Bs
# Agregando id: 1178 -> 175.0: Bs
# Agregando id: 1178 -> 136.5: Bs
# Agregando id: 1178 -> 175.0: Bs
# Agregando id: 1179 -> 78.0: Bs
# Agregando id: 1179 -> 136.5: Bs
# Agregando id: 1179 -> 175.0: Bs
# Agregando id: 1179 -> 78.0: Bs
# Agregando id: 1179 -> 136.5: Bs
# Agregando id: 1179 -> 175.0: Bs
# Agregando id: 1180 -> 54.0: Bs
# Agregando id: 1180 -> 54.0: Bs
# Agregando id: 1181 -> 107.0: Bs
# Agregando id: 1181 -> 107.0: Bs
# Agregando id: 1182 -> 78.0: Bs
# Agregando id: 1182 -> 136.5: Bs
# Agregando id: 1182 -> 175.0: Bs
# Agregando id: 1182 -> 78.0: Bs
# Agregando id: 1182 -> 136.5: Bs
# Agregando id: 1182 -> 175.0: Bs
# Agregando id: 1183 -> 136.5: Bs
# Agregando id: 1183 -> 175.0: Bs
# Agregando id: 1183 -> 136.5: Bs
# Agregando id: 1183 -> 175.0: Bs
# Agregando id: 1184 -> 54.0: Bs
# Agregando id: 1184 -> 54.0: Bs
# Agregando id: 1185 -> 78.0: Bs
# Agregando id: 1185 -> 136.5: Bs
# Agregando id: 1185 -> 175.0: Bs
# Agregando id: 1185 -> 78.0: Bs
# Agregando id: 1185 -> 136.5: Bs
# Agregando id: 1185 -> 175.0: Bs
# Agregando id: 1186 -> 175.0: Bs
# Agregando id: 1186 -> 175.0: Bs
# Agregando id: 1187 -> 62.5: Bs
# Agregando id: 1187 -> 109.0: Bs
# Agregando id: 1187 -> 140.0: Bs
# Agregando id: 1188 -> 62.5: Bs
# Agregando id: 1188 -> 109.0: Bs
# Agregando id: 1188 -> 140.0: Bs
# Agregando id: 1189 -> 78.0: Bs
# Agregando id: 1189 -> 136.5: Bs
# Agregando id: 1189 -> 175.0: Bs
# Agregando id: 1190 -> 22.0: Bs
# Agregando id: 1190 -> 22.0: Bs
# Agregando id: 1191 -> 78.0: Bs
# Agregando id: 1191 -> 136.5: Bs
# Agregando id: 1191 -> 175.0: Bs
# Agregando id: 1192 -> 78.0: Bs
# Agregando id: 1192 -> 136.5: Bs
# Agregando id: 1192 -> 175.0: Bs
# Agregando id: 1193 -> 78.0: Bs
# Agregando id: 1193 -> 136.5: Bs
# Agregando id: 1193 -> 175.0: Bs
# Agregando id: 1194 -> 78.0: Bs
# Agregando id: 1194 -> 136.5: Bs
# Agregando id: 1194 -> 175.0: Bs
# Agregando id: 1195 -> 107.0: Bs
# Agregando id: 1195 -> 107.0: Bs
# Agregando id: 1196 -> 78.0: Bs
# Agregando id: 1196 -> 136.5: Bs
# Agregando id: 1196 -> 175.0: Bs
# Agregando id: 1197 -> 78.0: Bs
# Agregando id: 1198 -> 78.0: Bs
# Agregando id: 1199 -> 175.0: Bs
# Agregando id: 1199 -> 175.0: Bs
# Agregando id: 1200 -> 175.0: Bs
# Agregando id: 1201 -> 22.0: Bs
# Agregando id: 1201 -> 22.0: Bs
# Agregando id: 1202 -> 1575.0: Bs
# Agregando id: 1202 -> 1575.0: Bs
# Agregando id: 1202 -> 1575.0: Bs
# Agregando id: 1202 -> 1575.0: Bs
# Agregando id: 1203 -> 272.0: Bs
# Agregando id: 1204 -> 123.0: Bs
# Agregando id: 1204 -> 123.0: Bs
# Agregando id: 1205 -> 680.5: Bs
# Agregando id: 1205 -> 875.0: Bs
# Agregando id: 1205 -> 192.0: Bs
# Agregando id: 1205 -> 680.5: Bs
# Agregando id: 1205 -> 875.0: Bs
# Agregando id: 1205 -> 192.0: Bs
# Agregando id: 1206 -> 680.5: Bs
# Agregando id: 1206 -> 875.0: Bs
# Agregando id: 1206 -> 192.0: Bs
# Agregando id: 1206 -> 680.5: Bs
# Agregando id: 1206 -> 875.0: Bs
# Agregando id: 1206 -> 192.0: Bs
# Agregando id: 1207 -> 680.5: Bs
# Agregando id: 1207 -> 875.0: Bs
# Agregando id: 1207 -> 192.0: Bs
# Agregando id: 1207 -> 680.5: Bs
# Agregando id: 1207 -> 875.0: Bs
# Agregando id: 1207 -> 192.0: Bs
# Agregando id: 1209 -> 875.0: Bs
# Agregando id: 1209 -> 192.0: Bs
# Agregando id: 1209 -> 875.0: Bs
# Agregando id: 1209 -> 192.0: Bs
# Agregando id: 1210 -> 272.0: Bs
# Agregando id: 1210 -> 680.5: Bs
# Agregando id: 1210 -> 875.0: Bs
# Agregando id: 1210 -> 272.0: Bs
# Agregando id: 1210 -> 680.5: Bs
# Agregando id: 1210 -> 875.0: Bs
# Agregando id: 1212 -> 107.0: Bs
# Agregando id: 1212 -> 107.0: Bs
# Agregando id: 1213 -> 78.0: Bs
# Agregando id: 1213 -> 136.5: Bs
# Agregando id: 1213 -> 175.0: Bs
# Agregando id: 1214 -> 78.0: Bs
# Agregando id: 1214 -> 136.5: Bs
# Agregando id: 1214 -> 175.0: Bs
# Agregando id: 1215 -> 78.0: Bs
# Agregando id: 1215 -> 136.5: Bs
# Agregando id: 1215 -> 175.0: Bs
# Agregando id: 1216 -> 23.0: Bs
# Agregando id: 1216 -> 23.0: Bs
# Agregando id: 1218 -> 78.0: Bs
# Agregando id: 1218 -> 136.5: Bs
# Agregando id: 1218 -> 175.0: Bs
# Agregando id: 1219 -> 78.0: Bs
# Agregando id: 1219 -> 136.5: Bs
# Agregando id: 1219 -> 175.0: Bs
# Agregando id: 1220 -> 23.0: Bs
# Agregando id: 1220 -> 23.0: Bs
# Agregando id: 1221 -> 78.0: Bs
# Agregando id: 1221 -> 136.5: Bs
# Agregando id: 1221 -> 175.0: Bs
# Agregando id: 1222 -> 78.0: Bs
# Agregando id: 1222 -> 136.5: Bs
# Agregando id: 1222 -> 175.0: Bs
# Agregando id: 1223 -> 12.0: Bs
# Agregando id: 1223 -> 12.0: Bs
# Agregando id: 1224 -> 78.0: Bs
# Agregando id: 1224 -> 136.5: Bs
# Agregando id: 1224 -> 175.0: Bs
# Agregando id: 1225 -> 78.0: Bs
# Agregando id: 1225 -> 136.5: Bs
# Agregando id: 1225 -> 175.0: Bs
# Agregando id: 1226 -> 78.0: Bs
# Agregando id: 1226 -> 136.5: Bs
# Agregando id: 1226 -> 175.0: Bs
# Agregando id: 1227 -> 80.0: Bs
# Agregando id: 1227 -> 140.0: Bs
# Agregando id: 1227 -> 180.0: Bs
# Agregando id: 1227 -> 400.0: Bs
# Agregando id: 1228 -> 22.0: Bs
# Agregando id: 1228 -> 22.0: Bs
# Agregando id: 1229 -> 78.0: Bs
# Agregando id: 1229 -> 136.5: Bs
# Agregando id: 1229 -> 175.0: Bs
# Agregando id: 1230 -> 78.0: Bs
# Agregando id: 1230 -> 136.5: Bs
# Agregando id: 1230 -> 175.0: Bs
# Agregando id: 1231 -> 22.0: Bs
# Agregando id: 1231 -> 22.0: Bs
# Agregando id: 1232 -> 54.0: Bs
# Agregando id: 1232 -> 54.0: Bs
# Agregando id: 1233 -> 54.0: Bs
# Agregando id: 1233 -> 54.0: Bs
# Agregando id: 1234 -> 160.0: Bs
# Agregando id: 1234 -> 160.0: Bs
# Agregando id: 1235 -> 128.0: Bs
# Agregando id: 1235 -> 128.0: Bs
# Agregando id: 1236 -> 80.0: Bs
# Agregando id: 1236 -> 80.0: Bs
# Agregando id: 1237 -> 38.0: Bs
# Agregando id: 1237 -> 38.0: Bs
# Agregando id: 1239 -> 22.0: Bs
# Agregando id: 1239 -> 22.0: Bs
# Agregando id: 1241 -> 54.0: Bs
# Agregando id: 1241 -> 54.0: Bs
# Agregando id: 1242 -> 107.0: Bs
# Agregando id: 1242 -> 107.0: Bs
# Agregando id: 1244 -> 38.0: Bs
# Agregando id: 1244 -> 38.0: Bs
# Agregando id: 1245 -> 107.0: Bs
# Agregando id: 1245 -> 107.0: Bs
# Agregando id: 1246 -> 54.0: Bs
# Agregando id: 1246 -> 54.0: Bs
# Agregando id: 1250 -> 160.0: Bs
# Agregando id: 1250 -> 160.0: Bs
# Agregando id: 1252 -> 30.0: Bs
# Agregando id: 1252 -> 20.0: Bs
# Agregando id: 1253 -> 12.0: Bs
# Agregando id: 1253 -> 12.0: Bs
# Agregando id: 1256 -> 160.0: Bs
# Agregando id: 1256 -> 160.0: Bs
# Agregando id: 1257 -> 54.0: Bs
# Agregando id: 1257 -> 54.0: Bs
# Agregando id: 1265 -> 93.47: Bs
# Agregando id: 1266 -> 160.0: Bs
# Agregando id: 1266 -> 160.0: Bs
# Agregando id: 1267 -> 54.0: Bs
# Agregando id: 1267 -> 54.0: Bs
# Agregando id: 1268 -> 54.0: Bs
# Agregando id: 1268 -> 54.0: Bs
# Agregando id: 1269 -> 13.0: Bs
# Agregando id: 1269 -> 13.0: Bs
# Agregando id: 1270 -> 54.0: Bs
# Agregando id: 1270 -> 54.0: Bs
# Agregando id: 1271 -> 54.0: Bs
# Agregando id: 1271 -> 54.0: Bs
# Agregando id: 1272 -> 62.0: Bs
# Agregando id: 1272 -> 62.0: Bs
# Agregando id: 1273 -> 213.0: Bs
# Agregando id: 1273 -> 213.0: Bs
# Agregando id: 1274 -> 50.0: Bs
# Agregando id: 1274 -> 40.0: Bs
# Agregando id: 1274 -> 30.0: Bs
# Agregando id: 1274 -> 50.0: Bs
# Agregando id: 1274 -> 40.0: Bs
# Agregando id: 1274 -> 30.0: Bs
# Agregando id: 1274 -> 50.0: Bs
# Agregando id: 1274 -> 40.0: Bs
# Agregando id: 1274 -> 30.0: Bs
# Agregando id: 1275 -> 160.0: Bs
# Agregando id: 1275 -> 160.0: Bs
# Agregando id: 1276 -> 115.0: Bs
# Agregando id: 1276 -> 144.0: Bs
# Agregando id: 1276 -> 172.0: Bs
# Agregando id: 1277 -> 70.0: Bs
# Agregando id: 1277 -> 175.0: Bs
# Agregando id: 1277 -> 70.0: Bs
# Agregando id: 1277 -> 175.0: Bs
# Agregando id: 1278 -> 54.0: Bs
# Agregando id: 1278 -> 54.0: Bs
# Agregando id: 1279 -> 123.0: Bs
# Agregando id: 1279 -> 123.0: Bs
# Agregando id: 1280 -> 107.0: Bs
# Agregando id: 1280 -> 107.0: Bs
# Agregando id: 1281 -> 160.0: Bs
# Agregando id: 1281 -> 160.0: Bs
# Agregando id: 1282 -> 11.0: Bs
# Agregando id: 1282 -> 11.0: Bs
# Agregando id: 1283 -> 38.0: Bs
# Agregando id: 1283 -> 38.0: Bs
# Agregando id: 1284 -> 62.0: Bs
# Agregando id: 1284 -> 62.0: Bs
# Agregando id: 1285 -> 100.0: Bs
# Agregando id: 1286 -> 54.0: Bs
# Agregando id: 1286 -> 54.0: Bs
# Agregando id: 1288 -> 54.0: Bs
# Agregando id: 1288 -> 54.0: Bs
# Agregando id: 1290 -> 100.0: Bs
# Agregando id: 1290 -> 500.0: Bs
# Agregando id: 1291 -> 107.0: Bs
# Agregando id: 1291 -> 107.0: Bs
# Agregando id: 1293 -> 22.0: Bs
# Agregando id: 1293 -> 22.0: Bs
# Agregando id: 1296 -> 5.0: Bs
# Agregando id: 1297 -> 107.0: Bs
# Agregando id: 1297 -> 107.0: Bs
# Agregando id: 1298 -> 66.94: Bs
# Agregando id: 1298 -> 133.87: Bs
# Agregando id: 1299 -> 213.0: Bs
# Agregando id: 1299 -> 213.0: Bs
# Agregando id: 1300 -> 52.74: Bs
# Agregando id: 1303 -> 62.0: Bs
# Agregando id: 1303 -> 62.0: Bs
# Agregando id: 1306 -> 15.0: Bs
# Agregando id: 1307 -> 160.0: Bs
# Agregando id: 1307 -> 160.0: Bs
# Agregando id: 1308 -> 125.0: Bs
# Agregando id: 1311 -> 123.0: Bs
# Agregando id: 1311 -> 123.0: Bs
# Agregando id: 1314 -> 63.0: Bs
# Agregando id: 1314 -> 63.0: Bs
# Agregando id: 1316 -> 123.0: Bs
# Agregando id: 1316 -> 123.0: Bs
# Agregando id: 1317 -> 62.0: Bs
# Agregando id: 1317 -> 62.0: Bs
# Agregando id: 1318 -> 213.0: Bs
# Agregando id: 1318 -> 213.0: Bs
# Agregando id: 1319 -> 15.0: Bs
# Agregando id: 1320 -> 107.0: Bs
# Agregando id: 1320 -> 107.0: Bs
# Agregando id: 1321 -> 213.0: Bs
# Agregando id: 1321 -> 213.0: Bs
# Agregando id: 1323 -> 100.0: Bs
# Agregando id: 1324 -> 38.0: Bs
# Agregando id: 1324 -> 38.0: Bs
# Agregando id: 1325 -> 100.0: Bs
# Agregando id: 1326 -> 123.0: Bs
# Agregando id: 1326 -> 123.0: Bs
# Agregando id: 1327 -> 54.0: Bs
# Agregando id: 1327 -> 54.0: Bs
# Agregando id: 1328 -> 62.0: Bs
# Agregando id: 1328 -> 62.0: Bs
# Agregando id: 1329 -> 107.0: Bs
# Agregando id: 1329 -> 107.0: Bs
# Agregando id: 1330 -> 107.0: Bs
# Agregando id: 1330 -> 107.0: Bs
# Agregando id: 1331 -> 38.0: Bs
# Agregando id: 1331 -> 38.0: Bs
# Agregando id: 1332 -> 213.0: Bs
# Agregando id: 1332 -> 213.0: Bs
# Agregando id: 1333 -> 38.0: Bs
# Agregando id: 1333 -> 38.0: Bs
# Agregando id: 1334 -> 35.0: Bs
# Agregando id: 1335 -> 43.0: Bs
# Agregando id: 1335 -> 43.0: Bs
# Agregando id: 1336 -> 213.0: Bs
# Agregando id: 1336 -> 213.0: Bs
# Agregando id: 1337 -> 62.0: Bs
# Agregando id: 1337 -> 62.0: Bs
# Agregando id: 1339 -> 424.0: Bs
# Agregando id: 1339 -> 424.0: Bs
# Agregando id: 1340 -> 54.0: Bs
# Agregando id: 1340 -> 54.0: Bs
# Agregando id: 1341 -> 54.0: Bs
# Agregando id: 1341 -> 54.0: Bs
# Agregando id: 1342 -> 1200.0: Bs
# Agregando id: 1343 -> 1300.0: Bs
# Agregando id: 1343 -> 600.0: Bs
# Agregando id: 1344 -> 1300.0: Bs
# Agregando id: 1345 -> 600.0: Bs
# Agregando id: 1345 -> 300.0: Bs
# Agregando id: 1345 -> 350.0: Bs
# Agregando id: 1345 -> 110.0: Bs
# Agregando id: 1346 -> 110.0: Bs
# Agregando id: 1347 -> 350.0: Bs
# Agregando id: 1347 -> 110.0: Bs
# Agregando id: 1348 -> 1300.0: Bs
# Agregando id: 1348 -> 1200.0: Bs
# Agregando id: 1348 -> 600.0: Bs
# Agregando id: 1348 -> 300.0: Bs
# Agregando id: 1348 -> 350.0: Bs
# Agregando id: 1348 -> 110.0: Bs
# Agregando id: 1348 -> 100.0: Bs
# Agregando id: 1354 -> 30000.0: Bs
# Agregando id: 1356 -> 100.0: Bs
# Agregando id: 1357 -> 180.0: Bs
# Agregando id: 1358 -> 100.0: Bs
# Agregando id: 1361 -> 100.0: Bs
# Agregando id: 1363 -> 100.0: Bs
# Agregando id: 1369 -> 52.0: Bs
# Agregando id: 1374 -> 70.0: Bs
# Agregando id: 1374 -> 130.0: Bs
# Agregando id: 1374 -> 300.0: Bs
# Agregando id: 1374 -> 70.0: Bs
# Agregando id: 1374 -> 130.0: Bs
# Agregando id: 1374 -> 300.0: Bs
# Agregando id: 1405 -> 800.0: Bs
# Agregando id: 1406 -> 1000.0: Bs
# Agregando id: 1407 -> 57.0: Bs
# Agregando id: 1408 -> 76.0: Bs
# Agregando id: 1409 -> 76.0: Bs
# Agregando id: 1417 -> 300.0: Bs
# Agregando id: 1418 -> 10.0: Bs
# Agregando id: 1419 -> 10.0: Bs
# Agregando id: 1420 -> 90.0: Bs
# Agregando id: 1421 -> 1000.0: Bs
# Agregando id: 1422 -> 800.0: Bs
# Agregando id: 1423 -> 800.0: Bs
# Agregando id: 1424 -> 500.0: Bs
# Agregando id: 1425 -> 500.0: Bs
# Agregando id: 1426 -> 500.0: Bs
# Agregando id: 1428 -> 300.0: Bs
# Agregando id: 1429 -> 80.0: Bs
# Agregando id: 1431 -> 100.0: Bs
# Agregando id: 1432 -> 100.0: Bs
# Agregando id: 1434 -> 200.0: Bs
# Agregando id: 1436 -> 80.0: Bs
# Agregando id: 1437 -> 200.0: Bs
# Agregando id: 1438 -> 4000.0: Bs
# Agregando id: 1438 -> 350.0: Bs
# Agregando id: 1439 -> 200.0: Bs
# Agregando id: 1441 -> 4000.0: Bs
# Agregando id: 1441 -> 350.0: Bs
# Agregando id: 1444 -> 5000.0: Bs
# Agregando id: 1444 -> 10000.0: Bs
# Agregando id: 1447 -> 76.0: Bs
# Agregando id: 1448 -> 300.0: Bs
# Agregando id: 1449 -> 76.0: Bs
# Agregando id: 1450 -> 57.0: Bs
# Agregando id: 1451 -> 0.0: Bs
# Agregando id: 1451 -> 500.0: Bs
# Agregando id: 1451 -> 400.0: Bs
# Agregando id: 1454 -> 500.0: Bs
# Agregando id: 1454 -> 400.0: Bs
# Agregando id: 1455 -> 0.0: Bs
# Agregando id: 1455 -> 500.0: Bs
# Agregando id: 1455 -> 400.0: Bs
# Agregando id: 1457 -> 10.0: Bs
# Agregando id: 1458 -> 50.0: Bs
# Agregando id: 1459 -> 65.0: Bs
# Agregando id: 1500 -> 0.0: Bs
# Agregando id: 1504 -> 329.0: Bs
# Agregando id: 1507 -> 35.2: Bs
# Agregando id: 1507 -> 10000.0: Bs
# Agregando id: 1507 -> 215.0: Bs
# Agregando id: 1509 -> 400.0: Bs
# Agregando id: 1509 -> 300.0: Bs
# Agregando id: 1511 -> 10.0: Bs
# Agregando id: 1512 -> 10.0: Bs
# Agregando id: 1513 -> 10.0: Bs
# Agregando id: 1514 -> 10.0: Bs
# Agregando id: 1516 -> 10.0: Bs
# Agregando id: 1517 -> 10.0: Bs
# Agregando id: 1518 -> 10.0: Bs
# Agregando id: 1524 -> 400.0: Bs
# Agregando id: 1524 -> 300.0: Bs
# Agregando id: 1525 -> 10.0: Bs
# Agregando id: 1526 -> 10.0: Bs
# Agregando id: 1527 -> 10.0: Bs
# Agregando id: 1528 -> 0.0: Bs
# Agregando id: 1531 -> 2520.0: Bs
# Agregando id: 1531 -> 600.0: Bs
# Agregando id: 1531 -> 860.0: Bs
# Agregando id: 1531 -> 1260.0: Bs
# Agregando id: 1531 -> 1620.0: Bs
# Agregando id: 1531 -> 4040.0: Bs
# Agregando id: 1532 -> 5500.0: Bs
# Agregando id: 1535 -> 100.0: Bs
# Agregando id: 1536 -> 100.0: Bs
# Agregando id: 1536 -> 150.0: Bs
# Agregando id: 1538 -> 50.0: Bs
# Agregando id: 1538 -> 150.0: Bs
# Agregando id: 1538 -> 200.0: Bs
# Agregando id: 1538 -> 300.0: Bs
# Agregando id: 1538 -> 400.0: Bs
# Agregando id: 1538 -> 600.0: Bs
# Agregando id: 1538 -> 800.0: Bs
# Agregando id: 1538 -> 950.0: Bs
# Agregando id: 1540 -> 25.0: Bs
# Agregando id: 1541 -> 182.0: Bs
# Agregando id: 1541 -> 142.0: Bs
# Agregando id: 1542 -> 82.0: Bs
# Agregando id: 1543 -> 62.0: Bs
# Agregando id: 1543 -> 160.0: Bs
# Agregando id: 1543 -> 268.0: Bs
# Agregando id: 1543 -> 376.0: Bs
# Agregando id: 1543 -> 508.0: Bs
# Agregando id: 1544 -> 0.2: USD
# Agregando id: 1546 -> 25.0: Bs
# Agregando id: 1551 -> 25.0: Bs
# Agregando id: 1553 -> 320.0: Bs
# Agregando id: 1553 -> 340.0: Bs
# Agregando id: 1560 -> 310.0: Bs
# Agregando id: 1560 -> 340.0: Bs
# Agregando id: 1562 -> 350.0: Bs
# Agregando id: 1562 -> 200.0: Bs
# Agregando id: 1563 -> 260.0: Bs
# Agregando id: 1563 -> 200.0: Bs
# Agregando id: 1564 -> 160.0: Bs
# Agregando id: 1564 -> 200.0: Bs
# Agregando id: 1565 -> 220.0: Bs
# Agregando id: 1565 -> 200.0: Bs
# Agregando id: 1566 -> 220.0: Bs
# Agregando id: 1566 -> 200.0: Bs
# Agregando id: 1567 -> 170.0: Bs
# Agregando id: 1567 -> 200.0: Bs
# Agregando id: 1568 -> 160.0: Bs
# Agregando id: 1569 -> 220.0: Bs
# Agregando id: 1575 -> 260.0: Bs
# Agregando id: 1575 -> 200.0: Bs
# Agregando id: 1576 -> 690.0: Bs
# Agregando id: 1576 -> 200.0: Bs
# Agregando id: 1577 -> 170.0: Bs
# Agregando id: 1577 -> 200.0: Bs
# Agregando id: 1578 -> 220.0: Bs
# Agregando id: 1578 -> 200.0: Bs
# Agregando id: 1579 -> 295.0: Bs
# Agregando id: 1579 -> 200.0: Bs
# Agregando id: 1580 -> 650.0: Bs
# Agregando id: 1580 -> 200.0: Bs
# Agregando id: 1581 -> 180.0: Bs
# Agregando id: 1582 -> 14.0: Bs
# Agregando id: 1583 -> 20.0: Bs
# Agregando id: 1584 -> 106.0: Bs
# Agregando id: 1585 -> 25.0: Bs
# Agregando id: 1586 -> 10.0: Bs
# Agregando id: 1587 -> 54.0: Bs
# Agregando id: 1588 -> 10.0: Bs
# Agregando id: 1589 -> 26.0: Bs
# Agregando id: 1590 -> 56.0: Bs
# Agregando id: 1591 -> 5.0: Bs
# Agregando id: 1592 -> 25.0: Bs
# Agregando id: 1593 -> 50.0: Bs
# Agregando id: 1594 -> 10.0: Bs
# Agregando id: 1595 -> 20.0: Bs
# Agregando id: 1596 -> 758.0: Bs
# Agregando id: 1596 -> 1408.0: Bs
# Agregando id: 1597 -> 181.0: Bs
# Agregando id: 1597 -> 391.0: Bs
# Agregando id: 1597 -> 231.0: Bs
# Agregando id: 1597 -> 481.0: Bs
# Agregando id: 1598 -> 458.0: Bs
# Agregando id: 1599 -> 7000.0: Bs
# Agregando id: 1599 -> 14000.0: Bs
# Agregando id: 1600 -> 458.0: Bs
# Agregando id: 1600 -> 1058.0: Bs
# Agregando id: 1604 -> 25.0: Bs
# Agregando id: 1605 -> 25.0: Bs
# Agregando id: 1606 -> 25.0: Bs
# Agregando id: 1607 -> 25.0: Bs
# Agregando id: 1608 -> 400.0: Bs
# Agregando id: 1608 -> 250.0: Bs
# Agregando id: 1608 -> 150.0: Bs
# Agregando id: 1608 -> 350.0: Bs
# Agregando id: 1608 -> 200.0: Bs
# Agregando id: 1608 -> 200.0: Bs
# Agregando id: 1609 -> 250.0: Bs
# Agregando id: 1609 -> 200.0: Bs
# Agregando id: 1609 -> 200.0: Bs
# Agregando id: 1610 -> 50.0: Bs
# Agregando id: 1610 -> 100.0: Bs
# Agregando id: 1610 -> 100.0: Bs
# Agregando id: 1614 -> 50.0: Bs
# Agregando id: 1614 -> 25.0: Bs
# Agregando id: 1614 -> 25.0: Bs
# Agregando id: 1616 -> 0.5: Bs
# Agregando id: 1617 -> 3.0: Bs
# Agregando id: 1618 -> 3.0: Bs
# Agregando id: 1620 -> 3.0: Bs
# Agregando id: 1621 -> 3.0: Bs
# Agregando id: 1623 -> 200.0: Bs
# Agregando id: 1623 -> 400.0: Bs
# Agregando id: 1628 -> 3.0: Bs
# Agregando id: 1633 -> 3.0: Bs
# Agregando id: 1634 -> 6.0: Bs
# Agregando id: 1635 -> 6.0: Bs
# Agregando id: 1636 -> 6.0: Bs
# Agregando id: 1637 -> 6.0: Bs
# Agregando id: 1638 -> 3.0: Bs
# Agregando id: 1639 -> 6.0: Bs
# Agregando id: 1642 -> 25.0: Bs
# Agregando id: 1643 -> 25.0: Bs
# Agregando id: 1644 -> 25.0: Bs
# Agregando id: 1645 -> 25.0: Bs
# Agregando id: 1646 -> 25.0: Bs
# Agregando id: 1647 -> 25.0: Bs
# Agregando id: 1648 -> 25.0: Bs
# Agregando id: 1649 -> 25.0: Bs
# Agregando id: 1650 -> 25.0: Bs
# Agregando id: 1651 -> 25.0: Bs
# Agregando id: 1652 -> 25.0: Bs
# Agregando id: 1653 -> 25.0: Bs
# Agregando id: 1654 -> 25.0: Bs
# Agregando id: 1655 -> 25.0: Bs
# Agregando id: 1656 -> 25.0: Bs
# Agregando id: 1657 -> 25.0: Bs
# Agregando id: 1658 -> 25.0: Bs
# Agregando id: 1659 -> 25.0: Bs
# Agregando id: 1660 -> 25.0: Bs
# Agregando id: 1661 -> 25.0: Bs
# Agregando id: 1662 -> 25.0: Bs
# Agregando id: 1663 -> 2.0: Bs
# Agregando id: 1668 -> 440.0: Bs
# Agregando id: 1669 -> 50.0: Bs
# Agregando id: 1671 -> 30.0: Bs
# Agregando id: 1672 -> 48.0: UFV
# Agregando id: 1673 -> 48.0: UFV
# Agregando id: 1674 -> 10.0: UFV
# Agregando id: 1675 -> 200.0: Bs
# Agregando id: 1676 -> 190.0: Bs
# Agregando id: 1678 -> 15.0: Bs
# Agregando id: 1679 -> 1600.0: Bs
# Agregando id: 1679 -> 5000.0: Bs
# Agregando id: 1679 -> 1800.0: Bs
# Agregando id: 1712 -> 1000.0: Bs
# Agregando id: 1712 -> 900.0: Bs
# Agregando id: 1712 -> 1000.0: Bs
# Agregando id: 1712 -> 900.0: Bs
# Agregando id: 1712 -> 100.0: Bs
# Agregando id: 1712 -> 900.0: Bs
# Agregando id: 1712 -> 1000.0: Bs
# Agregando id: 1712 -> 900.0: Bs
# Agregando id: 1712 -> 800.0: Bs
# Agregando id: 1712 -> 800.0: Bs
# Agregando id: 1712 -> 800.0: Bs
# Agregando id: 1712 -> 700.0: Bs
# Agregando id: 1712 -> 500.0: Bs
# Agregando id: 1712 -> 700.0: Bs
# Agregando id: 1712 -> 700.0: Bs
# Agregando id: 1712 -> 600.0: Bs
# Agregando id: 1712 -> 500.0: Bs
# Agregando id: 1712 -> 400.0: Bs
# Agregando id: 1712 -> 500.0: Bs
# Agregando id: 1712 -> 500.0: Bs
# Agregando id: 1712 -> 300.0: Bs
# Agregando id: 1712 -> 400.0: Bs
# Agregando id: 1712 -> 500.0: Bs
# Agregando id: 1712 -> 750.0: Bs
# Agregando id: 1712 -> 500.0: Bs
# Agregando id: 1712 -> 750.0: Bs
# Agregando id: 1712 -> 675.0: Bs
# Agregando id: 1712 -> 712.0: Bs
# Agregando id: 1712 -> 750.0: Bs
# Agregando id: 1712 -> 825.0: Bs
# Agregando id: 1712 -> 900.0: Bs
# Agregando id: 1712 -> 750.0: Bs
# Agregando id: 1712 -> 750.0: Bs
# Agregando id: 1712 -> 750.0: Bs
# Agregando id: 1712 -> 750.0: Bs
# Agregando id: 1712 -> 80.0: Bs
# Agregando id: 1712 -> 70.0: Bs
# Agregando id: 1712 -> 80.0: Bs
# Agregando id: 1712 -> 70.0: Bs
# Agregando id: 1712 -> 80.0: Bs
# Agregando id: 1712 -> 70.0: Bs
# Agregando id: 1712 -> 80.0: Bs
# Agregando id: 1712 -> 70.0: Bs
# Agregando id: 1712 -> 60.0: Bs
# Agregando id: 1712 -> 60.0: Bs
# Agregando id: 1712 -> 60.0: Bs
# Agregando id: 1712 -> 60.0: Bs
# Agregando id: 1712 -> 45.0: Bs
# Agregando id: 1712 -> 60.0: Bs
# Agregando id: 1712 -> 60.0: Bs
# Agregando id: 1712 -> 60.0: Bs
# Agregando id: 1712 -> 45.0: Bs
# Agregando id: 1712 -> 45.0: Bs
# Agregando id: 1712 -> 45.0: Bs
# Agregando id: 1712 -> 40.0: Bs
# Agregando id: 1712 -> 40.0: Bs
# Agregando id: 1712 -> 30.0: Bs
# Agregando id: 1712 -> 50.0: Bs
# Agregando id: 1712 -> 50.0: Bs
# Agregando id: 1712 -> 30.0: Bs
# Agregando id: 1712 -> 50.0: Bs
# Agregando id: 1712 -> 45.0: Bs
# Agregando id: 1712 -> 47.0: Bs
# Agregando id: 1712 -> 50.0: Bs
# Agregando id: 1712 -> 55.0: Bs
# Agregando id: 1712 -> 60.0: Bs
# Agregando id: 1712 -> 50.0: Bs
# Agregando id: 1712 -> 50.0: Bs
# Agregando id: 1712 -> 50.0: Bs
# Agregando id: 1712 -> 50.0: Bs
# Agregando id: 1713 -> 25.0: Bs
# Agregando id: 1714 -> 75.0: Bs
# Agregando id: 1714 -> 40.0: Bs
# Agregando id: 1714 -> 40.0: Bs
# Agregando id: 1714 -> 120.0: Bs
# Agregando id: 1714 -> 25.0: Bs
# Agregando id: 1714 -> 20.0: Bs
# Agregando id: 1714 -> 20.0: Bs
# Agregando id: 1714 -> 30.0: Bs
# Agregando id: 1715 -> 100.0: Bs
# Agregando id: 1715 -> 100.0: Bs
# Agregando id: 1715 -> 100.0: Bs
# Agregando id: 1715 -> 100.0: Bs
# Agregando id: 1716 -> 8000.0: Bs
# Agregando id: 1716 -> 8000.0: Bs
# Agregando id: 1716 -> 8000.0: Bs
# Agregando id: 1718 -> 20.0: Bs
# Agregando id: 1718 -> 50.0: Bs
# Agregando id: 1719 -> 127.0: Bs
# Agregando id: 1720 -> 350.0: Bs
# Agregando id: 1721 -> 20.0: Bs
# Agregando id: 1721 -> 50.0: Bs
# Agregando id: 1722 -> 20.0: Bs
# Agregando id: 1722 -> 50.0: Bs
# Agregando id: 1724 -> 10.0: Bs
# Agregando id: 1724 -> 20.0: Bs
# Agregando id: 1725 -> 50.0: Bs
# Agregando id: 1725 -> 20.0: Bs
# Agregando id: 1726 -> 40.0: Bs
# Agregando id: 1727 -> 20.0: Bs
# Agregando id: 1728 -> 20.0: Bs
# Agregando id: 1729 -> 40.0: Bs
# Agregando id: 1730 -> 20.0: Bs
# Agregando id: 1731 -> 40.0: Bs
# Agregando id: 1732 -> 20.0: Bs
# Agregando id: 1733 -> 20.0: Bs
# Agregando id: 1733 -> 100.0: Bs
# Agregando id: 1734 -> 90.0: Bs
# Agregando id: 1735 -> 20.0: Bs
# Agregando id: 1735 -> 20.0: Bs
# Agregando id: 1736 -> 20.0: Bs
# Agregando id: 1736 -> 500.0: Bs
# Agregando id: 1737 -> 20.0: Bs
# Agregando id: 1737 -> 400.0: Bs
# Agregando id: 1739 -> 20.0: Bs
# Agregando id: 1739 -> 20.0: Bs
# Agregando id: 1740 -> 20.0: Bs
# Agregando id: 1740 -> 100.0: Bs
# Agregando id: 1741 -> 20.0: Bs
# Agregando id: 1741 -> 20.0: Bs
# Agregando id: 1743 -> 20.0: Bs
# Agregando id: 1743 -> 100.0: Bs
# Agregando id: 1744 -> 20.0: Bs
# Agregando id: 1744 -> 30.0: Bs
# Agregando id: 1745 -> 20.0: Bs
# Agregando id: 1745 -> 62.0: Bs
# Agregando id: 1746 -> 400.0: USD
# Agregando id: 1746 -> 700.0: USD
# Agregando id: 1746 -> 1000.0: USD
# Agregando id: 1746 -> 100.0: USD
# Agregando id: 1746 -> 150.0: USD
# Agregando id: 1746 -> 200.0: USD
# Agregando id: 1750 -> 100.0: USD
# Agregando id: 1751 -> 3.0: Bs
# Agregando id: 1751 -> 3.0: Bs
# Agregando id: 1753 -> 30.0: Bs
# Agregando id: 1755 -> 21.0: Bs
# Agregando id: 1756 -> 30.0: USD
# Agregando id: 1757 -> 30.0: USD
# Agregando id: 1758 -> 340.0: Bs
# Agregando id: 1759 -> 300.0: Bs
# Agregando id: 1759 -> 300.0: Bs
# Agregando id: 1760 -> 230.0: Bs
# Agregando id: 1761 -> 300.0: Bs
# Agregando id: 1762 -> 25.0: Bs
# Agregando id: 1763 -> 35.0: Bs
# Agregando id: 1769 -> 200.0: Bs
# Agregando id: 1769 -> 400.0: Bs
# Agregando id: 1770 -> 200.0: Bs
# Agregando id: 1770 -> 400.0: Bs
# Agregando id: 1771 -> 250.0: Bs
# Agregando id: 1771 -> 500.0: Bs
# Agregando id: 1772 -> 500.0: Bs
# Agregando id: 1772 -> 1000.0: Bs
# Agregando id: 1773 -> 750.0: Bs
# Agregando id: 1773 -> 1500.0: Bs
# Agregando id: 1773 -> 255.0: Bs
# Agregando id: 1773 -> 510.0: Bs
# Agregando id: 1774 -> 750.0: Bs
# Agregando id: 1774 -> 1500.0: Bs
# Agregando id: 1774 -> 255.0: Bs
# Agregando id: 1774 -> 510.0: Bs
# Agregando id: 1775 -> 750.0: Bs
# Agregando id: 1775 -> 1500.0: Bs
# Agregando id: 1775 -> 255.0: Bs
# Agregando id: 1775 -> 510.0: Bs
# Agregando id: 1776 -> 300.0: Bs
# Agregando id: 1776 -> 600.0: Bs
# Agregando id: 1777 -> 250.0: Bs
# Agregando id: 1777 -> 500.0: Bs
# Agregando id: 1777 -> 50.0: Bs
# Agregando id: 1778 -> 200.0: Bs
# Agregando id: 1778 -> 400.0: Bs
# Agregando id: 1778 -> 50.0: Bs
# Agregando id: 1779 -> 200.0: Bs
# Agregando id: 1779 -> 400.0: Bs
# Agregando id: 1779 -> 300.0: Bs
# Agregando id: 1779 -> 600.0: Bs
# Agregando id: 1813 -> 200.0: Bs
# Agregando id: 1813 -> 400.0: Bs
# Agregando id: 1813 -> 350.0: Bs
# Agregando id: 1813 -> 700.0: Bs
# Agregando id: 1813 -> 500.0: Bs
# Agregando id: 1813 -> 1000.0: Bs
# Agregando id: 1814 -> 200.0: Bs
# Agregando id: 1814 -> 400.0: Bs
# Agregando id: 1814 -> 500.0: Bs
# Agregando id: 1814 -> 1000.0: Bs
# Agregando id: 1814 -> 400.0: Bs
# Agregando id: 1814 -> 800.0: Bs
# Agregando id: 1815 -> 200.0: Bs
# Agregando id: 1815 -> 400.0: Bs
# Agregando id: 1815 -> 50.0: Bs
# Agregando id: 1818 -> 100.0: Bs
# Agregando id: 1818 -> 200.0: Bs
# Agregando id: 1819 -> 200.0: Bs
# Agregando id: 1819 -> 400.0: Bs
# Agregando id: 1820 -> 50.0: Bs
# Agregando id: 1820 -> 100.0: Bs
# Agregando id: 1821 -> 60.0: Bs
# Agregando id: 1821 -> 120.0: Bs
# Agregando id: 1821 -> 100.0: Bs
# Agregando id: 1821 -> 200.0: Bs
# Agregando id: 1822 -> 150.0: Bs
# Agregando id: 1822 -> 300.0: Bs
# Agregando id: 1823 -> 150.0: Bs
# Agregando id: 1823 -> 300.0: Bs
# Agregando id: 1824 -> 50.0: Bs
# Agregando id: 1824 -> 100.0: Bs
# Agregando id: 1825 -> 1000.0: Bs
# Agregando id: 1826 -> 480.0: Bs
# Agregando id: 1827 -> 50.0: Bs
# Agregando id: 1828 -> 50.0: Bs
# Agregando id: 1832 -> 100.0: Bs
# Agregando id: 1865 -> 20.0: Bs
# Agregando id: 1865 -> 40.0: Bs
# Agregando id: 1866 -> 20.0: Bs
# Agregando id: 1866 -> 12.0: Bs
# Agregando id: 1867 -> 20.0: Bs
# Agregando id: 1867 -> 13.0: Bs
# Agregando id: 1868 -> 20.0: Bs
# Agregando id: 1868 -> 40.0: Bs
# Agregando id: 1868 -> 12.0: Bs
# Agregando id: 1869 -> 20.0: Bs
# Agregando id: 1870 -> 20.0: Bs
# Agregando id: 1870 -> 30.0: Bs
# Agregando id: 1871 -> 20.0: Bs
# Agregando id: 1871 -> 40.0: Bs
# Agregando id: 1872 -> 20.0: Bs
# Agregando id: 1875 -> 20.0: Bs
# Agregando id: 1875 -> 30.0: Bs
# Agregando id: 1876 -> 20.0: Bs
# Agregando id: 1876 -> 35.0: Bs
# Agregando id: 1876 -> 35.0: Bs
# Agregando id: 1877 -> 20.0: Bs
# Agregando id: 1877 -> 47.0: Bs
# Agregando id: 1877 -> 521.0: Bs
# Agregando id: 1878 -> 20.0: Bs
# Agregando id: 1878 -> 40.0: Bs
# Agregando id: 1878 -> 22.0: Bs
# Agregando id: 1879 -> 20.0: Bs
# Agregando id: 1879 -> 40.0: Bs
# Agregando id: 1879 -> 22.0: Bs
# Agregando id: 1880 -> 20.0: Bs
# Agregando id: 1880 -> 40.0: Bs
# Agregando id: 1880 -> 54.0: Bs
# Agregando id: 1881 -> 20.0: Bs
# Agregando id: 1881 -> 142.0: Bs
# Agregando id: 1882 -> 20.0: Bs
# Agregando id: 1882 -> 142.0: Bs
# Agregando id: 1883 -> 20.0: Bs
# Agregando id: 1883 -> 71.0: Bs
# Agregando id: 1885 -> 20.0: Bs
# Agregando id: 1885 -> 71.0: Bs
# Agregando id: 1888 -> 20.0: Bs
# Agregando id: 1888 -> 47.0: Bs
# Agregando id: 1891 -> 20.0: Bs
# Agregando id: 1891 -> 40.0: Bs
# Agregando id: 1892 -> 20.0: Bs
# Agregando id: 1892 -> 40.0: Bs
# Agregando id: 1894 -> 20.0: Bs
# Agregando id: 1894 -> 40.0: Bs
# Agregando id: 1894 -> 118.0: Bs
# Agregando id: 1895 -> 20.0: Bs
# Agregando id: 1895 -> 71.0: Bs
# Agregando id: 1896 -> 20.0: Bs
# Agregando id: 1896 -> 71.0: Bs
# Agregando id: 1897 -> 20.0: Bs
# Agregando id: 1897 -> 40.0: Bs
# Agregando id: 1897 -> 20.0: Bs
# Agregando id: 1898 -> 20.0: Bs
# Agregando id: 1898 -> 40.0: Bs
# Agregando id: 1898 -> 118.0: Bs
# Agregando id: 1899 -> 20.0: Bs
# Agregando id: 1899 -> 24.0: Bs
# Agregando id: 1900 -> 20.0: Bs
# Agregando id: 1900 -> 95.0: Bs
# Agregando id: 1901 -> 20.0: Bs
# Agregando id: 1901 -> 24.0: Bs
# Agregando id: 1906 -> 20.0: Bs
# Agregando id: 1906 -> 40.0: Bs
# Agregando id: 1908 -> 20.0: Bs
# Agregando id: 1908 -> 20.0: Bs
# Agregando id: 1909 -> 20.0: Bs
# Agregando id: 1909 -> 100.0: Bs
# Agregando id: 1910 -> 20.0: Bs
# Agregando id: 1910 -> 40.0: Bs
# Agregando id: 1910 -> 22.0: Bs
# Agregando id: 1913 -> 10.0: Bs
# Agregando id: 1918 -> 20.0: Bs
# Agregando id: 1918 -> 120.0: Bs
# Agregando id: 1919 -> 20.0: Bs
# Agregando id: 1919 -> 500.0: Bs
# Agregando id: 1920 -> 5.0: Bs
# Agregando id: 1960 -> 20.0: Bs
# Agregando id: 1960 -> 120.0: Bs
# Agregando id: 1964 -> 1000.0: Bs
# Agregando id: 1966 -> 100.0: Bs
# Agregando id: 1967 -> 10.0: Bs
# Agregando id: 1967 -> 20.0: Bs
# Agregando id: 1967 -> 30.0: Bs
# Agregando id: 1967 -> 50.0: Bs
# Agregando id: 1967 -> 70.0: Bs
# Agregando id: 1968 -> 1500.0: Bs
# Agregando id: 1970 -> 15.0: Bs
# Agregando id: 1970 -> 20.0: Bs
# Agregando id: 1971 -> 0.5: Bs
# Agregando id: 1973 -> 30.0: Bs
# Agregando id: 1974 -> 15.0: Bs
# Agregando id: 1975 -> 200.0: Bs
# Agregando id: 1975 -> 190.0: Bs
# Agregando id: 1975 -> 180.0: Bs
# Agregando id: 1975 -> 170.0: Bs
# Agregando id: 1975 -> 160.0: Bs
# Agregando id: 1975 -> 150.0: Bs
# Agregando id: 1976 -> 20.0: Bs
# Agregando id: 1976 -> 40.0: Bs
# Agregando id: 1978 -> 200.0: Bs
# Agregando id: 1979 -> 300.0: Bs
# Agregando id: 1979 -> 400.0: Bs
# Agregando id: 1979 -> 600.0: Bs
# Agregando id: 1979 -> 800.0: Bs
# Agregando id: 1982 -> 3500.0: Bs
# Agregando id: 1982 -> 500.0: Bs
# Agregando id: 1983 -> 2000.0: Bs
# Agregando id: 1983 -> 500.0: Bs
# Agregando id: 1985 -> 30.0: Bs
# Agregando id: 1990 -> 180.0: Bs
# Agregando id: 1991 -> 25.0: Bs
# Agregando id: 1995 -> 20.0: Bs
# Agregando id: 1995 -> 30.0: Bs
# Agregando id: 1997 -> 20.0: Bs
# Agregando id: 1997 -> 100.0: Bs
# Agregando id: 2008 -> 50.0: Bs
# Agregando id: 2014 -> 4000.0: Bs
# Agregando id: 2015 -> 100.0: Bs
# Agregando id: 2016 -> 50.0: Bs
# Agregando id: 2018 -> 500.0: Bs
# Agregando id: 2022 -> 5.0: Bs
# Agregando id: 2023 -> 3.0: Bs
# Agregando id: 2024 -> 3.0: Bs
# Agregando id: 2025 -> 10.0: Bs
# Agregando id: 2042 -> 20.0: Bs
# Agregando id: 2042 -> 30.0: Bs
# Agregando id: 2043 -> 20.0: Bs
# Agregando id: 2043 -> 100.0: Bs
# Agregando id: 2044 -> 20.0: Bs
# Agregando id: 2045 -> 20.0: Bs
# Agregando id: 2045 -> 100.0: Bs
# Agregando id: 2046 -> 20.0: Bs
# Agregando id: 2046 -> 100.0: Bs
# Agregando id: 2047 -> 20.0: Bs
# Agregando id: 2047 -> 100.0: Bs
# Agregando id: 2048 -> 20.0: Bs
# Agregando id: 2048 -> 100.0: Bs
# Agregando id: 2049 -> 20.0: Bs
# Agregando id: 2049 -> 100.0: Bs
# Agregando id: 2050 -> 20.0: Bs
# Agregando id: 2052 -> 20.0: Bs
# Agregando id: 2053 -> 20.0: Bs
# Agregando id: 2053 -> 100.0: Bs
# Agregando id: 2056 -> 20.0: Bs
# Agregando id: 2056 -> 80.0: Bs
# Agregando id: 2057 -> 20.0: Bs
# Agregando id: 2060 -> 20.0: Bs
# Agregando id: 2061 -> 20.0: Bs
# Agregando id: 2062 -> 20.0: Bs
# Agregando id: 2063 -> 20.0: Bs
# Agregando id: 2063 -> 100.0: Bs
# Agregando id: 2064 -> 20.0: Bs
# Agregando id: 2064 -> 100.0: Bs
# Agregando id: 2065 -> 20.0: Bs
# Agregando id: 2065 -> 100.0: Bs
# Agregando id: 2066 -> 20.0: Bs
# Agregando id: 2066 -> 100.0: Bs
# Agregando id: 2069 -> 20.0: Bs
# Agregando id: 2069 -> 100.0: Bs
# Agregando id: 2070 -> 20.0: Bs
# Agregando id: 2070 -> 100.0: Bs
# Agregando id: 2071 -> 20.0: Bs
# Agregando id: 2071 -> 100.0: Bs
# Agregando id: 2072 -> 20.0: Bs
# Agregando id: 2072 -> 100.0: Bs
# Agregando id: 2073 -> 20.0: Bs
# Agregando id: 2073 -> 100.0: Bs
# Agregando id: 2075 -> 20.0: Bs
# Agregando id: 2075 -> 100.0: Bs
# Agregando id: 2077 -> 20.0: Bs
# Agregando id: 2077 -> 100.0: Bs
# Agregando id: 2079 -> 20.0: Bs
# Agregando id: 2079 -> 100.0: Bs
# Agregando id: 2080 -> 20.0: Bs
# Agregando id: 2080 -> 2000.0: Bs
# Agregando id: 2081 -> 20.0: Bs
# Agregando id: 2081 -> 2000.0: Bs
# Agregando id: 2082 -> 20.0: Bs
# Agregando id: 2082 -> 2000.0: Bs
# Agregando id: 2083 -> 20.0: Bs
# Agregando id: 2083 -> 2000.0: Bs
# Agregando id: 2085 -> 20.0: Bs
# Agregando id: 2085 -> 100.0: Bs
# Agregando id: 2086 -> 20.0: Bs
# Agregando id: 2086 -> 2000.0: Bs
# Agregando id: 2087 -> 20.0: Bs
# Agregando id: 2087 -> 2000.0: Bs
# Agregando id: 2088 -> 20.0: Bs
# Agregando id: 2088 -> 1000.0: Bs
# Agregando id: 2089 -> 20.0: Bs
# Agregando id: 2089 -> 2000.0: Bs
# Agregando id: 2090 -> 20.0: Bs
# Agregando id: 2090 -> 100.0: Bs
# Agregando id: 2091 -> 20.0: Bs
# Agregando id: 2091 -> 2000.0: Bs
# Agregando id: 2092 -> 20.0: Bs
# Agregando id: 2092 -> 2000.0: Bs
# Agregando id: 2093 -> 20.0: Bs
# Agregando id: 2093 -> 500.0: Bs
# Agregando id: 2094 -> 20.0: Bs
# Agregando id: 2094 -> 100.0: Bs
# Agregando id: 2095 -> 20.0: Bs
# Agregando id: 2095 -> 500.0: Bs
# Agregando id: 2096 -> 20.0: Bs
# Agregando id: 2096 -> 2000.0: Bs
# Agregando id: 2097 -> 20.0: Bs
# Agregando id: 2097 -> 100.0: Bs
# Agregando id: 2098 -> 20.0: Bs
# Agregando id: 2098 -> 100.0: Bs
# Agregando id: 2099 -> 20.0: Bs
# Agregando id: 2099 -> 100.0: Bs
# Agregando id: 2100 -> 20.0: Bs
# Agregando id: 2100 -> 100.0: Bs
# Agregando id: 2101 -> 20.0: Bs
# Agregando id: 2101 -> 100.0: Bs
# Agregando id: 2102 -> 20.0: Bs
# Agregando id: 2102 -> 100.0: Bs
# Agregando id: 2103 -> 20.0: Bs
# Agregando id: 2103 -> 100.0: Bs
# Agregando id: 2108 -> 20.0: Bs
# Agregando id: 2108 -> 25.0: Bs
# Agregando id: 2109 -> 20.0: Bs
# Agregando id: 2109 -> 20.0: Bs
# Agregando id: 2110 -> 20.0: Bs
# Agregando id: 2110 -> 20.0: Bs
# Agregando id: 2111 -> 20.0: Bs
# Agregando id: 2111 -> 30.0: Bs
# Agregando id: 2113 -> 20.0: Bs
# Agregando id: 2113 -> 10.0: Bs
# Agregando id: 2114 -> 20.0: Bs
# Agregando id: 2114 -> 100.0: Bs
# Agregando id: 2115 -> 20.0: Bs
# Agregando id: 2115 -> 100.0: Bs
# Agregando id: 2116 -> 20.0: Bs
# Agregando id: 2116 -> 40.0: Bs
# Agregando id: 2117 -> 20.0: Bs
# Agregando id: 2117 -> 100.0: Bs
# Agregando id: 2118 -> 20.0: Bs
# Agregando id: 2118 -> 500.0: Bs
# Agregando id: 2119 -> 20.0: Bs
# Agregando id: 2119 -> 100.0: Bs
# Agregando id: 2120 -> 20.0: Bs
# Agregando id: 2121 -> 20.0: Bs
# Agregando id: 2122 -> 20.0: Bs
# Agregando id: 2122 -> 10.0: Bs
# Agregando id: 2123 -> 20.0: Bs
# Agregando id: 2123 -> 10.0: Bs
# Agregando id: 2124 -> 20.0: Bs
# Agregando id: 2124 -> 30.0: Bs
# Agregando id: 2125 -> 20.0: Bs
# Agregando id: 2125 -> 30.0: Bs
# Agregando id: 2126 -> 20.0: Bs
# Agregando id: 2126 -> 20.0: Bs
# Agregando id: 2126 -> 2000.0: Bs
# Agregando id: 2127 -> 20.0: Bs
# Agregando id: 2127 -> 20.0: Bs
# Agregando id: 2128 -> 20.0: Bs
# Agregando id: 2128 -> 1000.0: Bs
# Agregando id: 2129 -> 20.0: Bs
# Agregando id: 2129 -> 2000.0: Bs
# Agregando id: 2130 -> 20.0: Bs
# Agregando id: 2130 -> 20.0: Bs
# Agregando id: 2131 -> 20.0: Bs
# Agregando id: 2131 -> 30.0: Bs
# Agregando id: 2134 -> 20.0: Bs
# Agregando id: 2134 -> 30.0: Bs
# Agregando id: 2135 -> 20.0: Bs
# Agregando id: 2136 -> 20.0: Bs
# Agregando id: 2136 -> 500.0: Bs
# Agregando id: 2138 -> 20.0: Bs
# Agregando id: 2138 -> 40.0: Bs
# Agregando id: 2139 -> 20.0: Bs
# Agregando id: 2139 -> 100.0: Bs
# Agregando id: 2148 -> 20.0: Bs
# Agregando id: 2148 -> 40.0: Bs
# Agregando id: 2150 -> 20.0: Bs
# Agregando id: 2150 -> 30.0: Bs
# Agregando id: 2151 -> 20.0: Bs
# Agregando id: 2151 -> 20.0: Bs
# Agregando id: 2157 -> 47.0: Bs
# Agregando id: 2160 -> 20.0: Bs
# Agregando id: 2160 -> 500.0: Bs
# Agregando id: 2161 -> 20.0: Bs
# Agregando id: 2161 -> 1000.0: Bs
# Agregando id: 2162 -> 20.0: Bs
# Agregando id: 2162 -> 300.0: Bs
# Agregando id: 2163 -> 20.0: Bs
# Agregando id: 2163 -> 30.0: Bs
# Agregando id: 2164 -> 20.0: Bs
# Agregando id: 2164 -> 30.0: Bs
# Agregando id: 2165 -> 20.0: Bs
# Agregando id: 2165 -> 50.0: Bs
# Agregando id: 2166 -> 20.0: Bs
# Agregando id: 2166 -> 50.0: Bs
# Agregando id: 2167 -> 20.0: Bs
# Agregando id: 2167 -> 10.0: Bs
# Agregando id: 2168 -> 20.0: Bs
# Agregando id: 2168 -> 20.0: Bs
# Agregando id: 2169 -> 20.0: Bs
# Agregando id: 2170 -> 20.0: Bs
# Agregando id: 2171 -> 20.0: Bs
# Agregando id: 2171 -> 50.0: Bs
# Agregando id: 2208 -> 20.0: Bs
# Agregando id: 2209 -> 20.0: Bs
# Agregando id: 2210 -> 20.0: Bs
# Agregando id: 2211 -> 20.0: Bs
# Agregando id: 2212 -> 20.0: Bs
# Agregando id: 2213 -> 20.0: Bs
# Agregando id: 2214 -> 20.0: Bs
# Agregando id: 2215 -> 20.0: Bs
# Agregando id: 2216 -> 20.0: Bs
# Agregando id: 2217 -> 20.0: Bs
# Agregando id: 2218 -> 20.0: Bs
# Agregando id: 2219 -> 20.0: Bs
# Agregando id: 2220 -> 30.0: Bs
# Agregando id: 2221 -> 30.0: Bs
# Agregando id: 2225 -> 30.0: Bs
# Agregando id: 2229 -> 25.0: Bs
# Agregando id: 2234 -> 521.0: Bs
# Agregando id: 2234 -> 47.0: Bs
# Agregando id: 2235 -> 521.0: Bs
# Agregando id: 2235 -> 47.0: Bs
# Agregando id: 2237 -> 25.0: Bs
# Agregando id: 2238 -> 25.0: Bs
# Agregando id: 2239 -> 118.0: Bs
# Agregando id: 2240 -> 47.0: Bs
# Agregando id: 2241 -> 71.0: Bs
# Agregando id: 2242 -> 71.0: Bs
# Agregando id: 2243 -> 71.0: Bs
# Agregando id: 2244 -> 71.0: Bs
# Agregando id: 2247 -> 47.0: Bs
# Agregando id: 2249 -> 20.0: Bs
# Agregando id: 2250 -> 25.0: Bs
# Agregando id: 2252 -> 70.0: Bs
# Agregando id: 2252 -> 70.0: Bs
# Agregando id: 2256 -> 25.0: Bs
# Agregando id: 2257 -> 20.0: Bs
# Agregando id: 2257 -> 500.0: Bs
# Agregando id: 2258 -> 100.0: Bs
# Agregando id: 2259 -> 150.0: Bs
# Agregando id: 2259 -> 200.0: Bs
# Agregando id: 2259 -> 150.0: Bs
# Agregando id: 2260 -> 20.0: Bs
# Agregando id: 2267 -> 250.0: Bs
# Agregando id: 2268 -> 450.0: Bs
# Agregando id: 2270 -> 500.0: Bs
# Agregando id: 2281 -> 0.5: Bs
# Agregando id: 2287 -> 0.0: Bs
# Agregando id: 2290 -> 0.0: Bs
# Agregando id: 2293 -> 0.0: Bs
# Agregando id: 2293 -> 0.0: Bs
# Agregando id: 2298 -> 1550.0: Bs
# Agregando id: 2303 -> 344.0: Bs
# Agregando id: 2303 -> 344.0: Bs
# Agregando id: 2303 -> 14.0: Bs
# Agregando id: 2304 -> 39.0: Bs
# Agregando id: 2304 -> 83.0: Bs
# Agregando id: 2304 -> 14.0: Bs
# Agregando id: 2304 -> 20.0: Bs
# Agregando id: 2305 -> 39.0: Bs
# Agregando id: 2305 -> 14.0: Bs
# Agregando id: 2305 -> 24.0: Bs
# Agregando id: 2306 -> 39.0: Bs
# Agregando id: 2306 -> 128.0: Bs
# Agregando id: 2306 -> 107.0: Bs
# Agregando id: 2306 -> 14.0: Bs
# Agregando id: 2306 -> 39.0: Bs
# Agregando id: 2306 -> 128.0: Bs
# Agregando id: 2306 -> 20.0: Bs
# Agregando id: 2306 -> 0.3: Bs
# Agregando id: 2308 -> 20.0: Bs
# Agregando id: 2308 -> 39.0: UFV
# Agregando id: 2308 -> 128.0: Bs
# Agregando id: 2308 -> 39.0: Bs
# Agregando id: 2308 -> 128.0: Bs
# Agregando id: 2308 -> 107.0: Bs
# Agregando id: 2308 -> 0.3: Bs
# Agregando id: 2308 -> 14.0: Bs
# Agregando id: 2309 -> 128.0: Bs
# Agregando id: 2309 -> 128.0: Bs
# Agregando id: 2309 -> 107.0: Bs
# Agregando id: 2309 -> 39.0: Bs
# Agregando id: 2309 -> 14.0: Bs
# Agregando id: 2309 -> 0.3: Bs
# Agregando id: 2310 -> 83.0: Bs
# Agregando id: 2310 -> 128.0: Bs
# Agregando id: 2310 -> 128.0: Bs
# Agregando id: 2310 -> 107.0: Bs
# Agregando id: 2310 -> 39.0: Bs
# Agregando id: 2310 -> 22.0: Bs
# Agregando id: 2310 -> 14.0: Bs
# Agregando id: 2310 -> 0.3: Bs
# Agregando id: 2313 -> 1200.0: Bs
# Agregando id: 2315 -> 83.0: Bs
# Agregando id: 2315 -> 128.0: Bs
# Agregando id: 2315 -> 128.0: Bs
# Agregando id: 2315 -> 107.0: Bs
# Agregando id: 2315 -> 22.0: Bs
# Agregando id: 2315 -> 14.0: Bs
# Agregando id: 2315 -> 0.3: Bs
# Agregando id: 2316 -> 128.0: Bs
# Agregando id: 2316 -> 117.0: Bs
# Agregando id: 2316 -> 80.0: Bs
# Agregando id: 2316 -> 45.0: Bs
# Agregando id: 2316 -> 22.0: Bs
# Agregando id: 2316 -> 14.0: Bs
# Agregando id: 2318 -> 39.0: Bs
# Agregando id: 2318 -> 128.0: Bs
# Agregando id: 2318 -> 107.0: Bs
# Agregando id: 2318 -> 14.0: Bs
# Agregando id: 2318 -> 20.0: Bs
# Agregando id: 2318 -> 39.0: Bs
# Agregando id: 2318 -> 0.3: Bs
# Agregando id: 2338 -> 128.0: Bs
# Agregando id: 2338 -> 39.0: Bs
# Agregando id: 2338 -> 107.0: Bs
# Agregando id: 2338 -> 0.3: Bs
# Agregando id: 2338 -> 14.0: Bs
# Agregando id: 2340 -> 128.0: Bs
# Agregando id: 2340 -> 39.0: Bs
# Agregando id: 2340 -> 14.0: Bs
# Agregando id: 2342 -> 39.0: Bs
# Agregando id: 2342 -> 128.0: Bs
# Agregando id: 2342 -> 14.0: Bs
# Agregando id: 2343 -> 39.0: Bs
# Agregando id: 2343 -> 128.0: Bs
# Agregando id: 2343 -> 39.0: Bs
# Agregando id: 2343 -> 14.0: Bs
# Agregando id: 2344 -> 39.0: Bs
# Agregando id: 2344 -> 20.0: Bs
# Agregando id: 2344 -> 128.0: Bs
# Agregando id: 2344 -> 14.0: Bs
# Agregando id: 2346 -> 24.0: Bs
# Agregando id: 2346 -> 2.0: Bs
# Agregando id: 2347 -> 38.0: Bs
# Agregando id: 2347 -> 2.0: Bs
# Agregando id: 2348 -> 1000.0: Bs
# Agregando id: 2349 -> 1000.0: Bs
# Agregando id: 2350 -> 1000.0: Bs
# Agregando id: 2351 -> 1000.0: Bs
# Agregando id: 2426 -> 198.0: Bs
# Agregando id: 2427 -> 198.0: Bs
# Agregando id: 2428 -> 2298.0: Bs
# Agregando id: 2428 -> 897.0: Bs
# Agregando id: 2429 -> 705.3: Bs
# Agregando id: 2430 -> 507.3: Bs
# Agregando id: 2431 -> 182.0: Bs
# Agregando id: 2431 -> 583.0: Bs
# Agregando id: 2431 -> 321.0: Bs
# Agregando id: 2431 -> 168.0: Bs
# Agregando id: 2432 -> 10.0: Bs
# Agregando id: 2436 -> 1129.0: Bs
# Agregando id: 2437 -> 89.0: Bs
# Agregando id: 2437 -> 97.0: Bs
# Agregando id: 2437 -> 103.0: Bs
# Agregando id: 2437 -> 86.0: Bs
# Agregando id: 2439 -> 950.0: Bs
# Agregando id: 2439 -> 974.0: Bs
# Agregando id: 2439 -> 992.0: Bs
# Agregando id: 2439 -> 941.0: Bs
# Agregando id: 2441 -> 535.15: Bs
# Agregando id: 2441 -> 401.1: Bs
# Agregando id: 2441 -> 401.1: Bs
# Agregando id: 2442 -> 752.0: Bs
# Agregando id: 2442 -> 665.0: Bs
# Agregando id: 2444 -> 62.0: Bs
# Agregando id: 2448 -> 3.2: Bs
# Agregando id: 2448 -> 3.4: Bs
# Agregando id: 2448 -> 4.4: Bs
# Agregando id: 2448 -> 55.0: Bs
# Agregando id: 2448 -> 5.5: Bs
# Agregando id: 2448 -> 11.4: Bs
# Agregando id: 2448 -> 27.3: Bs
# Agregando id: 2448 -> 55.0: Bs
# Agregando id: 2448 -> 218.4: Bs
# Agregando id: 2448 -> 164.0: Bs
# Agregando id: 2448 -> 8.3: Bs
# Agregando id: 2448 -> 82.0: Bs
# Agregando id: 2448 -> 137.0: Bs
# Agregando id: 2448 -> 164.0: Bs
# Agregando id: 2448 -> 0.6: Bs
# Agregando id: 2448 -> 0.9: Bs
# Agregando id: 2448 -> 1.2: Bs
# Agregando id: 2448 -> 2.2: Bs
# Agregando id: 2448 -> 4.4: Bs
# Agregando id: 2448 -> 110.0: Bs
# Agregando id: 2448 -> 137.0: Bs
# Agregando id: 2448 -> 218.4: Bs
# Agregando id: 2448 -> 273.3: Bs
# Agregando id: 2448 -> 34.0: Bs
# Agregando id: 2448 -> 33.1: Bs
# Agregando id: 2448 -> 82.0: Bs
# Agregando id: 2452 -> 0.9: Bs
# Agregando id: 2452 -> 0.9: Bs
# Agregando id: 2452 -> 1.1: Bs
# Agregando id: 2456 -> 1.1: Bs
# Agregando id: 2456 -> 1.6: Bs
# Agregando id: 2456 -> 2.6: Bs
# Agregando id: 2459 -> 0.7: Bs
# Agregando id: 2459 -> 1.3: Bs
# Agregando id: 2459 -> 1.4: Bs
# Agregando id: 2459 -> 2.5: Bs
# Agregando id: 2460 -> 64.0: Bs
# Agregando id: 2461 -> 214.0: Bs
# Agregando id: 2463 -> 94.0: Bs
# Agregando id: 2464 -> 214.0: Bs
# Agregando id: 2469 -> 754.0: Bs
# Agregando id: 2470 -> 474.0: Bs
# Agregando id: 2471 -> 84.0: Bs
# Agregando id: 2472 -> 205.0: Bs
# Agregando id: 2473 -> 23.0: Bs
# Agregando id: 2474 -> 15.0: Bs
# Agregando id: 2475 -> 5.0: Bs
# Agregando id: 2477 -> 34.0: Bs
# Agregando id: 2478 -> 50.0: Bs
# Agregando id: 2478 -> 100.0: Bs
# Agregando id: 2487 -> 34.0: Bs
# Agregando id: 2489 -> 30.0: Bs
# Agregando id: 2502 -> 575.0: Bs
# Agregando id: 2502 -> 300.0: Bs
# Agregando id: 2503 -> 34.0: Bs
# Agregando id: 2508 -> 34.0: Bs
# Agregando id: 2509 -> 300.0: Bs
# Agregando id: 2510 -> 300.0: Bs
# Agregando id: 2510 -> 300.0: Bs
# Agregando id: 2510 -> 300.0: Bs
# Agregando id: 2510 -> 70.0: Bs
# Agregando id: 2510 -> 300.0: Bs
# Agregando id: 2510 -> 70.0: Bs
# Agregando id: 2510 -> 300.0: Bs
# Agregando id: 2510 -> 70.0: Bs
# Agregando id: 2510 -> 70.0: Bs
# Agregando id: 2510 -> 70.0: Bs
# Agregando id: 2510 -> 300.0: Bs
# Agregando id: 2512 -> 500.0: Bs
# Agregando id: 2515 -> 236.5: Bs
# Agregando id: 2517 -> 300.0: Bs
# Agregando id: 2518 -> 218.5: Bs
# Agregando id: 2521 -> 50.0: Bs
# Agregando id: 2522 -> 45.0: Bs
# Agregando id: 2523 -> 50.0: Bs
# Agregando id: 2524 -> 50.0: Bs
# Agregando id: 2525 -> 50.0: Bs
# Agregando id: 2526 -> 200.0: Bs
# Agregando id: 2527 -> 205.0: Bs
# Agregando id: 2534 -> 30.0: Bs
# Agregando id: 2536 -> 100.0: Bs
# Agregando id: 2537 -> 50.0: Bs
# Agregando id: 2538 -> 30.0: Bs
# Agregando id: 2539 -> 80.0: Bs
# Agregando id: 2541 -> 30.0: Bs
# Agregando id: 2542 -> 150.0: Bs
# Agregando id: 2543 -> 1986.0: Bs
# Agregando id: 2576 -> 20.0: Bs
# Agregando id: 2576 -> 30.0: Bs
# Agregando id: 2577 -> 25.0: Bs
# Agregando id: 2578 -> 25.0: Bs
# Agregando id: 2579 -> 3.0: Bs
# Agregando id: 2579 -> 5.0: Bs
# Agregando id: 2579 -> 5.0: Bs
# Agregando id: 2579 -> 8.0: Bs
# Agregando id: 2580 -> 3.0: Bs
# Agregando id: 2580 -> 5.0: Bs
# Agregando id: 2580 -> 10.0: Bs
# Agregando id: 2580 -> 12.0: Bs
# Agregando id: 2580 -> 15.0: Bs
# Agregando id: 2585 -> 25.0: Bs
# Agregando id: 2587 -> 62.0: Bs
# Agregando id: 2588 -> 62.0: Bs
# Agregando id: 2589 -> 124.0: Bs
# Agregando id: 2590 -> 277.0: Bs
# Agregando id: 2593 -> 1489.0: Bs
# Agregando id: 2595 -> 3.0: Bs
# Agregando id: 2595 -> 5.0: Bs
# Agregando id: 2595 -> 5.0: Bs
# Agregando id: 2595 -> 8.0: Bs
# Agregando id: 2599 -> 25.0: Bs
# Agregando id: 2600 -> 25.0: Bs
# Agregando id: 2601 -> 993.0: Bs
# Agregando id: 2604 -> 25.0: Bs
# Agregando id: 2605 -> 745.0: Bs
# Agregando id: 2605 -> 1241.0: Bs
# Agregando id: 2607 -> 0.36: Bs
# Agregando id: 2608 -> 160.0: Bs
# Agregando id: 2609 -> 1613.0: Bs
# Agregando id: 2610 -> 50.0: Bs
# Agregando id: 2611 -> 1241.0: Bs
# Agregando id: 2612 -> 807.0: Bs
# Agregando id: 2613 -> 621.0: Bs
# Agregando id: 2614 -> 993.0: Bs
# Agregando id: 2617 -> 745.0: Bs
# Agregando id: 2618 -> 496.0: Bs
# Agregando id: 2619 -> 372.0: Bs
# Agregando id: 2620 -> 1737.0: Bs
# Agregando id: 2621 -> 1241.0: Bs
# Agregando id: 2622 -> 869.0: Bs
# Agregando id: 2623 -> 621.0: Bs
# Agregando id: 2624 -> 2482.0: Bs
# Agregando id: 2625 -> 1862.0: Bs
# Agregando id: 2626 -> 1241.0: Bs
# Agregando id: 2627 -> 931.0: Bs
# Agregando id: 2628 -> 1489.0: Bs
# Agregando id: 2629 -> 1117.0: Bs
# Agregando id: 2630 -> 993.0: Bs
# Agregando id: 2631 -> 745.0: Bs
# Agregando id: 2632 -> 745.0: Bs
# Agregando id: 2633 -> 558.0: Bs
# Agregando id: 2634 -> 496.0: Bs
# Agregando id: 2635 -> 372.0: Bs
# Agregando id: 2636 -> 621.0: Bs
# Agregando id: 2637 -> 465.0: Bs
# Agregando id: 2638 -> 1241.0: Bs
# Agregando id: 2639 -> 931.0: Bs
# Agregando id: 2640 -> 31.0: Bs
# Agregando id: 2641 -> 62.0: Bs
# Agregando id: 2643 -> 1737.0: Bs
# Agregando id: 2644 -> 1241.0: Bs
# Agregando id: 2645 -> 869.0: Bs
# Agregando id: 2646 -> 621.0: Bs
# Agregando id: 2647 -> 993.0: Bs
# Agregando id: 2648 -> 621.0: Bs
# Agregando id: 2649 -> 621.0: Bs
# Agregando id: 2650 -> 30.0: Bs
# Agregando id: 2661 -> 100.0: Bs
# Agregando id: 2662 -> 100.0: Bs
# Agregando id: 2663 -> 100.0: Bs
# Agregando id: 2664 -> 100.0: Bs
# Agregando id: 2665 -> 100.0: Bs
# Agregando id: 2677 -> 595.0: Bs
# Agregando id: 2677 -> 60.0: Bs
# Agregando id: 2677 -> 60.0: Bs
# Agregando id: 2677 -> 60.0: Bs
# Agregando id: 2677 -> 60.0: Bs
# Agregando id: 2677 -> 60.0: Bs
# Agregando id: 2677 -> 90.0: Bs
# Agregando id: 2677 -> 70.0: Bs
# Agregando id: 2677 -> 75.0: Bs
# Agregando id: 2677 -> 70.0: Bs
# Agregando id: 2677 -> 65.0: Bs
# Agregando id: 2677 -> 70.0: Bs
# Agregando id: 2677 -> 70.0: Bs
# Agregando id: 2677 -> 70.0: Bs
# Agregando id: 2677 -> 70.0: Bs
# Agregando id: 2677 -> 60.0: Bs
# Agregando id: 2677 -> 70.0: Bs
# Agregando id: 2677 -> 75.0: Bs
# Agregando id: 2677 -> 60.0: Bs
# Agregando id: 2677 -> 75.0: Bs
# Agregando id: 2677 -> 60.0: Bs
# Agregando id: 2677 -> 132.0: Bs
# Agregando id: 2677 -> 100.0: Bs
# Agregando id: 2677 -> 70.0: Bs
# Agregando id: 2677 -> 90.0: Bs
# Agregando id: 2677 -> 300.0: Bs
# Agregando id: 2677 -> 10.0: Bs
# Agregando id: 2677 -> 250.0: Bs
# Agregando id: 2728 -> 100.0: Bs
# Agregando id: 2757 -> 60.0: Bs
# Agregando id: 2757 -> 40.0: Bs
# Agregando id: 2757 -> 15.0: Bs
# Agregando id: 2757 -> 30.0: Bs
# Agregando id: 2757 -> 95.0: Bs
# Agregando id: 2757 -> 80.0: Bs
# Agregando id: 2759 -> 1900.0: Bs
# Agregando id: 2759 -> 2750.0: Bs
# Agregando id: 2759 -> 3300.0: Bs
# Agregando id: 2759 -> 1500.0: Bs
# Agregando id: 2759 -> 2300.0: Bs
# Agregando id: 2759 -> 2800.0: Bs
# Agregando id: 2759 -> 300.0: Bs
# Agregando id: 2759 -> 350.0: Bs
# Agregando id: 2759 -> 450.0: Bs
# Agregando id: 2759 -> 330.0: Bs
# Agregando id: 2759 -> 380.0: Bs
# Agregando id: 2759 -> 660.0: Bs
# Agregando id: 2759 -> 440.0: Bs
# Agregando id: 2759 -> 450.0: Bs
# Agregando id: 2759 -> 380.0: Bs
# Agregando id: 2759 -> 380.0: Bs
# Agregando id: 2759 -> 380.0: Bs
# Agregando id: 2759 -> 380.0: Bs
# Agregando id: 2759 -> 330.0: Bs
# Agregando id: 2759 -> 300.0: Bs
# Agregando id: 2759 -> 500.0: Bs
# Agregando id: 2759 -> 440.0: Bs
# Agregando id: 2759 -> 2000.0: Bs
# Agregando id: 2759 -> 380.0: Bs
# Agregando id: 2759 -> 1950.0: Bs
# Agregando id: 2759 -> 350.0: Bs
# Agregando id: 2759 -> 1100.0: Bs
# Agregando id: 2759 -> 550.0: Bs
# Agregando id: 2759 -> 250.0: Bs
# Agregando id: 2764 -> 500.0: Bs
# Agregando id: 2765 -> 500.0: Bs
# Agregando id: 2766 -> 500.0: Bs
# Agregando id: 2767 -> 150.0: Bs
# Agregando id: 2768 -> 500.0: Bs
# Agregando id: 2769 -> 500.0: Bs
# Agregando id: 2771 -> 40.0: Bs
# Agregando id: 2771 -> 40.0: Bs
# Agregando id: 2771 -> 40.0: Bs
# Agregando id: 2771 -> 40.0: Bs
# Agregando id: 2771 -> 40.0: Bs
# Agregando id: 2772 -> 50.0: Bs
# Agregando id: 2773 -> 100.0: Bs
# Agregando id: 2774 -> 500.0: Bs
# Agregando id: 2777 -> 110.0: Bs
# Agregando id: 2777 -> 109.0: Bs
# Agregando id: 2777 -> 124.0: Bs
# Agregando id: 2777 -> 194.0: Bs
# Agregando id: 2777 -> 106.0: Bs
# Agregando id: 2777 -> 106.0: Bs
# Agregando id: 2778 -> 211.0: Bs
# Agregando id: 2778 -> 1266.0: Bs
# Agregando id: 2778 -> 211.0: Bs
# Agregando id: 2778 -> 1266.0: Bs
# Agregando id: 2778 -> 138.0: Bs
# Agregando id: 2778 -> 828.0: Bs
# Agregando id: 2778 -> 160.0: Bs
# Agregando id: 2778 -> 224.0: Bs
# Agregando id: 2778 -> 1344.0: Bs
# Agregando id: 2819 -> 700.0: Bs
# Agregando id: 2819 -> 550.0: Bs
# Agregando id: 2819 -> 550.0: Bs
# Agregando id: 2819 -> 550.0: Bs
# Agregando id: 2819 -> 880.0: Bs
# Agregando id: 2819 -> 2220.0: Bs
# Agregando id: 2819 -> 880.0: Bs
# Agregando id: 2819 -> 880.0: Bs
# Agregando id: 2819 -> 1325.0: Bs
# Agregando id: 2825 -> 2.0: Bs
# Agregando id: 2827 -> 20.0: Bs
# Agregando id: 2843 -> 0.0: Bs
# (1785, 49)
#        id     estado fechaActualización  \
# 677  1526  PUBLICADO         10/07/2025
# 764  1600  PUBLICADO         10/07/2025
# 574  1335  PUBLICADO         10/07/2025
#
#                                                 nombre  \
# 677              Convalidación y Homologación de Notas
# 764                                  DIPLOMA ACADEMICO
# 574  Certificación de Certificados de Estudio Postg...
#
#                                                   slug sigla  \
# 677              convalidacion-y-homologacion-de-notas   CHN
# 764                                  diploma-academico   NaN
# 574  certificacion-de-certificados-de-estudio-postg...   NaN
#
#                                            descripcion  \
# 677  Permite el reconocimiento de notas obtenidas e...
# 764  ES EL DOCUMENTO QUE LA UNIVERSIDAD CONFIERE A ...
# 574  Establecer Procedimiento para procesar la Cert...
#
#                                             marcoLegal  like  dislike  \
# 677  1. Ley N° 070 de la Educación "Avelino Siñani ...     0        0
# 764  •\tSEGUN RR Nº 257/2008 DE FECHA 1º DE JULIO D...     0        0
# 574  "R.M. N° 928/2015 R.M. N° 710/2016 R.M. N° 082...     0        0
#
#      esPresencial  esVirtual              resultado  \
# 677             1          0  Registro y constancia
# 764             1          0  Registro y constancia
# 574             1          1  Registro y constancia
#
#                                                enlaces  \
# 677                                                 []
# 764  [{"nombre": "Trámites", "url": "https://tramit...
# 574  [{"nombre": "ÁREA DE LEGALIZACIONES - UNIDAD D...
#
#                                            ubicaciones  \
# 677  [{"nombre": "Unidad de Asuntos Jurídicos", "ti...
# 764  [{"nombre": "Trámites", "tipo": "Oficina centr...
# 574  [{"nombre": "Ministerio de Educación", "tipo":...
#
#                              entidad.nombre entidad.sigla  \
# 677  Direc. Dptal. de Educación  Chuquisaca       DDE-CHU
# 764          Universidad Mayor de San Simón          UMSS
# 574                 Ministerio de Educación       MIN-EDU
#
#                             entidad.slug  \
# 677  direc-dptal-de-educacion-chuquisaca
# 764       universidad-mayor-de-san-simon
# 574              ministerio-de-educacion
#
#                                           entidad.logo  \
# 677  https://www.gob.bo/ws/api/archivos/2efbd20c-04...
# 764  https://www.gob.bo/ws/api/archivos/64632538-41...
# 574  https://www.gob.bo/ws/api/archivos/78598177-59...
#
#                                    entidad.descripcion  \
# 677  La DDECH es la Dirección Departamental de Educ...
# 764  La Universidad Mayor de San Simón (UMSS), fund...
# 574                            MINISTERIO DE EDUCACIÓN
#
#                    entidad.urlSitioWeb entidad.telefonoContacto  \
# 677  https://www.ddechuquisaca.gob.bo/                      NaN
# 764           https://www.umss.edu.bo/                      NaN
# 574         https://www.minedu.gob.bo/        (591-2)  2442144
#
#     entidad.correoElectronicoContacto  \
# 677     dirdepeduchuquisaca@gmail.com
# 764                  soporte@umss.edu
# 574         informacion@minedu.gob.bo
#
#                                          palabrasClave categorias  \
# 677  Resolución,Administrativa,Convalidación,Homolo...  Educación
# 764                                                NaN  Educación
# 574  Postgrado,Certificados,Universidad,Certificaci...  Educación
#
#       eventosVida                                         documentos  \
# 677  Mi educación  Resolución Administrativa de Convalidación y H...
# 764           NaN                             Certificado Supletorio
# 574  Mi educación  Certificación de Certificados de Estudio Postg...
#
#      herramientas modalidad.tipo                  tramite.url  \
# 677           NaN     PRESENCIAL                         None
# 764           NaN     PRESENCIAL                         None
# 574           NaN        VIRTUAL  https://legas.minedu.gob.bo
#
#     tramite.urlSeguimiento  tramite.tieneCosto tramite.duracion  \
# 677                   None                   1               24
# 764                   None                   1               24
# 574                   None                   1             None
#
#     tramite.unidadMedidaDuracion  \
# 677                     Horas(s)
# 764                       Día(s)
# 574
#
#                                  tramite.procedimiento  \
# 677  <p>IMPORTANTE: El trámite es exclusivamente pa...
# 764  <p>¿Qué necesito?</p><ul><li><p>Original del C...
# 574  <p>1.- Llene el formulario de solicitud ingres...
#
#                    tramite.publicoObjetivo tramite.requisitoNoParametrizado  \
# 677                 Comunidades Educativas                             None
# 764               Personas Aseguradas SSUE                             None
# 574  Todos (Cualquier persona solicitante)                             None
#
#     tramite.estado tramite.emisionFactura                tramite.formaCobro  \
# 677         ACTIVO       No emite factura  [Pago en efectivo en ventanilla]
# 764         ACTIVO       No emite factura  [Pago en efectivo en ventanilla]
# 574         ACTIVO       No emite factura    [Pasarela de pagos del estado]
#
#                                       tramite.horarios  \
# 677  [{'dia': 'Lunes', 'continuo': False, 'inicioMa...
# 764  [{'dia': 'Lunes', 'continuo': False, 'inicioMa...
# 574  [{'dia': 'Lunes', 'continuo': True, 'inicioMan...
#
#     tramite.depositoBancario  \
# 677                       []
# 764                       []
# 574                       []
#
#                                     tramite.requisitos  tramite.duracionMin  \
# 677  [{'comentario': '*Certificado de Estudios Real...               1440.0
# 764  [{'comentario': None, 'nombre': 'Certificado d...              34560.0
# 574  [{'comentario': 'Certificación de Certificados...                  NaN
#
#      tramite.duracionHora  tramite.duracionDia  \
# 677                  24.0                  1.0
# 764                 576.0                 24.0
# 574                   NaN                  NaN
#
#                                     costo.conceptoPago  costo.monto  \
# 677             Recibo de Convalidación y Homologación         10.0
# 764                   Derecho de Impresión: Nacionales        458.0
# 574  Certificación de Certificados de Estudio Postg...         43.0
#
#     costo.moneda
# 677           Bs
# 764           Bs
# 574           Bs

# %% [markdown]
# ## Requisitos y procedimientos
#
# Reto: Averiguar cúantos trámites y procedimientos requieren el Carnet de Identidad (C.I) como requisito.

# %%
def desglosar_segun_costos(df):
    _new_df = pd.DataFrame(columns=df.columns.to_list() + [
        'requisito.comentario', 'requisito.nombre', 'requisito.entidad', 'requisito.entidadActiva'])
    print(_new_df.columns)
    _df = df.copy()
    for i in _df.index.to_list():
        data = _df.iloc[i].to_dict()
        #print(data)
        requisitos = data['tramite.requisitos']
        for requisito in requisitos:
            data['requisito.comentario'] = requisito['comentario']
            data['requisito.nombre'] = requisito['nombre']
            data['requisito.entidad'] = requisito['entidad']
            data['requisito.entidadActiva'] = 1 if requisito['entidadActiva'] == True else 0
            #print('>>>>', data)
            print(f"Agregando id: {data['id']} -> {data['requisito.nombre']}")
            _new_df.loc[len(_new_df)] = data
    del _new_df['tramite.requisitos']
    return _new_df

new_df = desglosar_segun_costos(new_df)
print(new_df.shape)
new_df.sample(3)
# Out:
# Index(['id', 'estado', 'fechaActualización', 'nombre', 'slug', 'sigla',
#        'descripcion', 'marcoLegal', 'like', 'dislike', 'esPresencial',
#        'esVirtual', 'resultado', 'enlaces', 'ubicaciones', 'entidad.nombre',
#        'entidad.sigla', 'entidad.slug', 'entidad.logo', 'entidad.descripcion',
#        'entidad.urlSitioWeb', 'entidad.telefonoContacto',
#        'entidad.correoElectronicoContacto', 'palabrasClave', 'categorias',
#        'eventosVida', 'documentos', 'herramientas', 'modalidad.tipo',
#        'tramite.url', 'tramite.urlSeguimiento', 'tramite.tieneCosto',
#        'tramite.duracion', 'tramite.unidadMedidaDuracion',
#        'tramite.procedimiento', 'tramite.publicoObjetivo',
#        'tramite.requisitoNoParametrizado', 'tramite.estado',
#        'tramite.emisionFactura', 'tramite.formaCobro', 'tramite.horarios',
#        'tramite.depositoBancario', 'tramite.requisitos', 'tramite.duracionMin',
#        'tramite.duracionHora', 'tramite.duracionDia', 'costo.conceptoPago',
#        'costo.monto', 'costo.moneda', 'requisito.comentario',
#        'requisito.nombre', 'requisito.entidad', 'requisito.entidadActiva'],
#       dtype='object')
# Agregando id: 1010 -> Formulario
# Agregando id: 1010 -> Requisito de Trámite
# Agregando id: 1010 -> Certificado
# Agregando id: 1010 -> Fotografías
# Agregando id: 1010 -> Declaración Jurada
# Agregando id: 1010 -> Poder del Representante Legal
# Agregando id: 1010 -> Póliza de Seguro
# Agregando id: 1011 -> Formulario
# Agregando id: 1011 -> Requisito de Trámite
# Agregando id: 1011 -> Certificado
# Agregando id: 1011 -> Fotografías
# Agregando id: 1011 -> Declaración Jurada
# Agregando id: 1011 -> Poder del Representante Legal
# Agregando id: 1011 -> Póliza de Seguro
# Agregando id: 1014 -> Requisito de Trámite
# Agregando id: 1014 -> Certificado
# Agregando id: 1014 -> Poder del Representante Legal
# Agregando id: 1014 -> Póliza de Seguro
# Agregando id: 1017 -> Registro Docente Administrativo (RDA)
# Agregando id: 1017 -> Boleta de Depósito Bancario
# Agregando id: 1017 -> Formulario
# Agregando id: 1017 -> Cédula de Identidad
# Agregando id: 1017 -> Diploma de Bachiller
# Agregando id: 1017 -> Certificado de Egreso
# Agregando id: 1017 -> Fotografías
# Agregando id: 1018 -> Formulario
# Agregando id: 1018 -> Cédula de Identidad
# Agregando id: 1018 -> Fotografías
# Agregando id: 1018 -> Denuncias
# Agregando id: 1018 -> Publicaciones
# Agregando id: 1018 -> Certificados de Estudios
# Agregando id: 1018 -> Título Profesional
# Agregando id: 1018 -> Registro Docente Administrativo (RDA)
# Agregando id: 1018 -> Boleta de Depósito Bancario
# Agregando id: 1019 -> Requisito de Trámite
# Agregando id: 1019 -> Certificado
# Agregando id: 1019 -> Poder del Representante Legal
# Agregando id: 1019 -> Póliza de Seguro
# Agregando id: 1020 -> Carta/Nota de Solicitud
# Agregando id: 1020 -> Registro Docente Administrativo (RDA)
# Agregando id: 1020 -> Boleta de Depósito Bancario
# Agregando id: 1021 -> Registro Docente Administrativo (RDA)
# Agregando id: 1021 -> Estado de Ahorro
# Agregando id: 1021 -> Boleta de Depósito Bancario
# Agregando id: 1021 -> Requisito de Trámite
# Agregando id: 1021 -> Carta/Nota de Solicitud
# Agregando id: 1021 -> Resolución Administrativa Institucional
# Agregando id: 1021 -> Certificado de Trabajo
# Agregando id: 1021 -> Informe
# Agregando id: 1022 -> Formulario
# Agregando id: 1022 -> Registro Docente Administrativo (RDA)
# Agregando id: 1022 -> Boleta de Depósito Bancario
# Agregando id: 1022 -> Requisito de Trámite
# Agregando id: 1022 -> Certificado
# Agregando id: 1022 -> Informe
# Agregando id: 1022 -> Certificado de Nacimiento
# Agregando id: 1023 -> Formulario
# Agregando id: 1023 -> Registro Docente Administrativo (RDA)
# Agregando id: 1023 -> Memorándum de Designación
# Agregando id: 1023 -> Cédula de Identidad
# Agregando id: 1023 -> Título Profesional
# Agregando id: 1023 -> Certificación
# Agregando id: 1024 -> Requisito de Trámite
# Agregando id: 1024 -> Certificado
# Agregando id: 1024 -> Contrato
# Agregando id: 1024 -> Póliza de Seguro
# Agregando id: 1025 -> Cédula de Identidad
# Agregando id: 1025 -> Contrato de Trabajo
# Agregando id: 1025 -> Certificado de Trabajo
# Agregando id: 1025 -> Formulario
# Agregando id: 1025 -> Registro Docente Administrativo (RDA)
# Agregando id: 1025 -> Boleta de Depósito Bancario
# Agregando id: 1026 -> Requisito de Trámite
# Agregando id: 1027 -> Registro Docente Administrativo (RDA)
# Agregando id: 1027 -> Boleta de Depósito Bancario
# Agregando id: 1027 -> Cédula de Identidad
# Agregando id: 1027 -> Título Profesional
# Agregando id: 1027 -> Certificado
# Agregando id: 1028 -> Formulario
# Agregando id: 1028 -> Fotografías
# Agregando id: 1028 -> Pasaporte
# Agregando id: 1028 -> Certificado
# Agregando id: 1028 -> Requisito de Trámite
# Agregando id: 1029 -> Formulario
# Agregando id: 1030 -> Carta/Nota de Solicitud
# Agregando id: 1030 -> Planos
# Agregando id: 1030 -> Formulario
# Agregando id: 1030 -> Certificado
# Agregando id: 1030 -> Cédula de Identidad
# Agregando id: 1030 -> Poder del Representante Legal
# Agregando id: 1030 -> Boleta de Depósito Bancario
# Agregando id: 1030 -> Carta/Nota de Solicitud
# Agregando id: 1030 -> Planos
# Agregando id: 1030 -> Formulario
# Agregando id: 1030 -> Certificado
# Agregando id: 1030 -> Cédula de Identidad
# Agregando id: 1030 -> Poder del Representante Legal
# Agregando id: 1030 -> Boleta de Depósito Bancario
# Agregando id: 1032 -> Cédula de Identidad
# Agregando id: 1032 -> Certificado de Notas
# Agregando id: 1032 -> Comprobante de Pago
# Agregando id: 1033 -> Carta/Nota de Solicitud
# Agregando id: 1033 -> Cédula de Identidad
# Agregando id: 1033 -> Diploma de Bachiller
# Agregando id: 1033 -> Publicaciones
# Agregando id: 1033 -> Fotografías
# Agregando id: 1033 -> Denuncias
# Agregando id: 1033 -> Comprobante de Pago
# Agregando id: 1033 -> Boleta de Depósito Bancario
# Agregando id: 1034 -> Carta/Nota de Solicitud
# Agregando id: 1034 -> Certificado de Estudios
# Agregando id: 1034 -> Diploma de Bachiller
# Agregando id: 1034 -> Certificado de Nacimiento
# Agregando id: 1034 -> Cédula de Identidad
# Agregando id: 1034 -> Comprobante de Pago
# Agregando id: 1034 -> Fotografías
# Agregando id: 1035 -> Formulario
# Agregando id: 1035 -> Certificado de Nacimiento
# Agregando id: 1035 -> Cédula de Identidad
# Agregando id: 1035 -> Diploma de Bachiller
# Agregando id: 1035 -> Fotografías
# Agregando id: 1035 -> Carta/Nota de Solicitud
# Agregando id: 1035 -> Resolución Administrativa Institucional
# Agregando id: 1035 -> Comprobante de Pago
# Agregando id: 1035 -> Requisito de Trámite
# Agregando id: 1037 -> Diploma de Bachiller
# Agregando id: 1037 -> Cédula de Identidad
# Agregando id: 1037 -> Requisito de Trámite
# Agregando id: 1037 -> Comprobante de Pago
# Agregando id: 1038 -> Declaración Jurada
# Agregando id: 1038 -> Certificado de Egreso
# Agregando id: 1038 -> Cédula de Identidad
# Agregando id: 1038 -> Diploma de Bachiller
# Agregando id: 1038 -> Resolución Administrativa Institucional
# Agregando id: 1038 -> Registro
# Agregando id: 1038 -> Libro de Inscripciones
# Agregando id: 1038 -> Centralizador de Notas
# Agregando id: 1038 -> Acta
# Agregando id: 1038 -> Historial Académico
# Agregando id: 1038 -> Carta/Nota de Solicitud
# Agregando id: 1038 -> Declaración Jurada
# Agregando id: 1038 -> Certificado de Egreso
# Agregando id: 1038 -> Cédula de Identidad
# Agregando id: 1038 -> Diploma de Bachiller
# Agregando id: 1038 -> Resolución Administrativa Institucional
# Agregando id: 1038 -> Registro
# Agregando id: 1038 -> Libro de Inscripciones
# Agregando id: 1038 -> Centralizador de Notas
# Agregando id: 1038 -> Acta
# Agregando id: 1038 -> Historial Académico
# Agregando id: 1038 -> Carta/Nota de Solicitud
# Agregando id: 1039 -> Requisito de Trámite
# Agregando id: 1039 -> Formulario
# Agregando id: 1039 -> Certificado de Egreso
# Agregando id: 1039 -> Cédula de Identidad
# Agregando id: 1039 -> Diploma de Bachiller
# Agregando id: 1039 -> Registro
# Agregando id: 1039 -> Requisito de Trámite
# Agregando id: 1039 -> Formulario
# Agregando id: 1039 -> Certificado de Egreso
# Agregando id: 1039 -> Cédula de Identidad
# Agregando id: 1039 -> Diploma de Bachiller
# Agregando id: 1039 -> Registro
# Agregando id: 1041 -> Certificado
# Agregando id: 1041 -> Cédula de Identidad
# Agregando id: 1041 -> Registro
# Agregando id: 1041 -> Resolución
# Agregando id: 1041 -> Libro de Inscripciones
# Agregando id: 1041 -> Centralizador de Notas
# Agregando id: 1042 -> Cédula de Identidad
# Agregando id: 1042 -> Libro de Inscripciones
# Agregando id: 1042 -> Centralizador de Notas
# Agregando id: 1042 -> Certificado
# Agregando id: 1042 -> Fotografías
# Agregando id: 1042 -> Certificado de Notas
# Agregando id: 1045 -> Memorándum de Designación
# Agregando id: 1045 -> Cédula de Identidad
# Agregando id: 1045 -> Registro
# Agregando id: 1045 -> Título Profesional
# Agregando id: 1045 -> Diploma de Bachiller
# Agregando id: 1045 -> Ficha de Compulsa
# Agregando id: 1045 -> Formulario
# Agregando id: 1051 -> Carta/Nota de Solicitud
# Agregando id: 1051 -> Certificación Electrónica de NIT
# Agregando id: 1051 -> Certificado
# Agregando id: 1051 -> Requisito de Trámite
# Agregando id: 1051 -> Poder del Representante Legal
# Agregando id: 1051 -> Matrícula de Comercio
# Agregando id: 1051 -> Informe
# Agregando id: 1051 -> Formulario
# Agregando id: 1051 -> Carta/Nota de Solicitud
# Agregando id: 1051 -> Certificación Electrónica de NIT
# Agregando id: 1051 -> Certificado
# Agregando id: 1051 -> Requisito de Trámite
# Agregando id: 1051 -> Poder del Representante Legal
# Agregando id: 1051 -> Matrícula de Comercio
# Agregando id: 1051 -> Informe
# Agregando id: 1051 -> Formulario
# Agregando id: 1051 -> Carta/Nota de Solicitud
# Agregando id: 1051 -> Certificación Electrónica de NIT
# Agregando id: 1051 -> Certificado
# Agregando id: 1051 -> Requisito de Trámite
# Agregando id: 1051 -> Poder del Representante Legal
# Agregando id: 1051 -> Matrícula de Comercio
# Agregando id: 1051 -> Informe
# Agregando id: 1051 -> Formulario
# Agregando id: 1051 -> Carta/Nota de Solicitud
# Agregando id: 1051 -> Certificación Electrónica de NIT
# Agregando id: 1051 -> Certificado
# Agregando id: 1051 -> Requisito de Trámite
# Agregando id: 1051 -> Poder del Representante Legal
# Agregando id: 1051 -> Matrícula de Comercio
# Agregando id: 1051 -> Informe
# Agregando id: 1051 -> Formulario
# Agregando id: 1051 -> Carta/Nota de Solicitud
# Agregando id: 1051 -> Certificación Electrónica de NIT
# Agregando id: 1051 -> Certificado
# Agregando id: 1051 -> Requisito de Trámite
# Agregando id: 1051 -> Poder del Representante Legal
# Agregando id: 1051 -> Matrícula de Comercio
# Agregando id: 1051 -> Informe
# Agregando id: 1051 -> Formulario
# Agregando id: 1051 -> Carta/Nota de Solicitud
# Agregando id: 1051 -> Certificación Electrónica de NIT
# Agregando id: 1051 -> Certificado
# Agregando id: 1051 -> Requisito de Trámite
# Agregando id: 1051 -> Poder del Representante Legal
# Agregando id: 1051 -> Matrícula de Comercio
# Agregando id: 1051 -> Informe
# Agregando id: 1051 -> Formulario
# Agregando id: 1051 -> Carta/Nota de Solicitud
# Agregando id: 1051 -> Certificación Electrónica de NIT
# Agregando id: 1051 -> Certificado
# Agregando id: 1051 -> Requisito de Trámite
# Agregando id: 1051 -> Poder del Representante Legal
# Agregando id: 1051 -> Matrícula de Comercio
# Agregando id: 1051 -> Informe
# Agregando id: 1051 -> Formulario
# Agregando id: 1051 -> Carta/Nota de Solicitud
# Agregando id: 1051 -> Certificación Electrónica de NIT
# Agregando id: 1051 -> Certificado
# Agregando id: 1051 -> Requisito de Trámite
# Agregando id: 1051 -> Poder del Representante Legal
# Agregando id: 1051 -> Matrícula de Comercio
# Agregando id: 1051 -> Informe
# Agregando id: 1051 -> Formulario
# Agregando id: 1051 -> Carta/Nota de Solicitud
# Agregando id: 1051 -> Certificación Electrónica de NIT
# Agregando id: 1051 -> Certificado
# Agregando id: 1051 -> Requisito de Trámite
# Agregando id: 1051 -> Poder del Representante Legal
# Agregando id: 1051 -> Matrícula de Comercio
# Agregando id: 1051 -> Informe
# Agregando id: 1051 -> Formulario
# Agregando id: 1051 -> Carta/Nota de Solicitud
# Agregando id: 1051 -> Certificación Electrónica de NIT
# Agregando id: 1051 -> Certificado
# Agregando id: 1051 -> Requisito de Trámite
# Agregando id: 1051 -> Poder del Representante Legal
# Agregando id: 1051 -> Matrícula de Comercio
# Agregando id: 1051 -> Informe
# Agregando id: 1051 -> Formulario
# Agregando id: 1056 -> Cédula de Identidad
# Agregando id: 1056 -> Requisito de Trámite
# Agregando id: 1056 -> Certificación de No Sustancias Agotadoras de Ozono (SAO)
# Agregando id: 1056 -> Factura
# Agregando id: 1056 -> Informe
# Agregando id: 1056 -> Carta/Nota de Solicitud
# Agregando id: 1056 -> Recepción de Mercancías (PRM)
# Agregando id: 1059 -> Cédula de Identidad
# Agregando id: 1059 -> Certificación de No Sustancias Agotadoras de Ozono (SAO)
# Agregando id: 1059 -> Factura
# Agregando id: 1059 -> Requisito de Trámite
# Agregando id: 1059 -> Informe
# Agregando id: 1059 -> Manifiesto Terrestre Electrónico (MIC/DTA)
# Agregando id: 1059 -> NIT
# Agregando id: 1059 -> Recepción de Mercancías (PRM)
# Agregando id: 1059 -> Carta/Nota de Solicitud
# Agregando id: 1060 -> Cédula de Identidad
# Agregando id: 1060 -> Requisito de Trámite
# Agregando id: 1060 -> Factura
# Agregando id: 1060 -> Informe
# Agregando id: 1060 -> Póliza de Importación
# Agregando id: 1060 -> Registro Único
# Agregando id: 1060 -> Carta/Nota de Solicitud
# Agregando id: 1061 -> Certificación de No Sustancias Agotadoras de Ozono (SAO)
# Agregando id: 1061 -> Cédula de Identidad
# Agregando id: 1061 -> Factura
# Agregando id: 1061 -> Lista de Empaque
# Agregando id: 1061 -> Requisito de Trámite
# Agregando id: 1061 -> Carta/Nota de Solicitud
# Agregando id: 1061 -> Recepción de Mercancías (PRM)
# Agregando id: 1062 -> Requisito de Trámite
# Agregando id: 1062 -> Certificado
# Agregando id: 1062 -> Certificado de Origen
# Agregando id: 1062 -> Cédula de Identidad
# Agregando id: 1062 -> Factura
# Agregando id: 1062 -> Informe
# Agregando id: 1062 -> Carta/Nota de Solicitud
# Agregando id: 1062 -> Recepción de Mercancías (PRM)
# Agregando id: 1063 -> Legalización
# Agregando id: 1063 -> Legalización
# Agregando id: 1064 -> Certificación
# Agregando id: 1064 -> Certificación
# Agregando id: 1065 -> Certificado
# Agregando id: 1065 -> Certificado de Origen
# Agregando id: 1065 -> Cédula de Identidad
# Agregando id: 1065 -> Factura
# Agregando id: 1065 -> Informe
# Agregando id: 1065 -> Requisito de Trámite
# Agregando id: 1065 -> Carta/Nota de Solicitud
# Agregando id: 1065 -> Recepción de Mercancías (PRM)
# Agregando id: 1066 -> Certificación
# Agregando id: 1066 -> Certificación
# Agregando id: 1067 -> Legalización
# Agregando id: 1067 -> Legalización
# Agregando id: 1069 -> Legalización
# Agregando id: 1069 -> Legalización
# Agregando id: 1070 -> Legalización
# Agregando id: 1070 -> Legalización
# Agregando id: 1071 -> Requisito de Trámite
# Agregando id: 1071 -> Informe
# Agregando id: 1071 -> Carta/Nota de Solicitud
# Agregando id: 1073 -> Legalización
# Agregando id: 1073 -> Legalización
# Agregando id: 1074 -> Legalización
# Agregando id: 1074 -> Legalización
# Agregando id: 1079 -> Legalización
# Agregando id: 1079 -> Legalización
# Agregando id: 1082 -> Legalización
# Agregando id: 1082 -> Legalización
# Agregando id: 1084 -> Legalización
# Agregando id: 1084 -> Legalización
# Agregando id: 1087 -> Legalización
# Agregando id: 1087 -> Legalización
# Agregando id: 1089 -> Legalización
# Agregando id: 1089 -> Legalización
# Agregando id: 1091 -> Legalización
# Agregando id: 1091 -> Legalización
# Agregando id: 1104 -> Legalización
# Agregando id: 1104 -> Legalización
# Agregando id: 1105 -> Legalización
# Agregando id: 1105 -> Legalización
# Agregando id: 1106 -> Legalización
# Agregando id: 1106 -> Legalización
# Agregando id: 1107 -> Legalización
# Agregando id: 1107 -> Legalización de Copia de Resolución Ministerial de Título Profesional - Técnico Superior (Escuela Boliviana Intercultural de Música)
# Agregando id: 1108 -> Legalización
# Agregando id: 1108 -> Legalización
# Agregando id: 1109 -> Legalización
# Agregando id: 1109 -> Legalización
# Agregando id: 1110 -> Legalización
# Agregando id: 1110 -> Legalización
# Agregando id: 1111 -> Legalización
# Agregando id: 1111 -> Legalización
# Agregando id: 1114 -> Legalización
# Agregando id: 1114 -> Legalización
# Agregando id: 1118 -> Legalización
# Agregando id: 1118 -> Legalización
# Agregando id: 1120 -> Requisito de Trámite
# Agregando id: 1120 -> Requisito de Trámite
# Agregando id: 1121 -> Legalización
# Agregando id: 1121 -> Legalización
# Agregando id: 1122 -> Certificación
# Agregando id: 1122 -> Certificación
# Agregando id: 1123 -> Certificación
# Agregando id: 1123 -> Certificación
# Agregando id: 1124 -> Formulario
# Agregando id: 1124 -> Formulario
# Agregando id: 1124 -> Formulario
# Agregando id: 1124 -> Formulario
# Agregando id: 1125 -> Certificación
# Agregando id: 1125 -> Certificación
# Agregando id: 1126 -> Formulario
# Agregando id: 1126 -> Formulario
# Agregando id: 1126 -> Formulario
# Agregando id: 1126 -> Formulario
# Agregando id: 1127 -> Formulario
# Agregando id: 1127 -> Formulario
# Agregando id: 1127 -> Formulario
# Agregando id: 1127 -> Formulario
# Agregando id: 1128 -> Diploma Académico
# Agregando id: 1128 -> Diploma Académico
# Agregando id: 1129 -> Certificación Área Minera Libre
# Agregando id: 1129 -> Requisito de Trámite
# Agregando id: 1129 -> Poder del Representante Legal
# Agregando id: 1129 -> Certificación Electrónica de NIT
# Agregando id: 1129 -> Formulario
# Agregando id: 1129 -> Plan de Trabajo
# Agregando id: 1129 -> Certificación Área Minera Libre
# Agregando id: 1129 -> Requisito de Trámite
# Agregando id: 1129 -> Poder del Representante Legal
# Agregando id: 1129 -> Certificación Electrónica de NIT
# Agregando id: 1129 -> Formulario
# Agregando id: 1129 -> Plan de Trabajo
# Agregando id: 1129 -> Certificación Área Minera Libre
# Agregando id: 1129 -> Requisito de Trámite
# Agregando id: 1129 -> Poder del Representante Legal
# Agregando id: 1129 -> Certificación Electrónica de NIT
# Agregando id: 1129 -> Formulario
# Agregando id: 1129 -> Plan de Trabajo
# Agregando id: 1129 -> Certificación Área Minera Libre
# Agregando id: 1129 -> Requisito de Trámite
# Agregando id: 1129 -> Poder del Representante Legal
# Agregando id: 1129 -> Certificación Electrónica de NIT
# Agregando id: 1129 -> Formulario
# Agregando id: 1129 -> Plan de Trabajo
# Agregando id: 1129 -> Certificación Área Minera Libre
# Agregando id: 1129 -> Requisito de Trámite
# Agregando id: 1129 -> Poder del Representante Legal
# Agregando id: 1129 -> Certificación Electrónica de NIT
# Agregando id: 1129 -> Formulario
# Agregando id: 1129 -> Plan de Trabajo
# Agregando id: 1129 -> Certificación Área Minera Libre
# Agregando id: 1129 -> Requisito de Trámite
# Agregando id: 1129 -> Poder del Representante Legal
# Agregando id: 1129 -> Certificación Electrónica de NIT
# Agregando id: 1129 -> Formulario
# Agregando id: 1129 -> Plan de Trabajo
# Agregando id: 1129 -> Certificación Área Minera Libre
# Agregando id: 1129 -> Requisito de Trámite
# Agregando id: 1129 -> Poder del Representante Legal
# Agregando id: 1129 -> Certificación Electrónica de NIT
# Agregando id: 1129 -> Formulario
# Agregando id: 1129 -> Plan de Trabajo
# Agregando id: 1129 -> Certificación Área Minera Libre
# Agregando id: 1129 -> Testimonio de Constitución
# Agregando id: 1129 -> Certificado de Registro de Documento
# Agregando id: 1129 -> Matrícula de Comercio
# Agregando id: 1129 -> Poder del Representante Legal
# Agregando id: 1129 -> Formulario
# Agregando id: 1129 -> Requisito de Trámite
# Agregando id: 1129 -> Certificación Electrónica de NIT
# Agregando id: 1129 -> Plan de Trabajo
# Agregando id: 1129 -> Certificación Área Minera Libre
# Agregando id: 1129 -> Testimonio de Constitución
# Agregando id: 1129 -> Certificado de Registro de Documento
# Agregando id: 1129 -> Matrícula de Comercio
# Agregando id: 1129 -> Poder del Representante Legal
# Agregando id: 1129 -> Formulario
# Agregando id: 1129 -> Requisito de Trámite
# Agregando id: 1129 -> Certificación Electrónica de NIT
# Agregando id: 1129 -> Plan de Trabajo
# Agregando id: 1129 -> Certificación Área Minera Libre
# Agregando id: 1129 -> Testimonio de Constitución
# Agregando id: 1129 -> Certificado de Registro de Documento
# Agregando id: 1129 -> Matrícula de Comercio
# Agregando id: 1129 -> Poder del Representante Legal
# Agregando id: 1129 -> Formulario
# Agregando id: 1129 -> Requisito de Trámite
# Agregando id: 1129 -> Certificación Electrónica de NIT
# Agregando id: 1129 -> Plan de Trabajo
# Agregando id: 1129 -> Certificación Área Minera Libre
# Agregando id: 1129 -> Testimonio de Constitución
# Agregando id: 1129 -> Certificado de Registro de Documento
# Agregando id: 1129 -> Matrícula de Comercio
# Agregando id: 1129 -> Poder del Representante Legal
# Agregando id: 1129 -> Formulario
# Agregando id: 1129 -> Requisito de Trámite
# Agregando id: 1129 -> Certificación Electrónica de NIT
# Agregando id: 1129 -> Plan de Trabajo
# Agregando id: 1129 -> Certificación Área Minera Libre
# Agregando id: 1129 -> Testimonio de Constitución
# Agregando id: 1129 -> Certificado de Registro de Documento
# Agregando id: 1129 -> Matrícula de Comercio
# Agregando id: 1129 -> Poder del Representante Legal
# Agregando id: 1129 -> Formulario
# Agregando id: 1129 -> Requisito de Trámite
# Agregando id: 1129 -> Certificación Electrónica de NIT
# Agregando id: 1129 -> Plan de Trabajo
# Agregando id: 1129 -> Certificación Área Minera Libre
# Agregando id: 1129 -> Testimonio de Constitución
# Agregando id: 1129 -> Certificado de Registro de Documento
# Agregando id: 1129 -> Matrícula de Comercio
# Agregando id: 1129 -> Poder del Representante Legal
# Agregando id: 1129 -> Formulario
# Agregando id: 1129 -> Requisito de Trámite
# Agregando id: 1129 -> Certificación Electrónica de NIT
# Agregando id: 1129 -> Plan de Trabajo
# Agregando id: 1129 -> Certificación Área Minera Libre
# Agregando id: 1129 -> Testimonio de Constitución
# Agregando id: 1129 -> Certificado de Registro de Documento
# Agregando id: 1129 -> Matrícula de Comercio
# Agregando id: 1129 -> Poder del Representante Legal
# Agregando id: 1129 -> Formulario
# Agregando id: 1129 -> Requisito de Trámite
# Agregando id: 1129 -> Certificación Electrónica de NIT
# Agregando id: 1129 -> Plan de Trabajo
# Agregando id: 1129 -> Certificación Área Minera Libre
# Agregando id: 1129 -> Personería Jurídica
# Agregando id: 1129 -> Poder del Representante Legal
# Agregando id: 1129 -> Certificación Electrónica de NIT
# Agregando id: 1129 -> Plan de Trabajo
# Agregando id: 1129 -> Formulario
# Agregando id: 1129 -> Requisito de Trámite
# Agregando id: 1129 -> Certificación Área Minera Libre
# Agregando id: 1129 -> Personería Jurídica
# Agregando id: 1129 -> Poder del Representante Legal
# Agregando id: 1129 -> Certificación Electrónica de NIT
# Agregando id: 1129 -> Plan de Trabajo
# Agregando id: 1129 -> Formulario
# Agregando id: 1129 -> Requisito de Trámite
# Agregando id: 1129 -> Certificación Área Minera Libre
# Agregando id: 1129 -> Personería Jurídica
# Agregando id: 1129 -> Poder del Representante Legal
# Agregando id: 1129 -> Certificación Electrónica de NIT
# Agregando id: 1129 -> Plan de Trabajo
# Agregando id: 1129 -> Formulario
# Agregando id: 1129 -> Requisito de Trámite
# Agregando id: 1129 -> Certificación Área Minera Libre
# Agregando id: 1129 -> Personería Jurídica
# Agregando id: 1129 -> Poder del Representante Legal
# Agregando id: 1129 -> Certificación Electrónica de NIT
# Agregando id: 1129 -> Plan de Trabajo
# Agregando id: 1129 -> Formulario
# Agregando id: 1129 -> Requisito de Trámite
# Agregando id: 1129 -> Certificación Área Minera Libre
# Agregando id: 1129 -> Personería Jurídica
# Agregando id: 1129 -> Poder del Representante Legal
# Agregando id: 1129 -> Certificación Electrónica de NIT
# Agregando id: 1129 -> Plan de Trabajo
# Agregando id: 1129 -> Formulario
# Agregando id: 1129 -> Requisito de Trámite
# Agregando id: 1129 -> Certificación Área Minera Libre
# Agregando id: 1129 -> Personería Jurídica
# Agregando id: 1129 -> Poder del Representante Legal
# Agregando id: 1129 -> Certificación Electrónica de NIT
# Agregando id: 1129 -> Plan de Trabajo
# Agregando id: 1129 -> Formulario
# Agregando id: 1129 -> Requisito de Trámite
# Agregando id: 1129 -> Certificación Área Minera Libre
# Agregando id: 1129 -> Personería Jurídica
# Agregando id: 1129 -> Poder del Representante Legal
# Agregando id: 1129 -> Certificación Electrónica de NIT
# Agregando id: 1129 -> Plan de Trabajo
# Agregando id: 1129 -> Formulario
# Agregando id: 1129 -> Requisito de Trámite
# Agregando id: 1130 -> Formulario
# Agregando id: 1130 -> Formulario
# Agregando id: 1131 -> Formulario
# Agregando id: 1131 -> Formulario
# Agregando id: 1131 -> Formulario
# Agregando id: 1131 -> Formulario
# Agregando id: 1132 -> Legalización
# Agregando id: 1132 -> Legalización
# Agregando id: 1134 -> Formulario
# Agregando id: 1134 -> Formulario
# Agregando id: 1135 -> Formulario
# Agregando id: 1135 -> Formulario
# Agregando id: 1136 -> Formulario
# Agregando id: 1136 -> Formulario
# Agregando id: 1136 -> Formulario
# Agregando id: 1136 -> Formulario
# Agregando id: 1137 -> Resolución Rectoral del Diploma Académico
# Agregando id: 1137 -> Resolución Rectoral del Diploma Académico
# Agregando id: 1138 -> Carga Horaria
# Agregando id: 1138 -> Carga Horaria
# Agregando id: 1139 -> Formulario
# Agregando id: 1139 -> Formulario
# Agregando id: 1139 -> Formulario
# Agregando id: 1139 -> Formulario
# Agregando id: 1139 -> Formulario
# Agregando id: 1139 -> Formulario
# Agregando id: 1139 -> Formulario
# Agregando id: 1140 -> Formulario
# Agregando id: 1140 -> Formulario
# Agregando id: 1140 -> Formulario
# Agregando id: 1140 -> Formulario
# Agregando id: 1140 -> Formulario
# Agregando id: 1140 -> Formulario
# Agregando id: 1140 -> Formulario
# Agregando id: 1140 -> Formulario
# Agregando id: 1141 -> Legalización
# Agregando id: 1141 -> Legalización
# Agregando id: 1142 -> Formulario
# Agregando id: 1142 -> Formulario
# Agregando id: 1142 -> Formulario
# Agregando id: 1142 -> Formulario
# Agregando id: 1142 -> Formulario
# Agregando id: 1142 -> Formulario
# Agregando id: 1143 -> Certificado de Calificaciones
# Agregando id: 1143 -> Certificado de Calificaciones
# Agregando id: 1146 -> Certificación
# Agregando id: 1146 -> Certificación
# Agregando id: 1148 -> Certificación
# Agregando id: 1148 -> Certificación
# Agregando id: 1150 -> Acta de Defensa de Grado
# Agregando id: 1150 -> Acta de Defensa de Grado
# Agregando id: 1152 -> Plan de Estudio
# Agregando id: 1152 -> Plan de Estudio
# Agregando id: 1153 -> Certificación
# Agregando id: 1153 -> Certificación
# Agregando id: 1154 -> Certificación
# Agregando id: 1154 -> Certificación
# Agregando id: 1155 -> Historial Académico
# Agregando id: 1155 -> Historial Académico
# Agregando id: 1156 -> Diploma de Bachiller
# Agregando id: 1156 -> Diploma de Bachiller
# Agregando id: 1157 -> Certificado Postgrado
# Agregando id: 1157 -> Certificado Postgrado
# Agregando id: 1158 -> Diploma Académico
# Agregando id: 1158 -> Diploma Académico
# Agregando id: 1159 -> Legalización
# Agregando id: 1159 -> Legalización
# Agregando id: 1160 -> Certificación
# Agregando id: 1160 -> Certificación
# Agregando id: 1161 -> Legalización
# Agregando id: 1161 -> Legalización
# Agregando id: 1162 -> Formulario
# Agregando id: 1162 -> Formulario
# Agregando id: 1162 -> Formulario
# Agregando id: 1162 -> Formulario
# Agregando id: 1162 -> Formulario
# Agregando id: 1162 -> Formulario
# Agregando id: 1163 -> Formulario
# Agregando id: 1163 -> Formulario
# Agregando id: 1163 -> Formulario
# Agregando id: 1163 -> Formulario
# Agregando id: 1163 -> Formulario
# Agregando id: 1163 -> Formulario
# Agregando id: 1163 -> Formulario
# Agregando id: 1163 -> Formulario
# Agregando id: 1164 -> Certificación
# Agregando id: 1164 -> Certificación
# Agregando id: 1166 -> Requisito de Trámite
# Agregando id: 1166 -> Requisito de Trámite
# Agregando id: 1167 -> Requisito de Trámite
# Agregando id: 1167 -> Requisito de Trámite
# Agregando id: 1168 -> Formulario
# Agregando id: 1168 -> Formulario
# Agregando id: 1168 -> Formulario
# Agregando id: 1168 -> Formulario
# Agregando id: 1168 -> Formulario
# Agregando id: 1168 -> Formulario
# Agregando id: 1168 -> Formulario
# Agregando id: 1168 -> Formulario
# Agregando id: 1169 -> Formulario
# Agregando id: 1169 -> Formulario
# Agregando id: 1169 -> Formulario
# Agregando id: 1169 -> Formulario
# Agregando id: 1169 -> Formulario
# Agregando id: 1169 -> Formulario
# Agregando id: 1169 -> Formulario
# Agregando id: 1169 -> Formulario
# Agregando id: 1170 -> Formulario
# Agregando id: 1170 -> Formulario
# Agregando id: 1170 -> Formulario
# Agregando id: 1170 -> Formulario
# Agregando id: 1171 -> Certificado de Calificaciones
# Agregando id: 1171 -> Certificado de Calificaciones
# Agregando id: 1172 -> Formulario
# Agregando id: 1172 -> Formulario
# Agregando id: 1172 -> Formulario
# Agregando id: 1172 -> Formulario
# Agregando id: 1173 -> Legalización
# Agregando id: 1173 -> Legalización
# Agregando id: 1174 -> Formulario
# Agregando id: 1174 -> Formulario
# Agregando id: 1174 -> Formulario
# Agregando id: 1174 -> Formulario
# Agregando id: 1174 -> Formulario
# Agregando id: 1174 -> Formulario
# Agregando id: 1176 -> Formulario
# Agregando id: 1176 -> Formulario
# Agregando id: 1176 -> Formulario
# Agregando id: 1176 -> Formulario
# Agregando id: 1176 -> Formulario
# Agregando id: 1176 -> Formulario
# Agregando id: 1177 -> Certificado de Calificaciones
# Agregando id: 1177 -> Certificado de Calificaciones
# Agregando id: 1178 -> Formulario
# Agregando id: 1178 -> Formulario
# Agregando id: 1178 -> Formulario
# Agregando id: 1178 -> Formulario
# Agregando id: 1179 -> Formulario
# Agregando id: 1179 -> Formulario
# Agregando id: 1179 -> Formulario
# Agregando id: 1179 -> Formulario
# Agregando id: 1179 -> Formulario
# Agregando id: 1179 -> Formulario
# Agregando id: 1180 -> Certificado de Calificaciones
# Agregando id: 1180 -> Certificado de Calificaciones
# Agregando id: 1181 -> Certificación
# Agregando id: 1181 -> Certificación
# Agregando id: 1182 -> Formulario
# Agregando id: 1182 -> Formulario
# Agregando id: 1182 -> Formulario
# Agregando id: 1182 -> Formulario
# Agregando id: 1182 -> Formulario
# Agregando id: 1182 -> Formulario
# Agregando id: 1183 -> Formulario
# Agregando id: 1183 -> Formulario
# Agregando id: 1183 -> Formulario
# Agregando id: 1183 -> Formulario
# Agregando id: 1184 -> Certificado de Vestibulares
# Agregando id: 1184 -> Certificado de Vestibulares
# Agregando id: 1185 -> Formulario
# Agregando id: 1185 -> Formulario
# Agregando id: 1185 -> Formulario
# Agregando id: 1185 -> Formulario
# Agregando id: 1185 -> Formulario
# Agregando id: 1185 -> Formulario
# Agregando id: 1186 -> Formulario
# Agregando id: 1186 -> Formulario
# Agregando id: 1187 -> Formulario
# Agregando id: 1187 -> Formulario
# Agregando id: 1187 -> Formulario
# Agregando id: 1188 -> Formulario
# Agregando id: 1188 -> Formulario
# Agregando id: 1188 -> Formulario
# Agregando id: 1189 -> Formulario
# Agregando id: 1189 -> Formulario
# Agregando id: 1189 -> Formulario
# Agregando id: 1190 -> Legalización
# Agregando id: 1190 -> Legalización
# Agregando id: 1191 -> Formulario
# Agregando id: 1191 -> Formulario
# Agregando id: 1191 -> Formulario
# Agregando id: 1192 -> Formulario
# Agregando id: 1192 -> Formulario
# Agregando id: 1192 -> Formulario
# Agregando id: 1193 -> Formulario
# Agregando id: 1193 -> Formulario
# Agregando id: 1193 -> Formulario
# Agregando id: 1194 -> Formulario
# Agregando id: 1194 -> Formulario
# Agregando id: 1194 -> Formulario
# Agregando id: 1195 -> Legalización
# Agregando id: 1195 -> Legalización
# Agregando id: 1196 -> Formulario
# Agregando id: 1196 -> Formulario
# Agregando id: 1196 -> Formulario
# Agregando id: 1197 -> Formulario
# Agregando id: 1198 -> Formulario
# Agregando id: 1199 -> Formulario
# Agregando id: 1199 -> Formulario
# Agregando id: 1200 -> Formulario
# Agregando id: 1201 -> Legalización
# Agregando id: 1201 -> Legalización
# Agregando id: 1202 -> Formulario
# Agregando id: 1202 -> Formulario
# Agregando id: 1202 -> Formulario
# Agregando id: 1202 -> Formulario
# Agregando id: 1203 -> Formulario
# Agregando id: 1204 -> Certificación
# Agregando id: 1204 -> Certificación
# Agregando id: 1205 -> Formulario
# Agregando id: 1205 -> Formulario
# Agregando id: 1205 -> Formulario
# Agregando id: 1205 -> Formulario
# Agregando id: 1205 -> Formulario
# Agregando id: 1205 -> Formulario
# Agregando id: 1206 -> Formulario
# Agregando id: 1206 -> Formulario
# Agregando id: 1206 -> Formulario
# Agregando id: 1206 -> Formulario
# Agregando id: 1206 -> Formulario
# Agregando id: 1206 -> Formulario
# Agregando id: 1207 -> Formulario
# Agregando id: 1207 -> Formulario
# Agregando id: 1207 -> Formulario
# Agregando id: 1207 -> Formulario
# Agregando id: 1207 -> Formulario
# Agregando id: 1207 -> Formulario
# Agregando id: 1209 -> Formulario
# Agregando id: 1209 -> Formulario
# Agregando id: 1209 -> Formulario
# Agregando id: 1209 -> Formulario
# Agregando id: 1210 -> Formulario
# Agregando id: 1210 -> Formulario
# Agregando id: 1210 -> Formulario
# Agregando id: 1210 -> Formulario
# Agregando id: 1210 -> Formulario
# Agregando id: 1210 -> Formulario
# Agregando id: 1212 -> Certificado Postgrado
# Agregando id: 1212 -> Certificado Postgrado
# Agregando id: 1213 -> Formulario
# Agregando id: 1213 -> Formulario
# Agregando id: 1213 -> Formulario
# Agregando id: 1214 -> Formulario
# Agregando id: 1214 -> Formulario
# Agregando id: 1214 -> Formulario
# Agregando id: 1215 -> Formulario
# Agregando id: 1215 -> Formulario
# Agregando id: 1215 -> Formulario
# Agregando id: 1216 -> Legalización
# Agregando id: 1216 -> Legalización
# Agregando id: 1218 -> Formulario
# Agregando id: 1218 -> Formulario
# Agregando id: 1218 -> Formulario
# Agregando id: 1219 -> Formulario
# Agregando id: 1219 -> Formulario
# Agregando id: 1219 -> Formulario
# Agregando id: 1220 -> Legalización
# Agregando id: 1220 -> Legalización
# Agregando id: 1221 -> Formulario
# Agregando id: 1221 -> Formulario
# Agregando id: 1221 -> Formulario
# Agregando id: 1222 -> Formulario
# Agregando id: 1222 -> Formulario
# Agregando id: 1222 -> Formulario
# Agregando id: 1223 -> Certificación
# Agregando id: 1223 -> Certificación
# Agregando id: 1224 -> Formulario
# Agregando id: 1224 -> Formulario
# Agregando id: 1224 -> Formulario
# Agregando id: 1225 -> Formulario
# Agregando id: 1225 -> Formulario
# Agregando id: 1225 -> Formulario
# Agregando id: 1226 -> Formulario
# Agregando id: 1226 -> Formulario
# Agregando id: 1226 -> Formulario
# Agregando id: 1227 -> Formulario
# Agregando id: 1227 -> Formulario
# Agregando id: 1227 -> Formulario
# Agregando id: 1227 -> Formulario
# Agregando id: 1228 -> Legalización
# Agregando id: 1228 -> Legalización
# Agregando id: 1229 -> Formulario
# Agregando id: 1229 -> Formulario
# Agregando id: 1229 -> Formulario
# Agregando id: 1230 -> Formulario
# Agregando id: 1230 -> Formulario
# Agregando id: 1230 -> Formulario
# Agregando id: 1231 -> Certificado de Promedio
# Agregando id: 1231 -> Certificado de Promedio
# Agregando id: 1232 -> Historial Académico
# Agregando id: 1232 -> Historial Académico
# Agregando id: 1233 -> Certificación
# Agregando id: 1233 -> Certificación
# Agregando id: 1234 -> Carga Horaria
# Agregando id: 1234 -> Carga Horaria
# Agregando id: 1235 -> Carga Horaria
# Agregando id: 1235 -> Carga Horaria
# Agregando id: 1236 -> Certificado de Egreso
# Agregando id: 1236 -> Certificado de Egreso
# Agregando id: 1237 -> Legalización
# Agregando id: 1237 -> Legalización
# Agregando id: 1239 -> Legalización
# Agregando id: 1239 -> Legalización
# Agregando id: 1241 -> Certificado Postgrado
# Agregando id: 1241 -> Certificado Postgrado
# Agregando id: 1242 -> Resolución Rectoral del Diploma Académico
# Agregando id: 1242 -> Resolución Rectoral del Diploma Académico
# Agregando id: 1244 -> Legalización
# Agregando id: 1244 -> Legalización
# Agregando id: 1245 -> Legalización
# Agregando id: 1245 -> Legalización
# Agregando id: 1246 -> Legalización
# Agregando id: 1246 -> Legalización
# Agregando id: 1250 -> Carga Horaria
# Agregando id: 1250 -> Carga Horaria
# Agregando id: 1252 -> Comprobante de Pago
# Agregando id: 1252 -> Diploma de Bachiller
# Agregando id: 1252 -> Requisito de Trámite
# Agregando id: 1252 -> Declaración Jurada
# Agregando id: 1252 -> Formulario
# Agregando id: 1252 -> Cédula de Identidad
# Agregando id: 1252 -> Certificado de Nacimiento
# Agregando id: 1252 -> Fotografías
# Agregando id: 1252 -> Publicación en Medio de Prensa
# Agregando id: 1252 -> Certificado
# Agregando id: 1252 -> Comprobante de Pago
# Agregando id: 1252 -> Diploma de Bachiller
# Agregando id: 1252 -> Requisito de Trámite
# Agregando id: 1252 -> Declaración Jurada
# Agregando id: 1252 -> Formulario
# Agregando id: 1252 -> Cédula de Identidad
# Agregando id: 1252 -> Certificado de Nacimiento
# Agregando id: 1252 -> Fotografías
# Agregando id: 1252 -> Publicación en Medio de Prensa
# Agregando id: 1252 -> Certificado
# Agregando id: 1253 -> Legalización
# Agregando id: 1253 -> Legalización
# Agregando id: 1256 -> Requisito de Trámite
# Agregando id: 1256 -> Requisito de Trámite
# Agregando id: 1257 -> Plan de Estudio
# Agregando id: 1257 -> Plan de Estudio
# Agregando id: 1265 -> Cédula de Identidad
# Agregando id: 1265 -> Requisito de Trámite
# Agregando id: 1266 -> Carga Horaria
# Agregando id: 1266 -> Carga Horaria
# Agregando id: 1267 -> Certificado de Estudios
# Agregando id: 1267 -> Certificados de Estudios
# Agregando id: 1268 -> Certificado Postgrado
# Agregando id: 1268 -> Certificado Postgrado
# Agregando id: 1269 -> Certificado de Calificaciones
# Agregando id: 1269 -> Certificado de Calificaciones
# Agregando id: 1270 -> Certificado de Calificaciones
# Agregando id: 1270 -> Certificado de Calificaciones
# Agregando id: 1271 -> Certificado de Calificaciones
# Agregando id: 1271 -> Certificado de Calificaciones
# Agregando id: 1272 -> Diploma de Bachiller
# Agregando id: 1272 -> Diploma de Bachiller
# Agregando id: 1273 -> Legalización
# Agregando id: 1273 -> Legalización
# Agregando id: 1274 -> Certificación Área Minera Libre
# Agregando id: 1274 -> Personería Jurídica
# Agregando id: 1274 -> Poder del Representante Legal
# Agregando id: 1274 -> Certificación Electrónica de NIT
# Agregando id: 1274 -> Plan de Trabajo
# Agregando id: 1274 -> Formulario
# Agregando id: 1274 -> Requisito de Trámite
# Agregando id: 1274 -> Certificación Área Minera Libre
# Agregando id: 1274 -> Personería Jurídica
# Agregando id: 1274 -> Poder del Representante Legal
# Agregando id: 1274 -> Certificación Electrónica de NIT
# Agregando id: 1274 -> Plan de Trabajo
# Agregando id: 1274 -> Formulario
# Agregando id: 1274 -> Requisito de Trámite
# Agregando id: 1274 -> Certificación Área Minera Libre
# Agregando id: 1274 -> Personería Jurídica
# Agregando id: 1274 -> Poder del Representante Legal
# Agregando id: 1274 -> Certificación Electrónica de NIT
# Agregando id: 1274 -> Plan de Trabajo
# Agregando id: 1274 -> Formulario
# Agregando id: 1274 -> Requisito de Trámite
# Agregando id: 1274 -> Certificación Área Minera Libre
# Agregando id: 1274 -> Requisito de Trámite
# Agregando id: 1274 -> Poder del Representante Legal
# Agregando id: 1274 -> Certificación Electrónica de NIT
# Agregando id: 1274 -> Plan de Trabajo
# Agregando id: 1274 -> Formulario
# Agregando id: 1274 -> Certificación Área Minera Libre
# Agregando id: 1274 -> Requisito de Trámite
# Agregando id: 1274 -> Poder del Representante Legal
# Agregando id: 1274 -> Certificación Electrónica de NIT
# Agregando id: 1274 -> Plan de Trabajo
# Agregando id: 1274 -> Formulario
# Agregando id: 1274 -> Certificación Área Minera Libre
# Agregando id: 1274 -> Requisito de Trámite
# Agregando id: 1274 -> Poder del Representante Legal
# Agregando id: 1274 -> Certificación Electrónica de NIT
# Agregando id: 1274 -> Plan de Trabajo
# Agregando id: 1274 -> Formulario
# Agregando id: 1274 -> Certificación Área Minera Libre
# Agregando id: 1274 -> Testimonio de Constitución
# Agregando id: 1274 -> Certificado de Registro de Documento
# Agregando id: 1274 -> Matrícula de Comercio
# Agregando id: 1274 -> Poder del Representante Legal
# Agregando id: 1274 -> Certificación Electrónica de NIT
# Agregando id: 1274 -> Plan de Trabajo
# Agregando id: 1274 -> Formulario
# Agregando id: 1274 -> Requisito de Trámite
# Agregando id: 1274 -> Certificación Área Minera Libre
# Agregando id: 1274 -> Testimonio de Constitución
# Agregando id: 1274 -> Certificado de Registro de Documento
# Agregando id: 1274 -> Matrícula de Comercio
# Agregando id: 1274 -> Poder del Representante Legal
# Agregando id: 1274 -> Certificación Electrónica de NIT
# Agregando id: 1274 -> Plan de Trabajo
# Agregando id: 1274 -> Formulario
# Agregando id: 1274 -> Requisito de Trámite
# Agregando id: 1274 -> Certificación Área Minera Libre
# Agregando id: 1274 -> Testimonio de Constitución
# Agregando id: 1274 -> Certificado de Registro de Documento
# Agregando id: 1274 -> Matrícula de Comercio
# Agregando id: 1274 -> Poder del Representante Legal
# Agregando id: 1274 -> Certificación Electrónica de NIT
# Agregando id: 1274 -> Plan de Trabajo
# Agregando id: 1274 -> Formulario
# Agregando id: 1274 -> Requisito de Trámite
# Agregando id: 1275 -> Certificado Postgrado
# Agregando id: 1275 -> Certificado Postgrado
# Agregando id: 1276 -> Formulario
# Agregando id: 1276 -> Formulario
# Agregando id: 1276 -> Formulario
# Agregando id: 1277 -> Boleta de Depósito Bancario
# Agregando id: 1277 -> Cédula de Identidad
# Agregando id: 1277 -> Factura
# Agregando id: 1277 -> Boleta de Depósito Bancario
# Agregando id: 1277 -> Cédula de Identidad
# Agregando id: 1277 -> Factura
# Agregando id: 1277 -> Memorándum de Designación
# Agregando id: 1277 -> NIT
# Agregando id: 1277 -> Cédula de Identidad
# Agregando id: 1277 -> Carta/Nota de Solicitud
# Agregando id: 1277 -> Boleta de Depósito Bancario
# Agregando id: 1277 -> Memorándum de Designación
# Agregando id: 1277 -> NIT
# Agregando id: 1277 -> Cédula de Identidad
# Agregando id: 1277 -> Carta/Nota de Solicitud
# Agregando id: 1277 -> Boleta de Depósito Bancario
# Agregando id: 1278 -> Convenio
# Agregando id: 1278 -> Convenio
# Agregando id: 1279 -> Legalización
# Agregando id: 1279 -> Legalización
# Agregando id: 1280 -> Certificado de Estudios
# Agregando id: 1280 -> Certificado de Estudios
# Agregando id: 1281 -> Carga Horaria
# Agregando id: 1281 -> Carga Horaria
# Agregando id: 1282 -> Certificación
# Agregando id: 1282 -> Certificación
# Agregando id: 1283 -> Legalización
# Agregando id: 1283 -> Legalización
# Agregando id: 1284 -> Legalización
# Agregando id: 1284 -> Legalización
# Agregando id: 1285 -> Carta/Nota de Solicitud
# Agregando id: 1285 -> Croquis
# Agregando id: 1285 -> Factura de Luz
# Agregando id: 1285 -> Derecho Propietario
# Agregando id: 1285 -> Testimonio de Constitución
# Agregando id: 1285 -> Poder del Representante Legal
# Agregando id: 1285 -> Cédula de Identidad
# Agregando id: 1286 -> Legalización
# Agregando id: 1286 -> Legalización
# Agregando id: 1288 -> Certificado de Calificaciones
# Agregando id: 1288 -> Certificado de Calificaciones
# Agregando id: 1290 -> Informe
# Agregando id: 1290 -> Carta/Nota de Solicitud
# Agregando id: 1290 -> Requisito de Trámite
# Agregando id: 1290 -> Certificado
# Agregando id: 1290 -> Comprobante de Pago
# Agregando id: 1290 -> Informe
# Agregando id: 1290 -> Carta/Nota de Solicitud
# Agregando id: 1290 -> Requisito de Trámite
# Agregando id: 1290 -> Certificado
# Agregando id: 1290 -> Comprobante de Pago
# Agregando id: 1291 -> Legalización
# Agregando id: 1291 -> Legalización
# Agregando id: 1293 -> Certificado de Calificaciones
# Agregando id: 1293 -> Certificado de Calificaciones
# Agregando id: 1296 -> Comprobante de Pago
# Agregando id: 1296 -> Cédula de Identidad
# Agregando id: 1296 -> Poder Especial (Trámites)
# Agregando id: 1296 -> Carta/Nota de Solicitud
# Agregando id: 1297 -> Legalización
# Agregando id: 1297 -> Legalización
# Agregando id: 1298 -> Carta/Nota de Solicitud
# Agregando id: 1298 -> Formulario
# Agregando id: 1298 -> Cédula de Identidad
# Agregando id: 1298 -> Derecho Propietario
# Agregando id: 1298 -> Factura de Luz
# Agregando id: 1298 -> Croquis
# Agregando id: 1298 -> Testimonio de Constitución
# Agregando id: 1298 -> Poder del Representante Legal
# Agregando id: 1298 -> Requisito de Trámite
# Agregando id: 1298 -> Carta/Nota de Solicitud
# Agregando id: 1298 -> Formulario
# Agregando id: 1298 -> Cédula de Identidad
# Agregando id: 1298 -> Derecho Propietario
# Agregando id: 1298 -> Factura de Luz
# Agregando id: 1298 -> Croquis
# Agregando id: 1298 -> Testimonio de Constitución
# Agregando id: 1298 -> Poder del Representante Legal
# Agregando id: 1298 -> Requisito de Trámite
# Agregando id: 1299 -> Legalización
# Agregando id: 1299 -> Legalización
# Agregando id: 1300 -> Formulario
# Agregando id: 1300 -> Cédula de Identidad
# Agregando id: 1300 -> Derecho Propietario
# Agregando id: 1300 -> Factura de Luz
# Agregando id: 1300 -> Título en Provisión Nacional
# Agregando id: 1300 -> Croquis
# Agregando id: 1300 -> Testimonio de Constitución
# Agregando id: 1300 -> Poder del Representante Legal
# Agregando id: 1300 -> Requisito de Trámite
# Agregando id: 1300 -> Carta/Nota de Solicitud
# Agregando id: 1303 -> Requisito de Trámite
# Agregando id: 1303 -> Requisito de Trámite
# Agregando id: 1306 -> Certificado
# Agregando id: 1306 -> Cédula de Identidad
# Agregando id: 1306 -> Memorial
# Agregando id: 1306 -> Registro Docente Administrativo (RDA)
# Agregando id: 1307 -> Legalización
# Agregando id: 1307 -> Legalización
# Agregando id: 1308 -> Carta/Nota de Solicitud
# Agregando id: 1308 -> Formulario
# Agregando id: 1308 -> Cédula de Identidad
# Agregando id: 1308 -> Factura de Luz
# Agregando id: 1308 -> Derecho Propietario
# Agregando id: 1308 -> Croquis
# Agregando id: 1308 -> Testimonio de Constitución
# Agregando id: 1308 -> Poder del Representante Legal
# Agregando id: 1308 -> Requisito de Trámite
# Agregando id: 1311 -> Certificación
# Agregando id: 1311 -> Certificación
# Agregando id: 1314 -> Certificado Postgrado
# Agregando id: 1314 -> Certificado Postgrado
# Agregando id: 1316 -> Carga Horaria
# Agregando id: 1316 -> Carga Horaria
# Agregando id: 1317 -> Historial Académico
# Agregando id: 1317 -> Historial Académico
# Agregando id: 1318 -> Resolución Rectoral del Diploma Académico
# Agregando id: 1318 -> Resolución Rectoral del Diploma Académico
# Agregando id: 1319 -> Certificado
# Agregando id: 1319 -> Cédula de Identidad
# Agregando id: 1319 -> Memorial
# Agregando id: 1319 -> Registro Docente Administrativo (RDA)
# Agregando id: 1320 -> Legalización
# Agregando id: 1320 -> Legalización
# Agregando id: 1321 -> Legalización
# Agregando id: 1321 -> Legalización
# Agregando id: 1323 -> Certificado de Nacimiento
# Agregando id: 1323 -> Declaración Jurada
# Agregando id: 1323 -> Formulario
# Agregando id: 1323 -> Cédula de Identidad
# Agregando id: 1323 -> Memorial
# Agregando id: 1324 -> Legalización
# Agregando id: 1324 -> Legalización
# Agregando id: 1325 -> Poder Especial (Trámites)
# Agregando id: 1325 -> Carta/Nota de Solicitud
# Agregando id: 1325 -> Certificado
# Agregando id: 1325 -> Certificado de Trabajo
# Agregando id: 1325 -> Papeleta de Pago Sueldo
# Agregando id: 1325 -> Memorándum de Designación
# Agregando id: 1325 -> Memorial
# Agregando id: 1325 -> Registro Docente Administrativo (RDA)
# Agregando id: 1325 -> Resolución Administrativa Institucional
# Agregando id: 1326 -> Plan de Estudio
# Agregando id: 1326 -> Plan de Estudio
# Agregando id: 1327 -> Certificado de Calificaciones
# Agregando id: 1327 -> Certificado de Calificaciones
# Agregando id: 1328 -> Legalización
# Agregando id: 1328 -> Legalización
# Agregando id: 1329 -> Legalización
# Agregando id: 1329 -> Legalización
# Agregando id: 1330 -> Plan de Estudio
# Agregando id: 1330 -> Plan de Estudio
# Agregando id: 1331 -> Legalización
# Agregando id: 1331 -> Legalización
# Agregando id: 1332 -> Legalización
# Agregando id: 1332 -> Legalización
# Agregando id: 1333 -> Legalización
# Agregando id: 1333 -> Legalización
# Agregando id: 1334 -> Carta/Nota de Solicitud
# Agregando id: 1334 -> Formulario
# Agregando id: 1334 -> Requisito de Trámite
# Agregando id: 1335 -> Certificación
# Agregando id: 1335 -> Certificación
# Agregando id: 1336 -> Legalización
# Agregando id: 1336 -> Legalización
# Agregando id: 1337 -> Requisito de Trámite
# Agregando id: 1337 -> Requisito de Trámite
# Agregando id: 1339 -> Legalización
# Agregando id: 1339 -> Legalización
# Agregando id: 1340 -> Plan de Estudio
# Agregando id: 1340 -> Plan de Estudio
# Agregando id: 1341 -> Resolución Rectoral del Diploma Académico
# Agregando id: 1341 -> Resolución Rectoral del Diploma Académico
# Agregando id: 1342 -> Título Profesional
# Agregando id: 1343 -> Título Profesional
# Agregando id: 1343 -> Título Profesional
# Agregando id: 1344 -> Título Profesional
# Agregando id: 1345 -> Título Profesional
# Agregando id: 1345 -> Título Profesional
# Agregando id: 1345 -> Título Profesional
# Agregando id: 1345 -> Título Profesional
# Agregando id: 1346 -> Título Profesional
# Agregando id: 1347 -> Título Profesional
# Agregando id: 1347 -> Título Profesional
# Agregando id: 1348 -> Certificación
# Agregando id: 1348 -> Certificación
# Agregando id: 1348 -> Certificación
# Agregando id: 1348 -> Certificación
# Agregando id: 1348 -> Certificación
# Agregando id: 1348 -> Certificación
# Agregando id: 1348 -> Certificación
# ...
# Agregando id: 2759 -> Formulario de inscripción PEEC-INLASA
# Agregando id: 2759 -> Requisitos para Lab. Públicos, Universidades, Seguridad social, Servicios de Sangre
# Agregando id: 2759 -> Requisitos para Lab. Privados y de Convenio
# Agregando id: 2759 -> Contrato PEEC-INLASA
# Agregando id: 2759 -> Formulario de inscripción PEEC-INLASA
# Agregando id: 2759 -> Requisitos para Lab. Públicos, Universidades, Seguridad social, Servicios de Sangre
# Agregando id: 2759 -> Requisitos para Lab. Privados y de Convenio
# Agregando id: 2759 -> Contrato PEEC-INLASA
# Agregando id: 2759 -> Formulario de inscripción PEEC-INLASA
# Agregando id: 2759 -> Requisitos para Lab. Públicos, Universidades, Seguridad social, Servicios de Sangre
# Agregando id: 2759 -> Requisitos para Lab. Privados y de Convenio
# Agregando id: 2759 -> Contrato PEEC-INLASA
# Agregando id: 2759 -> Formulario de inscripción PEEC-INLASA
# Agregando id: 2759 -> Requisitos para Lab. Públicos, Universidades, Seguridad social, Servicios de Sangre
# Agregando id: 2759 -> Requisitos para Lab. Privados y de Convenio
# Agregando id: 2759 -> Contrato PEEC-INLASA
# Agregando id: 2759 -> Formulario de inscripción PEEC-INLASA
# Agregando id: 2759 -> Requisitos para Lab. Públicos, Universidades, Seguridad social, Servicios de Sangre
# Agregando id: 2759 -> Requisitos para Lab. Privados y de Convenio
# Agregando id: 2759 -> Contrato PEEC-INLASA
# Agregando id: 2759 -> Formulario de inscripción PEEC-INLASA
# Agregando id: 2759 -> Requisitos para Lab. Públicos, Universidades, Seguridad social, Servicios de Sangre
# Agregando id: 2759 -> Requisitos para Lab. Privados y de Convenio
# Agregando id: 2759 -> Contrato PEEC-INLASA
# Agregando id: 2759 -> Formulario de inscripción PEEC-INLASA
# Agregando id: 2759 -> Requisitos para Lab. Públicos, Universidades, Seguridad social, Servicios de Sangre
# Agregando id: 2759 -> Requisitos para Lab. Privados y de Convenio
# Agregando id: 2759 -> Contrato PEEC-INLASA
# Agregando id: 2759 -> Formulario de inscripción PEEC-INLASA
# Agregando id: 2759 -> Requisitos para Lab. Públicos, Universidades, Seguridad social, Servicios de Sangre
# Agregando id: 2759 -> Requisitos para Lab. Privados y de Convenio
# Agregando id: 2759 -> Contrato PEEC-INLASA
# Agregando id: 2759 -> Formulario de inscripción PEEC-INLASA
# Agregando id: 2759 -> Requisitos para Lab. Públicos, Universidades, Seguridad social, Servicios de Sangre
# Agregando id: 2759 -> Requisitos para Lab. Privados y de Convenio
# Agregando id: 2759 -> Contrato PEEC-INLASA
# Agregando id: 2759 -> Formulario de inscripción PEEC-INLASA
# Agregando id: 2759 -> Requisitos para Lab. Públicos, Universidades, Seguridad social, Servicios de Sangre
# Agregando id: 2759 -> Requisitos para Lab. Privados y de Convenio
# Agregando id: 2759 -> Contrato PEEC-INLASA
# Agregando id: 2759 -> Formulario de inscripción PEEC-INLASA
# Agregando id: 2759 -> Requisitos para Lab. Públicos, Universidades, Seguridad social, Servicios de Sangre
# Agregando id: 2759 -> Requisitos para Lab. Privados y de Convenio
# Agregando id: 2759 -> Contrato PEEC-INLASA
# Agregando id: 2759 -> Formulario de inscripción PEEC-INLASA
# Agregando id: 2759 -> Requisitos para Lab. Públicos, Universidades, Seguridad social, Servicios de Sangre
# Agregando id: 2759 -> Requisitos para Lab. Privados y de Convenio
# Agregando id: 2759 -> Contrato PEEC-INLASA
# Agregando id: 2759 -> Formulario de inscripción PEEC-INLASA
# Agregando id: 2759 -> Requisitos para Lab. Públicos, Universidades, Seguridad social, Servicios de Sangre
# Agregando id: 2759 -> Requisitos para Lab. Privados y de Convenio
# Agregando id: 2759 -> Contrato PEEC-INLASA
# Agregando id: 2759 -> Formulario de inscripción PEEC-INLASA
# Agregando id: 2759 -> Requisitos para Lab. Públicos, Universidades, Seguridad social, Servicios de Sangre
# Agregando id: 2759 -> Requisitos para Lab. Privados y de Convenio
# Agregando id: 2759 -> Contrato PEEC-INLASA
# Agregando id: 2759 -> Formulario de inscripción PEEC-INLASA
# Agregando id: 2759 -> Requisitos para Lab. Públicos, Universidades, Seguridad social, Servicios de Sangre
# Agregando id: 2759 -> Requisitos para Lab. Privados y de Convenio
# Agregando id: 2759 -> Contrato PEEC-INLASA
# Agregando id: 2759 -> Formulario de inscripción PEEC-INLASA
# Agregando id: 2759 -> Requisitos para Lab. Públicos, Universidades, Seguridad social, Servicios de Sangre
# Agregando id: 2759 -> Requisitos para Lab. Privados y de Convenio
# Agregando id: 2759 -> Contrato PEEC-INLASA
# Agregando id: 2759 -> Formulario de inscripción PEEC-INLASA
# Agregando id: 2759 -> Requisitos para Lab. Públicos, Universidades, Seguridad social, Servicios de Sangre
# Agregando id: 2759 -> Requisitos para Lab. Privados y de Convenio
# Agregando id: 2759 -> Contrato PEEC-INLASA
# Agregando id: 2759 -> Formulario de inscripción PEEC-INLASA
# Agregando id: 2759 -> Requisitos para Lab. Públicos, Universidades, Seguridad social, Servicios de Sangre
# Agregando id: 2759 -> Requisitos para Lab. Privados y de Convenio
# Agregando id: 2759 -> Contrato PEEC-INLASA
# Agregando id: 2759 -> Formulario de inscripción PEEC-INLASA
# Agregando id: 2759 -> Requisitos para Lab. Públicos, Universidades, Seguridad social, Servicios de Sangre
# Agregando id: 2759 -> Requisitos para Lab. Privados y de Convenio
# Agregando id: 2759 -> Contrato PEEC-INLASA
# Agregando id: 2759 -> Formulario de inscripción PEEC-INLASA
# Agregando id: 2759 -> Requisitos para Lab. Públicos, Universidades, Seguridad social, Servicios de Sangre
# Agregando id: 2759 -> Requisitos para Lab. Privados y de Convenio
# Agregando id: 2759 -> Contrato PEEC-INLASA
# Agregando id: 2759 -> Formulario de inscripción PEEC-INLASA
# Agregando id: 2759 -> Requisitos para Lab. Públicos, Universidades, Seguridad social, Servicios de Sangre
# Agregando id: 2759 -> Requisitos para Lab. Privados y de Convenio
# Agregando id: 2759 -> Contrato PEEC-INLASA
# Agregando id: 2759 -> Formulario de inscripción PEEC-INLASA
# Agregando id: 2759 -> Requisitos para Lab. Públicos, Universidades, Seguridad social, Servicios de Sangre
# Agregando id: 2759 -> Requisitos para Lab. Privados y de Convenio
# Agregando id: 2759 -> Contrato PEEC-INLASA
# Agregando id: 2759 -> Formulario de inscripción PEEC-INLASA
# Agregando id: 2759 -> Requisitos para Lab. Públicos, Universidades, Seguridad social, Servicios de Sangre
# Agregando id: 2759 -> Requisitos para Lab. Privados y de Convenio
# Agregando id: 2759 -> Contrato PEEC-INLASA
# Agregando id: 2759 -> Formulario de inscripción PEEC-INLASA
# Agregando id: 2759 -> Requisitos para Lab. Públicos, Universidades, Seguridad social, Servicios de Sangre
# Agregando id: 2759 -> Requisitos para Lab. Privados y de Convenio
# Agregando id: 2764 -> Cédula de Identidad
# Agregando id: 2765 -> Cédula de Identidad
# Agregando id: 2766 -> Cédula de Identidad
# Agregando id: 2767 -> Otros Documentos
# Agregando id: 2768 -> Cédula de Identidad
# Agregando id: 2769 -> Cédula de Identidad
# Agregando id: 2771 -> Nota de Solicitud de capacitación
# Agregando id: 2771 -> Nota de Solicitud de capacitación
# Agregando id: 2771 -> Nota de Solicitud de capacitación
# Agregando id: 2771 -> Nota de Solicitud de capacitación
# Agregando id: 2771 -> Nota de Solicitud de capacitación
# Agregando id: 2772 -> Nota de solicitud a la Dirección General Ejecutiva
# Agregando id: 2773 -> Nota de Solicitud a MAE del INLASA
# Agregando id: 2774 -> Nota de Solicitud de certificación de muestra internacional
# Agregando id: 2777 -> Fotocopia simple de la Cedula de Identidad - Orden Médica - Formulario D-8 debidamente llenado sin tachaduras ni borrones
# Agregando id: 2777 -> Fotocopia simple de la Cedula de Identidad - Orden Médica - Formulario D-8 debidamente llenado sin tachaduras ni borrones
# Agregando id: 2777 -> Fotocopia simple de la Cedula de Identidad - Orden Médica - Formulario D-8 debidamente llenado sin tachaduras ni borrones
# Agregando id: 2777 -> Fotocopia simple de la Cedula de Identidad - Orden Médica - Formulario D-8 debidamente llenado sin tachaduras ni borrones
# Agregando id: 2777 -> Fotocopia simple de la Cedula de Identidad - Orden Médica - Formulario D-8 debidamente llenado sin tachaduras ni borrones
# Agregando id: 2777 -> Fotocopia simple de la Cedula de Identidad - Orden Médica - Formulario D-8 debidamente llenado sin tachaduras ni borrones
# Agregando id: 2778 -> Factura
# Agregando id: 2778 -> Factura
# Agregando id: 2778 -> Factura
# Agregando id: 2778 -> Factura
# Agregando id: 2778 -> Factura
# Agregando id: 2778 -> Factura
# Agregando id: 2778 -> Factura
# Agregando id: 2778 -> Factura
# Agregando id: 2778 -> Factura
# Agregando id: 2819 -> Cédula de Identidad
# Agregando id: 2819 -> Cédula de Identidad
# Agregando id: 2819 -> Cédula de Identidad
# Agregando id: 2819 -> Cédula de Identidad
# Agregando id: 2819 -> Cédula de Identidad
# Agregando id: 2819 -> Cédula de Identidad
# Agregando id: 2819 -> Cédula de Identidad
# Agregando id: 2819 -> Cédula de Identidad
# Agregando id: 2819 -> Cédula de Identidad
# Agregando id: 2825 -> Nota de Solicitud a MAE del INLASA
# Agregando id: 2827 -> Cédula de Identidad
# Agregando id: 2843 -> Cédula de Identidad
# (5991, 52)
#         id     estado fechaActualización  \
# 1672  1568  PUBLICADO         10/07/2025
# 5673  2595  PUBLICADO         15/09/2025
# 2381  1714  PUBLICADO         09/07/2025
#
#                                                nombre  \
# 1672   LEGALIZACIÓN DE FOTOCOPIA DE DIPLOMA ACADEMICO
# 5673       LEGALIZACION DE 4º MEDIO Y/O 6º SECUNDARIA
# 2381  LICENCIA TURISTICA DE GUIAS DE TURISMO NACIONAL
#
#                                                  slug     sigla  \
# 1672   legalizacion-de-fotocopia-de-diploma-academico       NaN
# 5673         legalizacion-de-4-medio-y-o-6-secundaria  DDE-CBBA
# 2381  licencia-turistica-de-guias-de-turismo-nacional   SIRETUR
#
#                                             descripcion  \
# 1672  Trámite dirigido a Profesionales, para realiza...
# 5673  La legalización de 4º de Medio y/o 6º de Secun...
# 2381  Documento que acredita al titular como Guía de...
#
#                                              marcoLegal  like  dislike  \
# 1672                       Verificación de Originalidad     0        0
# 5673  Ley Nº 070 de la Educación “Avelino Siñani – E...     0        0
# 2381  DECRETO SUPREMO N° 2609\nLey General de Turism...     0        0
#
#       esPresencial  esVirtual              resultado  \
# 1672             1          0             Constancia
# 5673             1          0  Registro y constancia
# 2381             0          1  Registro y constancia
#
#                                                 enlaces  \
# 1672  [{"nombre": "Archivos", "url": "https://www.ar...
# 5673  [{"nombre": "LEGALIZACION DE 4º MEDIO Y/O 6º S...
# 2381  [{"nombre": "SISTEMA DE REGISTRO DE PRESTADORE...
#
#                                             ubicaciones  \
# 1672  [{"nombre": "Archivos", "tipo": "Oficina centr...
# 5673  [{"nombre": "Oficina Direccion Departamental d...
# 2381  [{"nombre": "Viceministerio de Turismo", "tipo...
#
#                                          entidad.nombre entidad.sigla  \
# 1672                     Universidad Mayor de San Simón          UMSS
# 5673              Direc. Dptal. de Educación Cochabamba       DDE-CBB
# 2381  Ministerio de Desarrollo Productivo y Economía...      MIN-DPEP
#
#                                            entidad.slug  \
# 1672                     universidad-mayor-de-san-simon
# 5673                direc-dptal-de-educacion-cochabamba
# 2381  ministerio-de-desarrollo-productivo-y-economia...
#
#                                            entidad.logo  \
# 1672  https://www.gob.bo/ws/api/archivos/64632538-41...
# 5673  https://www.gob.bo/ws/api/archivos/9b73a6a1-ab...
# 2381  https://www.gob.bo/ws/api/archivos/6d0f464f-23...
#
#                                     entidad.descripcion  \
# 1672  La Universidad Mayor de San Simón (UMSS), fund...
# 5673  La Dirección Departamental de Educación de Coc...
# 2381  En la década de los años 80, la propuesta de l...
#
#                     entidad.urlSitioWeb entidad.telefonoContacto  \
# 1672           https://www.umss.edu.bo/                      NaN
# 5673  https://www.ddecochabamba.gob.bo/        +(591)(4) 4228777
# 2381          https://produccion.gob.bo                800101585
#
#      entidad.correoElectronicoContacto  \
# 1672                  soporte@umss.edu
# 5673       info@educacioncochabamba.bo
# 2381            info@produccion.gob.bo
#
#                                           palabrasClave      categorias  \
# 1672                                                NaN       Educación
# 5673  LEGALIZACION DE 4º MEDIO Y/O 6º SECUNDARIA,dde...       Educación
# 2381                                                NaN  Identificación
#
#        eventosVida                                  documentos  herramientas  \
# 1672  Mi educación         Sello de Originalidad del Documento           NaN
# 5673           NaN  LEGALIZACION DE 4º MEDIO Y/O 6º SECUNDARIA           NaN
# 2381           NaN                          Licencia Turística           NaN
#
#      modalidad.tipo                        tramite.url tramite.urlSeguimiento  \
# 1672     PRESENCIAL                               None                   None
# 5673     PRESENCIAL                               None                   None
# 2381        VIRTUAL  https://siretur.produccion.gob.bo                   None
#
#       tramite.tieneCosto tramite.duracion tramite.unidadMedidaDuracion  \
# 1672                   1               24                     Horas(s)
# 5673                   1             None
# 2381                   1                1                       Año(s)
#
#                                   tramite.procedimiento  \
# 1672  <p>¿Qué necesito?</p><ul><li><p>1. VALORADO DE...
# 5673  <p>Primeramente, se debe comprar los certifica...
# 2381  <p>Para poder obtener la Licencia Turistica Na...
#
#                  tramite.publicoObjetivo tramite.requisitoNoParametrizado  \
# 1672            Personas Aseguradas SSUE                             None
# 5673  Estudiantes de unidades educativas                             None
# 2381                    Guías de Turismo                             None
#
#      tramite.estado tramite.emisionFactura  \
# 1672         ACTIVO       No emite factura
# 5673         ACTIVO       No emite factura
# 2381         ACTIVO       No emite factura
#
#                                 tramite.formaCobro  \
# 1672              [Pago en efectivo en ventanilla]
# 5673              [Pago en efectivo en ventanilla]
# 2381  [Pago en banco(presenta boleta de depósito)]
#
#                                        tramite.horarios  \
# 1672  [{'dia': 'Lunes', 'continuo': False, 'inicioMa...
# 5673  [{'dia': 'Lunes', 'continuo': True, 'inicioMan...
# 2381  [{'dia': 'Lunes', 'continuo': True, 'inicioMan...
#
#      tramite.depositoBancario  tramite.duracionMin  tramite.duracionHora  \
# 1672                       []               1440.0                  24.0
# 5673                       []                  NaN                   NaN
# 2381                       []           15768000.0              262800.0
#
#       tramite.duracionDia                                 costo.conceptoPago  \
# 1672                  1.0  VALORADO PARA LEGALIZACIÓN DE FOTOCOPIA DE DIP...
# 5673                  NaN                               Certificado de Notas
# 2381              10950.0  Licencia Turística Guía Fijo o de Sitio period...
#
#       costo.monto costo.moneda                         requisito.comentario  \
# 1672        160.0           Bs                                         None
# 5673          3.0           Bs   •\tFotocopia de Certificado de Nacimiento.
# 2381         20.0           Bs  Carnet Laboral (En caso de Guía Extranjero)
#
#                requisito.nombre requisito.entidad  requisito.entidadActiva
# 1672          Diploma Académico              None                        1
# 5673  Certificado de Nacimiento              None                        1
# 2381       Requisito de Trámite              None                        1

# %% [markdown]
# ## Guardando como csv
#
# Solo quedaría pendiente guardar los campos que son diccionarios como cadenas JSON.

# %%
df_desglosado = pd.DataFrame(columns=new_df.columns.to_list())

for column in new_df.columns:
    print(column, new_df[column].dtype)
    if new_df[column].dtype != 'object':
        df_desglosado[column] = new_df[column]
    else:
        # comprobando si la columna tiene objetos que pueden representarse como json
        contains_dict = new_df[column].map(lambda x: isinstance(x, dict) | isinstance(x, list) | isinstance(x, tuple))
        #print(f'{column}:\n {True in contains_dict.unique()}')
        if True in contains_dict.unique(): # existe al menos un valor que es diccionario
            print(f'Existe dict o array: {contains_dict.unique()}')
            try:
                df_desglosado[column] = new_df[column].map(lambda x: json.dumps(x, ensure_ascii=False))
            except:
                print(f'No se pudo convertir diccionario a json: {new_df[column]}')
                df_desglosado[column] = new_df[column]
        else:
            #print(f'No existe dict: {contains_dict.unique()}')
            df_desglosado[column] = new_df[column]

print(df_desglosado.shape, df_desglosado.columns)
df_desglosado.sample(3)
# Out:
# id int64
# estado object
# fechaActualización object
# nombre object
# slug object
# sigla object
# descripcion object
# marcoLegal object
# like int64
# dislike int64
# esPresencial int64
# esVirtual int64
# resultado object
# enlaces object
# ubicaciones object
# entidad.nombre object
# entidad.sigla object
# entidad.slug object
# entidad.logo object
# entidad.descripcion object
# entidad.urlSitioWeb object
# entidad.telefonoContacto object
# entidad.correoElectronicoContacto object
# palabrasClave object
# categorias object
# eventosVida object
# documentos object
# herramientas float64
# modalidad.tipo object
# tramite.url object
# tramite.urlSeguimiento object
# tramite.tieneCosto int64
# tramite.duracion object
# tramite.unidadMedidaDuracion object
# tramite.procedimiento object
# tramite.publicoObjetivo object
# tramite.requisitoNoParametrizado object
# tramite.estado object
# tramite.emisionFactura object
# tramite.formaCobro object
# Existe dict o array: [ True]
# tramite.horarios object
# Existe dict o array: [ True]
# tramite.depositoBancario object
# Existe dict o array: [ True]
# tramite.duracionMin float64
# tramite.duracionHora float64
# tramite.duracionDia float64
# costo.conceptoPago object
# costo.monto float64
# costo.moneda object
# requisito.comentario object
# requisito.nombre object
# requisito.entidad object
# Existe dict o array: [False  True]
# requisito.entidadActiva int64
# (5991, 52) Index(['id', 'estado', 'fechaActualización', 'nombre', 'slug', 'sigla',
#        'descripcion', 'marcoLegal', 'like', 'dislike', 'esPresencial',
#        'esVirtual', 'resultado', 'enlaces', 'ubicaciones', 'entidad.nombre',
#        'entidad.sigla', 'entidad.slug', 'entidad.logo', 'entidad.descripcion',
#        'entidad.urlSitioWeb', 'entidad.telefonoContacto',
#        'entidad.correoElectronicoContacto', 'palabrasClave', 'categorias',
#        'eventosVida', 'documentos', 'herramientas', 'modalidad.tipo',
#        'tramite.url', 'tramite.urlSeguimiento', 'tramite.tieneCosto',
#        'tramite.duracion', 'tramite.unidadMedidaDuracion',
#        'tramite.procedimiento', 'tramite.publicoObjetivo',
#        'tramite.requisitoNoParametrizado', 'tramite.estado',
#        'tramite.emisionFactura', 'tramite.formaCobro', 'tramite.horarios',
#        'tramite.depositoBancario', 'tramite.duracionMin',
#        'tramite.duracionHora', 'tramite.duracionDia', 'costo.conceptoPago',
#        'costo.monto', 'costo.moneda', 'requisito.comentario',
#        'requisito.nombre', 'requisito.entidad', 'requisito.entidadActiva'],
#       dtype='object')
#         id     estado fechaActualización  \
# 3351  1909  PUBLICADO         10/07/2025
# 5672  2595  PUBLICADO         15/09/2025
# 2140  1712  PUBLICADO         09/07/2025
#
#                                                  nombre  \
# 3351       Apertura de Módulos Tecnológicos Productivos
# 5672         LEGALIZACION DE 4º MEDIO Y/O 6º SECUNDARIA
# 2140  LICENCIA TURÍSTICA DE PRESTADORES DE SERVICIOS...
#
#                                                    slug     sigla  \
# 3351       apertura-de-modulos-tecnologicos-productivos   Regular
# 5672           legalizacion-de-4-medio-y-o-6-secundaria  DDE-CBBA
# 2140  licencia-turistica-de-prestadores-de-servicios...   SIRETUR
#
#                                             descripcion  \
# 3351       Apertura de Módulos Tecnológicos Productivos
# 5672  La legalización de 4º de Medio y/o 6º de Secun...
# 2140  Documento que representa la autorización de fu...
#
#                                              marcoLegal  like  dislike  \
# 3351  Resolución Administrativa Departamental DDE-BE...     0        0
# 5672  Ley Nº 070 de la Educación “Avelino Siñani – E...     0        0
# 2140  DECRETO SUPREMO N° 2609\nLey General de Turism...     0        0
#
#       esPresencial  esVirtual              resultado  \
# 3351             1          0  Registro y constancia
# 5672             1          0  Registro y constancia
# 2140             0          1  Registro y constancia
#
#                                                 enlaces  \
# 3351                                                 []
# 5672  [{"nombre": "LEGALIZACION DE 4º MEDIO Y/O 6º S...
# 2140  [{"nombre": "SISTEMA DE REGISTRO DE PRESTADORE...
#
#                                             ubicaciones  \
# 3351  [{"nombre": "DIRECCION DEPARTAMENTAL DEL BENI"...
# 5672  [{"nombre": "Oficina Direccion Departamental d...
# 2140  [{"nombre": "Viceministerio de Turismo", "tipo...
#
#                                          entidad.nombre entidad.sigla  \
# 3351                    Direc. Dptal. de Educación Beni       DDE-BEN
# 5672              Direc. Dptal. de Educación Cochabamba       DDE-CBB
# 2140  Ministerio de Desarrollo Productivo y Economía...      MIN-DPEP
#
#                                            entidad.slug  \
# 3351                      direc-dptal-de-educacion-beni
# 5672                direc-dptal-de-educacion-cochabamba
# 2140  ministerio-de-desarrollo-productivo-y-economia...
#
#                                            entidad.logo  \
# 3351  https://www.gob.bo/ws/api/archivos/7197f9e0-96...
# 5672  https://www.gob.bo/ws/api/archivos/9b73a6a1-ab...
# 2140  https://www.gob.bo/ws/api/archivos/6d0f464f-23...
#
#                                     entidad.descripcion  \
# 3351  La Dirección Departamental de Educación del Be...
# 5672  La Dirección Departamental de Educación de Coc...
# 2140  En la década de los años 80, la propuesta de l...
#
#                     entidad.urlSitioWeb entidad.telefonoContacto  \
# 3351        https://www.ddebeni.edu.bo/                346-22226
# 5672  https://www.ddecochabamba.gob.bo/        +(591)(4) 4228777
# 2140          https://produccion.gob.bo                800101585
#
#      entidad.correoElectronicoContacto  \
# 3351             ddebeni20221@gmai.com
# 5672       info@educacioncochabamba.bo
# 2140            info@produccion.gob.bo
#
#                                           palabrasClave categorias  \
# 3351                      apertura,modulos,tecnologicos  Educación
# 5672  LEGALIZACION DE 4º MEDIO Y/O 6º SECUNDARIA,dde...  Educación
# 2140                                                NaN   Empresas
#
#        eventosVida                                         documentos  \
# 3351  Mi educación  Resolución Administrativa - Apertura de Módulo...
# 5672           NaN         LEGALIZACION DE 4º MEDIO Y/O 6º SECUNDARIA
# 2140           NaN                                 Licencia Turística
#
#       herramientas modalidad.tipo                        tramite.url  \
# 3351           NaN     PRESENCIAL                               None
# 5672           NaN     PRESENCIAL                               None
# 2140           NaN        VIRTUAL  https://siretur.produccion.gob.bo
#
#      tramite.urlSeguimiento  tramite.tieneCosto tramite.duracion  \
# 3351                   None                   1               15
# 5672                   None                   1             None
# 2140                   None                   1             None
#
#      tramite.unidadMedidaDuracion  \
# 3351                       Día(s)
# 5672
# 2140
#
#                                   tramite.procedimiento  \
# 3351  <p><strong>Ventanilla 1 - Informaciones:</stro...
# 5672  <p>Primeramente, se debe comprar los certifica...
# 2140  <p>Para poder obtener la Licencia Turística Na...
#
#                     tramite.publicoObjetivo tramite.requisitoNoParametrizado  \
# 3351                 Comunidades Educativas                             None
# 5672     Estudiantes de unidades educativas                             None
# 2140  Todos (Cualquier persona solicitante)                             None
#
#      tramite.estado tramite.emisionFactura  \
# 3351         ACTIVO       No emite factura
# 5672         ACTIVO       No emite factura
# 2140         ACTIVO       No emite factura
#
#                                   tramite.formaCobro  \
# 3351  ["Pago en banco(presenta boleta de depósito)"]
# 5672              ["Pago en efectivo en ventanilla"]
# 2140  ["Pago en banco(presenta boleta de depósito)"]
#
#                                        tramite.horarios  \
# 3351  [{"dia": "Lunes", "continuo": true, "inicioMan...
# 5672  [{"dia": "Lunes", "continuo": true, "inicioMan...
# 2140  [{"dia": "Lunes", "continuo": true, "inicioMan...
#
#                                tramite.depositoBancario  tramite.duracionMin  \
# 3351  [{"nombre": "Banco Unión S.A.", "nroCuenta": "...              21600.0
# 5672                                                 []                  NaN
# 2140  [{"nombre": "Banco Unión S.A.", "nroCuenta": "...                  NaN
#
#       tramite.duracionHora  tramite.duracionDia  \
# 3351                 360.0                 15.0
# 5672                   NaN                  NaN
# 2140                   NaN                  NaN
#
#                                      costo.conceptoPago  costo.monto  \
# 3351                                      CTA. DDE-BENI         20.0
# 5672                               Certificado de Notas          3.0
# 2140  Licencia Turística Nacional Alojamiento B peri...        300.0
#
#      costo.moneda                               requisito.comentario  \
# 3351           Bs  Fotocopia de Cédula de Identidad vigente del u...
# 5672           Bs                               •\tFotocopia de C.I.
# 2140           Bs  Certificado de Registro de Testimonio de Const...
#
#                           requisito.nombre requisito.entidad  \
# 3351                   Cédula de Identidad              null
# 5672                   Cédula de Identidad              null
# 2140  Certificado de Registro de Documento              null
#
#       requisito.entidadActiva
# 3351                        1
# 5672                        1
# 2140                        1

# %%
df_desglosado.to_csv('../tramites_desglosados.csv', index=False)
