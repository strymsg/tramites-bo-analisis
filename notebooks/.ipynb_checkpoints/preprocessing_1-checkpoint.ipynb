# %% [markdown]
# # Preprocesamiento datos tramites.jsonl

# %%
import json
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

# Obteniendo data frame pandas para explorar
lines = []
with open(r'../tramites.jsonl') as f:
    lines = f.read().splitlines()

line_dicts = [json.loads(line) for line in lines]
df = pd.DataFrame(line_dicts)

df
# Out:
#         id     estado fechaActualización  \
# 0     1002  PUBLICADO         22/10/2025
# 1     1003  PUBLICADO         22/10/2025
# 2     1005  PUBLICADO         09/07/2025
# 3     1006  PUBLICADO         09/09/2025
# 4     1008  PUBLICADO         04/08/2025
# ...    ...        ...                ...
# 1364  2867  PUBLICADO         24/10/2025
# 1365  2868  PUBLICADO         24/10/2025
# 1366  2869  PUBLICADO         24/10/2025
# 1367  2870  PUBLICADO         24/10/2025
# 1368  2871  PUBLICADO         24/10/2025
#
#                                                  nombre  \
# 0                           SOLICITUD DE COPIAS SIMPLES
# 1       SOLICITUD DE LEGALIZACIONES Y/O AUTENTICACIONES
# 2                      Registro de Ciudadanos Digitales
# 3                        Registro en Ciudadanía Digital
# 4                       RESOLUCIÓN DE RECURSO DE ALZADA
# ...                                                 ...
# 1364  Actualización de Datos\nConvalidación de estud...
# 1365                              TOPOGRAFÍA Y GEODESIA
# 1366  Actualización de Datos\nSolicitud de Anteceden...
# 1367                                          GEOFÍSICA
# 1368                                     MEDIO AMBIENTE
#
#                                                    slug sigla  \
# 0                           solicitud-de-copias-simples  TCOP
# 1       solicitud-de-legalizaciones-y-o-autenticaciones  TLEG
# 2                      registro-de-ciudadanos-digitales  None
# 3                        registro-en-ciudadania-digital    CD
# 4                       resolucion-de-recurso-de-alzada  None
# ...                                                 ...   ...
# 1364  actualizacion-de-datos-convalidacion-de-estudi...  None
# 1365                              topografia-y-geodesia    TG
# 1366  actualizacion-de-datos-solicitud-de-antecedent...  None
# 1367                                          geofisica    AG
# 1368                                     medio-ambiente   UMA
#
#                                             descripcion  \
# 0     Se refiere a la solicitud de copias simples de...
# 1     Se refiere a la solicitud de Legalización de d...
# 2     Se brinda la colaboración personalizada a la c...
# 3     Ciudadanía Digital es la identidad digital de ...
# 4     Es el recurso que tiene el contribuyente o suj...
# ...                                                 ...
# 1364  El trámite consiste en presentar los certifica...
# 1365  El Área de Geodesia y Topografía brinda servic...
# 1366  El trámite consiste en presentar una carta de ...
# 1367  La geofísica aplicada es un área especializada...
# 1368  El Área de Medio Ambiente se encarga de la ela...
#
#                                              marcoLegal  \
# 0             Resolución Nº RD 01-096-24 de 24/10/2024.
# 1              Resolución Nº RD 01-096-24 de 24/10/2024
# 2     1. Ley N° 1173 - Ley de abreviación procesal p...
# 3                      Ley N° 1080 - Ciudadanía Digital
# 4     La Autoridad de Impugnación Tributaria (AIT), ...
# ...                                                 ...
# 1364                                 R.A. Departamental
# 1365  La Ley N° 535, en sus artículos 9, 10 y 71, es...
# 1366                                 R.A. Departamental
# 1367  La ley N°535 de 28 de mayo de 2014 – Ley de Mi...
# 1368  El Área de Medio Ambiente se encarga de la ela...
#
#                                           palabrasClave  like  dislike  \
# 0                                                  None     0        0
# 1                                                  None     0        0
# 2                                                  None     0        0
# 3     [digital, ciudadania, registro, pre registro, ...     0        0
# 4                                                  None     0        0
# ...                                                 ...   ...      ...
# 1364                                               None     0        0
# 1365                                               None     0        0
# 1366                                               None     0        0
# 1367                                               None     0        0
# 1368                                               None     0        0
#
#       esPresencial  esVirtual  \
# 0            False       True
# 1            False       True
# 2             True      False
# 3             True       True
# 4             True      False
# ...            ...        ...
# 1364          True      False
# 1365          True      False
# 1366          True      False
# 1367          True      False
# 1368          True      False
#
#                                                 entidad resultado  \
# 0     {'nombre': 'Aduana Nacional', 'sigla': 'AN', '...  Registro
# 1     {'nombre': 'Aduana Nacional', 'sigla': 'AN', '...  Registro
# 2     {'nombre': 'Tribunal Supremo de Justicia', 'si...
# 3     {'nombre': 'Agencia de Gobierno Electrónico y ...  Registro
# 4     {'nombre': 'Autoridad de Impugnación Tributari...
# ...                                                 ...       ...
# 1364  {'nombre': 'Direc. Dptal. de Educación Potosí'...  Registro
# 1365  {'nombre': 'Servicio Geológico Minero', 'sigla...
# 1366  {'nombre': 'Direc. Dptal. de Educación Potosí'...  Registro
# 1367  {'nombre': 'Servicio Geológico Minero', 'sigla...
# 1368  {'nombre': 'Servicio Geológico Minero', 'sigla...
#
#                                                 enlaces  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [{'nombre': 'Ciudadania Digital', 'url': 'http...
# 4     [{'nombre': 'Doctrina Tributaria', 'url': 'htt...
# ...                                                 ...
# 1364                                                 []
# 1365                                                 []
# 1366                                                 []
# 1367                                                 []
# 1368                                                 []
#
#                                              categorias     eventosVida  \
# 0          [{'nombre': 'Empresas', 'slug': 'empresas'}]              []
# 1          [{'nombre': 'Empresas', 'slug': 'empresas'}]              []
# 2          [{'nombre': 'Justicia', 'slug': 'justicia'}]              []
# 3     [{'nombre': 'Seguridad', 'slug': 'seguridad'},...        [Empleo]
# 4     [{'nombre': 'Justicia', 'slug': 'justicia'}, {...              []
# ...                                                 ...             ...
# 1364     [{'nombre': 'Educación', 'slug': 'educacion'}]  [Mi educación]
# 1365   [{'nombre': 'Transporte', 'slug': 'transporte'}]              []
# 1366     [{'nombre': 'Educación', 'slug': 'educacion'}]  [Mi educación]
# 1367   [{'nombre': 'Transporte', 'slug': 'transporte'}]              []
# 1368  [{'nombre': 'Medio ambiente', 'slug': 'medio-a...              []
#
#      herramientas                                         documentos  \
# 0              []  [COPIA SIMPLE DE DOCUMENTO DE IMPORTACIÓN O EX...
# 1              []  [LEGALIZACIONES Y/O AUTENTICACIONES DE DOCUMEN...
# 2              []                                                 []
# 3              []                                         [Registro]
# 4              []                                                 []
# ...           ...                                                ...
# 1364           []  [Resolución de convalidación y Diploma de Bach...
# 1365           []                                                 []
# 1366           []  [Certificado o informe de antecedentes adminis...
# 1367           []                                                 []
# 1368           []                                                 []
#
#                                             modalidades  \
# 0     [{'tipo': 'VIRTUAL', 'url': 'https://jarembae....
# 1     [{'tipo': 'VIRTUAL', 'url': 'https://jarembae....
# 2     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 3     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 4     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# ...                                                 ...
# 1364  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1365  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1366  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1367  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1368  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
#
#                                             ubicaciones
# 0                                                    []
# 1                                                    []
# 2     [{'nombre': 'Tribunal Supremo de Justicia', 't...
# 3     [{'nombre': 'AGETIC', 'tipo': 'Oficina central...
# 4     [{'nombre': 'Autoridad Regional de Impugnación...
# ...                                                 ...
# 1364  [{'nombre': 'Subdirección de Educación Regular...
# 1365  [{'nombre': 'OFICINA CENTRAL DE SERGEOMIN', 't...
# 1366  [{'nombre': 'Subdirección de Educación Regular...
# 1367  [{'nombre': 'OFICINA CENTRAL DE SERGEOMIN', 't...
# 1368  [{'nombre': 'OFICINA CENTRAL DE SERGEOMIN', 't...
#
# [1369 rows x 22 columns]

# %%
# columnas pendientes:
pendientes = ['palabrasClave', 'entidad', 'categorias', 'eventosVida',
              'herramientas', 'documentos',
             ]

new_df = df[[col for col in df.columns if col not in pendientes]].copy()
new_df.sample(3)
# Out:
#         id     estado fechaActualización  \
# 1096  2384  PUBLICADO         04/08/2025
# 1211  2509  PUBLICADO         29/08/2025
# 1217  2516  PUBLICADO         03/09/2025
#
#                                         nombre  \
# 1096  BASES IMPONIBLES - REGISTRO VALOR TABLAS
# 1211          Certificado de Despacho Aduanero
# 1217                 CERTIFICADO DE DOSIMETRIA
#
#                                         slug       sigla  \
# 1096  bases-imponibles-registro-valor-tablas        None
# 1211        certificado-de-despacho-aduanero     INSO-DA
# 1217               certificado-de-dosimetria  INSO-CEDRI
#
#                                             descripcion  \
# 1096  Es el registro de la Base Imponible del Impues...
# 1211  Certificado de Despacho Aduanero es un proceso...
# 1217  La valoración dosimétrica por radiación es un ...
#
#                                              marcoLegal  like  dislike  \
# 1096  Código Tributario, Ley Nacional Nº 2492 y sus ...     0        0
# 1211     Decreto Supremo  N°  26119/01\t Tuición y f...     0        0
# 1217      Decreto Ley  15629/78 – Código de Salud, y...     0        0
#
#       esPresencial  esVirtual              resultado  \
# 1096          True      False             Constancia
# 1211          True      False  Registro y constancia
# 1217          True      False  Registro y constancia
#
#                                                 enlaces  \
# 1096  [{'nombre': 'GAMLP', 'url': 'https://lapaz.bo/...
# 1211                                                 []
# 1217                                                 []
#
#                                             modalidades  \
# 1096  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1211  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1217  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
#
#                                             ubicaciones
# 1096  [{'nombre': 'Plataforma de Vehículos', 'tipo':...
# 1211  [{'nombre': 'INSO-La Paz', 'tipo': 'Oficina ce...
# 1217  [{'nombre': 'INSO-La Paz', 'tipo': 'Oficina ce...

# %% [markdown]
# ## Desglosando columnas
#
# ### entidad

# %%
# desglosando columnas de la entidad

new_rows = {
    'entidad.nombre': [],
    'entidad.sigla': [],
    'entidad.slug': [],
    'entidad.logo': [],
    'entidad.descripcion': [],
    'entidad.urlSitioWeb': [],
    'entidad.telefonoContacto': [],
    'entidad.correoElectronicoContacto': [],
}
for i in range(0, df.shape[0]):
    entidad_json = df.iloc[i]['entidad']
    #entidad_json = json.loads(df.iloc[i]['entidad'])
    new_rows['entidad.nombre'].append(entidad_json['nombre'])
    new_rows['entidad.sigla'].append(entidad_json['sigla'])
    new_rows['entidad.slug'].append(entidad_json['slug'])
    new_rows['entidad.logo'].append(entidad_json['logo'])
    new_rows['entidad.descripcion'].append(entidad_json['descripcion'])
    new_rows['entidad.urlSitioWeb'].append(entidad_json['urlSitioWeb'])
    new_rows['entidad.telefonoContacto'].append(entidad_json['telefonoContacto'])
    new_rows['entidad.correoElectronicoContacto'].append(entidad_json['correoElectronicoContacto'])

for k, v in new_rows.items():
    new_df[k] = pd.Series(v).values

new_df.sample(3)
# Out:
#         id     estado fechaActualización  \
# 669   1764  PUBLICADO         07/07/2025
# 747   1915  PUBLICADO         08/07/2025
# 1363  2863  PUBLICADO         24/10/2025
#
#                                                  nombre  \
# 669   FORMULARIO DE PERMISO DE VIAJE PARA MENORES DE...
# 747   Solicitud de Financiamiento para Adquisición d...
# 1363   Servicios del Centro Piscícola de Tiquina-La Paz
#
#                                                    slug sigla  \
# 669   formulario-de-permiso-de-viaje-para-menores-de...  None
# 747   solicitud-de-financiamiento-para-adquisicion-d...  None
# 1363   servicios-del-centro-piscicola-de-tiquina-la-paz  None
#
#                                             descripcion  \
# 669   OTORGACION DE FORMULARIO DE AUTORIZACIÓN DE VI...
# 747   Se financian proyectos para la adquisición de ...
# 1363  En el Centro Piscícola de Tiquina se desarroll...
#
#                                              marcoLegal  like  dislike  \
# 669   ART. 58 Y SIGUIENTES DEL D.S. N° 2377 \nREGLAM...     0        0
# 747   Ley N° 218\nLey N° 1178\nLey N° 2341\nDS N° 23318     0        0
# 1363  Decreto Supremo N°1922 de fecha 12 de marzo de...     0        0
#
#       esPresencial  esVirtual              resultado  \
# 669           True      False  Registro y constancia
# 747           True      False               Registro
# 1363          True      False
#
#                                                 enlaces  \
# 669   [{'nombre': 'FORMULARIO DE SOLICITUD', 'url': ...
# 747                                                  []
# 1363                                                 []
#
#                                             modalidades  \
# 669   [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 747   [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1363  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
#
#                                             ubicaciones  \
# 669   [{'nombre': 'OFICINA DEL SLIM  y DEFENSORIA DE...
# 747   [{'nombre': 'Fondo Nacional de Desarrollo Regi...
# 1363  [{'nombre': 'Centro Piscícola de Tiquina', 'ti...
#
#                                          entidad.nombre entidad.sigla  \
# 669                Gobierno Autónomo Municipal de Sucre           SUC
# 747               Fondo Nacional de Desarrollo Regional          FNDR
# 1363  Institución Pública Desconcentrada de Pesca y ...          PACU
#
#                                            entidad.slug  \
# 669                gobierno-autonomo-municipal-de-sucre
# 747               fondo-nacional-de-desarrollo-regional
# 1363  institucion-publica-desconcentrada-de-pesca-y-...
#
#                                            entidad.logo  \
# 669   https://www.gob.bo/ws/api/archivos/34c1052a-76...
# 747   https://www.gob.bo/ws/api/archivos/f815f712-75...
# 1363  https://www.gob.bo/ws/api/archivos/1cecd806-45...
#
#                                     entidad.descripcion  \
# 669   El Gobierno Autónomo Municipal de Sucre desemp...
# 747   El Fondo Nacional de Desarrollo Regional (FNDR...
# 1363  La Institución Pública Desconcentrada de Pesca...
#
#              entidad.urlSitioWeb entidad.telefonoContacto  \
# 669             https://sucre.bo                     None
# 747     https://www.fndr.gob.bo/                  2417575
# 1363  https://www.ipdpacu.gob.bo                 76463457
#
#      entidad.correoElectronicoContacto
# 669                      info@sucre.bo
# 747               contacto@fndr.gob.bo
# 1363  jose.choque@ruralytierras.gob.bo

# %% [markdown]
# ### esPresencial y esVirtual

# %%
rows = []
for i in range(0, df.shape[0]):
    palabras_clave = df.iloc[i]['palabrasClave']
    if isinstance(palabras_clave, list):
        rows.append(','.join(palabras_clave))
    else:
        rows.append('')

new_df['palabrasClave'] = pd.Series(rows).values
new_df.sample(5)['palabrasClave']
# Out:
# 217        Diploma,Certificado,Supletorio,Bachiller
# 824        casos,no,previstos,manual,procedimientos
# 820     modificacion,calificaciones,gestion,pasadas
# 254    Legalización,Supletorio,Técnico,Medio,Título
# 78
# Name: palabrasClave, dtype: object

# %% [markdown]
# ### categorias

# %%
rows = []
for i in range(0, df.shape[0]):
    categorias = df.iloc[i]['categorias']
    categorias_list = [categoria['nombre'] for categoria in categorias]
    if len(categorias_list) > 0:
        rows.append(','.join(categorias_list))
    else:
        # TODO: ver como normalizar valores vacios, NULL o cadena vacia?
        rows.append('')
new_df['categorias'] = rows
new_df.sample(5)['categorias']
# Out:
# 159                   Empresas
# 1322                Transporte
# 1146                 Impuestos
# 1027    Salud,Seguridad social
# 96                   Educación
# Name: categorias, dtype: object

# %% [markdown]
# ### eventosVida

# %%
def separar_lista_por_caracter(df, col, separator=','):
    rows = []
    for i in range(0, df.shape[0]):
        words = df.iloc[i][col]
        if isinstance(words, list):
            rows.append(separator.join(words))
        else:
            rows.append('')
    return rows

# %%
rows = separar_lista_por_caracter(df, 'eventosVida')
new_df['eventosVida'] = pd.Series(rows).values
new_df.sample(5)['eventosVida']
# Out:
# 441                  Jubilación
# 373
# 735     Maternidad / paternidad
# 710                Mi educación
# 1062
# Name: eventosVida, dtype: object

# %% [markdown]
# ### documentos

# %%
rows = separar_lista_por_caracter(df, 'documentos')
new_df['documentos'] = pd.Series(rows).values
new_df.sample(5)['documentos']
# Out:
# 690                            Resolución Administrativa.
# 1200    Reglamentos Internos Centros de Conciliación, ...
# 1100                           Emisión de certificaciones
# 734                     Fotocopia de Categoria Legalizada
# 315              Fotocopia legible de sus ultima licencia
# Name: documentos, dtype: object

# %%
new_df['enlaces'] = df['enlaces']

# %% [markdown]
# ### herramientas

# %%
rows = separar_lista_por_caracter(df, 'herramientas')
new_df['herramientas'] = pd.Series(rows).values
new_df.sample(5)['herramientas']
# Out:
# 1161
# 829
# 297
# 787
# 650
# Name: herramientas, dtype: object

# %%
new_df.dtypes
# Out:
# id                                   object
# estado                               object
# fechaActualización                   object
# nombre                               object
# slug                                 object
# sigla                                object
# descripcion                          object
# marcoLegal                           object
# like                                  int64
# dislike                               int64
# esPresencial                           bool
# esVirtual                              bool
# resultado                            object
# enlaces                              object
# modalidades                          object
# ubicaciones                          object
# entidad.nombre                       object
# entidad.sigla                        object
# entidad.slug                         object
# entidad.logo                         object
# entidad.descripcion                  object
# entidad.urlSitioWeb                  object
# entidad.telefonoContacto             object
# entidad.correoElectronicoContacto    object
# palabrasClave                        object
# categorias                           object
# eventosVida                          object
# documentos                           object
# herramientas                         object
# dtype: object

# %% [markdown]
# ### esPresencial

# %%
new_df['esPresencial'] = new_df['esPresencial'].apply(lambda value: 1 if value is True else 0)
new_df['esVirtual'] = new_df['esVirtual'].apply(lambda value: 1 if value is True else 0)
new_df.sample(5)[['id', 'nombre', 'esPresencial', 'esVirtual']]
# Out:
#         id                                             nombre  esPresencial  \
# 1184  2480  REQUISITOS LICENCIA DE FUNCIONAMIENTO RUBRO AC...             1
# 207   1240   AFILIACION DE BENEFICIARIO PAREJA EN UNION LIBRE             1
# 1314  2652                                      Venta Pasajes             1
# 680   1776            Signo distintivo - demanda de oposición             1
# 643   1735  Certificación de Inscripción, No Inscripción y...             1
#
#       esVirtual
# 1184          0
# 207           0
# 1314          0
# 680           0
# 643           0

# %% [markdown]
# ## Guardado como csv

# %%
new_df.sample(4)
# Out:
#         id     estado fechaActualización  \
# 458   1542  PUBLICADO         07/07/2025
# 1017  2298  PUBLICADO         01/08/2025
# 677   1773  PUBLICADO         10/07/2025
# 552   1639  PUBLICADO         30/07/2025
#
#                                               nombre  \
# 458                     DECLARACIÓN JURADA DE ORIGEN
# 1017                    Titulo en Provision Nacional
# 677   Registro de nombre comercial, rotulo comercial
# 552              AFILIACIÓN DERECHO HABIENTE SENASIR
#
#                                                slug      sigla  \
# 458                    declaracion-jurada-de-origen       DDJJ
# 1017                   titulo-en-provision-nacional  TPN-UABJB
# 677   registro-de-nombre-comercial-rotulo-comercial         SM
# 552             afiliacion-derecho-habiente-senasir       None
#
#                                             descripcion  \
# 458   Es un documento por medio del cual el exportad...
# 1017           Emisión del Titulo en Provisión Nacional
# 677   El registro de un nombre comercial y rótulo co...
# 552                 AFILIACIÓN DERECHO HABIENTE SENASIR
#
#                                              marcoLegal  like  dislike  \
# 458   Procedimiento S-SNV/SER/P/304 REVISIÓN DE DECL...     0        0
# 1017                               Normativa de la CEUB     0        0
# 677   Decisión 486 de la Comunidad Andina (Régimen C...     0        0
# 552                 AFILIACIÓN DERECHO HABIENTE SENASIR     0        0
#
#       esPresencial  esVirtual              resultado  \
# 458              0          1  Registro y constancia
# 1017             1          0             Constancia
# 677              1          0               Registro
# 552              1          0               Registro
#
#                                                 enlaces  \
# 458   [{'nombre': 'TAYPI', 'url': 'https://taypi.sen...
# 1017  [{'nombre': 'Tramites UABJB', 'url': 'https://...
# 677   [{'nombre': 'Signos Distintivos', 'url': 'http...
# 552                                                  []
#
#                                             modalidades  \
# 458   [{'tipo': 'VIRTUAL', 'url': 'https://taypi.sen...
# 1017  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 677   [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 552   [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
#
#                                             ubicaciones  \
# 458   [{'nombre': 'SENAVEX', 'tipo': 'Oficina centra...
# 1017  [{'nombre': 'Edificio Central Edificio 'Antoni...
# 677   [{'nombre': 'La Paz', 'tipo': 'Oficina central...
# 552   [{'nombre': 'CAJA NACIONAL DE SALUD', 'tipo': ...
#
#                                          entidad.nombre entidad.sigla  \
# 458   Servicio Nacional De Verificacion De Exportaci...       SENAVEX
# 1017       Universidad Autónoma del Beni José Ballivián           UAB
# 677          Servicio Nacional De Propiedad Intelectual        SENAPI
# 552                              Caja Nacional de Salud           CNS
#
#                                            entidad.slug  \
# 458   servicio-nacional-de-verificacion-de-exportaci...
# 1017       universidad-autonoma-del-beni-jose-ballivian
# 677          servicio-nacional-de-propiedad-intelectual
# 552                              caja-nacional-de-salud
#
#                                            entidad.logo  \
# 458   https://www.gob.bo/ws/api/archivos/a6857405-6c...
# 1017  https://www.gob.bo/ws/api/archivos/327c3932-eb...
# 677   https://www.gob.bo/ws/api/archivos/33cec5bc-5a...
# 552   https://www.gob.bo/ws/api/archivos/8c891d9b-56...
#
#                                     entidad.descripcion  \
# 458   El SENAVEX es una Institución Pública que admi...
# 1017                                Universidad Pública
# 677   El Servicio Nacional de Propiedad Intelectual ...
# 552   La Caja Nacional de Salud es una institución d...
#
#             entidad.urlSitioWeb entidad.telefonoContacto  \
# 458     https://senavex.gob.bo/                     None
# 1017      https://uabjb.edu.bo/                     None
# 677   https://www.senapi.gob.bo                 80102460
# 552      https://www.cns.gob.bo                  2112064
#
#      entidad.correoElectronicoContacto  \
# 458                               None
# 1017                              None
# 677           plataforma@senapi.gob.bo
# 552                               None
#
#                                           palabrasClave  \
# 458           senavex,declaracion jurada de origen,DDJJ
# 1017                              universidad,educacion
# 677   Registro,Signo Distintivo,Marca,Nombre comerci...
# 552
#
#                    categorias       eventosVida  \
# 458   Identificación,Empresas
# 1017                Educación
# 677                  Empresas
# 552                     Salud  Cuidado de salud
#
#                                 documentos herramientas
# 458           DECLARACIÓN JURADA DE ORIGEN
# 1017  TITULO EN PROVISION NACIONAL - UABJB
# 677     Titulo y Resolución Administrativa
# 552    AFILIACIÓN DERECHO HABIENTE SENASIR

# %%
print(df.shape)
print(new_df.shape)
# Out:
# (1369, 22)
# (1369, 29)

# %%
new_df.to_csv('../tramites.csv', index=False)
