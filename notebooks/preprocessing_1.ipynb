# %% [markdown]
# # Preprocesamiento datos tramites.jsonl

# %%
import json
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

# Obteniendo data frame pandas para explorar
lines = []
with open(r'../tramites.jsonl') as f:
    lines = f.read().splitlines()

line_dicts = [json.loads(line) for line in lines]
df = pd.DataFrame(line_dicts)

df
# Out:
#         id     estado fechaActualización  \
# 0     1005  PUBLICADO         09/07/2025
# 1     1006  PUBLICADO         09/09/2025
# 2     1008  PUBLICADO         04/08/2025
# 3     1009  PUBLICADO         04/08/2025
# 4     1010  PUBLICADO         09/07/2025
# ...    ...        ...                ...
# 1343  2793  PUBLICADO         02/10/2025
# 1344  2819  PUBLICADO         03/10/2025
# 1345  2825  PUBLICADO         03/10/2025
# 1346  2827  PUBLICADO         03/10/2025
# 1347  2843  PUBLICADO         08/10/2025
#
#                                                  nombre  \
# 0                      Registro de Ciudadanos Digitales
# 1                        Registro en Ciudadanía Digital
# 2                       RESOLUCIÓN DE RECURSO DE ALZADA
# 3                      RESOLUCIÓN DE RECURSO JERÁRQUICO
# 4                                  REGISTRO PROVISIONAL
# ...                                                 ...
# 1343  Servicio de denuncia de vulneración de derecho...
# 1344  DETECCION Y CUANTIFICACION DE ORGANISMOS GENÉT...
# 1345  Desinfección ambiental por termoniebla empresa...
# 1346                        VENTA DE PALMITO 800 GRAMOS
# 1347                         Transporte Aereo  de Carga
#
#                                                    slug    sigla  \
# 0                      registro-de-ciudadanos-digitales     None
# 1                        registro-en-ciudadania-digital       CD
# 2                       resolucion-de-recurso-de-alzada     None
# 3                      resolucion-de-recurso-jerarquico     None
# 4                                  registro-provisional     None
# ...                                                 ...      ...
# 1343  servicio-de-denuncia-de-vulneracion-de-derecho...      SSP
# 1344  deteccion-y-cuantificacion-de-organismos-genet...      OGM
# 1345  desinfeccion-ambiental-por-termoniebla-empresa...  PBS-007
# 1346                        venta-de-palmito-800-gramos    INBOL
# 1347                          transporte-aereo-de-carga     None
#
#                                             descripcion  \
# 0     Se brinda la colaboración personalizada a la c...
# 1     Ciudadanía Digital es la identidad digital de ...
# 2     Es el recurso que tiene el contribuyente o suj...
# 3     Es la impugnación que se presenta en contra de...
# 4     Modalidad de inscripción que tiene por objeto ...
# ...                                                 ...
# 1343  Servicio de denuncia de vulneración de derecho...
# 1344  DETECCION Y CUANTIFICACION DE ORGANISMOS GENÉT...
# 1345  Desinfección de ambientes utilizando un produc...
# 1346            Venta de palmito en lata de 800 gramos.
# 1347  Realizar servicios de Transporte Aereo de carg...
#
#                                              marcoLegal  \
# 0     1. Ley N° 1173 - Ley de abreviación procesal p...
# 1                      Ley N° 1080 - Ciudadanía Digital
# 2     La Autoridad de Impugnación Tributaria (AIT), ...
# 3     La Autoridad de Impugnación Tributaria (AIT), ...
# 4                                           D.S. 26256
# ...                                                 ...
# 1343  Reglamento del Sistema de Servicio al Pueblo R...
# 1344                        Resolución Ministerial 0533
# 1345    Resolución Administrativa INLASA/UJ/N° 25/2022
# 1346                           Decreto Supremo N° 29727
# 1347  Decreto Supremo No. 15091 del 7 de noviembre d...
#
#                                           palabrasClave  like  dislike  \
# 0                                                  None     0        0
# 1     [digital, ciudadania, registro, pre registro, ...     0        0
# 2                                                  None     0        0
# 3                                                  None     0        0
# 4                                                  None     0        0
# ...                                                 ...   ...      ...
# 1343                             [denuncia, defensoria]     0        0
# 1344                                               None     0        0
# 1345                                               None     0        0
# 1346                                   [venta, palmito]     0        0
# 1347  [Transporte de carga, transporte, aerea, logis...     0        0
#
#       esPresencial  esVirtual  \
# 0             True      False
# 1             True       True
# 2             True      False
# 3             True      False
# 4             True      False
# ...            ...        ...
# 1343          True      False
# 1344          True      False
# 1345          True      False
# 1346          True      False
# 1347          True      False
#
#                                                 entidad resultado  \
# 0     {'nombre': 'Tribunal Supremo de Justicia', 'si...
# 1     {'nombre': 'Agencia de Gobierno Electrónico y ...  Registro
# 2     {'nombre': 'Autoridad de Impugnación Tributari...
# 3     {'nombre': 'Autoridad de Impugnación Tributari...
# 4     {'nombre': 'Registro Internacional Boliviano D...
# ...                                                 ...       ...
# 1343  {'nombre': 'Defensoria del Pueblo', 'sigla': '...
# 1344  {'nombre': 'Instituto Nacional De Laboratorio ...
# 1345  {'nombre': 'Instituto Nacional De Laboratorio ...
# 1346  {'nombre': 'Insumos Bolivia', 'sigla': 'IN - B...
# 1347  {'nombre': 'Transportes Aéreos Bolivianos', 's...
#
#                                                 enlaces  \
# 0                                                    []
# 1     [{'nombre': 'Ciudadania Digital', 'url': 'http...
# 2     [{'nombre': 'Doctrina Tributaria', 'url': 'htt...
# 3     [{'nombre': 'Registro Público', 'url': 'https:...
# 4     [{'nombre': 'información', 'url': 'https://www...
# ...                                                 ...
# 1343                                                 []
# 1344                                                 []
# 1345                                                 []
# 1346                                                 []
# 1347                                                 []
#
#                                              categorias         eventosVida  \
# 0          [{'nombre': 'Justicia', 'slug': 'justicia'}]                  []
# 1     [{'nombre': 'Seguridad', 'slug': 'seguridad'},...            [Empleo]
# 2     [{'nombre': 'Justicia', 'slug': 'justicia'}, {...                  []
# 3     [{'nombre': 'Justicia', 'slug': 'justicia'}, {...                  []
# 4          [{'nombre': 'Empresas', 'slug': 'empresas'}]                  []
# ...                                                 ...                 ...
# 1343       [{'nombre': 'Justicia', 'slug': 'justicia'}]                  []
# 1344  [{'nombre': 'Medio ambiente', 'slug': 'medio-a...  [Cuidado de salud]
# 1345             [{'nombre': 'Salud', 'slug': 'salud'}]                  []
# 1346       [{'nombre': 'Empresas', 'slug': 'empresas'}]                  []
# 1347   [{'nombre': 'Transporte', 'slug': 'transporte'}]                  []
#
#      herramientas  documentos  \
# 0              []          []
# 1              []  [Registro]
# 2              []          []
# 3              []          []
# 4              []          []
# ...           ...         ...
# 1343           []          []
# 1344           []          []
# 1345           []          []
# 1346           []          []
# 1347           []          []
#
#                                             modalidades  \
# 0     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 2     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 3     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 4     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# ...                                                 ...
# 1343  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1344  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1345  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1346  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1347  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
#
#                                             ubicaciones
# 0     [{'nombre': 'Tribunal Supremo de Justicia', 't...
# 1     [{'nombre': 'AGETIC', 'tipo': 'Oficina central...
# 2     [{'nombre': 'Autoridad Regional de Impugnación...
# 3     [{'nombre': 'AUTORIDAD GENERAL DE IMPUGNACIÓN ...
# 4     [{'nombre': 'REGISTRO INTERNACIONAL BOLIVIANO ...
# ...                                                 ...
# 1343  [{'nombre': 'Oficina Nacional', 'tipo': 'Ofici...
# 1344  [{'nombre': 'INLASA', 'tipo': 'Oficina central...
# 1345  [{'nombre': 'INLASA', 'tipo': 'Oficina central...
# 1346  [{'nombre': 'OFICINA CENTRAL', 'tipo': 'Oficin...
# 1347  [{'nombre': 'TRANSPORTES AÉREOS BOLIVIANOS GER...
#
# [1348 rows x 22 columns]

# %%
# columnas pendientes:
pendientes = ['palabrasClave', 'entidad', 'categorias', 'eventosVida',
              'herramientas', 'documentos',
             ]

new_df = df[[col for col in df.columns if col not in pendientes]].copy()
new_df.sample(3)
# Out:
#         id     estado fechaActualización  \
# 681   1778  PUBLICADO         14/07/2025
# 1065  2356  PUBLICADO         18/08/2025
# 191   1225  PUBLICADO         10/07/2025
#
#                                                  nombre  \
# 681               Signo Distintivo - demanda de nulidad
# 1065  REGISTRO DE AUTORIZACIONES DE ÓRDENES PARA ATE...
# 191          Trámite 56 - Solicitud de Copias Digitales
#
#                                                    slug       sigla  \
# 681                 signo-distintivo-demanda-de-nulidad        None
# 1065  registro-de-autorizaciones-de-ordenes-para-ate...        None
# 191            tramite-56-solicitud-de-copias-digitales  Trámite 56
#
#                                             descripcion  \
# 681   La demanda de nulidad de un signo distintivo s...
# 1065  Este tramite consiste  en la recepción de órde...
# 191   Solicitud para la obtención de copias digitale...
#
#                                              marcoLegal  like  dislike  \
# 681   Decisión 486 de la Comunidad Andina (Régimen C...     0        0
# 1065                                               S/ML     0        0
# 191   Constitución Política del Estado Plurinacional...     0        0
#
#       esPresencial  esVirtual              resultado  \
# 681           True      False               Registro
# 1065          True      False  Registro y constancia
# 191          False       True               Registro
#
#                                                 enlaces  \
# 681   [{'nombre': 'Oposición al Signo Distintivo', '...
# 1065                                                 []
# 191   [{'nombre': 'Guía de Trámites', 'url': 'https:...
#
#                                             modalidades  \
# 681   [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1065  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 191   [{'tipo': 'VIRTUAL', 'url': 'https://tramites....
#
#                                             ubicaciones
# 681   [{'nombre': 'La Paz', 'tipo': 'Oficina central...
# 1065  [{'nombre': 'Seguro Social Universitario La Pa...
# 191   [{'nombre': 'Oficina Nacional', 'tipo': 'Ofici...

# %% [markdown]
# ## Desglosando columnas
#
# ### entidad

# %%
# desglosando columnas de la entidad

new_rows = {
    'entidad.nombre': [],
    'entidad.sigla': [],
    'entidad.slug': [],
    'entidad.logo': [],
    'entidad.descripcion': [],
    'entidad.urlSitioWeb': [],
    'entidad.telefonoContacto': [],
    'entidad.correoElectronicoContacto': [],
}
for i in range(0, df.shape[0]):
    entidad_json = df.iloc[i]['entidad']
    #entidad_json = json.loads(df.iloc[i]['entidad'])
    new_rows['entidad.nombre'].append(entidad_json['nombre'])
    new_rows['entidad.sigla'].append(entidad_json['sigla'])
    new_rows['entidad.slug'].append(entidad_json['slug'])
    new_rows['entidad.logo'].append(entidad_json['logo'])
    new_rows['entidad.descripcion'].append(entidad_json['descripcion'])
    new_rows['entidad.urlSitioWeb'].append(entidad_json['urlSitioWeb'])
    new_rows['entidad.telefonoContacto'].append(entidad_json['telefonoContacto'])
    new_rows['entidad.correoElectronicoContacto'].append(entidad_json['correoElectronicoContacto'])

for k, v in new_rows.items():
    new_df[k] = pd.Series(v).values

new_df.sample(3)
# Out:
#         id     estado fechaActualización  \
# 1310  2655  PUBLICADO         07/10/2025
# 212   1246  PUBLICADO         09/07/2025
# 193   1227  PUBLICADO         10/07/2025
#
#                                                  nombre  \
# 1310  Solicitud de Otorgación de Licencia de Servici...
# 212   Legalización de habilitación de examen de grad...
# 193   Trámite 58 - Solicitud de Información Estadística
#
#                                                    slug       sigla  \
# 1310  solicitud-de-otorgacion-de-licencia-de-servici...        None
# 212   legalizacion-de-habilitacion-de-examen-de-grad...        None
# 193     tramite-58-solicitud-de-informacion-estadistica  Trámite 58
#
#                                             descripcion  \
# 1310  Tramitar solicitudes de Otorgamiento de Licenc...
# 212   Establecer Procedimiento para procesar la Lega...
# 193   Solicitud que presentan usuarios que son perso...
#
#                                              marcoLegal  like  dislike  \
# 1310  Ley General de Telecomunicaciones y TIC N°164 ...     0        0
# 212   "R.M. N° 928/2015 R.M. N° 710/2016 R.M. N° 082...     0        0
# 193   D.S. No. 4596 de 06 de octubre de 2021, creaci...     0        0
#
#       esPresencial  esVirtual              resultado  \
# 1310          True      False  Registro y constancia
# 212           True       True  Registro y constancia
# 193          False       True               Registro
#
#                                                 enlaces  \
# 1310  [{'nombre': 'Solicitud de Otorgación de Licenc...
# 212   [{'nombre': 'ÁREA DE LEGALIZACIONES - UNIDAD D...
# 193   [{'nombre': 'Guía de Trámites', 'url': 'https:...
#
#                                             modalidades  \
# 1310  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 212   [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 193   [{'tipo': 'VIRTUAL', 'url': 'https://tramites....
#
#                                             ubicaciones  \
# 1310  [{'nombre': 'ATT', 'tipo': 'Oficina central', ...
# 212   [{'nombre': 'Ministerio de Educación', 'tipo':...
# 193   [{'nombre': 'Oficina Nacional', 'tipo': 'Ofici...
#
#                                          entidad.nombre entidad.sigla  \
# 1310  Autoridad de Regulación y Fiscalización de Tel...           ATT
# 212                             Ministerio de Educación       MIN-EDU
# 193      Servicio Plurinacional de Registro de Comercio        SEPREC
#
#                                            entidad.slug  \
# 1310  autoridad-de-regulacion-y-fiscalizacion-de-tel...
# 212                             ministerio-de-educacion
# 193      servicio-plurinacional-de-registro-de-comercio
#
#                                            entidad.logo  \
# 1310  https://www.gob.bo/ws/api/archivos/3bcfc1b3-34...
# 212   https://www.gob.bo/ws/api/archivos/78598177-59...
# 193   https://www.gob.bo/ws/api/archivos/dec5dd8d-a6...
#
#                                     entidad.descripcion  \
# 1310  Autoridad encargada de Regular y Fiscalizar la...
# 212                             MINISTERIO DE EDUCACIÓN
# 193   El Servicio Plurinacional de Registro de Comer...
#
#              entidad.urlSitioWeb entidad.telefonoContacto  \
# 1310     https://www.att.gob.bo/                  2615000
# 212   https://www.minedu.gob.bo/        (591-2)  2442144
# 193    https://www.seprec.gob.bo                800102992
#
#      entidad.correoElectronicoContacto
# 1310              webmaster@att.gob.bo
# 212          informacion@minedu.gob.bo
# 193                               None

# %% [markdown]
# ### esPresencial y esVirtual

# %%
rows = []
for i in range(0, df.shape[0]):
    palabras_clave = df.iloc[i]['palabrasClave']
    if isinstance(palabras_clave, list):
        rows.append(','.join(palabras_clave))
    else:
        rows.append('')

new_df['palabrasClave'] = pd.Series(rows).values
new_df.sample(5)['palabrasClave']
# Out:
# 248
# 497
# 1109    transferencia especial,Aceptación de Herencia,...
# 1186
# 287          Notas,Equivalencia,Certificación,Certificado
# Name: palabrasClave, dtype: object

# %% [markdown]
# ### categorias

# %%
rows = []
for i in range(0, df.shape[0]):
    categorias = df.iloc[i]['categorias']
    categorias_list = [categoria['nombre'] for categoria in categorias]
    if len(categorias_list) > 0:
        rows.append(','.join(categorias_list))
    else:
        # TODO: ver como normalizar valores vacios, NULL o cadena vacia?
        rows.append('')
new_df['categorias'] = rows
new_df.sample(5)['categorias']
# Out:
# 186                         Educación
# 281                         Educación
# 118                         Educación
# 1069           Salud,Seguridad social
# 1051    Impuestos,Transporte,Empresas
# Name: categorias, dtype: object

# %% [markdown]
# ### eventosVida

# %%
def separar_lista_por_caracter(df, col, separator=','):
    rows = []
    for i in range(0, df.shape[0]):
        words = df.iloc[i][col]
        if isinstance(words, list):
            rows.append(separator.join(words))
        else:
            rows.append('')
    return rows

# %%
rows = separar_lista_por_caracter(df, 'eventosVida')
new_df['eventosVida'] = pd.Series(rows).values
new_df.sample(5)['eventosVida']
# Out:
# 110     Mi educación
# 1242
# 673
# 443     Mi educación
# 313     Mi educación
# Name: eventosVida, dtype: object

# %% [markdown]
# ### documentos

# %%
rows = separar_lista_por_caracter(df, 'documentos')
new_df['documentos'] = pd.Series(rows).values
new_df.sample(5)['documentos']
# Out:
# 351    SOLICITUD DE INFORMACIÓN DE OPERACIONES DE MER...
# 434    Resolución Administrativa de Rectificación de ...
# 589                               Registro del Asegurado
# 757
# 599                               Registro del Asegurado
# Name: documentos, dtype: object

# %%
new_df['enlaces'] = df['enlaces']

# %% [markdown]
# ### herramientas

# %%
rows = separar_lista_por_caracter(df, 'herramientas')
new_df['herramientas'] = pd.Series(rows).values
new_df.sample(5)['herramientas']
# Out:
# 1318
# 209
# 1123
# 42
# 1210
# Name: herramientas, dtype: object

# %%
new_df.dtypes
# Out:
# id                                   object
# estado                               object
# fechaActualización                   object
# nombre                               object
# slug                                 object
# sigla                                object
# descripcion                          object
# marcoLegal                           object
# like                                  int64
# dislike                               int64
# esPresencial                           bool
# esVirtual                              bool
# resultado                            object
# enlaces                              object
# modalidades                          object
# ubicaciones                          object
# entidad.nombre                       object
# entidad.sigla                        object
# entidad.slug                         object
# entidad.logo                         object
# entidad.descripcion                  object
# entidad.urlSitioWeb                  object
# entidad.telefonoContacto             object
# entidad.correoElectronicoContacto    object
# palabrasClave                        object
# categorias                           object
# eventosVida                          object
# documentos                           object
# herramientas                         object
# dtype: object

# %% [markdown]
# ### esPresencial

# %%
new_df['esPresencial'] = new_df['esPresencial'].apply(lambda value: 1 if value is True else 0)
new_df['esVirtual'] = new_df['esVirtual'].apply(lambda value: 1 if value is True else 0)
new_df.sample(5)[['id', 'nombre', 'esPresencial', 'esVirtual']]
# Out:
#         id                                             nombre  esPresencial  \
# 519   1605  Préstamo a Largo Plazo con Garantía  Personal ...             1
# 676   1773     Registro de nombre comercial, rotulo comercial             1
# 873   2103  Nivelación por rezago escolar o desventaja social             1
# 1239  2543  62. MEDICAMENTO IMPORTADO (MARCA, GENéRICO, HO...             0
# 143   1176  Trámite 20 - Registro de Otorgamiento de Poder...             1
#
#       esVirtual
# 519           0
# 676           0
# 873           0
# 1239          1
# 143           1

# %% [markdown]
# ## Guardado como csv

# %%
new_df.sample(4)
# Out:
#         id     estado fechaActualización  \
# 469   1554  PUBLICADO         08/07/2025
# 1179  2478  PUBLICADO         13/08/2025
# 1333  2768  PUBLICADO         26/09/2025
# 612   1703  PUBLICADO         09/07/2025
#
#                                                  nombre  \
# 469   SOLICITUD DE ENVÍO DE CERTIFICADOS (FORMATO FÍ...
# 1179                              Certificado Catastral
# 1333                       Servicios de Embellecimiento
# 612                  Solicitud de Pensión de Jubilación
#
#                                                    slug sigla  \
# 469   solicitud-de-envio-de-certificados-formato-fis...  None
# 1179                              certificado-catastral  None
# 1333                       servicios-de-embellecimiento  None
# 612                  solicitud-de-pension-de-jubilacion  None
#
#                                             descripcion  \
# 469   Los certificados físicos emitidos en la EGPP p...
# 1179  El Primer Certificado Catastral es el document...
# 1333  Producción de estampados con máquinas modernas...
# 612   Consiste en el pago de una Pensión Mensual de ...
#
#                                              marcoLegal  like  dislike  \
# 469                  Resolución Administrativa 054/2018     0        0
# 1179  Marco Legal del Certificado Catastral en La Pa...     0        0
# 1333  MANUAL DE PROCESOS Y PROCEDIMIENTOS DE FLUJO D...     0        0
# 612   Ley 065 de Pensiones del 10 de diciembre de 20...     0        0
#
#       esPresencial  esVirtual              resultado  \
# 469              0          1               Registro
# 1179             1          0             Constancia
# 1333             1          0
# 612              1          0  Registro y constancia
#
#                                                 enlaces  \
# 469                                                  []
# 1179  [{'nombre': 'Requisitos Certificado Catastral ...
# 1333                                                 []
# 612   [{'nombre': 'GESTORA', 'url': 'https://www.ges...
#
#                                             modalidades  \
# 469   [{'tipo': 'VIRTUAL', 'url': 'https://egpp.gob....
# 1179  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1333  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 612   [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
#
#                                             ubicaciones  \
# 469   [{'nombre': 'Oficina Central', 'tipo': 'Oficin...
# 1179  [{'nombre': 'INRA NACIONAL', 'tipo': 'Oficina ...
# 1333  [{'nombre': 'Central SENATEX', 'tipo': 'Oficin...
# 612   [{'nombre': 'Oficina Central', 'tipo': 'Oficin...
#
#                                          entidad.nombre entidad.sigla  \
# 469            Escuela de Gestión Pública Plurinacional          EGPP
# 1179              Instituto Nacional de Reforma Agraria          INRA
# 1333                           Servicio Nacional Textil       SENATEX
# 612   Gestora Pública de la Seguridad Social de Larg...       GESTORA
#
#                                            entidad.slug  \
# 469            escuela-de-gestion-publica-plurinacional
# 1179              instituto-nacional-de-reforma-agraria
# 1333                           servicio-nacional-textil
# 612   gestora-publica-de-la-seguridad-social-de-larg...
#
#                                            entidad.logo  \
# 469   https://www.gob.bo/ws/api/archivos/13a5029a-4f...
# 1179  https://www.gob.bo/ws/api/archivos/a3dc6fe6-a7...
# 1333  https://www.gob.bo/ws/api/archivos/6ea30c1c-1c...
# 612   https://www.gob.bo/ws/api/archivos/a1f8c52b-2d...
#
#                                     entidad.descripcion  \
# 469   La Escuela de Gestión Pública Plurinacional es...
# 1179  El Instituto Nacional de Reforma Agraria INRA ...
# 1333  El Servicio Nacional Textil - Senatex, es una ...
# 612   La Gestora Pública de la Seguridad Social de L...
#
#            entidad.urlSitioWeb entidad.telefonoContacto  \
# 469       https://egpp.gob.bo/                  2200353
# 1179  https://www.inra.gob.bo/                2-2408757
# 1333   https://senatex.gob.bo/                 2-219595
# 612     https://www.gestora.bo                800101610
#
#      entidad.correoElectronicoContacto  \
# 469                               None
# 1179         inra.nacional@inra.gob.bo
# 1333            senatex@senatex.gob.bo
# 612                contacto@gestora.bo
#
#                                           palabrasClave        categorias  \
# 469                            EGPP,courier,certificado         Educación
# 1179                         Certificado,Catastral,INRA    Medio ambiente
# 1333  estampado,bordado,confeccion,senatex,dtf,servi...          Empresas
# 612                                                      Seguridad social
#
#      eventosVida                               documentos herramientas
# 469               Certificado de aprobación/participación
# 1179                         CERTIFICADO CATASTRAL - INRA
# 1333
# 612   Jubilación                        Registro de Datos

# %%
new_df.to_csv('../tramites.csv', index=False)
