# %% [markdown]
# # Preprocesamiento datos tramites.jsonl

# %%
import json
import pandas as pd

# Obteniendo data frame pandas para explorar
lines = []
with open(r'../tramites.jsonl') as f:
    lines = f.read().splitlines()

line_dicts = [json.loads(line) for line in lines]
df = pd.DataFrame(line_dicts)

df
# Out:
#         id     estado fechaActualización  \
# 0     1005  PUBLICADO         09/07/2025
# 1     1006  PUBLICADO         09/09/2025
# 2     1008  PUBLICADO         04/08/2025
# 3     1009  PUBLICADO         04/08/2025
# 4     1010  PUBLICADO         09/07/2025
# ...    ...        ...                ...
# 1395  2743  PUBLICADO         23/09/2025
# 1396  2744  PUBLICADO         23/09/2025
# 1397  2745  PUBLICADO         23/09/2025
# 1398  2746  PUBLICADO         23/09/2025
# 1399  2748  PUBLICADO         23/09/2025
#
#                                                  nombre  \
# 0                      Registro de Ciudadanos Digitales
# 1                        Registro en Ciudadanía Digital
# 2                       RESOLUCIÓN DE RECURSO DE ALZADA
# 3                      RESOLUCIÓN DE RECURSO JERÁRQUICO
# 4                                  REGISTRO PROVISIONAL
# ...                                                 ...
# 1395                 Vitamina D por Quimioluminiscencia
# 1396                 Prolactina por Quimioluminiscencia
# 1397               Testosterona por Quimioluminiscencia
# 1398  Verificación de la Precisión de Equipos Hemogl...
# 1399  Evaluación de Desempeño de Reactivos para Bioq...
#
#                                                    slug    sigla  \
# 0                      registro-de-ciudadanos-digitales     None
# 1                        registro-en-ciudadania-digital       CD
# 2                       resolucion-de-recurso-de-alzada     None
# 3                      resolucion-de-recurso-jerarquico     None
# 4                                  registro-provisional     None
# ...                                                 ...      ...
# 1395                 vitamina-d-por-quimioluminiscencia  LAC-072
# 1396                 prolactina-por-quimioluminiscencia  LAC-074
# 1397               testosterona-por-quimioluminiscencia  LAC-075
# 1398  verificacion-de-la-precision-de-equipos-hemogl...  LAC-059
# 1399  evaluacion-de-desempeno-de-reactivos-para-bioq...  LAC-060
#
#                                             descripcion  \
# 0     Se brinda la colaboración personalizada a la c...
# 1     Ciudadanía Digital es la identidad digital de ...
# 2     Es el recurso que tiene el contribuyente o suj...
# 3     Es la impugnación que se presenta en contra de...
# 4     Modalidad de inscripción que tiene por objeto ...
# ...                                                 ...
# 1395                              Prueba de Laboratorio
# 1396                              Prueba de Laboratorio
# 1397                              Prueba de Laboratorio
# 1398              Servicio para Verificación de equipos
# 1399  Evaluación de Desempeño de Reactivos para Bioq...
#
#                                              marcoLegal  \
# 0     1. Ley N° 1173 - Ley de abreviación procesal p...
# 1                      Ley N° 1080 - Ciudadanía Digital
# 2     La Autoridad de Impugnación Tributaria (AIT), ...
# 3     La Autoridad de Impugnación Tributaria (AIT), ...
# 4                                           D.S. 26256
# ...                                                 ...
# 1395      Resolución Administrativa INLASA/UJ N°01/2025
# 1396      Resolución Administrativa INLASA/UJ N°01/2025
# 1397      Resolución Administrativa INLASA/UJ N°01/2025
# 1398      Resolución Administrativa INLASA/UJ N°01/2025
# 1399  Resolución Administrativa INLASA/UJ N°01/2025\n\n
#
#                                           palabrasClave  like  dislike  \
# 0                                                  None     0        0
# 1     [digital, ciudadania, registro, pre registro, ...     0        0
# 2                                                  None     0        0
# 3                                                  None     0        0
# 4                                                  None     0        0
# ...                                                 ...   ...      ...
# 1395   [Vitamina D, Vitamina D por Quimioluminiscencia]     0        0
# 1396   [Prolactina, Prolactina por Quimioluminiscencia]     0        0
# 1397  [Testosterona, Testosterona por Quimioluminisc...     0        0
# 1398                                          [equipos]     0        0
# 1399                             [reactivos, desempeño]     0        0
#
#       esPresencial  esVirtual  \
# 0             True      False
# 1             True       True
# 2             True      False
# 3             True      False
# 4             True      False
# ...            ...        ...
# 1395          True      False
# 1396          True      False
# 1397          True      False
# 1398          True      False
# 1399          True      False
#
#                                                 entidad resultado  \
# 0     {'nombre': 'Tribunal Supremo de Justicia', 'si...
# 1     {'nombre': 'Agencia de Gobierno Electrónico y ...  Registro
# 2     {'nombre': 'Autoridad de Impugnación Tributari...
# 3     {'nombre': 'Autoridad de Impugnación Tributari...
# 4     {'nombre': 'Registro Internacional Boliviano D...
# ...                                                 ...       ...
# 1395  {'nombre': 'Instituto Nacional De Laboratorio ...
# 1396  {'nombre': 'Instituto Nacional De Laboratorio ...
# 1397  {'nombre': 'Instituto Nacional De Laboratorio ...
# 1398  {'nombre': 'Instituto Nacional De Laboratorio ...
# 1399  {'nombre': 'Instituto Nacional De Laboratorio ...
#
#                                                 enlaces  \
# 0                                                    []
# 1     [{'nombre': 'Ciudadania Digital', 'url': 'http...
# 2     [{'nombre': 'Doctrina Tributaria', 'url': 'htt...
# 3     [{'nombre': 'Registro Público', 'url': 'https:...
# 4     [{'nombre': 'información', 'url': 'https://www...
# ...                                                 ...
# 1395                                                 []
# 1396                                                 []
# 1397                                                 []
# 1398                                                 []
# 1399                                                 []
#
#                                              categorias         eventosVida  \
# 0          [{'nombre': 'Justicia', 'slug': 'justicia'}]                  []
# 1     [{'nombre': 'Seguridad', 'slug': 'seguridad'},...            [Empleo]
# 2     [{'nombre': 'Justicia', 'slug': 'justicia'}, {...                  []
# 3     [{'nombre': 'Justicia', 'slug': 'justicia'}, {...                  []
# 4          [{'nombre': 'Empresas', 'slug': 'empresas'}]                  []
# ...                                                 ...                 ...
# 1395             [{'nombre': 'Salud', 'slug': 'salud'}]  [Cuidado de salud]
# 1396             [{'nombre': 'Salud', 'slug': 'salud'}]  [Cuidado de salud]
# 1397             [{'nombre': 'Salud', 'slug': 'salud'}]  [Cuidado de salud]
# 1398             [{'nombre': 'Salud', 'slug': 'salud'}]  [Cuidado de salud]
# 1399             [{'nombre': 'Salud', 'slug': 'salud'}]  [Cuidado de salud]
#
#      herramientas  documentos  \
# 0              []          []
# 1              []  [Registro]
# 2              []          []
# 3              []          []
# 4              []          []
# ...           ...         ...
# 1395           []          []
# 1396           []          []
# 1397           []          []
# 1398           []          []
# 1399           []          []
#
#                                             modalidades  \
# 0     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 2     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 3     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 4     [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# ...                                                 ...
# 1395  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1396  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1397  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1398  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1399  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
#
#                                             ubicaciones
# 0     [{'nombre': 'Tribunal Supremo de Justicia', 't...
# 1     [{'nombre': 'AGETIC', 'tipo': 'Oficina central...
# 2     [{'nombre': 'Autoridad Regional de Impugnación...
# 3     [{'nombre': 'AUTORIDAD GENERAL DE IMPUGNACIÓN ...
# 4     [{'nombre': 'REGISTRO INTERNACIONAL BOLIVIANO ...
# ...                                                 ...
# 1395  [{'nombre': 'INLASA', 'tipo': 'Oficina central...
# 1396  [{'nombre': 'INLASA', 'tipo': 'Oficina central...
# 1397  [{'nombre': 'INLASA', 'tipo': 'Oficina central...
# 1398  [{'nombre': 'INLASA', 'tipo': 'Oficina central...
# 1399  [{'nombre': 'INLASA', 'tipo': 'Oficina central...
#
# [1400 rows x 22 columns]

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

# %%
# columnas pendientes:
pendientes = ['palabrasClave', 'entidad', 'categorias', 'eventosVida',
              'herramientas', 'documentos',
             ]

new_df = df[[col for col in df.columns if col not in pendientes]].copy()
new_df.sample(3)
# Out:
#        id     estado fechaActualización  \
# 290  1330  PUBLICADO         09/07/2025
# 651  1746  PUBLICADO         11/07/2025
# 553  1643  PUBLICADO         11/07/2025
#
#                                                 nombre  \
# 290  Certificación de Programa Analítico (Universid...
# 651                  LICENCIAS DE FILMACIÓN EN BOLIVIA
# 553  Pago del Complemento Económico - Viuda (o) - I...
#
#                                                   slug       sigla  \
# 290  certificacion-de-programa-analitico-universida...        None
# 651                  licencias-de-filmacion-en-bolivia        None
# 553  pago-del-complemento-economico-viuda-o-inclusi...  COM-ECO-VI
#
#                                            descripcion  \
# 290  Establecer Procedimiento para procesar la cert...
# 651  Es el permiso que se le otorga a las empresas ...
# 553  El Complemento Económico es un beneficio que o...
#
#                                             marcoLegal  like  dislike  \
# 290  "R.M. N° 928/2015 R.M. N° 710/2016 R.M. N° 082...     0        0
# 651                                           Ley 1134     0        0
# 553  -LEY N°734 - LEY ORGÁNICA DE LA POLICÍA NACION...     0        0
#
#      esPresencial  esVirtual              resultado  \
# 290          True       True  Registro y constancia
# 651          True      False               Registro
# 553          True      False
#
#                                                enlaces  \
# 290  [{'nombre': 'ÁREA DE LEGALIZACIONES - UNIDAD D...
# 651  [{'nombre': 'PÁGINA WEB', 'url': 'https://www....
# 553                                                 []
#
#                                            modalidades  \
# 290  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 651  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 553  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
#
#                                            ubicaciones
# 290  [{'nombre': 'Ministerio de Educación', 'tipo':...
# 651  [{'nombre': 'Agencia del Desarrollo del Cine y...
# 553  [{'nombre': 'OFICINA CENTRAL LA PAZ', 'tipo': ...

# %% [markdown]
# ## Desglosando columnas
#
# ### entidad

# %%
# desglosando columnas de la entidad

new_rows = {
    'entidad.nombre': [],
    'entidad.sigla': [],
    'entidad.slug': [],
    'entidad.logo': [],
    'entidad.descripcion': [],
    'entidad.urlSitioWeb': [],
    'entidad.telefonoContacto': [],
    'entidad.correoElectronicoContacto': [],
}
for i in range(0, df.shape[0]):
    entidad_json = df.iloc[i]['entidad']
    #entidad_json = json.loads(df.iloc[i]['entidad'])
    new_rows['entidad.nombre'].append(entidad_json['nombre'])
    new_rows['entidad.sigla'].append(entidad_json['sigla'])
    new_rows['entidad.slug'].append(entidad_json['slug'])
    new_rows['entidad.logo'].append(entidad_json['logo'])
    new_rows['entidad.descripcion'].append(entidad_json['descripcion'])
    new_rows['entidad.urlSitioWeb'].append(entidad_json['urlSitioWeb'])
    new_rows['entidad.telefonoContacto'].append(entidad_json['telefonoContacto'])
    new_rows['entidad.correoElectronicoContacto'].append(entidad_json['correoElectronicoContacto'])

for k, v in new_rows.items():
    new_df[k] = pd.Series(v).values

new_df.sample(3)
# Out:
#         id     estado fechaActualización  \
# 803   2020  PUBLICADO         08/07/2025
# 408   1459  PUBLICADO         10/07/2025
# 1082  2372  PUBLICADO         04/08/2025
#
#                                                  nombre  \
# 803                      AGENDA DE CONSULTAS Y TRÁMITES
# 408   Legalización de Certificado de Egreso y Capaci...
# 1082  REGISTRO DEL IMPUESTO A LA TRANSFERENCIAS DE V...
#
#                                                    slug sigla  \
# 803                      agenda-de-consultas-y-tramites  None
# 408   legalizacion-de-certificado-de-egreso-y-capaci...  LCEC
# 1082  registro-del-impuesto-a-la-transferencias-de-v...  None
#
#                                             descripcion  \
# 803   Es la herramienta WEB ubicada en la plataforma...
# 408   El Certificado de Egreso y Capacitación Legali...
# 1082  Es el registro, procesamiento y liquidación de...
#
#                                              marcoLegal  like  dislike  \
# 803                                            Ley 2492     0        0
# 408   1. Reglamento General de Institutos Técnicos y...     0        0
# 1082  Código Tributario, Ley Nacional Nº 2492 y sus ...     0        0
#
#       esPresencial  esVirtual              resultado  \
# 803          False       True
# 408           True      False  Registro y constancia
# 1082          True      False             Constancia
#
#                                                 enlaces  \
# 803   [{'nombre': 'AGENDA DE CONSULTAS DE TRAMITES',...
# 408                                                  []
# 1082  [{'nombre': 'GAMLP', 'url': 'https://lapaz.bo/...
#
#                                             modalidades  \
# 803   [{'tipo': 'VIRTUAL', 'url': 'https://agenda.im...
# 408   [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 1082  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
#
#                                             ubicaciones  \
# 803   [{'nombre': 'Gerencia Distrital Beni', 'tipo':...
# 408   [{'nombre': 'Subdirección de Educación Superio...
# 1082  [{'nombre': 'Plataforma de Vehículos', 'tipo':...
#
#                               entidad.nombre entidad.sigla  \
# 803         Servicio de Impuestos Nacionales           SIN
# 408   Direc. Dptal. de Educación  Chuquisaca       DDE-CHU
# 1082   Gobierno Autónomo Municipal de La Paz           LPZ
#
#                                entidad.slug  \
# 803        servicio-de-impuestos-nacionales
# 408     direc-dptal-de-educacion-chuquisaca
# 1082  gobierno-autonomo-municipal-de-la-paz
#
#                                            entidad.logo  \
# 803   https://www.gob.bo/ws/api/archivos/2ef56f69-0f...
# 408                                                None
# 1082  https://www.gob.bo/ws/api/archivos/a9f8ee34-74...
#
#                                     entidad.descripcion  \
# 803   El Servicio de Impuestos Nacionales (SIN) tien...
# 408                                                None
# 1082  Somos una institución pública municipal renova...
#
#                 entidad.urlSitioWeb entidad.telefonoContacto  \
# 803   https://www.impuestos.gob.bo/                  2606060
# 408                            None                     None
# 1082               https://lapaz.bo            591-2-2650000
#
#            entidad.correoElectronicoContacto
# 803   informaciontributaria@impuestos.gob.bo
# 408                                     None
# 1082                     info.gamlp@lapaz.bo

# %% [markdown]
# ### esPresencial y esVirtual

# %%
rows = []
for i in range(0, df.shape[0]):
    palabras_clave = df.iloc[i]['palabrasClave']
    if isinstance(palabras_clave, list):
        rows.append(','.join(palabras_clave))
    else:
        rows.append('')

new_df['palabrasClave'] = pd.Series(rows).values
new_df.sample(5)['palabrasClave']
# Out:
# 1030
# 440     SENASIR,SISTEMA DE REPARTO,NO COBRO,REVERSIÓN,...
# 1335
# 1194                                           PSICOLOGIA
# 140
# Name: palabrasClave, dtype: object

# %% [markdown]
# ### categorias

# %%
rows = []
for i in range(0, df.shape[0]):
    categorias = df.iloc[i]['categorias']
    categorias_list = [categoria['nombre'] for categoria in categorias]
    if len(categorias_list) > 0:
        rows.append(','.join(categorias_list))
    else:
        # TODO: ver como normalizar valores vacios, NULL o cadena vacia?
        rows.append('')
new_df['categorias'] = rows
new_df.sample(5)['categorias']
# Out:
# 1319    Transporte
# 29       Educación
# 595     Transporte
# 470      Educación
# 532          Salud
# Name: categorias, dtype: object

# %% [markdown]
# ### eventosVida

# %%
def separar_lista_por_caracter(df, col, separator=','):
    rows = []
    for i in range(0, df.shape[0]):
        words = df.iloc[i][col]
        if isinstance(words, list):
            rows.append(separator.join(words))
        else:
            rows.append('')
    return rows

# %%
rows = separar_lista_por_caracter(df, 'eventosVida')
new_df['eventosVida'] = pd.Series(rows).values
new_df.sample(5)['eventosVida']
# Out:
# 1318
# 269
# 724           Empleo
# 642     Mi educación
# 362
# Name: eventosVida, dtype: object

# %% [markdown]
# ### documentos

# %%
rows = separar_lista_por_caracter(df, 'documentos')
new_df['documentos'] = pd.Series(rows).values
new_df.sample(5)['documentos']
# Out:
# 237                Licencias de Prospección y Exploración
# 1104                           Emisión de certificaciones
# 94            Legalización de Título Profesional (UNIBOL)
# 1246
# 60      Legalización de Copia de Resolución Ministeria...
# Name: documentos, dtype: object

# %%
new_df['enlaces'] = df['enlaces']

# %% [markdown]
# ### herramientas

# %%
rows = separar_lista_por_caracter(df, 'herramientas')
new_df['herramientas'] = pd.Series(rows).values
new_df.sample(5)['herramientas']
# Out:
# 371
# 939
# 127
# 1143
# 1226
# Name: herramientas, dtype: object

# %%
new_df.dtypes
# Out:
# id                                   object
# estado                               object
# fechaActualización                   object
# nombre                               object
# slug                                 object
# sigla                                object
# descripcion                          object
# marcoLegal                           object
# like                                  int64
# dislike                               int64
# esPresencial                           bool
# esVirtual                              bool
# resultado                            object
# enlaces                              object
# modalidades                          object
# ubicaciones                          object
# entidad.nombre                       object
# entidad.sigla                        object
# entidad.slug                         object
# entidad.logo                         object
# entidad.descripcion                  object
# entidad.urlSitioWeb                  object
# entidad.telefonoContacto             object
# entidad.correoElectronicoContacto    object
# palabrasClave                        object
# categorias                           object
# eventosVida                          object
# documentos                           object
# herramientas                         object
# dtype: object

# %% [markdown]
# ### esPresencial

# %%
new_df['esPresencial'] = new_df['esPresencial'].apply(lambda value: 1 if value is True else 0)
new_df['esVirtual'] = new_df['esVirtual'].apply(lambda value: 1 if value is True else 0)
new_df.sample(5)[['id', 'nombre', 'esPresencial', 'esVirtual']]
# Out:
#         id                                             nombre  esPresencial  \
# 1197  2497  Trámite de Autorización de Funcionamiento Cent...             1
# 545   1633                  AFILIACIÓN DEL (LA) TRABAJADOR(A)             1
# 211   1245  Legalización de Certificado Supletorio/Resoluc...             1
# 854   2084  Cambio de Infraestructura de Unidades Educativ...             1
# 1241  2576                 SUPLETORIO DE DIPLOMA DE BACHILLER             1
#
#       esVirtual
# 1197          0
# 545           0
# 211           1
# 854           0
# 1241          0

# %% [markdown]
# ## Guardado como csv

# %%
new_df.sample(4)
# Out:
#        id     estado fechaActualización  \
# 316  1359  PUBLICADO         20/01/2025
# 308  1351  PUBLICADO         10/07/2025
# 592  1683  PUBLICADO         09/07/2025
# 257  1295  PUBLICADO         11/07/2025
#
#                                                 nombre  \
# 316             SOLICITUD DE LICENCIA PILOTO COMERCIAL
# 308  Solicitud de Autorizacion de Promocion Empresa...
# 592  Pago de Contribuciones para el Asegurado Indep...
# 257                  RENOVACION DE CARNET DE ASEGURADO
#
#                                                   slug sigla  \
# 316             solicitud-de-licencia-piloto-comercial  None
# 308  solicitud-de-autorizacion-de-promocion-empresa...  None
# 592  pago-de-contribuciones-para-el-asegurado-indep...  None
# 257                  renovacion-de-carnet-de-asegurado  None
#
#                                            descripcion  \
# 316  Dirección General de Aeronáutica Civil - DGAC\...
# 308  Tramite de autorización para aquellas activida...
# 592  Todo Asegurado Independiente y/o Consultor a n...
# 257  TRAMITE PARA LA RENOVACION DEL CARNET DE ASEGU...
#
#                                             marcoLegal  like  dislike  \
# 316  LEY 2902 en su artículo 63 - licencias al pers...     0        0
# 308  "Ley N° 060 de 25 de noviembre de 2010, Ley de...     0        0
# 592                             Ley N°065 de pensiones     0        0
# 257  REGLAMENTO DE AFILIACION, DESAFILIACION Y REAF...     0        0
#
#      esPresencial  esVirtual              resultado  \
# 316             1          0  Registro y constancia
# 308             1          1  Registro y constancia
# 592             0          1               Registro
# 257             1          0  Registro y constancia
#
#                                                enlaces  \
# 316                                                 []
# 308  [{'nombre': 'PAJEL', 'url': 'https://pajel.aj....
# 592  [{'nombre': 'Gestora', 'url': 'https://www.ges...
# 257                                                 []
#
#                                            modalidades  \
# 316  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 308  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
# 592  [{'tipo': 'VIRTUAL', 'url': None, 'urlSeguimie...
# 257  [{'tipo': 'PRESENCIAL', 'url': None, 'urlSegui...
#
#                                            ubicaciones  \
# 316  [{'nombre': 'willams cordova caballero', 'tipo...
# 308  [{'nombre': 'Regional La Paz', 'tipo': 'Region...
# 592  [{'nombre': 'Oficina Central', 'tipo': 'Oficin...
# 257  [{'nombre': 'SEGURO SOCIAL UNIVERSITARIO DEL B...
#
#                                         entidad.nombre entidad.sigla  \
# 316             Dirección General de Aeronáutica Civil          DGAC
# 308               Autoridad de Fiscalización del Juego            AJ
# 592  Gestora Pública de la Seguridad Social de Larg...       GESTORA
# 257                Seguro Social Universitario de Beni       SSUBENI
#
#                                           entidad.slug  \
# 316             direccion-general-de-aeronautica-civil
# 308               autoridad-de-fiscalizacion-del-juego
# 592  gestora-publica-de-la-seguridad-social-de-larg...
# 257                seguro-social-universitario-de-beni
#
#                                           entidad.logo  \
# 316  https://www.gob.bo/ws/api/archivos/76b10922-90...
# 308  https://www.gob.bo/ws/api/archivos/7c9fba78-ce...
# 592  https://www.gob.bo/ws/api/archivos/a1f8c52b-2d...
# 257  https://www.gob.bo/ws/api/archivos/0a9fd325-35...
#
#                                    entidad.descripcion  \
# 316  Fortalecer la DGAC, para contar con una autori...
# 308  Conforme lo establecen la Ley N° 060 de Juegos...
# 592  La Gestora Pública de la Seguridad Social de L...
# 257  El Seguro Social Universitario es una instituc...
#
#              entidad.urlSitioWeb entidad.telefonoContacto  \
# 316     https://www.dgac.gob.bo/                 77705763
# 308        https://www.aj.gob.bo                  2125081
# 592       https://www.gestora.bo                800101610
# 257  https://www.ssubeni.org.bo/                     None
#
#     entidad.correoElectronicoContacto  \
# 316            wccconsultor@gmail.com
# 308                    info@aj.gob.bo
# 592               contacto@gestora.bo
# 257           ssutrinidad@hotmail.com
#
#                                      palabrasClave              categorias  \
# 316                                                             Transporte
# 308  Promocion,Promoción,autorizacion,autorización                Empresas
# 592                                                       Seguridad social
# 257                                                 Salud,Seguridad social
#
#           eventosVida                                         documentos  \
# 316            Empleo  Fotocopia legible del Certificado Médico Aeron...
# 308                    Resolusion Administrativa de Autorizacion de P...
# 592        Jubilación                                 Registros de pagos
# 257  Cuidado de salud                                CARNET DE ASEGURADO
#
#     herramientas
# 316
# 308
# 592
# 257

# %%
new_df.to_csv('../tramites.csv', index=False)
